# %% [markdown]
# ## Abu Dhabi Grand Prix

# %% [markdown]
# First of all, it is neccesary to obtain the name of the session which you refers. In this case I will obtain all the data refered at Abu Dhabi Grand Prix

# %%
from urllib.request import urlopen
import json


import pandas as pd
import numpy as np

# %%
response = urlopen('https://api.openf1.org/v1/sessions?year=2023')
data = json.loads(response.read().decode('utf-8'))
print(data)
calendar = pd.DataFrame(data)
# Out:
# [{'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Practice', 'session_name': 'Practice 1', 'date_start': '2023-02-23T07:00:00', 'date_end': '2023-02-23T16:30:00', 'gmt_offset': '03:00:00', 'session_key': 9222, 'meeting_key': 1140, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Practice', 'session_name': 'Practice 2', 'date_start': '2023-02-24T07:00:00', 'date_end': '2023-02-24T16:30:00', 'gmt_offset': '03:00:00', 'session_key': 7763, 'meeting_key': 1140, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Practice', 'session_name': 'Practice 3', 'date_start': '2023-02-25T07:00:00', 'date_end': '2023-02-25T16:30:00', 'gmt_offset': '03:00:00', 'session_key': 7764, 'meeting_key': 1140, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Practice', 'session_name': 'Practice 1', 'date_start': '2023-03-03T11:30:00', 'date_end': '2023-03-03T12:30:00', 'gmt_offset': '03:00:00', 'session_key': 7765, 'meeting_key': 1141, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Practice', 'session_name': 'Practice 2', 'date_start': '2023-03-03T15:00:00', 'date_end': '2023-03-03T16:00:00', 'gmt_offset': '03:00:00', 'session_key': 7766, 'meeting_key': 1141, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Practice', 'session_name': 'Practice 3', 'date_start': '2023-03-04T11:30:00', 'date_end': '2023-03-04T12:30:00', 'gmt_offset': '03:00:00', 'session_key': 7767, 'meeting_key': 1141, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Qualifying', 'session_name': 'Qualifying', 'date_start': '2023-03-04T15:00:00', 'date_end': '2023-03-04T16:00:00', 'gmt_offset': '03:00:00', 'session_key': 7768, 'meeting_key': 1141, 'year': 2023}, {'location': 'Sakhir', 'country_key': 36, 'country_code': 'BRN', 'country_name': 'Bahrain', 'circuit_key': 63, 'circuit_short_name': 'Sakhir', 'session_type': 'Race', 'session_name': 'Race', 'date_start': '2023-03-05T15:00:00', 'date_end': '2023-03-05T17:00:00', 'gmt_offset': '03:00:00', 'session_key': 7953, 'meeting_key': 1141, 'year': 2023}, {'location': 'Jeddah', 'country_key': 153, 'country_code': 'KSA', 'country_name': 'Saudi Arabia', 'circuit_key': 149, 'circuit_short_name': 'Jeddah', 'session_type': 'Practice', 'session_name': 'Practice 1', 'date_start': '2023-03-17T13:30:00', 'date_end': '2023-03-17T14:30:00', 'gmt_offset': '03:00:00', 'session_key': 7772, 'meeting_key': 1142, 'year': 2023}, {'location': 'Jeddah', 'country_key': 153, 'country_code': 'KSA', 'country_name': 'Saudi Arabia', 'circuit_key': 149, 'circuit_short_name': 'Jeddah', 'session_type': 'Practice', 'session_name': 'Practice 2', 'date_start': '2023-03-17T17:00:00', 'date_end': '2023-03-17T18:00:00', 'gmt_offset': '03:00:00', 'session_key': 7773, 'meeting_key': 1142, 'year': 2023}, {'location': 'Jeddah', 'country_key': 153, 'country_code': 'KSA', 'country_name': 'Saudi Arabia', 'circuit_key': 149, 'circuit_short_name': 'Jeddah', 'session_type': 'Practice', 'session_name': 'Practice 3', 'date_start': '2023-03-18T13:30:00', 'date_end': '2023-03-18T14:30:00', 'gmt_offset': '03:00:00', 'session_key': 7774, 'meeting_key': 1142, 'year': 2023}, {'location': 'Jeddah', 'country_key': 153, 'country_code': 'KSA', 'cou ...

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Abu Dhabi
url = 'https://api.openf1.org/v1/sessions?'
year = 'year=2023'
country_code = 'country_code=UAE'

urltotal = url+year+'&'+country_code

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
print(data)
sessionInformation = pd.DataFrame(data)
# Out:
# [{'location': 'Yas Island', 'country_key': 21, 'country_code': 'UAE', 'country_name': 'United Arab Emirates', 'circuit_key': 70, 'circuit_short_name': 'Yas Marina Circuit', 'session_type': 'Practice', 'session_name': 'Practice 1', 'date_start': '2023-11-24T09:30:00', 'date_end': '2023-11-24T10:30:00', 'gmt_offset': '04:00:00', 'session_key': 9190, 'meeting_key': 1226, 'year': 2023}, {'location': 'Yas Island', 'country_key': 21, 'country_code': 'UAE', 'country_name': 'United Arab Emirates', 'circuit_key': 70, 'circuit_short_name': 'Yas Marina Circuit', 'session_type': 'Practice', 'session_name': 'Practice 2', 'date_start': '2023-11-24T13:00:00', 'date_end': '2023-11-24T14:00:00', 'gmt_offset': '04:00:00', 'session_key': 9191, 'meeting_key': 1226, 'year': 2023}, {'location': 'Yas Island', 'country_key': 21, 'country_code': 'UAE', 'country_name': 'United Arab Emirates', 'circuit_key': 70, 'circuit_short_name': 'Yas Marina Circuit', 'session_type': 'Practice', 'session_name': 'Practice 3', 'date_start': '2023-11-25T10:30:00', 'date_end': '2023-11-25T11:30:00', 'gmt_offset': '04:00:00', 'session_key': 9192, 'meeting_key': 1226, 'year': 2023}, {'location': 'Yas Island', 'country_key': 21, 'country_code': 'UAE', 'country_name': 'United Arab Emirates', 'circuit_key': 70, 'circuit_short_name': 'Yas Marina Circuit', 'session_type': 'Qualifying', 'session_name': 'Qualifying', 'date_start': '2023-11-25T14:00:00', 'date_end': '2023-11-25T15:00:00', 'gmt_offset': '04:00:00', 'session_key': 9193, 'meeting_key': 1226, 'year': 2023}, {'location': 'Yas Island', 'country_key': 21, 'country_code': 'UAE', 'country_name': 'United Arab Emirates', 'circuit_key': 70, 'circuit_short_name': 'Yas Marina Circuit', 'session_type': 'Race', 'session_name': 'Race', 'date_start': '2023-11-26T13:00:00', 'date_end': '2023-11-26T15:00:00', 'gmt_offset': '04:00:00', 'session_key': 9197, 'meeting_key': 1226, 'year': 2023}]

# %%
sessionInformation
# Out:
#      location  country_key country_code          country_name  circuit_key  \
# 0  Yas Island           21          UAE  United Arab Emirates           70
# 1  Yas Island           21          UAE  United Arab Emirates           70
# 2  Yas Island           21          UAE  United Arab Emirates           70
# 3  Yas Island           21          UAE  United Arab Emirates           70
# 4  Yas Island           21          UAE  United Arab Emirates           70
#
#    circuit_short_name session_type session_name           date_start  \
# 0  Yas Marina Circuit     Practice   Practice 1  2023-11-24T09:30:00
# 1  Yas Marina Circuit     Practice   Practice 2  2023-11-24T13:00:00
# 2  Yas Marina Circuit     Practice   Practice 3  2023-11-25T10:30:00
# 3  Yas Marina Circuit   Qualifying   Qualifying  2023-11-25T14:00:00
# 4  Yas Marina Circuit         Race         Race  2023-11-26T13:00:00
#
#               date_end gmt_offset  session_key  meeting_key  year
# 0  2023-11-24T10:30:00   04:00:00         9190         1226  2023
# 1  2023-11-24T14:00:00   04:00:00         9191         1226  2023
# 2  2023-11-25T11:30:00   04:00:00         9192         1226  2023
# 3  2023-11-25T15:00:00   04:00:00         9193         1226  2023
# 4  2023-11-26T15:00:00   04:00:00         9197         1226  2023

# %%
# Completed name of the grand prix
url = 'https://api.openf1.org/v1/meetings?'
year = 'year=2023'
country_code = 'country_code=UAE'

urltotal = url+year+'&'+country_code

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
print(data)
# Out:
# [{'meeting_name': 'Abu Dhabi Grand Prix', 'meeting_official_name': 'FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX 2023', 'location': 'Yas Island', 'country_key': 21, 'country_code': 'UAE', 'country_name': 'United Arab Emirates', 'circuit_key': 70, 'circuit_short_name': 'Yas Marina Circuit', 'date_start': '2023-11-24T09:30:00', 'gmt_offset': '04:00:00', 'meeting_key': 1226, 'year': 2023}]

# %% [markdown]
# ## Practice 1

# %% [markdown]
# In this case, according to thee last table, we can see that the session_key is 9190

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Abu Dhabi
url = 'https://api.openf1.org/v1/laps?'
session_key = 'session_key=9190'
year = 'year=2023'
country_code = 'country_code=UAE'

urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
print(data)
practice1 = pd.DataFrame(data)
# Out:
# [{'meeting_key': 1226, 'session_key': 9190, 'driver_number': 18, 'i1_speed': 273, 'i2_speed': 276, 'st_speed': 299, 'date_start': '2023-11-24T09:30:03.724000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 40.601, 'duration_sector_3': 35.569, 'segments_sector_1': [2064, 2064, 2064, 2064, 2051], 'segments_sector_2': [2051, 2051, 2051, 2051, 2051, 2051, 2051, 2051, 2051], 'segments_sector_3': [2051, 2051, 2051, 2051, 2048, 2051, 2048, 2051, 0], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 34, 'i1_speed': 268, 'i2_speed': 260, 'st_speed': 269, 'date_start': '2023-11-24T09:30:10.224000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 52.426, 'duration_sector_3': 39.209, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2049, 2049, 2064, 2064], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 37, 'i1_speed': 248, 'i2_speed': 227, 'st_speed': 246, 'date_start': '2023-11-24T09:30:15.083000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 44.521, 'duration_sector_3': 46.927, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 29, 'i1_speed': 139, 'i2_speed': 131, 'st_speed': 196, 'date_start': '2023-11-24T09:30:17.443000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 57.47, 'duration_sector_3': 51.61, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'segments_sector_3': [2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 81, 'i1_speed': 139, 'i2_speed': 236, 'st_speed': 221, 'date_start': '2023-11-24T09:30:25.833000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 50.417, 'duration_sector_3': 42.701, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'segments_sector_3': [2049, 2049, 2048, 2049, 2049, 2049, 2049, 2064, 2064], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 50, 'i1_speed': 244, 'i2_speed': 256, 'st_speed': 217, 'date_start': '2023-11-24T09:30:28.192000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 44.293, 'duration_sector_3': 40.91, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'segments_sector_3': [2049, 2049, 2049, 2049, 2051, 2049, 2051, 2051, 0], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 39, 'i1_speed': 158, 'i2_speed': 237, 'st_speed': 198, 'date_start': '2023-11-24T09:30:33.802000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 56.23, 'duration_sector_3': 47.57, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'segments_sector_3': [2048, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], 'lap_number': 1}, {'meeting_key': 1226, 'session_key': 9190, 'driver_number': 77, 'i1_speed': 239, 'i2_speed': 236, 'st_speed': 229, 'date_start': '2023-11-24T09:30:36.020000', 'lap_duration': None, 'is_pit_out_lap': True, 'duration_sector_1': None, 'duration_sector_2': 54.66, 'duration_sector_3': 45.733, 'segments_sector_1': [2064, 2064, 2064, 2064, 2049], 'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049, 2049, ...

# %%
practice1
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1226         9190             18     273.0       276       299
# 1           1226         9190             34     268.0       260       269
# 2           1226         9190             37     248.0       227       246
# 3           1226         9190             29     139.0       131       196
# 4           1226         9190             81     139.0       236       221
# ..           ...          ...            ...       ...       ...       ...
# 484         1226         9190             20     264.0       301       302
# 485         1226         9190             61     205.0       279       269
# 486         1226         9190             55     257.0       292       295
# 487         1226         9190             18     252.0       238       302
# 488         1226         9190             34     284.0       270       317
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 0    2023-11-24T09:30:03.724000           NaN            True
# 1    2023-11-24T09:30:10.224000           NaN            True
# 2    2023-11-24T09:30:15.083000           NaN            True
# 3    2023-11-24T09:30:17.443000           NaN            True
# 4    2023-11-24T09:30:25.833000           NaN            True
# ..                          ...           ...             ...
# 484  2023-11-24T10:33:19.095000       127.859           False
# 485  2023-11-24T10:33:35.407000       136.330           False
# 486  2023-11-24T10:33:38.532000       124.004           False
# 487  2023-11-24T10:33:48.485000       127.035           False
# 488  2023-11-24T10:34:10.422000       134.089           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             40.601             35.569
# 1                  NaN             52.426             39.209
# 2                  NaN             44.521             46.927
# 3                  NaN             57.470             51.610
# 4                  NaN             50.417             42.701
# ..                 ...                ...                ...
# 484             46.342             39.598             41.919
# 485             47.654             44.959             43.717
# 486             45.827             41.868             36.309
# 487             49.826             39.934             37.275
# 488             50.726             39.009             44.354
#
#                   segments_sector_1  \
# 0    [2064, 2064, 2064, 2064, 2051]
# 1    [2064, 2064, 2064, 2064, 2049]
# 2    [2064, 2064, 2064, 2064, 2049]
# 3    [2064, 2064, 2064, 2064, 2049]
# 4    [2064, 2064, 2064, 2064, 2049]
# ..                              ...
# 484  [None, 2048, 2048, 2048, 2048]
# 485  [None, 2048, 2048, 2048, 2048]
# 486  [None, 2048, 2048, 2048, 2048]
# 487  [None, 2048, 2048, 2048, 2048]
# 488  [None, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 0    [2051, 2051, 2051, 2051, 2051, 2051, 2051, 205...
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 484  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 485  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 486  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 487  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 488  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                                      segments_sector_3  lap_number
# 0    [2051, 2051, 2051, 2051, 2048, 2051, 2048, 205...           1
# 1    [2048, 2048, 2048, 2049, 2049, 2049, 2049, 206...           1
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           1
# 3    [2049, 2048, 2048, 2048, 2048, 2048, 2048, 204...           1
# 4    [2049, 2049, 2048, 2049, 2049, 2049, 2049, 206...           1
# ..                                                 ...         ...
# 484                                                 []          26
# 485                                                 []          23
# 486                                                 []          24
# 487                                                 []          21
# 488                                                 []          26
#
# [489 rows x 16 columns]

# %%
#practice1Gasly = practice1.query('driver_number == 10')
#practice1Gasly

# %% [markdown]
# Table of segments:
# <ul>
# <li>Yellow sector:2048</li>
# <li>Green sector:2049</li>
# <li>Purple sector:2051</li>
# </ul>

# %%
#Stints
url = 'https://api.openf1.org/v1/stints?'
year = 'year=2023'
country_code = 'country_code=UAE'
session_key = 'session_key=9190'

urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
print(data)
stintInformation = pd.DataFrame(data)
# Out:
# [{'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 10, 'lap_start': 1, 'lap_end': 1, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 29, 'lap_start': 1, 'lap_end': 1, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 61, 'lap_start': 1, 'lap_end': 1, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 77, 'lap_start': 1, 'lap_end': 1, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 81, 'lap_start': 1, 'lap_end': 1, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 98, 'lap_start': 1, 'lap_end': 1, 'compound': 'HARD', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 34, 'lap_start': 1, 'lap_end': 2, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 36, 'lap_start': 1, 'lap_end': 2, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 18, 'lap_start': 1, 'lap_end': 3, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 63, 'lap_start': 1, 'lap_end': 3, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 39, 'lap_start': 1, 'lap_end': 4, 'compound': 'SOFT', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 2, 'lap_start': 1, 'lap_end': 5, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 37, 'lap_start': 1, 'lap_end': 5, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 55, 'lap_start': 1, 'lap_end': 5, 'compound': 'SOFT', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 20, 'lap_start': 1, 'lap_end': 7, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 50, 'lap_start': 1, 'lap_end': 7, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 22, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 45, 'lap_start': 1, 'lap_end': 9, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 42, 'lap_start': 1, 'lap_end': 10, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 1, 'driver_number': 3, 'lap_start': 1, 'lap_end': 11, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 2, 'driver_number': 77, 'lap_start': 2, 'lap_end': 2, 'compound': 'MEDIUM', 'tyre_age_at_start': 1}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 2, 'driver_number': 81, 'lap_start': 2, 'lap_end': 2, 'compound': 'MEDIUM', 'tyre_age_at_start': 1}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 2, 'driver_number': 10, 'lap_start': 2, 'lap_end': 6, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 2, 'driver_number': 61, 'lap_start': 2, 'lap_end': 6, 'compound': 'MEDIUM', 'tyre_age_at_start': 1}, {'meeting_key': 1226, 'session_key': 9190, 'stint_number': 2, 'driver_number': 29, 'lap_start': 2, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'mee ...

# %%
stintInformation[0:30]
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0          1226         9190             1             10          1        1
# 1          1226         9190             1             29          1        1
# 2          1226         9190             1             61          1        1
# 3          1226         9190             1             77          1        1
# 4          1226         9190             1             81          1        1
# 5          1226         9190             1             98          1        1
# 6          1226         9190             1             34          1        2
# 7          1226         9190             1             36          1        2
# 8          1226         9190             1             18          1        3
# 9          1226         9190             1             63          1        3
# 10         1226         9190             1             39          1        4
# 11         1226         9190             1              2          1        5
# 12         1226         9190             1             37          1        5
# 13         1226         9190             1             55          1        5
# 14         1226         9190             1             20          1        7
# 15         1226         9190             1             50          1        7
# 16         1226         9190             1             22          1        8
# 17         1226         9190             1             45          1        9
# 18         1226         9190             1             42          1       10
# 19         1226         9190             1              3          1       11
# 20         1226         9190             2             77          2        2
# 21         1226         9190             2             81          2        2
# 22         1226         9190             2             10          2        6
# 23         1226         9190             2             61          2        6
# 24         1226         9190             2             29          2        8
# 25         1226         9190             2             98          2        9
# 26         1226         9190             2             34          3        4
# 27         1226         9190             3             81          3        5
# 28         1226         9190             2             36          3        9
# 29         1226         9190             3             77          3       11
#
#    compound  tyre_age_at_start
# 0    MEDIUM                  0
# 1    MEDIUM                  0
# 2    MEDIUM                  0
# 3    MEDIUM                  0
# 4    MEDIUM                  0
# 5      HARD                  0
# 6    MEDIUM                  0
# 7    MEDIUM                  0
# 8    MEDIUM                  0
# 9    MEDIUM                  0
# 10     SOFT                  0
# 11   MEDIUM                  0
# 12   MEDIUM                  0
# 13     SOFT                  0
# 14   MEDIUM                  0
# 15   MEDIUM                  0
# 16   MEDIUM                  0
# 17   MEDIUM                  0
# 18   MEDIUM                  0
# 19   MEDIUM                  0
# 20   MEDIUM                  1
# 21   MEDIUM                  1
# 22   MEDIUM                  0
# 23   MEDIUM                  1
# 24   MEDIUM                  0
# 25     HARD                  1
# 26   MEDIUM                  2
# 27   MEDIUM                  2
# 28   MEDIUM                  2
# 29   MEDIUM                  2

# %%
#stintInformationfiltered = stintInformation.query('driver_number == 10')

# %%
#stintInformationfiltered

# %%
# stintsDataFrame = pd.DataFrame()
# for index,row in stintInformationfiltered.iterrows():
#     if row.lap_start != row.lap_end:
#         contador = row.lap_start
#         while contador <= row.lap_end :
#             new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':contador}
#             #stintsDataFrame=stintsDataFrame.append(new_row, ignore_index=True)
#             stintsDataFrame = pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)
#             contador+=1
#     else:
#         new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':row.lap_start}
#         #stintsDataFrame= stintsDataFrame.append(new_row, ignore_index=True)
#         stintsDataFrame =pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)

# %%
#stintsDataFrame

# %%
# practice1Gasly =practice1Gasly.reset_index(drop=True)
# practice1Gasly

# %%
# jointables = pd.concat([practice1Gasly,stintsDataFrame],axis=1,join="inner")
# jointables

# %%
stintsDataFrame = pd.DataFrame()
for index,row in stintInformation.iterrows():
    if row.lap_start != row.lap_end:
        contador = row.lap_start
        while contador <= row.lap_end :
            new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':contador}
            #stintsDataFrame=stintsDataFrame.append(new_row, ignore_index=True)
            stintsDataFrame = pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)
            contador+=1
    else:
        new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':row.lap_start}
        #stintsDataFrame= stintsDataFrame.append(new_row, ignore_index=True)
        stintsDataFrame =pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)

# %%
stintsDataFrame.query('driver_number == 18')
# Out:
#      driver_number compound  lap_number
# 10              18   MEDIUM           1
# 11              18   MEDIUM           2
# 12              18   MEDIUM           3
# 138             18   MEDIUM           4
# 139             18   MEDIUM           5
# 140             18   MEDIUM           6
# 141             18   MEDIUM           7
# 142             18   MEDIUM           8
# 143             18   MEDIUM           9
# 144             18   MEDIUM          10
# 256             18   MEDIUM          11
# 257             18   MEDIUM          12
# 258             18   MEDIUM          13
# 303             18     SOFT          14
# 304             18     SOFT          15
# 305             18     SOFT          16
# 306             18     SOFT          17
# 307             18     SOFT          18
# 308             18     SOFT          19
# 309             18     SOFT          20
# 310             18     SOFT          21

# %%
stintInformation.query('driver_number == 18')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 8          1226         9190             1             18          1        3
# 31         1226         9190             2             18          4       10
# 54         1226         9190             3             18         11       13
# 67         1226         9190             4             18         14       21
#
#    compound  tyre_age_at_start
# 8    MEDIUM                  0
# 31   MEDIUM                  3
# 54   MEDIUM                 10
# 67     SOFT                  0

# %%
jointables = pd.merge(practice1,stintsDataFrame,on=['lap_number','driver_number'])
jointables
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1226         9190             18     273.0       276       299
# 1           1226         9190             34     268.0       260       269
# 2           1226         9190             37     248.0       227       246
# 3           1226         9190             29     139.0       131       196
# 4           1226         9190             81     139.0       236       221
# ..           ...          ...            ...       ...       ...       ...
# 484         1226         9190             20     264.0       301       302
# 485         1226         9190             61     205.0       279       269
# 486         1226         9190             55     257.0       292       295
# 487         1226         9190             18     252.0       238       302
# 488         1226         9190             34     284.0       270       317
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 0    2023-11-24T09:30:03.724000           NaN            True
# 1    2023-11-24T09:30:10.224000           NaN            True
# 2    2023-11-24T09:30:15.083000           NaN            True
# 3    2023-11-24T09:30:17.443000           NaN            True
# 4    2023-11-24T09:30:25.833000           NaN            True
# ..                          ...           ...             ...
# 484  2023-11-24T10:33:19.095000       127.859           False
# 485  2023-11-24T10:33:35.407000       136.330           False
# 486  2023-11-24T10:33:38.532000       124.004           False
# 487  2023-11-24T10:33:48.485000       127.035           False
# 488  2023-11-24T10:34:10.422000       134.089           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             40.601             35.569
# 1                  NaN             52.426             39.209
# 2                  NaN             44.521             46.927
# 3                  NaN             57.470             51.610
# 4                  NaN             50.417             42.701
# ..                 ...                ...                ...
# 484             46.342             39.598             41.919
# 485             47.654             44.959             43.717
# 486             45.827             41.868             36.309
# 487             49.826             39.934             37.275
# 488             50.726             39.009             44.354
#
#                   segments_sector_1  \
# 0    [2064, 2064, 2064, 2064, 2051]
# 1    [2064, 2064, 2064, 2064, 2049]
# 2    [2064, 2064, 2064, 2064, 2049]
# 3    [2064, 2064, 2064, 2064, 2049]
# 4    [2064, 2064, 2064, 2064, 2049]
# ..                              ...
# 484  [None, 2048, 2048, 2048, 2048]
# 485  [None, 2048, 2048, 2048, 2048]
# 486  [None, 2048, 2048, 2048, 2048]
# 487  [None, 2048, 2048, 2048, 2048]
# 488  [None, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 0    [2051, 2051, 2051, 2051, 2051, 2051, 2051, 205...
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 484  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 485  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 486  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 487  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 488  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                                      segments_sector_3  lap_number compound
# 0    [2051, 2051, 2051, 2051, 2048, 2051, 2048, 205...           1   MEDIUM
# 1    [2048, 2048, 2048, 2049, 2049, 2049, 2049, 206...           1   MEDIUM
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           1   MEDIUM
# 3    [2049, 2048, 2048, 2048, 2048, 2048, 2048, 204...           1   MEDIUM
# 4    [2049, 2049, 2048, 2049, 2049, 2049, 2049, 206...           1   MEDIUM
# ..                                                 ...         ...      ...
# 484                                                 []          26   MEDIUM
# 485                                                 []          23     SOFT
# 486                                                 []          24     SOFT
# 487                                                 []          21     SOFT
# 488                                                 []          26     SOFT
#
# [489 rows x 17 columns]

# %%
mediumTyres = jointables.query('compound == "MEDIUM" and lap_duration <100 and is_pit_out_lap == False')

# %%
mediumTyres
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 17          1226         9190             18     278.0       302       302
# 21          1226         9190             37     267.0       296       296
# 22          1226         9190             50     276.0       309       311
# 23          1226         9190             63     286.0       311       312
# 25          1226         9190             42     277.0       284       282
# ..           ...          ...            ...       ...       ...       ...
# 442         1226         9190              2       NaN       304       308
# 443         1226         9190             42     283.0       291       295
# 445         1226         9190             81       NaN       312       310
# 447         1226         9190             45       NaN       290       294
# 448         1226         9190             20     276.0       287       292
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 17   2023-11-24T09:31:43.488000        91.035           False
# 21   2023-11-24T09:32:19.347000        96.373           False
# 22   2023-11-24T09:32:35.862000        91.057           False
# 23   2023-11-24T09:32:57.612000        87.673           False
# 25   2023-11-24T09:33:05.518000        97.943           False
# ..                          ...           ...             ...
# 442  2023-11-24T10:29:09.115000        91.405           False
# 443  2023-11-24T10:29:13.802000        91.829           False
# 445  2023-11-24T10:29:21.568000        89.315           False
# 447  2023-11-24T10:29:31.896000        93.180           False
# 448  2023-11-24T10:29:34.271000        93.566           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 17              18.084             37.869             35.082
# 21              20.153             40.181             36.039
# 22              19.094             38.315             33.648
# 23              17.992             37.625             32.056
# 25              19.060             39.284             39.599
# ..                 ...                ...                ...
# 442             18.550             38.940             33.915
# 443             18.566             39.201             34.062
# 445             17.960             38.372             32.983
# 447             18.882             39.956             34.342
# 448             19.220             39.733             34.613
#
#                   segments_sector_1  \
# 17   [2049, 2051, 2049, 2051, 2051]
# 21   [2049, 2049, 2049, 2049, 2049]
# 22   [2049, 2049, 2049, 2049, 2049]
# 23   [2051, 2049, 2049, 2049, 2049]
# 25   [2049, 2049, 2049, 2049, 2049]
# ..                              ...
# 442  [None, 2048, 2048, 2048, 2048]
# 443  [2048, 2048, 2048, 2048, 2048]
# 445  [None, 2048, 2048, 2048, 2049]
# 447  [None, 2048, 2048, 2048, 2048]
# 448  [None, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 17   [2051, 2051, 2051, 2051, 2048, 2051, 2051, 205...
# 21   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 22   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 23   [2049, 2049, 2051, 2049, 2049, 2049, 2051, 204...
# 25   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 442  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 443  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 445  [2048, 2048, 2048, 2048, 2049, 2048, 2048, 204...
# 447  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 448  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                                      segments_sector_3  lap_number compound
# 17   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...           2   MEDIUM
# 21   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           2   MEDIUM
# 22   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2   MEDIUM
# 23   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...           2   MEDIUM
# 25   [2049, 2048, 2051, 2049, 2049, 2049, 2049, 204...           2   MEDIUM
# ..                                                 ...         ...      ...
# 442  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          25   MEDIUM
# 443  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          25   MEDIUM
# 445  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          23   MEDIUM
# 447  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          26   MEDIUM
# 448  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          24   MEDIUM
#
# [136 rows x 17 columns]

# %%
drivers_number = []
medium_dict = {}
for index,row in mediumTyres.iterrows():
    if row.driver_number not in drivers_number:
        medium_dict[row.driver_number] = []
        drivers_number.append(row.driver_number)

    medium_dict[row.driver_number].append(row)

# %%
medium_dict
# Out:
# {18: [meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         278.0
#   i2_speed                                                           302
#   st_speed                                                           302
#   date_start                                  2023-11-24T09:31:43.488000
#   lap_duration                                                    91.035
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.084
#   duration_sector_2                                               37.869
#   duration_sector_3                                               35.082
#   segments_sector_1                       [2049, 2051, 2049, 2051, 2051]
#   segments_sector_2    [2051, 2051, 2051, 2051, 2048, 2051, 2051, 205...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           2
#   compound                                                        MEDIUM
#   Name: 17, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         287.0
#   i2_speed                                                           270
#   st_speed                                                           312
#   date_start                                  2023-11-24T09:33:14.361000
#   lap_duration                                                    99.128
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.855
#   duration_sector_2                                               37.932
#   duration_sector_3                                               42.341
#   segments_sector_1                       [2048, 2048, 2048, 2048, 2049]
#   segments_sector_2    [2049, 2048, 2048, 2049, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           3
#   compound                                                        MEDIUM
#   Name: 28, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         284.0
#   i2_speed                                                           292
#   st_speed                                                           292
#   date_start                                  2023-11-24T09:48:33.814000
#   lap_duration                                                    88.609
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.035
#   duration_sector_2                                               38.292
#   duration_sector_3                                               32.282
#   segments_sector_1                       [2049, 2049, 2048, 2048, 2048]
#   segments_sector_2    [2049, 2048, 2049, 2048, 2048, 2048, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           5
#   compound                                                        MEDIUM
#   Name: 134, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         285.0
#   i2_speed                                                           312
#   st_speed                                                           316
#   date_start                                  2023-11-24T09:52:25.279000
#   lap_duration                                                    87.253
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.854
#   duration_sector_2                                               37.207
#   duration_sector_3                                               32.192
#   segments_sector_1                       [2049, 2048, 2049, 2049, 2048]
#   segments_sector_2    [2048, 2048, 2049, 2048, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           7
#   compound                                                        MEDIUM
#   Name: 157, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         288.0
#   i2_speed                                                           311
#   st_speed                                                           316
#   date_start                                  2023-11-24T09:56:09.212000
#   lap_duration                                                    87.536
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.884
#   duration_sector_2                                               37.408
#   duration_sector_3                                               32.244
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2051, 2049, 2048, 2048, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           9
#   compound                                                        MEDIUM
#   Name: 178, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         261.0
#   i2_speed                                                           234
#   st_speed                                                           275
#   date_start                                  2023-11-24T09:57:36.851000
#   lap_duration                                                    99.567
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                20.41
#   duration_sector_2                                               41.618
#   duration_sector_3                                               37.539
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          10
#   compound                                                        MEDIUM
#   Name: 190, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         284.0
#   i2_speed                                                           309
#   st_speed                                                           312
#   date_start                                  2023-11-24T10:08:51.730000
#   lap_duration                                                    88.007
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.963
#   duration_sector_2                                               37.337
#   duration_sector_3                                               32.707
#   segments_sector_1                       [2048, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2049, 2048, 2048, 2048, 2049, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                          12
#   compound                                                        MEDIUM
#   Name: 279, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       18
#   i1_speed                                                         265.0
#   i2_speed                                                           257
#   st_speed                                                           319
#   date_start                                  2023-11-24T10:10:19.713000
#   lap_duration                                                    98.546
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               20.316
#   duration_sector_2                                               39.765
#   duration_sector_3                                               38.465
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          13
#   compound                                                        MEDIUM
#   Name: 289, dtype: object],
#  37: [meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       37
#   i1_speed                                                         267.0
#   i2_speed                                                           296
#   st_speed                                                           296
#   date_start                                  2023-11-24T09:32:19.347000
#   lap_duration                                                    96.373
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               20.153
#   duration_sector_2                                               40.181
#   duration_sector_3                                               36.039
#   segments_sector_1                       [2049, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   lap_number                                                           2
#   compound                                                        MEDIUM
#   Name: 21, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       37
#   i1_speed                                                         279.0
#   i2_speed                                                           301
#   st_speed                                                           297
#   date_start                                  2023-11-24T09:33:56.017000
#   lap_duration                                                    92.856
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               19.126
#   duration_sector_2                                               39.156
#   duration_sector_3                                               34.574
#   segments_sector_1                       [None, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2049, 2049, 2049, 2049, 2048, 2049, 2049, 204...
#   lap_number                                                           3
#   compound                                                        MEDIUM
#   Name: 33, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       37
#   i1_speed                                                           NaN
#   i2_speed                                                           303
#   st_speed                                                           298
#   date_start                                  2023-11-24T09:35:28.468000
#   lap_duration                                                    92.112
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               19.068
#   duration_sector_2                                                38.76
#   duration_sector_3                                               34.284
#   segments_sector_1                       [None, 2049, 2049, 2048, 2048]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           4
#   compound                                                        MEDIUM
#   Name: 47, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       37
#   i1_speed                                                         282.0
#   i2_speed                                                           319
#   st_speed                                                           324
#   date_start                                  2023-11-24T09:54:47.917000
#   lap_duration                                                    90.123
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.965
#   duration_sector_2                                               37.861
#   duration_sector_3                                               33.297
#   segments_sector_1                       [2048, 2048, 2048, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2048, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           7
#   compound                                                        MEDIUM
#   Name: 166, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       37
#   i1_speed                                                         282.0
#   i2_speed                                                           322
#   st_speed                                                           327
#   date_start                                  2023-11-24T09:59:05.647000
#   lap_duration                                                    90.246
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                18.91
#   duration_sector_2                                               38.351
#   duration_sector_3                                               32.985
#   segments_sector_1                       [None, 2049, 2048, 2049, 2049]
#   segments_sector_2    [2048, 2049, 2049, 2049, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           9
#   compound                                                        MEDIUM
#   Name: 203, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       37
#   i1_speed                                                         284.0
#   i2_speed                                                           323
#   st_speed                                                           327
#   date_start                                  2023-11-24T10:03:15.595000
#   lap_duration                                                    88.862
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.545
#   duration_sector_2                                               37.522
#   duration_sector_3                                               32.795
#   segments_sector_1                       [2049, 2048, 2049, 2049, 2049]
#   segments_sector_2    [2048, 2049, 2048, 2049, 2049, 2049, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                          11
#   compound                                                        MEDIUM
#   Name: 234, dtype: object],
#  50: [meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         276.0
#   i2_speed                                                           309
#   st_speed                                                           311
#   date_start                                  2023-11-24T09:32:35.862000
#   lap_duration                                                    91.057
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               19.094
#   duration_sector_2                                               38.315
#   duration_sector_3                                               33.648
#   segments_sector_1                       [2049, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           2
#   compound                                                        MEDIUM
#   Name: 22, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         282.0
#   i2_speed                                                           316
#   st_speed                                                           318
#   date_start                                  2023-11-24T09:36:24.139000
#   lap_duration                                                    89.079
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.278
#   duration_sector_2                                                37.83
#   duration_sector_3                                               32.971
#   segments_sector_1                       [2048, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           4
#   compound                                                        MEDIUM
#   Name: 51, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         282.0
#   i2_speed                                                           316
#   st_speed                                                           318
#   date_start                                  2023-11-24T09:40:10.073000
#   lap_duration                                                     88.87
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.287
#   duration_sector_2                                               37.781
#   duration_sector_3                                               32.802
#   segments_sector_1                       [None, 2049, 2048, 2048, 2048]
#   segments_sector_2    [2049, 2048, 2048, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           6
#   compound                                                        MEDIUM
#   Name: 79, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         257.0
#   i2_speed                                                           284
#   st_speed                                                           287
#   date_start                                  2023-11-24T10:22:22.622000
#   lap_duration                                                    93.955
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               20.401
#   duration_sector_2                                               39.683
#   duration_sector_3                                               33.871
#   segments_sector_1                       [2048, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          18
#   compound                                                        MEDIUM
#   Name: 368, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         278.0
#   i2_speed                                                           288
#   st_speed                                                           291
#   date_start                                  2023-11-24T10:23:56.511000
#   lap_duration                                                    92.228
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.725
#   duration_sector_2                                               39.457
#   duration_sector_3                                               34.046
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          19
#   compound                                                        MEDIUM
#   Name: 382, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         279.0
#   i2_speed                                                           288
#   st_speed                                                           293
#   date_start                                  2023-11-24T10:25:28.697000
#   lap_duration                                                    91.893
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.804
#   duration_sector_2                                               39.288
#   duration_sector_3                                               33.801
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          20
#   compound                                                        MEDIUM
#   Name: 400, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                         277.0
#   i2_speed                                                           289
#   st_speed                                                           293
#   date_start                                  2023-11-24T10:27:00.680000
#   lap_duration                                                    92.123
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.569
#   duration_sector_2                                               39.575
#   duration_sector_3                                               33.979
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          21
#   compound                                                        MEDIUM
#   Name: 419, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       50
#   i1_speed                                                           NaN
#   i2_speed                                                           299
#   st_speed                                                           311
#   date_start                                  2023-11-24T10:28:32.819000
#   lap_duration                                                    91.462
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.511
#   duration_sector_2                                                39.14
#   duration_sector_3                                               33.811
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          22
#   compound                                                        MEDIUM
#   Name: 435, dtype: object],
#  63: [meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         286.0
#   i2_speed                                                           311
#   st_speed                                                           312
#   date_start                                  2023-11-24T09:32:57.612000
#   lap_duration                                                    87.673
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.992
#   duration_sector_2                                               37.625
#   duration_sector_3                                               32.056
#   segments_sector_1                       [2051, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2051, 2049, 2049, 2049, 2051, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           2
#   compound                                                        MEDIUM
#   Name: 23, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         287.0
#   i2_speed                                                           313
#   st_speed                                                           313
#   date_start                                  2023-11-24T09:39:20.261000
#   lap_duration                                                    86.963
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.806
#   duration_sector_2                                               37.219
#   duration_sector_3                                               31.938
#   segments_sector_1                       [2049, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           5
#   compound                                                        MEDIUM
#   Name: 72, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         287.0
#   i2_speed                                                           312
#   st_speed                                                           313
#   date_start                                  2023-11-24T09:45:44.583000
#   lap_duration                                                    86.313
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.663
#   duration_sector_2                                               36.992
#   duration_sector_3                                               31.658
#   segments_sector_1                       [2051, 2049, 2051, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2048, 2048, 2048, 2051, 2051, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           8
#   compound                                                        MEDIUM
#   Name: 114, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         277.0
#   i2_speed                                                           289
#   st_speed                                                           287
#   date_start                                  2023-11-24T10:18:23.782000
#   lap_duration                                                    91.303
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                18.58
#   duration_sector_2                                               38.946
#   duration_sector_3                                               33.777
#   segments_sector_1                       [2048, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          17
#   compound                                                        MEDIUM
#   Name: 329, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         278.0
#   i2_speed                                                           301
#   st_speed                                                           297
#   date_start                                  2023-11-24T10:19:55.046000
#   lap_duration                                                    91.674
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.798
#   duration_sector_2                                               39.057
#   duration_sector_3                                               33.819
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          18
#   compound                                                        MEDIUM
#   Name: 342, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         279.0
#   i2_speed                                                           300
#   st_speed                                                           299
#   date_start                                  2023-11-24T10:21:26.795000
#   lap_duration                                                    91.144
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                18.59
#   duration_sector_2                                               38.827
#   duration_sector_3                                               33.727
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          19
#   compound                                                        MEDIUM
#   Name: 357, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         280.0
#   i2_speed                                                           289
#   st_speed                                                           295
#   date_start                                  2023-11-24T10:22:57.840000
#   lap_duration                                                     91.64
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.651
#   duration_sector_2                                               39.065
#   duration_sector_3                                               33.924
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          20
#   compound                                                        MEDIUM
#   Name: 374, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                           NaN
#   i2_speed                                                           299
#   st_speed                                                           297
#   date_start                                  2023-11-24T10:24:29.604000
#   lap_duration                                                     91.71
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.847
#   duration_sector_2                                                39.12
#   duration_sector_3                                               33.743
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          21
#   compound                                                        MEDIUM
#   Name: 388, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         284.0
#   i2_speed                                                           295
#   st_speed                                                           297
#   date_start                                  2023-11-24T10:26:01.274000
#   lap_duration                                                    91.606
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.419
#   duration_sector_2                                               39.271
#   duration_sector_3                                               33.916
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          22
#   compound                                                        MEDIUM
#   Name: 407, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         282.0
#   i2_speed                                                           295
#   st_speed                                                           295
#   date_start                                  2023-11-24T10:27:32.820000
#   lap_duration                                                    91.491
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.538
#   duration_sector_2                                                39.11
#   duration_sector_3                                               33.843
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          23
#   compound                                                        MEDIUM
#   Name: 422, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       63
#   i1_speed                                                         283.0
#   i2_speed                                                           295
#   st_speed                                                           299
#   date_start                                  2023-11-24T10:29:04.380000
#   lap_duration                                                    91.387
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.446
#   duration_sector_2                                                39.16
#   duration_sector_3                                               33.781
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          24
#   compound                                                        MEDIUM
#   Name: 441, dtype: object],
#  42: [meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       42
#   i1_speed                                                         277.0
#   i2_speed                                                           284
#   st_speed                                                           282
#   date_start                                  2023-11-24T09:33:05.518000
#   lap_duration                                                    97.943
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                19.06
#   duration_sector_2                                               39.284
#   duration_sector_3                                               39.599
#   segments_sector_1                       [2049, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2049, 2048, 2051, 2049, 2049, 2049, 2049, 204...
#   lap_number                                                           2
#   compound                                                        MEDIUM
#   Name: 25, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       42
#   i1_speed                                                         285.0
#   i2_speed                                                           314
#   st_speed                                                           314
#   date_start                                  2023-11-24T09:34:43.313000
#   lap_duration                                                    89.496
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.083
#   duration_sector_2                                               37.795
#   duration_sector_3                                               33.618
#   segments_sector_1                       [2049, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2048, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           3
#   compound                                                        MEDIUM
#   Name: 40, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       42
#   i1_speed                                                         284.0
#   i2_speed                                                           315
#   st_speed                                                           317
#   date_start                                  2023-11-24T09:38:19.622000
#   lap_duration                                                    88.622
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.008
#   duration_sector_2                                               37.665
#   duration_sector_3                                               32.949
#   segments_sector_1                       [None, 2048, 2049, 2049, 2048]
#   segments_sector_2    [2048, 2049, 2049, 2049, 2049, 2049, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           5
#   compound                                                        MEDIUM
#   Name: 66, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       42
#   i1_speed                                                         286.0
#   i2_speed                                                           313
#   st_speed                                                           313
#   date_start                                  2023-11-24T09:41:57.524000
#   lap_duration                                                    88.527
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.953
#   duration_sector_2                                               38.053
#   duration_sector_3                                               32.521
#   segments_sector_1                       [None, 2048, 2049, 2048, 2049]
#   segments_sector_2    [2049, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           7
#   compound                                                        MEDIUM
#   Name: 87, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       42
#   i1_speed                                                         287.0
#   i2_speed                                                           313
#   st_speed                                                           314
#   date_start                                  2023-11-24T09:45:31.708000
#   lap_duration                                                    88.026
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.892
#   duration_sector_2                                               37.509
#   duration_sector_3                                               32.625
#   segments_sector_1                       [2049, 2049, 2049, 2048, 2049]
#   segments_sector_2    [2049, 2048, 2049, 2048, 2048, 2049, 2049, 204...
# ...
#   lap_duration                                                    87.438
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.902
#   duration_sector_2                                               37.598
#   duration_sector_3                                               31.938
#   segments_sector_1                       [2048, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2048, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           7
#   compound                                                        MEDIUM
#   Name: 167, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                         283.0
#   i2_speed                                                           309
#   st_speed                                                           312
#   date_start                                  2023-11-24T09:58:31.819000
#   lap_duration                                                    87.074
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.746
#   duration_sector_2                                               37.594
#   duration_sector_3                                               31.734
#   segments_sector_1                       [None, 2049, 2051, 2049, 2049]
#   segments_sector_2    [2048, 2048, 2048, 2049, 2049, 2049, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                           9
#   compound                                                        MEDIUM
#   Name: 196, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                         281.0
#   i2_speed                                                           292
#   st_speed                                                           288
#   date_start                                  2023-11-24T10:21:50.997000
#   lap_duration                                                    89.619
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.933
#   duration_sector_2                                               38.884
#   duration_sector_3                                               32.802
#   segments_sector_1                       [2048, 2048, 2048, 2048, 2049]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          18
#   compound                                                        MEDIUM
#   Name: 362, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                         290.0
#   i2_speed                                                           299
#   st_speed                                                           296
#   date_start                                  2023-11-24T10:23:20.761000
#   lap_duration                                                    90.713
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.049
#   duration_sector_2                                               38.701
#   duration_sector_3                                               33.963
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          19
#   compound                                                        MEDIUM
#   Name: 379, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                         286.0
#   i2_speed                                                           302
#   st_speed                                                           310
#   date_start                                  2023-11-24T10:24:51.307000
#   lap_duration                                                    89.994
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.333
#   duration_sector_2                                                38.71
#   duration_sector_3                                               32.951
#   segments_sector_1                       [None, 2048, 2048, 2048, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2049, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          20
#   compound                                                        MEDIUM
#   Name: 393, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                         287.0
#   i2_speed                                                           295
#   st_speed                                                           293
#   date_start                                  2023-11-24T10:26:21.305000
#   lap_duration                                                    89.901
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.845
#   duration_sector_2                                               38.901
#   duration_sector_3                                               33.155
#   segments_sector_1                       [None, 2048, 2048, 2048, 2049]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2049, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          21
#   compound                                                        MEDIUM
#   Name: 410, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                         288.0
#   i2_speed                                                           297
#   st_speed                                                           293
#   date_start                                  2023-11-24T10:27:51.194000
#   lap_duration                                                    90.394
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.091
#   duration_sector_2                                               39.134
#   duration_sector_3                                               33.169
#   segments_sector_1                       [None, 2048, 2048, 2048, 2049]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2049, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          22
#   compound                                                        MEDIUM
#   Name: 427, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       81
#   i1_speed                                                           NaN
#   i2_speed                                                           312
#   st_speed                                                           310
#   date_start                                  2023-11-24T10:29:21.568000
#   lap_duration                                                    89.315
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                17.96
#   duration_sector_2                                               38.372
#   duration_sector_3                                               32.983
#   segments_sector_1                       [None, 2048, 2048, 2048, 2049]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          23
#   compound                                                        MEDIUM
#   Name: 445, dtype: object],
#  34: [meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       34
#   i1_speed                                                         285.0
#   i2_speed                                                           309
#   st_speed                                                           311
#   date_start                                  2023-11-24T09:50:36.530000
#   lap_duration                                                    88.073
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               18.044
#   duration_sector_2                                                37.52
#   duration_sector_3                                               32.509
#   segments_sector_1                       [2049, 2049, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           6
#   compound                                                        MEDIUM
#   Name: 146, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       34
#   i1_speed                                                         287.0
#   i2_speed                                                           313
#   st_speed                                                           312
#   date_start                                  2023-11-24T09:54:05.058000
#   lap_duration                                                    87.974
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.924
#   duration_sector_2                                               37.765
#   duration_sector_3                                               32.285
#   segments_sector_1                       [2049, 2048, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2049, 2049, 2049, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                           8
#   compound                                                        MEDIUM
#   Name: 163, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       34
#   i1_speed                                                         288.0
#   i2_speed                                                           315
#   st_speed                                                           318
#   date_start                                  2023-11-24T09:57:35.414000
#   lap_duration                                                    87.901
#   is_pit_out_lap                                                   False
#   duration_sector_1                                                17.89
#   duration_sector_2                                               37.345
#   duration_sector_3                                               32.666
#   segments_sector_1                       [None, 2048, 2049, 2049, 2049]
#   segments_sector_2    [2049, 2048, 2048, 2049, 2049, 2048, 2049, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          10
#   compound                                                        MEDIUM
#   Name: 189, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       34
#   i1_speed                                                         288.0
#   i2_speed                                                           314
#   st_speed                                                           316
#   date_start                                  2023-11-24T10:03:05.908000
#   lap_duration                                                    87.382
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.894
#   duration_sector_2                                               37.434
#   duration_sector_3                                               32.054
#   segments_sector_1                       [None, 2049, 2048, 2048, 2048]
#   segments_sector_2    [2051, 2048, 2048, 2049, 2049, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   lap_number                                                          13
#   compound                                                        MEDIUM
#   Name: 232, dtype: object,
#   meeting_key                                                       1226
#   session_key                                                       9190
#   driver_number                                                       34
#   i1_speed                                                         289.0
#   i2_speed                                                           300
#   st_speed                                                           300
#   date_start                                  2023-11-24T10:06:42.983000
#   lap_duration                                                     87.79
#   is_pit_out_lap                                                   False
#   duration_sector_1                                               17.787
#   duration_sector_2                                               37.847
#   duration_sector_3                                               32.156
#   segments_sector_1                       [2049, 2048, 2049, 2049, 2048]
#   segments_sector_2    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#   segments_sector_3    [2048, 2048, 2048, 2048, 2048, 2048, 2048, 206...
#   lap_number                                                          15
#   compound                                                        MEDIUM
#   Name: 262, dtype: object]}

# %%
arrayDataframes = []
for valor in medium_dict.values():
  arrayDataframes.append(pd.DataFrame(valor))

# %%
from matplotlib import pyplot as plt
figure, axis = plt.subplots(len(arrayDataframes),figsize=(20,30))
i=0
for arr in arrayDataframes:
    arr.reset_index(drop=True, inplace=True)
    axis[(i)].plot( arr.lap_duration,marker ="o",color="yellow",label = "Driver Number"+str(arr.driver_number[0])+" with medium tyres" )
    axis[i].set_xlabel("Lap time")
    axis[i].set_ylabel("Lap Time Seconds")
    axis[i].legend()
    i = i+1
