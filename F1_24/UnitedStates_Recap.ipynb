# %%
from F1_library import libraryF1dataNotebook as libraryDataF1
import pandas as pd
import numpy as np
import fastf1 as ff1

from fastf1 import utils
from matplotlib import pyplot as plt

# %% [markdown]
# # FORMULA 1 PIRELLI UNITED STATES GRAND PRIX 2024
# The United States Grand Prix is a motor racing event that has been held on and off since 1908, when it was known as the American Grand Prize. The Grand Prix later became part of the Formula One World Championship. As of 2023, the Grand Prix has been held 52 times at ten different locations. Since 2012, it has been held every year at the Circuit of the Americas in Austin, Texas, except in 2020.
# Source: Wikipedia

# %% [markdown]
# ## Upgrades
# In this section those upgrades brought by the teams will be shown.
# <table>
# <tr>
#     <td>
#     Team
#     </td>
#     <td>
#     Updated component
#     </td>
#     <td>
#     Upgrade type
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Alpine
#     </td>
#     <td>
#     Floor Body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Alpine
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Alpine
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Alpine
#     </td>
#     <td>
#     Rear wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Front Wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Front Suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Rear Suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Rear Corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Floor Body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Sidepot inlet
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Floor fences
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Floor edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Cooling Louvres
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Front Wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Front suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Floor edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Sidepot inlet
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Floor fences
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Front suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Front corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Front corner
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#    Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Beam wing
#     </td>
#     <td>
#    Circuit specific
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#    Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Front wing Endplate
#     </td>
#     <td>
#    Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#    Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#    Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Diffuser
#     </td>
#     <td>
#    Performance
#     </td>
# </tr>
# </table>

# %% [markdown]
# ## Obtain session information

# %%
libraryDataF1.obtain_information('sessions',year=2024,country_acronym='USA').query("circuit_short_name== 'Austin'")
# Out:
#    session_key       session_name                 date_start  \
# 5         9607         Practice 1  2024-10-18T17:30:00+00:00
# 6         9612  Sprint Qualifying  2024-10-18T21:30:00+00:00
# 7         9616             Sprint  2024-10-19T18:00:00+00:00
#
#                     date_end gmt_offset session_type  meeting_key location  \
# 5  2024-10-18T18:30:00+00:00  -05:00:00     Practice         1247   Austin
# 6  2024-10-18T22:14:00+00:00  -05:00:00   Qualifying         1247   Austin
# 7  2024-10-19T19:00:00+00:00  -05:00:00         Race         1247   Austin
#
#    country_key country_code   country_name  circuit_key circuit_short_name  \
# 5           19          USA  United States            9             Austin
# 6           19          USA  United States            9             Austin
# 7           19          USA  United States            9             Austin
#
#    year
# 5  2024
# 6  2024
# 7  2024

# %% [markdown]
# ## Free Practice 1
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9607)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9607)
drivers = libraryDataF1.obtain_information('drivers',session_key=9607)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1247         9607              4     163.0       152       295
# 1           1247         9607             14     147.0       155       293
# 2           1247         9607             18     132.0       108       288
# 3           1247         9607             27     141.0       154       273
# 4           1247         9607             31     157.0       149       271
# ..           ...          ...            ...       ...       ...       ...
# 484         1247         9607             43     166.0       153       240
# 485         1247         9607             31     219.0       178       305
# 486         1247         9607              1     188.0       169       276
# 487         1247         9607             10     208.0       150       297
# 488         1247         9607              4     150.0       136       216
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-10-18T17:30:04.477000+00:00           NaN            True
# 1    2024-10-18T17:30:05.998000+00:00           NaN            True
# 2    2024-10-18T17:30:08.013000+00:00           NaN            True
# 3    2024-10-18T17:30:10.477000+00:00           NaN            True
# 4    2024-10-18T17:30:10.622000+00:00           NaN            True
# ..                                ...           ...             ...
# 484  2024-10-18T18:33:46.913000+00:00       160.266           False
# 485  2024-10-18T18:33:49.309000+00:00       131.540           False
# 486  2024-10-18T18:33:58.308000+00:00       137.079           False
# 487  2024-10-18T18:34:08.625000+00:00       136.364           False
# 488  2024-10-18T18:34:10.727000+00:00       145.155           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             47.256             37.473
# 1                  NaN             50.110             44.215
# 2                  NaN             48.670             53.006
# 3                  NaN             47.368             40.893
# 4                  NaN             48.165             48.560
# ..                 ...                ...                ...
# 484             70.347             53.448             36.471
# 485             57.884             39.967             33.689
# 486             59.476             42.965             34.638
# 487             52.182             43.135             41.047
# 488             57.647             48.135             39.373
#
#                         segments_sector_1  \
# 0    [2064, 2064, 2049, 2049, 2049, 2049]
# 1    [2064, 2064, 2049, 2049, 2049, 2049]
# 2    [2064, 2064, 2049, 2049, 2049, 2049]
# 3    [2064, 2064, 2049, 2049, 2049, 2049]
# 4    [2064, 2064, 2049, 2049, 2049, 2049]
# ..                                    ...
# 484  [None, 2048, 2048, 2048, 2048, 2048]
# 485  [None, 2048, 2048, 2048, 2048, 2048]
# 486  [None, 2048, 2048, 2048, 2048, 2048]
# 487  [None, 2048, 2048, 2048, 2048, 2048]
# 488  [None, 2048, 2048, 2048, 2048, 2048]
#
#                                     segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2049, 2049, 2049, 2049, 2049, 2051, 2051, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                                ...
# 484  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 485  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 486  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 487  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 488  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                               segments_sector_3  lap_number compound  \
# 0    [2049, 2049, 2051, 2051, 2051, 2051, 2049]           1     HARD
# 1    [2048, 2048, 2048, 2049, 2049, 2049, 2049]           1     HARD
# 2    [2049, 2049, 2048, 2049, 2049, 2049, 2049]           1     HARD
# 3       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1     HARD
# 4       [2049, 2051, 2049, 2049, 2049, 2051, 0]           1     HARD
# ..                                          ...         ...      ...
# 484                                          []          27     HARD
# 485                                          []          24     SOFT
# 486                                          []          23     SOFT
# 487                                          []          24     SOFT
# 488                                          []          25     SOFT
#
#     name_acronym         full_name        team_name
# 0            NOR      Lando NORRIS          McLaren
# 1            ALO   Fernando ALONSO     Aston Martin
# 2            STR      Lance STROLL     Aston Martin
# 3            HUL   Nico HULKENBERG     Haas F1 Team
# 4            OCO      Esteban OCON           Alpine
# ..           ...               ...              ...
# 484          COL  Franco COLAPINTO         Williams
# 485          OCO      Esteban OCON           Alpine
# 486          VER    Max VERSTAPPEN  Red Bull Racing
# 487          GAS      Pierre GASLY           Alpine
# 488          NOR      Lando NORRIS          McLaren
#
# [489 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",99)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",99)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",99)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#            full_name compound  duration_sector_1  duration_sector_2  \
# 210     Carlos SAINZ     HARD             25.510             38.005
# 166  Valtteri BOTTAS   MEDIUM             26.034             38.313
# 375     Carlos SAINZ     SOFT             25.340             37.479
#
#      duration_sector_3  lap_duration
# 210             31.202        94.717
# 166             31.664        96.011
# 375             30.783        93.602

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. Also, each sector will be commented. As we can see in the free practice, these data  are not very representative due to the changing conditions.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 275             25.258    Max VERSTAPPEN     SOFT        93.991          12
# 459             25.267   Charles LECLERC     SOFT       135.937          26
# 375             25.340      Carlos SAINZ     SOFT        93.602          19
# 419             25.340   Kevin MAGNUSSEN     SOFT        94.096          21
# 406             25.399    George RUSSELL     SOFT        94.436          23
# 428             25.455    Lewis HAMILTON     SOFT        93.963          19
# 284             25.472      Sergio PEREZ     SOFT        94.638          14
# 403             25.520      Yuki TSUNODA     SOFT        94.313          19
# 383             25.534   Alexander ALBON     SOFT        94.618          21
# 396             25.567      Lance STROLL     SOFT       134.117          20
# 379             25.568      Pierre GASLY     SOFT        94.375          18
# 430             25.577       Liam LAWSON     SOFT        94.633          25
# 376             25.577   Fernando ALONSO     SOFT        94.112          20
# 436             25.579      Lando NORRIS     SOFT        93.868          22
# 424             25.579     Oscar PIASTRI     SOFT        93.908          23
# 445             25.701   Valtteri BOTTAS     SOFT        95.041          24
# 377             25.745      Esteban OCON     SOFT        94.813          18
# 405             25.763  Franco COLAPINTO     SOFT        99.105          23
# 416             25.774   Nico HULKENBERG     SOFT        94.364          21
# 173             26.516       ZHOU Guanyu     SOFT        97.219           8

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 424             37.466     Oscar PIASTRI     SOFT        93.908          23
# 375             37.479      Carlos SAINZ     SOFT        93.602          19
# 425             37.482   Charles LECLERC     SOFT        93.623          24
# 436             37.508      Lando NORRIS     SOFT        93.868          22
# 376             37.556   Fernando ALONSO     SOFT        94.112          20
# 374             37.557       Liam LAWSON     SOFT        94.443          22
# 208             37.561    Max VERSTAPPEN     SOFT        93.855           9
# 428             37.576    Lewis HAMILTON     SOFT        93.963          19
# 448             37.617    George RUSSELL     SOFT        94.093          25
# 403             37.671      Yuki TSUNODA     SOFT        94.313          19
# 379             37.709      Pierre GASLY     SOFT        94.375          18
# 416             37.729   Nico HULKENBERG     SOFT        94.364          21
# 419             37.792   Kevin MAGNUSSEN     SOFT        94.096          21
# 405             37.803  Franco COLAPINTO     SOFT        99.105          23
# 383             37.855   Alexander ALBON     SOFT        94.618          21
# 435             37.873      Esteban OCON     SOFT        94.806          21
# 212             37.897      Sergio PEREZ     SOFT        94.717          11
# 411             37.922      Lance STROLL     SOFT        94.619          21
# 445             37.927   Valtteri BOTTAS     SOFT        95.041          24
# 173             38.902       ZHOU Guanyu     SOFT        97.219           8

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 425             30.728   Charles LECLERC     SOFT        93.623          24
# 436             30.781      Lando NORRIS     SOFT        93.868          22
# 375             30.783      Carlos SAINZ     SOFT        93.602          19
# 208             30.833    Max VERSTAPPEN     SOFT        93.855           9
# 416             30.861   Nico HULKENBERG     SOFT        94.364          21
# 424             30.863     Oscar PIASTRI     SOFT        93.908          23
# 428             30.932    Lewis HAMILTON     SOFT        93.963          19
# 419             30.964   Kevin MAGNUSSEN     SOFT        94.096          21
# 376             30.979   Fernando ALONSO     SOFT        94.112          20
# 448             30.980    George RUSSELL     SOFT        94.093          25
# 377             30.991      Esteban OCON     SOFT        94.813          18
# 411             31.034      Lance STROLL     SOFT        94.619          21
# 379             31.098      Pierre GASLY     SOFT        94.375          18
# 403             31.122      Yuki TSUNODA     SOFT        94.313          19
# 374             31.147       Liam LAWSON     SOFT        94.443          22
# 284             31.183      Sergio PEREZ     SOFT        94.638          14
# 383             31.229   Alexander ALBON     SOFT        94.618          21
# 356             31.356  Franco COLAPINTO     SOFT        95.248          20
# 445             31.413   Valtteri BOTTAS     SOFT        95.041          24
# 173             31.801       ZHOU Guanyu     SOFT        97.219           8

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration > 96 and lap_duration <=100").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# HARD         97.964706
# MEDIUM       98.675900
# SOFT         98.895250

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 96
MAXIMUM_SECONDS = 100.5

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 7          1247         9607             1              1          1        8
# 12         1247         9607             1             11          1       10
# 28         1247         9607             2              1          9       14
# 34         1247         9607             2             11         11       13
# 47         1247         9607             3             11         14       16
# 49         1247         9607             3              1         15       24
# 51         1247         9607             4             11         17       25
#
#    compound  tyre_age_at_start
# 7      HARD                  0
# 12     HARD                  0
# 28     SOFT                  0
# 34     SOFT                  0
# 47     SOFT                  0
# 49     SOFT                  0
# 51     SOFT                  6

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 35   Max VERSTAPPEN     HARD  2024-10-18T17:33:32.175000+00:00           2
# 367  Max VERSTAPPEN     SOFT  2024-10-18T18:19:42.121000+00:00          15
# 408  Max VERSTAPPEN     SOFT  2024-10-18T18:24:56.983000+00:00          18
# 422  Max VERSTAPPEN     SOFT  2024-10-18T18:26:37.519000+00:00          19
# 452  Max VERSTAPPEN     SOFT  2024-10-18T18:29:58.737000+00:00          21
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 35              26.493             38.936             32.164        97.593
# 367             27.383             40.009             33.107       100.499
# 408             27.397             39.964             33.135       100.496
# 422             27.341             39.928             33.030       100.299
# 452             27.125             40.167             32.959       100.251

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
#
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 20              26.793             39.320             32.645        98.758
# 61              26.585             38.591             31.996        97.172
# 143             26.202             38.627             31.592        96.421
# 166             26.034             38.313             31.664        96.011
# 221             27.476             40.086             32.396        99.958
# 234             27.223             40.027             32.819       100.069
# 253             27.033             39.844             32.859        99.736
# 273             26.997             39.843             32.715        99.555
# 292             27.008             39.982             32.667        99.657
# 310             27.060             39.791             32.741        99.592
# 324             26.970             40.128             32.801        99.899
# 409             25.857             38.193             34.153        98.203

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)
# Out:
#               driver compound  lap_duration    sector1    sector2    sector3
# 5    Charles LECLERC     HARD     96.762000  26.097000  38.705000  31.960000
# 4    Fernando ALONSO     HARD     97.307857  26.498429  38.835571  31.973857
# 16      Carlos SAINZ     HARD     97.524857  26.303857  38.921571  32.299429
# 17    George RUSSELL     HARD     97.671667  26.348333  39.058111  32.265222
# 1       Lando NORRIS     HARD     97.817400  26.632600  38.984100  32.200700
# 6       Lance STROLL     HARD     97.817444  26.673111  39.149111  31.995222
# 13      Esteban OCON     HARD     97.888333  26.485889  39.222111  32.180333
# 19     Oscar PIASTRI     HARD     98.084846  26.675692  39.122462  32.286692
# 11   Nico HULKENBERG     HARD     98.183222  26.656778  39.278111  32.248333
# 2       Pierre GASLY     HARD     98.203286  26.606286  39.265286  32.331714
# 7    Kevin MAGNUSSEN     HARD     98.301900  26.700500  39.426900  32.174500
# 12       Liam LAWSON     HARD     98.595100  26.866700  39.239300  32.489100
# 14  Franco COLAPINTO     HARD     98.598667  26.514750  39.193167  32.890750
# 10       ZHOU Guanyu     SOFT     98.622000  26.997000  39.519333  32.105667
# 15    Lewis HAMILTON     HARD     98.683667  26.582333  39.573167  32.528167
# 9    Alexander ALBON     HARD     98.713889  26.530222  39.425444  32.758222
# 3       Sergio PEREZ     SOFT     98.715714  26.802429  39.366857  32.546429
# 18   Valtteri BOTTAS   MEDIUM     98.752583  26.769833  39.395417  32.587333
# 8       Yuki TSUNODA     HARD     99.026750  26.791625  39.646625  32.588500
# 0     Max VERSTAPPEN     SOFT     99.827600  27.147800  39.800800  32.879000

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)
# Out:
#               driver compound  lap_duration    sector1    sector2    sector3
# 5    Charles LECLERC     HARD     96.762000  26.097000  38.705000  31.960000
# 16      Carlos SAINZ     HARD     97.524857  26.303857  38.921571  32.299429
# 17    George RUSSELL     HARD     97.671667  26.348333  39.058111  32.265222
# 13      Esteban OCON     HARD     97.888333  26.485889  39.222111  32.180333
# 4    Fernando ALONSO     HARD     97.307857  26.498429  38.835571  31.973857
# 14  Franco COLAPINTO     HARD     98.598667  26.514750  39.193167  32.890750
# 9    Alexander ALBON     HARD     98.713889  26.530222  39.425444  32.758222
# 15    Lewis HAMILTON     HARD     98.683667  26.582333  39.573167  32.528167
# 2       Pierre GASLY     HARD     98.203286  26.606286  39.265286  32.331714
# 1       Lando NORRIS     HARD     97.817400  26.632600  38.984100  32.200700
# 11   Nico HULKENBERG     HARD     98.183222  26.656778  39.278111  32.248333
# 6       Lance STROLL     HARD     97.817444  26.673111  39.149111  31.995222
# 19     Oscar PIASTRI     HARD     98.084846  26.675692  39.122462  32.286692
# 7    Kevin MAGNUSSEN     HARD     98.301900  26.700500  39.426900  32.174500
# 18   Valtteri BOTTAS   MEDIUM     98.752583  26.769833  39.395417  32.587333
# 8       Yuki TSUNODA     HARD     99.026750  26.791625  39.646625  32.588500
# 3       Sergio PEREZ     SOFT     98.715714  26.802429  39.366857  32.546429
# 12       Liam LAWSON     HARD     98.595100  26.866700  39.239300  32.489100
# 10       ZHOU Guanyu     SOFT     98.622000  26.997000  39.519333  32.105667
# 0     Max VERSTAPPEN     SOFT     99.827600  27.147800  39.800800  32.879000

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)
# Out:
#               driver compound  lap_duration    sector1    sector2    sector3
# 5    Charles LECLERC     HARD     96.762000  26.097000  38.705000  31.960000
# 4    Fernando ALONSO     HARD     97.307857  26.498429  38.835571  31.973857
# 16      Carlos SAINZ     HARD     97.524857  26.303857  38.921571  32.299429
# 1       Lando NORRIS     HARD     97.817400  26.632600  38.984100  32.200700
# 17    George RUSSELL     HARD     97.671667  26.348333  39.058111  32.265222
# 19     Oscar PIASTRI     HARD     98.084846  26.675692  39.122462  32.286692
# 6       Lance STROLL     HARD     97.817444  26.673111  39.149111  31.995222
# 14  Franco COLAPINTO     HARD     98.598667  26.514750  39.193167  32.890750
# 13      Esteban OCON     HARD     97.888333  26.485889  39.222111  32.180333
# 12       Liam LAWSON     HARD     98.595100  26.866700  39.239300  32.489100
# 2       Pierre GASLY     HARD     98.203286  26.606286  39.265286  32.331714
# 11   Nico HULKENBERG     HARD     98.183222  26.656778  39.278111  32.248333
# 3       Sergio PEREZ     SOFT     98.715714  26.802429  39.366857  32.546429
# 18   Valtteri BOTTAS   MEDIUM     98.752583  26.769833  39.395417  32.587333
# 9    Alexander ALBON     HARD     98.713889  26.530222  39.425444  32.758222
# 7    Kevin MAGNUSSEN     HARD     98.301900  26.700500  39.426900  32.174500
# 10       ZHOU Guanyu     SOFT     98.622000  26.997000  39.519333  32.105667
# 15    Lewis HAMILTON     HARD     98.683667  26.582333  39.573167  32.528167
# 8       Yuki TSUNODA     HARD     99.026750  26.791625  39.646625  32.588500
# 0     Max VERSTAPPEN     SOFT     99.827600  27.147800  39.800800  32.879000

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)
# Out:
#               driver compound  lap_duration    sector1    sector2    sector3
# 5    Charles LECLERC     HARD     96.762000  26.097000  38.705000  31.960000
# 30       None                           CLEAR IN TRACK SECTOR 14
# 31       None  FIA STEWARDS: TURN 5 INCIDENT INVOLVING CARS 4...
# 32       None  CAR 43 (COL) LAP DELETED - TRACK LIMITS AT TUR...
# 33       None                                     CHEQUERED FLAG
# 34       None          FIRST CAR TO TAKE THE FLAG - CAR 55 (SAI)
# 35       None  FIA STEWARDS: SQ1 INCIDENT INVOLVING CARS 1 (V...
#
#    driver_number   scope  sector
# 0           None  Sector    12.0
# 1           None  Sector    13.0
# 2           None  Sector    14.0
# 3           None  Sector    15.0
# 4           None  Sector    16.0
# 5           None  Sector    17.0
# 6           None  Sector    18.0
# 7           None  Sector    19.0
# 8           None  Sector    20.0
# 9           None   Track     NaN
# 10          None    None     NaN
# 11          None   Track     NaN
# 12          None    None     NaN
# 13          None    None     NaN
# 14          None    None     NaN
# 15          None    None     NaN
# 16          None    None     NaN
# 17          None    None     NaN
# 18          None   Track     NaN
# 19          None   Track     NaN
# 20          None    None     NaN
# 21          None    None     NaN
# 22          None    None     NaN
# 23          None    None     NaN
# 24          None    None     NaN
# 25          None    None     NaN
# 26          None   Track     NaN
# 27          None  Sector    14.0
# 28          None    None     NaN
# 29          None    None     NaN
# 30          None  Sector    14.0
# 31          None    None     NaN
# 32          None    None     NaN
# 33          None   Track     NaN
# 34          None    None     NaN
# 35          None    None     NaN

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9612)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9612)
drivers = libraryDataF1.obtain_information('drivers',session_key=9612)

# %% [markdown]
# In race control dataset, I can see a lot of laptimes deleted, principally for track limits. Those laps deleted ,within the 107%, were deleted from dataset in order to obtain only the valid laps for the analysis.

# %%
laptimes_deleted = [94.716,94.285,94.306,95.193,94.251,94.421,94.284]
driver_number_lap_deleted = [11,81,14,24,14,18,30]

for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
    try:
        id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
        qualyfing = qualyfing.drop(id_deleted)
    except:
        print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 195         1247         9612              1       244       191       325
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 195  2024-10-18T22:13:32.811000+00:00        92.833           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 195             25.001             37.309             30.523
#
#                         segments_sector_1  \
# 195  [2049, 2049, 2051, 2049, 2049, 2049]
#
#                                     segments_sector_2  \
# 195  [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
#
#                               segments_sector_3  lap_number
# 195  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          11

# %% [markdown]
# The fastest lap is 92.833 seconds (1.32.833= so that to obtain the competitve laps the fastest lap will be multiplied by 1.07 (99.33 seconds) due to, according to the rules all the drivers have to do unless one lap within this gap.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration < 99.33")
competitiveLaps
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
#
# 64                        [0, 0, 0, 0, 0, 0, 0]           5
# 70   [2048, 2048, 2048, 2048, 2048, 2064, 2064]           5
# 83                        [0, 0, 0, 0, 0, 0, 0]           5
# 85                        [0, 0, 0, 0, 0, 0, 0]           5
# 87                        [0, 0, 0, 0, 0, 0, 0]           5
# 88                        [0, 0, 0, 0, 0, 0, 0]           5
# 89                        [0, 0, 0, 0, 0, 0, 0]           5
# 90                        [0, 0, 0, 0, 0, 0, 0]           5
# 91                        [0, 0, 0, 0, 0, 0, 0]           5
# 92                        [0, 0, 0, 0, 0, 0, 0]           5
# 94                        [0, 0, 0, 0, 0, 0, 0]           5
# 96                        [0, 0, 0, 0, 0, 0, 0]           5
# 97                        [0, 0, 0, 0, 0, 0, 0]           5
# 99                        [0, 0, 0, 0, 0, 0, 0]           5
# 100  [2049, 2049, 2049, 2049, 2049, 2049, 2051]           5
# 102  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           5
# 104  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           5
# 127  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           8
# 128  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           8
# 129  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           8
# 130  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           7
# 131  [2048, 2048, 2048, 2048, 2048, 2048, 2048]           8
# 132                       [0, 0, 0, 0, 0, 0, 0]           8
# 133                       [0, 0, 0, 0, 0, 0, 0]           8
# 134  [2048, 2048, 2048, 2048, 2048, 2064, 2064]           8
# 145                       [0, 0, 0, 0, 0, 0, 0]           8
# 151                       [0, 0, 0, 0, 0, 0, 0]           8
# 158                    [0, 0, 0, 0, 0, 0, 2064]           8
# 160                       [0, 0, 0, 0, 0, 0, 0]           8
# 161  [2049, 2049, 2049, 2049, 2049, 2049, 2049]          11
# 166  [2049, 2049, 2049, 2049, 2049, 2049, 2049]          11
# 177  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          13
# 179  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          11
# 190  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          11
# 191  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          13
# 192  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          11
# 193  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          13
# 194  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          11
# 195  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          11
# 196  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          13
# 197  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          14

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)
# Out:
#     driver_number  fastest_lap  delta  st_speed  i1_speed  i2_speed  \
# 0               1       92.833  0.000       325       236       186
# 17             63       92.845  0.012       327       233       191
# 14             16       93.059  0.226       326       232       190
# 11              4       93.083  0.250       324       234       191
# 13             55       93.089  0.256       325       234       188
# 1              27       93.183  0.350       326       238       189
# 18             44       93.370  0.537       320       240       186
# 4              20       93.398  0.565       325       234       189
# 7              22       93.802  0.969       325       234       185
# 10             43       93.952  1.119       322       229       188
# 19             11       94.244  1.411       325       227       189
# 16             18       94.324  1.491       324       232       190
# 5              10       94.363  1.530       326       235       187
# 15             14       94.436  1.603       329       236       190
# 6              30       94.617  1.784       326       239       189
# 12             81       94.881  2.048       323       227       188
# 8              31       94.917  2.084       325       239       188
# 9              23       95.054  2.221       323       230       189
# 3              77       95.148  2.315       325       235       190
# 2              24       96.472  3.639       325       233       187
#
#     session_key  meeting_key broadcast_name country_code first_name  \
# 0          9612         1247   M VERSTAPPEN          NED        Max
# 17         9612         1247      G RUSSELL          GBR     George
# 14         9612         1247      C LECLERC          MON    Charles
# 11         9612         1247       L NORRIS          GBR      Lando
# 13         9612         1247        C SAINZ          ESP     Carlos
# 1          9612         1247   N HULKENBERG          GER       Nico
# 18         9612         1247     L HAMILTON          GBR      Lewis
# 4          9612         1247    K MAGNUSSEN          DEN      Kevin
# 7          9612         1247      Y TSUNODA          JPN       Yuki
# 10         9612         1247    F COLAPINTO          ARG     Franco
# 19         9612         1247        S PEREZ          MEX     Sergio
# 16         9612         1247       L STROLL          CAN      Lance
# 5          9612         1247        P GASLY          FRA     Pierre
# 15         9612         1247       F ALONSO          ESP   Fernando
# 6          9612         1247       L LAWSON          NZL       Liam
# 12         9612         1247      O PIASTRI          AUS      Oscar
# 8          9612         1247         E OCON          FRA    Esteban
# 9          9612         1247        A ALBON          THA  Alexander
# 3          9612         1247       V BOTTAS          FIN   Valtteri
# 2          9612         1247         G ZHOU          CHN     Guanyu
#
#            full_name                                       headshot_url  \
# 0     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 17    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 14   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 11      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 13      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 1    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 18    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 4    Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 7       Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 10  Franco COLAPINTO                                               None
# 19      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 16      Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 5       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 15   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 6        Liam LAWSON                                               None
# 12     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 8       Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 9    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 3    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 2        ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name team_colour        team_name name_acronym
# 0   Verstappen      3671C6  Red Bull Racing          VER
# 17     Russell      27F4D2         Mercedes          RUS
# 14     Leclerc      E80020          Ferrari          LEC
# 11      Norris      FF8000          McLaren          NOR
# 13       Sainz      E80020          Ferrari          SAI
# 1   Hulkenberg      B6BABD     Haas F1 Team          HUL
# 18    Hamilton      27F4D2         Mercedes          HAM
# 4    Magnussen      B6BABD     Haas F1 Team          MAG
# 7      Tsunoda      6692FF               RB          TSU
# 10   Colapinto      64C4FF         Williams          COL
# 19       Perez      3671C6  Red Bull Racing          PER
# 16      Stroll      229971     Aston Martin          STR
# 5        Gasly      0093CC           Alpine          GAS
# 15      Alonso      229971     Aston Martin          ALO
# 6       Lawson      6692FF               RB          LAW
# 1              25.238  ...    M VERSTAPPEN           NED        Max
# 33             25.688  ...        L NORRIS           GBR      Lando
# 40             25.389  ...         C SAINZ           ESP     Carlos
# 51             25.494  ...       G RUSSELL           GBR     George
# 49             25.451  ...        L STROLL           CAN      Lance
# 58             25.547  ...         S PEREZ           MEX     Sergio
# 11             25.417  ...     K MAGNUSSEN           DEN      Kevin
# 47             25.505  ...        F ALONSO           ESP   Fernando
# 30             25.499  ...     F COLAPINTO           ARG     Franco
# 20             25.407  ...        L LAWSON           NZL       Liam
# 22             25.326  ...       Y TSUNODA           JPN       Yuki
# 5              25.923  ...    N HULKENBERG           GER       Nico
# 16             25.690  ...         P GASLY           FRA     Pierre
# 38             26.167  ...       O PIASTRI           AUS      Oscar
# 26             25.638  ...          E OCON           FRA    Esteban
# 27             25.585  ...         A ALBON           THA  Alexander
# 10             25.743  ...        V BOTTAS           FIN   Valtteri
# 8              26.381  ...          G ZHOU           CHN     Guanyu
#
#            full_name                                       headshot_url  \
# 44   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 54    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 1     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 33      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 40      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 51    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 49      Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 58      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 11   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 47   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 30  Franco COLAPINTO                                               None
# 20       Liam LAWSON                                               None
# 22      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 5    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 16      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 38     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 26      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 27   Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 10   Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 8        ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 44     Leclerc       E80020          Ferrari          LEC         True
# 54    Hamilton       27F4D2         Mercedes          HAM         True
# 1   Verstappen       3671C6  Red Bull Racing          VER         True
# 33      Norris       FF8000          McLaren          NOR         True
# 40       Sainz       E80020          Ferrari          SAI         True
# 51     Russell       27F4D2         Mercedes          RUS         True
# 49      Stroll       229971     Aston Martin          STR         True
# 58       Perez       3671C6  Red Bull Racing          PER         True
# 11   Magnussen       B6BABD     Haas F1 Team          MAG         True
# 47      Alonso       229971     Aston Martin          ALO         True
# 30   Colapinto       64C4FF         Williams          COL         True
# 20      Lawson       6692FF               RB          LAW         True
# 22     Tsunoda       6692FF               RB          TSU         True
# 5   Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 16       Gasly       0093CC           Alpine          GAS         True
# 38     Piastri       FF8000          McLaren          PIA         True
# 26        Ocon       0093CC           Alpine          OCO         True
# 27       Albon       64C4FF         Williams          ALB         True
# 10      Bottas       52E252      Kick Sauber          BOT         True
# 8         Zhou       52E252      Kick Sauber          ZHO         True
#
# [20 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P15 = q1Data[14:15]
P15
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 16           1247           9612             10       241       187       326
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 16  2024-10-18T21:32:50.974000+00:00        94.865           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 16              25.69  ...         P GASLY           FRA     Pierre
#
#        full_name                                       headshot_url  \
# 16  Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
#
#     last_name  team_colour  team_name name_acronym isFastestLap
# 16      Gasly       0093CC     Alpine          GAS         True
#
# [1 rows x 28 columns]

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Pierre GASLY Sector 1:  25.69 Sector 2:  38.016 Sector 3:  31.159

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 =  libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             81         0.016                0.477               -0.274
# 1             31         0.052               -0.052                0.047
# 2             23         0.189               -0.105                0.108
# 3             77         0.283                0.053                0.159
# 4             24         1.607                0.691                0.585
#
#    difference_sector_3 name_acronym
# 0               -0.187          PIA
# 1                0.057          OCO
# 2                0.186          ALB
# 3                0.071          BOT
# 4                0.331          ZHO

# %% [markdown]
# ### Best sector per driver

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# HAM                      25.185
# VER                      25.238
# TSU                      25.326
# SAI                      25.389
# LAW                      25.407
# MAG                      25.417
# LEC                      25.431
# STR                      25.451
# RUS                      25.494
# COL                      25.499
# ALO                      25.505
# PER                      25.547
# ALB                      25.585
# OCO                      25.638
# NOR                      25.688
# GAS                      25.690
# BOT                      25.743
# HUL                      25.923
# PIA                      26.167
# ZHO                      26.381

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# LEC                      37.374
# NOR                      37.606
# RUS                      37.611
# STR                      37.634
# MAG                      37.711
# VER                      37.737
# PIA                      37.742
# PER                      37.756
# HAM                      37.767
# ALO                      37.795
# SAI                      37.814
# COL                      37.864
# HUL                      37.893
# LAW                      38.005
# GAS                      38.016
# TSU                      38.033
# OCO                      38.063
# ALB                      38.124
# BOT                      38.175
# ZHO                      38.601

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# NOR                      30.625
# LEC                      30.842
# HAM                      30.888
# SAI                      30.906
# VER                      30.933
# PIA                      30.972
# HUL                      31.009
# RUS                      31.020
# PER                      31.030
# ALO                      31.136
# GAS                      31.159
# LAW                      31.205
# OCO                      31.216
# BOT                      31.230
# STR                      31.239
# COL                      31.243
# MAG                      31.275
# TSU                      31.287
# ALB                      31.345
# ZHO                      31.490

# %% [markdown]
# ### Sprint Qualyfing 2

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 41           1247           9612             55       236       192       325
# 2            1247           9612              1       240       190       325
# 56           1247           9612             44       244       190       327
# 45           1247           9612             16       237       191       326
# 52           1247           9612             63       238       192       328
# 35           1247           9612              4       235       191       324
# 13           1247           9612             20       239       191       325
# 31           1247           9612             43       235       188       322
# 6            1247           9612             27       241       191       326
# 23           1247           9612             22       244       189       327
# 59           1247           9612             11       230       189       325
# 18           1247           9612             10       236       189       327
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 41  2024-10-18T21:51:55.962000+00:00        93.274           False
# 2   2024-10-18T21:54:26.141000+00:00        93.290           False
# 56  2024-10-18T21:51:27.148000+00:00        93.370           False
# 45  2024-10-18T21:52:04.985000+00:00        93.392           False
# 52  2024-10-18T21:51:18.881000+00:00        93.544           False
# 35  2024-10-18T21:51:40.373000+00:00        93.566           False
# 13  2024-10-18T21:51:10.219000+00:00        93.788           False
# 31  2024-10-18T21:52:21.096000+00:00        93.952           False
# 6   2024-10-18T21:51:02.745000+00:00        93.994           False
# 23  2024-10-18T21:57:25.934000+00:00        94.052           False
# 59  2024-10-18T21:55:45.463000+00:00        94.244           False
# 18  2024-10-18T21:57:09.134000+00:00        94.363           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 41             25.280  ...         C SAINZ           ESP     Carlos
# 2              25.144  ...    M VERSTAPPEN           NED        Max
# 56             25.111  ...      L HAMILTON           GBR      Lewis
# 45             25.225  ...       C LECLERC           MON    Charles
# 52             25.307  ...       G RUSSELL           GBR     George
# 35             25.416  ...        L NORRIS           GBR      Lando
# 13             25.324  ...     K MAGNUSSEN           DEN      Kevin
# 31             25.373  ...     F COLAPINTO           ARG     Franco
# 6              25.648  ...    N HULKENBERG           GER       Nico
# 23             25.309  ...       Y TSUNODA           JPN       Yuki
# 59             25.457  ...         S PEREZ           MEX     Sergio
# 18             25.390  ...         P GASLY           FRA     Pierre
#
#            full_name                                       headshot_url  \
# 41      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 2     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 56    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 45   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 52    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 35      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 13   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 31  Franco COLAPINTO                                               None
# 6    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 23      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 59      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 18      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 41       Sainz       E80020          Ferrari          SAI         True
# 2   Verstappen       3671C6  Red Bull Racing          VER         True
# 56    Hamilton       27F4D2         Mercedes          HAM         True
# 45     Leclerc       E80020          Ferrari          LEC         True
# 52     Russell       27F4D2         Mercedes          RUS         True
# 35      Norris       FF8000          McLaren          NOR         True
# 13   Magnussen       B6BABD     Haas F1 Team          MAG         True
# 31   Colapinto       64C4FF         Williams          COL         True
# 6   Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 23     Tsunoda       6692FF               RB          TSU         True
# 59       Perez       3671C6  Red Bull Racing          PER         True
# 18       Gasly       0093CC           Alpine          GAS         True
#
# [12 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Yuki TSUNODA Sector 1:  25.309 Sector 2:  37.604 Sector 3:  31.139

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             11         0.192                0.148                0.175
# 1             10         0.311                0.081                0.217
#
#    difference_sector_3 name_acronym
# 0               -0.131          PER
# 1                0.013          GAS

# %% [markdown]
# ### Best sector per driver

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# HAM                      25.111
# VER                      25.144
# LEC                      25.225
# SAI                      25.280
# RUS                      25.307
# TSU                      25.309
# MAG                      25.324
# COL                      25.373
# GAS                      25.390
# NOR                      25.416
# PER                      25.457
# HUL                      25.648

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# RUS                      37.291
# VER                      37.369
# HAM                      37.398
# SAI                      37.400
# LEC                      37.409
# HUL                      37.496
# NOR                      37.507
# TSU                      37.604
# MAG                      37.659
# COL                      37.691
# PER                      37.779
# GAS                      37.821

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# SAI                      30.594
# NOR                      30.643
# LEC                      30.758
# VER                      30.777
# MAG                      30.805
# HUL                      30.850
# HAM                      30.861
# COL                      30.888
# RUS                      30.946
# PER                      31.008
# TSU                      31.139
# GAS                      31.152

# %% [markdown]
# ### Sprint Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 3            1247           9612              1       244       191       325
# 53           1247           9612             63       240       193       329
# 46           1247           9612             16       234       191       327
# 37           1247           9612              4       237       191       325
# 42           1247           9612             55       239       192       325
# 7            1247           9612             27       247       192       327
# 57           1247           9612             44       245       186       320
# 15           1247           9612             20       241       192       326
# 24           1247           9612             22       242       188       326
# 32           1247           9612             43       236       189       324
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 3   2024-10-18T22:13:32.811000+00:00        92.833           False
# 53  2024-10-18T22:08:04.517000+00:00        92.845           False
# 46  2024-10-18T22:12:51.987000+00:00        93.059           False
# 37  2024-10-18T22:12:42.113000+00:00        93.083           False
# 42  2024-10-18T22:12:33.798000+00:00        93.089           False
# 7   2024-10-18T22:13:42.250000+00:00        93.183           False
# 57  2024-10-18T22:08:38.914000+00:00        93.378           False
# 15  2024-10-18T22:13:06.997000+00:00        93.398           False
# 24  2024-10-18T22:13:21.480000+00:00        93.802           False
# 32  2024-10-18T22:13:58.115000+00:00        94.406           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 3              25.001  ...    M VERSTAPPEN           NED        Max
# 53             25.245  ...       G RUSSELL           GBR     George
# 46             25.288  ...       C LECLERC           MON    Charles
# 37             25.177  ...        L NORRIS           GBR      Lando
# 42             25.189  ...         C SAINZ           ESP     Carlos
# 7              25.321  ...    N HULKENBERG           GER       Nico
# 57             24.874  ...      L HAMILTON           GBR      Lewis
# 15             25.366  ...     K MAGNUSSEN           DEN      Kevin
# 24             25.316  ...       Y TSUNODA           JPN       Yuki
# 32             25.614  ...     F COLAPINTO           ARG     Franco
#
#            full_name                                       headshot_url  \
# 3     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 53    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 46   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 37      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 42      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 7    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 57    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 15   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 24      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 32  Franco COLAPINTO                                               None
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 3   Verstappen       3671C6  Red Bull Racing          VER         True
# 53     Russell       27F4D2         Mercedes          RUS         True
# 46     Leclerc       E80020          Ferrari          LEC         True
# 37      Norris       FF8000          McLaren          NOR         True
# 42       Sainz       E80020          Ferrari          SAI         True
# 7   Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 57    Hamilton       27F4D2         Mercedes          HAM         True
# 15   Magnussen       B6BABD     Haas F1 Team          MAG         True
# 24     Tsunoda       6692FF               RB          TSU         True
# 32   Colapinto       64C4FF         Williams          COL         True
#
# [10 rows x 28 columns]

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Max VERSTAPPEN Sector 1:  25.001 Sector 2:  37.309 Sector 3:  30.523

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             63         0.012                0.244               -0.195
# 1             16         0.226                0.287               -0.022
# 2              4         0.250                0.176               -0.136
# 3             55         0.256                0.188                0.031
# 4             27         0.350                0.320                0.069
# 5             44         0.545               -0.127                0.359
# 6             20         0.565                0.365                0.148
# 7             22         0.969                0.315                0.191
# 8             43         1.573                0.613                0.386
#
#    difference_sector_3 name_acronym
# 0               -0.037          RUS
# 1               -0.039          LEC
# 2                0.210          NOR
# 3                0.037          SAI
# 4               -0.039          HUL
# 5                0.313          HAM
# 6                0.052          MAG
# 7                0.463          TSU
# 8                0.574          COL

# %% [markdown]
# ### Best sector per driver

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# HAM                      24.874
# VER                      25.001
# NOR                      25.177
# SAI                      25.189
# RUS                      25.245
# LEC                      25.288
# TSU                      25.316
# HUL                      25.321
# MAG                      25.366
# COL                      25.614

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# RUS                      37.114
# NOR                      37.173
# LEC                      37.287
# VER                      37.309
# SAI                      37.340
# HUL                      37.378
# MAG                      37.457
# TSU                      37.500
# HAM                      37.668
# COL                      37.695

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# HUL                      30.484
# LEC                      30.484
# RUS                      30.486
# VER                      30.523
# SAI                      30.560
# MAG                      30.575
# NOR                      30.733
# HAM                      30.836
# TSU                      30.986
# COL                      31.097

# %% [markdown]
# ### Best sector in the session

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# HAM                      24.874
# VER                      25.001
# NOR                      25.177
# SAI                      25.189
# LEC                      25.225
# RUS                      25.245
# TSU                      25.309
# HUL                      25.321
# MAG                      25.324
# COL                      25.373
# GAS                      25.390
# LAW                      25.407
# STR                      25.451
# PER                      25.457
# ALB                      25.505
# ALO                      25.505
# OCO                      25.638
# BOT                      25.743
# PIA                      26.167
# ZHO                      26.381

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# RUS                      37.114
# NOR                      37.173
# LEC                      37.287
# VER                      37.309
# SAI                      37.340
# HUL                      37.378
# HAM                      37.398
# MAG                      37.457
# TSU                      37.500
# STR                      37.634
# COL                      37.691
# PIA                      37.742
# PER                      37.756
# LAW                      37.773
# ALO                      37.795
# GAS                      37.821
# ALB                      38.008
# OCO                      38.063
# BOT                      38.073
# ZHO                      38.601

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# LEC                      30.484
# HUL                      30.484
# RUS                      30.486
# VER                      30.523
# SAI                      30.560
# MAG                      30.575
# NOR                      30.625
# HAM                      30.836
# COL                      30.888
# PIA                      30.972
# TSU                      30.986
# PER                      31.008
# LAW                      31.129
# ALO                      31.136
# GAS                      31.152
# STR                      31.167
# OCO                      31.194
# BOT                      31.230
# ALB                      31.345
# ZHO                      31.490

# %% [markdown]
# ## Predictions

# %%
# Free Practice 1
practice = libraryDataF1.obtain_information('laps',session_key=9599)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9599)
drivers = libraryDataF1.obtain_information('drivers',session_key=9599)

stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice1 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# Free Practice 2
practice = libraryDataF1.obtain_information('laps',session_key=9600)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9600)
drivers = libraryDataF1.obtain_information('drivers',session_key=9600)


stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# Free Practice 3
# practice = libraryDataF1.obtain_information('laps',session_key=9591)
# stintInformation = libraryDataF1.obtain_information('stints',session_key=9591)
# drivers = libraryDataF1.obtain_information('drivers',session_key=9591)

# stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
# jointablesfreepractice1 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# ### Qualyfing prediction

# %%
qualy_simulation = libraryDataF1.qualyfing_prediction([jointablesfreepractice1,jointablesfreepractice2],drivers,0.05,0.07,0.08)
qualy_simulation.sort_values(by='qualy_lap_time')

# %% [markdown]
# ### Race prediction

# %%
race_simulation = libraryDataF1.race_prediction(jointablesfreepractice2,drivers,96.5,100.3)
race_simulation.groupby('team').mean().sort_values(by='mean_lap_duration')

# %% [markdown]
# ## Sprint

# %%
race = libraryDataF1.obtain_information('laps',session_key=9616)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9616)
drivers = libraryDataF1.obtain_information('drivers',session_key=9616)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables = pd.merge(race,stintsDataFrame,on=['lap_number','driver_number'])
jointables
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1247         9616              1     222.0       181       307
# 1           1247         9616              4     210.0       185       302
# 2           1247         9616             10     196.0       170       320
# 3           1247         9616             11     201.0       183       320
# 4           1247         9616             14     193.0       185       319
# ..           ...          ...            ...       ...       ...       ...
# 375         1247         9616             44     228.0       181       292
# 376         1247         9616             55     230.0       186       309
# 377         1247         9616             63       NaN       185       314
# 378         1247         9616             77     212.0       182       298
# 379         1247         9616             81     228.0       187       309
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0                                None           NaN           False
# 1                                None           NaN           False
# 2                                None           NaN           False
# 3                                None           NaN           False
# 4                                None           NaN           False
# ..                                ...           ...             ...
# 375  2024-10-19T18:33:36.351000+00:00       100.469           False
# 376  2024-10-19T18:33:24.371000+00:00        97.552           False
# 377  2024-10-19T18:33:34.998000+00:00        98.785           False
# 378  2024-10-19T18:34:09.401000+00:00       103.136           False
# 379  2024-10-19T18:33:52.522000+00:00        97.567           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             39.197             32.649
# 1                  NaN             39.227             32.882
# 2                  NaN             41.024             34.037
# 3                  NaN             40.482             33.874
# 4                  NaN             41.927             33.899
# ..                 ...                ...                ...
# 375             26.217             40.004             34.248
# 376             25.964             39.206             32.382
# 377             26.555             39.091             33.139
# 378             27.933             40.693             34.510
# 379             26.271             38.978             32.318
#
#                         segments_sector_1  \
# 0    [2048, 2049, 2051, 2051, 2051, 2051]
# 1    [2048, 2049, 2049, 2049, 2049, 2049]
# 2    [2048, 2049, 2049, 2049, 2049, 2049]
# 3    [2048, 2049, 2049, 2049, 2049, 2049]
# 4          [2048, 2049, 2049, 2049, 0, 0]
# ..                                    ...
# 375  [2048, 2048, 2048, 2048, 2048, 2049]
# 376  [None, 2048, 2048, 2048, 2048, 2049]
# 377  [None, 2048, 2048, 2048, 2048, 2048]
# 378  [None, 2048, 2048, 2048, 2048, 2048]
# 379  [None, 2048, 2048, 2048, 2048, 2049]
#
#                                     segments_sector_2  \
# 0    [2051, 2051, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                                ...
# 375  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 376  [2051, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 377  [2049, 2048, 2049, 2048, 2048, 2048, 2048, 2048]
# 378  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 379  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049]
#
#                               segments_sector_3  lap_number compound  \
# 0    [2048, 2049, 2048, 2049, 2049, 2049, 2048]           1   MEDIUM
# 1    [2049, 2048, 2049, 2049, 2049, 2049, 2048]           1   MEDIUM
# 2    [2049, 2049, 2049, 2048, 2049, 2049, 2049]           1   MEDIUM
# 3    [2048, 2049, 2049, 2049, 2049, 2049, 2049]           1   MEDIUM
# 4    [2049, 2048, 2048, 2049, 2049, 2048, 2049]           1   MEDIUM
# ..                                          ...         ...      ...
# 375  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          19   MEDIUM
# 376                       [0, 0, 0, 0, 0, 0, 0]          19   MEDIUM
# 377  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          19   MEDIUM
# 378                    [2052, 0, 0, 0, 0, 0, 0]          19   MEDIUM
# 379  [2048, 2048, 2048, 2048, 2048, 2064, 2064]          19   MEDIUM
#
#     name_acronym        full_name        team_name
# 0            VER   Max VERSTAPPEN  Red Bull Racing
# 1            NOR     Lando NORRIS          McLaren
# 2            GAS     Pierre GASLY           Alpine
# 3            PER     Sergio PEREZ  Red Bull Racing
# 4            ALO  Fernando ALONSO     Aston Martin
# ..           ...              ...              ...
# 375          HAM   Lewis HAMILTON         Mercedes
# 376          SAI     Carlos SAINZ          Ferrari
# 377          RUS   George RUSSELL         Mercedes
# 378          BOT  Valtteri BOTTAS      Kick Sauber
# 379          PIA    Oscar PIASTRI          McLaren
#
# [380 rows x 20 columns]

# %% [markdown]
# ### Pace per compound

# %%
libraryDataF1.obtain_data_tyres(jointables,"MEDIUM",102)

# %% [markdown]
# ### Top speed captured in the speed trap

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=102").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  lap_duration
# team_name
# Ferrari             98.334618
# Red Bull Racing     98.863581
# Mercedes            99.000241
# McLaren             99.069788
# Haas F1 Team        99.384129
# Williams           100.036088
# Alpine             100.075800
# RB                 100.134727
# Aston Martin       100.201714
# Kick Sauber        100.502970

# %% [markdown]
# ### Race pace per teams

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=102").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  duration_sector_1
# team_name
# Ferrari                  26.356412
# Mercedes                 26.497966
# Red Bull Racing          26.541645
# McLaren                  26.663606
# Haas F1 Team             26.673645
# Williams                 26.859853
# RB                       26.954455
# Alpine                   26.985367
# Aston Martin             27.006457
# Kick Sauber              27.066152

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=102").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  duration_sector_2
# team_name
# Ferrari                  39.172500
# Mercedes                 39.326448
# McLaren                  39.356758
# Red Bull Racing          39.486387
# Haas F1 Team             39.705097
# Alpine                   39.797400
# Williams                 39.827265
# Aston Martin             39.828800
# RB                       39.860636
# Kick Sauber              40.028242

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=102").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  duration_sector_3
# team_name
# Ferrari                  32.805706
# Red Bull Racing          32.835548
# Haas F1 Team             33.005387
# McLaren                  33.049424
# Mercedes                 33.175828
# Alpine                   33.293033
# RB                       33.319636
# Williams                 33.348971
# Aston Martin             33.366457
# Kick Sauber              33.408576

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 98
MAXIMUM_SECONDS = 102

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11
# 318             26.898             39.713             33.031        99.642
# 338             26.914             39.793             33.089        99.796
# 358             26.936             39.952             33.452       100.340

# %% [markdown]
# ## Qualyfing
# ### Set up
# First of all, it is neccesary to obtain the data about the qualyfing
# #### Race control
# This section has been added in order to know which laps has been deleted and knowing what happened on track during this session. As every laptime that has been deleted were slow laps, none of them were removed.

# %%
libraryDataF1.obtain_information('race_control',session_key=9602)

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9602)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9602)
drivers = libraryDataF1.obtain_information('drivers',session_key=9602)

# %%
import fastf1 as ff1

from fastf1 import utils
from matplotlib import pyplot as plt

session = ff1.get_session(2024, 'Singapore', 'Q')
session.load()
session.laps["LapTimeSeconds"] = session.laps["LapTime"].dt.total_seconds()

# %%
laptimes_deleted = [89.791,90.119,90.371]
driver_number_lap_deleted = [1,16,1]

for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
    try:
        id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
        qualyfing = qualyfing.drop(id_deleted)
    except:
        print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]

# %% [markdown]
# In this case, the fastest lap is 89.525 seconds (1.29.525= so that to obtain the competitve laps the fastest lap will be multiplied by 1.07 95.791 seconds) due to, according to the rules all the drivers have to do unless one lap within this gap.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration <= 95.791")
competitiveLaps

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session
# In this chart we can see the deltas with compared with the fastest lap of the session that it could be different than the pole.

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %% [markdown]
# ### Speed trap

# %% [markdown]
# #### Maximum speed per drivers

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %% [markdown]
# ### Maximum speed per teams

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","st_speed",top_speed)

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])
mergequaly

# %% [markdown]
# In order to know when each session finished, race control dataset will be consulted.

# %%
maximumDateQ1 = "date_start <'2024-09-21T13:25:00+00:00'"
maximumDateQ2 = "date_start <'2024-09-21T13:48:00+00:00' and date_start >'2024-09-21T13:25:00+00:00'"
maximumDateQ3 = "date_start >'2024-09-21T13:48:00+00:00'"

# %% [markdown]
# ### Qualyfing 1

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver,I will do a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P15 = q1Data[14:15]
P15

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)

# %%
q1Data[15::]

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %%
libraryDataF1.draw_gap(P15,15,20,q1Data,drivers,session)

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk
# I bring this section in order to know where the driver at risk lost his chances to improve in the qualyfing.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[0:14].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 2

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %%
# def draw_gap(zeros,driver_at_risk,position_min,position_max,dataset,drivers,session):
#     fastest_lap_session_qualyfing = []
#     name_acronym_reference = []
#     # It is necesary to take the reference of the driver that finished P10 in this session.
#     driver_risk = session.laps.pick_driver(driver_at_risk.name_acronym.to_string(index=False)).query("LapTimeSeconds=="+driver_at_risk.lap_duration.to_string(index=False))
#     fastest_lap_session_qualyfing.append(np.zeros(zeros))
#     name_acronym_reference.append(driver_risk.Driver.to_string(index=False))

#     #Take the reference of the eliminated drivers.
#     for index,row in dataset[position_min:position_max].iterrows():
#         bestlap_qualyfing_driver = session.laps.pick_driver(row.name_acronym).pick_fastest()
#         name_acronym_reference.append(bestlap_qualyfing_driver.Driver)
#         delta_time, ref_tel, compare_tel = utils.delta_time(driver_risk,bestlap_qualyfing_driver)
#         fastest_lap_session_qualyfing.append(delta_time)
#     fig, ax = plt.subplots()
#     count = 0
#     for row in (name_acronym_reference):
#         ax.plot(ref_tel['Distance'], fastest_lap_session_qualyfing[count], '--',label=row,color = "#"+drivers.query("name_acronym=='"+row+"'").team_colour.to_string(index=False) )
#         ax.legend(loc=0)
#         ax.set_title("Delta driver at risk vs drivers knocked-out")
#         count+=1
#     plt.show()

# %%
libraryDataF1.draw_gap(P10,10,15,q2Data,drivers,session)

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[0:9].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the poleman compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2

# %%
libraryDataF1.draw_gap(P1,1,10,q3Data,drivers,session)

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %% [markdown]
# #### Best sector per driver of the session (in general)

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ## Race
# ### Obtain setup

# %%
race = libraryDataF1.obtain_information('laps',session_key=9606)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9606)
drivers = libraryDataF1.obtain_information('drivers',session_key=9606)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)

# %%
raceLaps = race.query("is_pit_out_lap == False")
jointables = pd.merge(raceLaps,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# #### Obtain data tyres

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'HARD',100)

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'MEDIUM',100)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'SOFT',100)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >96 and lap_duration <=100").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Race pace

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >96 and lap_duration <=100").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Mean race pace per sector
# In this section, we can see the pace shown per each team in each sector sorted ascending.

# %% [markdown]
# #### Sector 1

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >96 and lap_duration <=100").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 2

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >96 and lap_duration <=100").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 3

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False and lap_duration >96 and lap_duration <=100").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Comparaison beetween drivers

# %% [markdown]
# #### Red Bull Racing

# %%
race.query("driver_number== 1 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 11 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Ferrari

# %%
race.query("driver_number== 16 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 55 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### McLaren

# %%
race.query("driver_number== 4 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 81 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Mercedes

# %%
race.query("driver_number== 44 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 63 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Aston Martin

# %%
race.query("driver_number== 14 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 18 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Haas F1 Team

# %%
race.query("driver_number== 20 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 27 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### RB

# %%
race.query("driver_number== 3 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 22 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Williams

# %%
race.query("driver_number== 2 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 23 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Alpine

# %%
race.query("driver_number== 10 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 31 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# #### Kick Sauber

# %%
race.query("driver_number== 24 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %%
race.query("driver_number== 77 and lap_duration >96 and lap_duration <=100").lap_duration.mean()

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 96
MAXIMUM_SECONDS = 100

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')

# %%
libraryDataF1.getinfolongruns(jointables,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')

# %%
libraryDataF1.getinfolongruns(jointables,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 14 or driver_number == 18')

# %%
libraryDataF1.getinfolongruns(jointables,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 4 or driver_number == 81')

# %%
libraryDataF1.getinfolongruns(jointables,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas F1 Team

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 23 or driver_number == 43')

# %%
libraryDataF1.getinfolongruns(jointables,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,43,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ### Pits
# Before to finish the analysis, I added the Pits sections where it can see how much time teams spent in the box.

# %%
pit = libraryDataF1.obtain_information('pit',session_key=9606)

# %%
jointables = pd.merge(drivers,pit,on=['driver_number']).query("pit_duration<120")
jointables
pit_duration = pd.DataFrame(jointables.groupby('team_name')['pit_duration'].mean().sort_values(ascending=True))
pit_duration
