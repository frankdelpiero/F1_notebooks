# %%
from urllib.request import urlopen
import json
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
response = urlopen('https://api.openf1.org/v1/sessions?year=2024')
data = json.loads(response.read().decode('utf-8'))
calendar = pd.DataFrame(data)
calendar
# Out:
#    session_key session_name           date_start             date_end  \
# 0         9465   Practice 1  2024-02-29T11:30:00  2024-02-29T12:30:00
# 1         9466   Practice 2  2024-02-29T15:00:00  2024-02-29T16:00:00
# 2         9467   Practice 3  2024-03-01T12:30:00  2024-03-01T13:30:00
# 3         9468   Qualifying  2024-03-01T16:00:00  2024-03-01T17:00:00
# 4         9472         Race  2024-03-02T15:00:00  2024-03-02T17:00:00
# 5         9473   Practice 1  2024-03-07T13:30:00  2024-03-07T14:30:00
# 6         9474   Practice 2  2024-03-07T17:00:00  2024-03-07T18:00:00
# 7         9475   Practice 3  2024-03-08T13:30:00  2024-03-08T14:30:00
# 8         9476   Qualifying  2024-03-08T17:00:00  2024-03-08T18:00:00
# 9         9480         Race  2024-03-09T17:00:00  2024-03-09T19:00:00
#
#   gmt_offset session_type  meeting_key location  country_key country_code  \
# 0   03:00:00     Practice         1229   Sakhir           36          BRN
# 1   03:00:00     Practice         1229   Sakhir           36          BRN
# 2   03:00:00     Practice         1229   Sakhir           36          BRN
# 3   03:00:00   Qualifying         1229   Sakhir           36          BRN
# 4   03:00:00         Race         1229   Sakhir           36          BRN
# 5   03:00:00     Practice         1230   Jeddah          153          KSA
# 6   03:00:00     Practice         1230   Jeddah          153          KSA
# 7   03:00:00     Practice         1230   Jeddah          153          KSA
# 8   03:00:00   Qualifying         1230   Jeddah          153          KSA
# 9   03:00:00         Race         1230   Jeddah          153          KSA
#
#    country_name  circuit_key circuit_short_name  year
# 0       Bahrain           63             Sakhir  2024
# 1       Bahrain           63             Sakhir  2024
# 2       Bahrain           63             Sakhir  2024
# 3       Bahrain           63             Sakhir  2024
# 4       Bahrain           63             Sakhir  2024
# 5  Saudi Arabia          149             Jeddah  2024
# 6  Saudi Arabia          149             Jeddah  2024
# 7  Saudi Arabia          149             Jeddah  2024
# 8  Saudi Arabia          149             Jeddah  2024
# 9  Saudi Arabia          149             Jeddah  2024

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Bahrain
url = 'https://api.openf1.org/v1/sessions?'
year = 'year=2024'
country_code = 'country_code=KSA'

urltotal = url+year+'&'+country_code

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
sessionInformation = pd.DataFrame(data)
sessionInformation
# Out:
#    session_key session_name           date_start             date_end  \
# 0         9473   Practice 1  2024-03-07T13:30:00  2024-03-07T14:30:00
# 1         9474   Practice 2  2024-03-07T17:00:00  2024-03-07T18:00:00
# 2         9475   Practice 3  2024-03-08T13:30:00  2024-03-08T14:30:00
# 3         9476   Qualifying  2024-03-08T17:00:00  2024-03-08T18:00:00
# 4         9480         Race  2024-03-09T17:00:00  2024-03-09T19:00:00
#
#   gmt_offset session_type  meeting_key location  country_key country_code  \
# 0   03:00:00     Practice         1230   Jeddah          153          KSA
# 1   03:00:00     Practice         1230   Jeddah          153          KSA
# 2   03:00:00     Practice         1230   Jeddah          153          KSA
# 3   03:00:00   Qualifying         1230   Jeddah          153          KSA
# 4   03:00:00         Race         1230   Jeddah          153          KSA
#
#    country_name  circuit_key circuit_short_name  year
# 0  Saudi Arabia          149             Jeddah  2024
# 1  Saudi Arabia          149             Jeddah  2024
# 2  Saudi Arabia          149             Jeddah  2024
# 3  Saudi Arabia          149             Jeddah  2024
# 4  Saudi Arabia          149             Jeddah  2024

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Abu Dhabi
url = 'https://api.openf1.org/v1/laps?'
session_key = 'session_key=9473'
year = 'year=2024'
country_code = 'country_code=KSA'

urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
practice1 = pd.DataFrame(data)
practice1
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1230         9473             77     254.0       299       303
# 1           1230         9473             44     269.0       312       163
# 2           1230         9473             24     257.0       292       281
# 3           1230         9473             31     268.0       298       304
# 4           1230         9473             55     252.0       285       290
# ..           ...          ...            ...       ...       ...       ...
# 466         1230         9473              3     280.0       281       281
# 467         1230         9473             11     282.0       282       290
# 468         1230         9473             31     278.0       299       305
# 469         1230         9473              1     154.0       255       292
# 470         1230         9473             10     268.0       299       304
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 0    2024-03-07T13:30:03.436000           NaN            True
# 1    2024-03-07T13:30:08.940000           NaN            True
# 2    2024-03-07T13:30:13.579000           NaN            True
# 3    2024-03-07T13:30:32.994000           NaN            True
# 4    2024-03-07T13:30:34.003000           NaN            True
# ..                          ...           ...             ...
# 466  2024-03-07T14:33:34.517000       145.120           False
# 467  2024-03-07T14:33:37.159000       140.545           False
# 468  2024-03-07T14:33:40.497000       135.350           False
# 469  2024-03-07T14:33:45.284000       161.281           False
# 470  2024-03-07T14:33:50.583000       142.795           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             32.476             31.465
# 1                  NaN             31.893             35.511
# 2                  NaN             32.808             34.776
# 3                  NaN             32.805             31.976
# 4                  NaN             33.911             33.923
# ..                 ...                ...                ...
# 466             72.658             35.230             37.232
# 467             72.203             32.484             35.858
# 468             67.891             31.617             35.842
# 469             79.483             46.798             35.000
# 470             72.085             30.874             39.836
#
#                                      segments_sector_1  \
# 0    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 1    [2064, 2064, 2064, 2049, 2049, 2051, 2049, 204...
# 2    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 3    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 4    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 466  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 467  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 468  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 469  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 470  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 0    [2049, 2051, 2049, 2051, 2049, 2049, 2049]
# 1    [2049, 2049, 2051, 2049, 2051, 2049, 2051]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 466  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 467  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 468  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 469  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 470  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number
# 0    [2049, 2049, 2051, 2051, 2051, 2051, 2049, 204...           1
# 1    [2051, 2049, 2051, 2051, 2051, 2049, 2048, 204...           1
# 2    [2049, 2049, 2049, 2049, 2049, 2051, 2049, 204...           1
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           1
# 4    [2049, 2051, 2049, 2049, 2049, 2049, 2049, 204...           1
# ..                                                 ...         ...
# 466                                                 []          25
# 467                                                 []          23
# 468                                                 []          27
# 469                                                 []          24
# 470                                                 []          25
#
# [471 rows x 16 columns]

# %%
#Stints
url = 'https://api.openf1.org/v1/stints?'
year = 'year=2024'
country_code = 'country_code=KSA'
session_key = 'session_key=9473'

urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
stintInformation = pd.DataFrame(data)
stintInformation
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0          1230         9473             1             31          1        4
# 1          1230         9473             1             18          1        6
# 2          1230         9473             1             27          1        6
# 3          1230         9473             1             11          1        7
# 4          1230         9473             1             20          1        7
# ..          ...          ...           ...            ...        ...      ...
# 69         1230         9473             4             77         20       27
# 70         1230         9473             4             31         20       28
# 71         1230         9473             4             81         21       23
# 72         1230         9473             4              3         23       26
# 73         1230         9473             4              4         24       27
#
#    compound  tyre_age_at_start
# 0    MEDIUM                  0
# 1      HARD                  0
# 2    MEDIUM                  0
# 3      HARD                  0
# 4      HARD                  0
# ..      ...                ...
# 69     SOFT                 11
# 70   MEDIUM                 10
# 71     HARD                  0
# 72   MEDIUM                  0
# 73   MEDIUM                  7
#
# [74 rows x 8 columns]

# %%
# Name of the drivers
url = 'https://api.openf1.org/v1/drivers?'
session_key = 'session_key=9473'
urltotal = url+session_key

response = urlopen(urltotal)
drivers = json.loads(response.read().decode('utf-8'))
drivers = pd.DataFrame(drivers).dropna()
drivers
# Out:
#     session_key  meeting_key broadcast_name country_code first_name  \
# 1          9473         1230   M VERSTAPPEN          NED        Max
# 3          9473         1230     L SARGEANT          USA      Logan
# 5          9473         1230    D RICCIARDO          AUS     Daniel
# 7          9473         1230       L NORRIS          GBR      Lando
# 9          9473         1230        P GASLY          FRA     Pierre
# 11         9473         1230        S PEREZ          MEX     Sergio
# 13         9473         1230       F ALONSO          ESP   Fernando
# 15         9473         1230      C LECLERC          MON    Charles
# 17         9473         1230       L STROLL          CAN      Lance
# 19         9473         1230    K MAGNUSSEN          DEN      Kevin
# 21         9473         1230      Y TSUNODA          JPN       Yuki
# 23         9473         1230        A ALBON          THA  Alexander
# 25         9473         1230         G ZHOU          CHN     Guanyu
# 27         9473         1230   N HULKENBERG          GER       Nico
# 29         9473         1230         E OCON          FRA    Esteban
# 31         9473         1230     L HAMILTON          GBR      Lewis
# 33         9473         1230        C SAINZ          ESP     Carlos
# 35         9473         1230      G RUSSELL          GBR     George
# 37         9473         1230       V BOTTAS          FIN   Valtteri
# 39         9473         1230      O PIASTRI          AUS      Oscar
#
#            full_name                                       headshot_url  \
# 1     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 3     Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 5   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 7       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 9       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 11      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 13   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 15   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 17      Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 19   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 21      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 23   Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 25       ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 27   Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 29      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 31    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 33      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 35    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 37   Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 39     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  driver_number  \
# 1   Verstappen              1
# 3     Sargeant              2
# 5    Ricciardo              3
# 7       Norris              4
# 9        Gasly             10
# 11       Perez             11
# 13      Alonso             14
# 15     Leclerc             16
# 17      Stroll             18
# 19   Magnussen             20
# 21     Tsunoda             22
# 23       Albon             23
# 25        Zhou             24
# 27  Hulkenberg             27
# 29        Ocon             31
# 31    Hamilton             44
# 33       Sainz             55
# 35     Russell             63
# 37      Bottas             77
# 39     Piastri             81
#
#                                           team_colour        team_name  \
# 1                                              3671c6  Red Bull Racing
# 3                                              64c4ff         Williams
# 5                                              6692ff               RB
# 7                                              ff8000          McLaren
# 9                                              ff87bc           Alpine
# 11                                             3671c6  Red Bull Racing
# 13                                             229971     Aston Martin
# 15                                             e8002d          Ferrari
# 17                                             229971     Aston Martin
# 19                                             b6babd     Haas F1 Team
# 21                                             6692ff               RB
# 23                                             64c4ff         Williams
# 25  5200000000000000190003903645130092385429788960...      Kick Sauber
# 27                                             b6babd     Haas F1 Team
# 29                                             ff87bc           Alpine
# 31                                             27f4d2         Mercedes
# 33                                             e8002d          Ferrari
# 35                                             27f4d2         Mercedes
# 37  5200000000000000190003903645130092385429788960...      Kick Sauber
# 39                                             ff8000          McLaren
#
#    name_acronym
# 1           VER
# 3           SAR
# 5           RIC
# 7           NOR
# 9           GAS
# 11          PER
# 13          ALO
# 15          LEC
# 17          STR
# 19          MAG
# 21          TSU
# 23          ALB
# 25          ZHO
# 27          HUL
# 29          OCO
# 31          HAM
# 33          SAI
# 35          RUS
# 37          BOT
# 39          PIA

# %%
stintsDataFrame = pd.DataFrame()
for index,row in stintInformation.iterrows():
    number_driver = row.driver_number
    acronym_driver = drivers.query('driver_number == @number_driver').name_acronym.to_string(index=False)
    full_name = drivers.query('driver_number == @number_driver').full_name.to_string(index=False)
    if row.lap_start != row.lap_end:
        contador = row.lap_start
        while contador <= row.lap_end :
            new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':contador,'name_acronym':acronym_driver,'full_name':full_name}
            #stintsDataFrame=stintsDataFrame.append(new_row, ignore_index=True)
            stintsDataFrame = pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)
            contador+=1
    else:
    
        new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':row.lap_start,'name_acronym':acronym_driver,'full_name':full_name}
        #stintsDataFrame= stintsDataFrame.append(new_row, ignore_index=True)
        stintsDataFrame =pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)

# %%
stintsDataFrame
# Out:
#      driver_number compound  lap_number name_acronym         full_name
# 0               31   MEDIUM           1          OCO      Esteban OCON
# 1               31   MEDIUM           2          OCO      Esteban OCON
# 2               31   MEDIUM           3          OCO      Esteban OCON
# 3               31   MEDIUM           4          OCO      Esteban OCON
# 4               18     HARD           1          STR      Lance STROLL
# ..             ...      ...         ...          ...               ...
# 486              3   MEDIUM          26          RIC  Daniel RICCIARDO
# 487              4   MEDIUM          24          NOR      Lando NORRIS
# 488              4   MEDIUM          25          NOR      Lando NORRIS
# 489              4   MEDIUM          26          NOR      Lando NORRIS
# 490              4   MEDIUM          27          NOR      Lando NORRIS
#
# [491 rows x 5 columns]

# %%
jointables = pd.merge(practice1,stintsDataFrame,on=['lap_number','driver_number'])
jointables
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1230         9473             77     254.0       299       303
# 1           1230         9473             44     269.0       312       163
# 2           1230         9473             24     257.0       292       281
# 3           1230         9473             31     268.0       298       304
# 4           1230         9473             55     252.0       285       290
# ..           ...          ...            ...       ...       ...       ...
# 466         1230         9473              3     280.0       281       281
# 467         1230         9473             11     282.0       282       290
# 468         1230         9473             31     278.0       299       305
# 469         1230         9473              1     154.0       255       292
# 470         1230         9473             10     268.0       299       304
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 0    2024-03-07T13:30:03.436000           NaN            True
# 1    2024-03-07T13:30:08.940000           NaN            True
# 2    2024-03-07T13:30:13.579000           NaN            True
# 3    2024-03-07T13:30:32.994000           NaN            True
# 4    2024-03-07T13:30:34.003000           NaN            True
# ..                          ...           ...             ...
# 466  2024-03-07T14:33:34.517000       145.120           False
# 467  2024-03-07T14:33:37.159000       140.545           False
# 468  2024-03-07T14:33:40.497000       135.350           False
# 469  2024-03-07T14:33:45.284000       161.281           False
# 470  2024-03-07T14:33:50.583000       142.795           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             32.476             31.465
# 1                  NaN             31.893             35.511
# 2                  NaN             32.808             34.776
# 3                  NaN             32.805             31.976
# 4                  NaN             33.911             33.923
# ..                 ...                ...                ...
# 466             72.658             35.230             37.232
# 467             72.203             32.484             35.858
# 468             67.891             31.617             35.842
# 469             79.483             46.798             35.000
# 470             72.085             30.874             39.836
#
#                                      segments_sector_1  \
# 0    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 1    [2064, 2064, 2064, 2049, 2049, 2051, 2049, 204...
# 2    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 3    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 4    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 466  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 467  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 468  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 469  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 470  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 0    [2049, 2051, 2049, 2051, 2049, 2049, 2049]
# 1    [2049, 2049, 2051, 2049, 2051, 2049, 2051]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 466  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 467  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 468  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 469  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 470  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number compound  \
# 0    [2049, 2049, 2051, 2051, 2051, 2051, 2049, 204...           1   MEDIUM
# 1    [2051, 2049, 2051, 2051, 2051, 2049, 2048, 204...           1     HARD
# 2    [2049, 2049, 2049, 2049, 2049, 2051, 2049, 204...           1     HARD
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           1   MEDIUM
# 4    [2049, 2051, 2049, 2049, 2049, 2049, 2049, 204...           1     HARD
# ..                                                 ...         ...      ...
# 466                                                 []          25   MEDIUM
# 467                                                 []          23     SOFT
# 468                                                 []          27   MEDIUM
# 469                                                 []          24     HARD
# 470                                                 []          25   MEDIUM
#
#     name_acronym         full_name
# 0            BOT   Valtteri BOTTAS
# 1            HAM    Lewis HAMILTON
# 2            ZHO       ZHOU Guanyu
# 3            OCO      Esteban OCON
# 4            SAI      Carlos SAINZ
# ..           ...               ...
# 466          RIC  Daniel RICCIARDO
# 467          PER      Sergio PEREZ
# 468          OCO      Esteban OCON
# 469          VER    Max VERSTAPPEN
# 470          GAS      Pierre GASLY
#
# [471 rows x 19 columns]

# %%
jointables.query("is_pit_out_lap == False").describe()
# Out:
#        meeting_key  session_key  driver_number    i1_speed    i2_speed  \
# count        397.0        397.0     397.000000  383.000000  397.000000
# mean        1230.0       9473.0      26.581864  249.031332  275.899244
# std            0.0          0.0      23.829603   51.379239   57.393995
# min         1230.0       9473.0       1.000000   84.000000   73.000000
# 25%         1230.0       9473.0      10.000000  220.500000  245.000000
# 50%         1230.0       9473.0      20.000000  279.000000  301.000000
# 75%         1230.0       9473.0      31.000000  284.000000  318.000000
# max         1230.0       9473.0      81.000000  290.000000  332.000000
#
#          st_speed  lap_duration  duration_sector_1  duration_sector_2  \
# count  397.000000    397.000000         397.000000         397.000000
# mean   285.894207    110.909295          41.810579          34.805247
# std     53.332991     22.574244          11.081109           7.913572
# min     84.000000     89.659000          32.615000          28.387000
# 25%    273.000000     93.072000          33.851000          29.210000
# 50%    304.000000     96.089000          35.202000          30.105000
# 75%    322.000000    128.556000          48.998000          38.938000
# max    339.000000    179.773000          83.769000          65.585000
#
#        duration_sector_3  lap_number
# count         397.000000  397.000000
# mean           34.293469   12.921914
# std             6.529892    7.012719
# min            28.524000    2.000000
# 25%            29.543000    7.000000
# 50%            30.553000   13.000000
# 75%            37.003000   19.000000
# max            61.507000   27.000000

# %%
mediumTyres = jointables.query('compound == "MEDIUM" and lap_duration >1 and lap_duration < 100')

# %%
mediumTyres
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 16          1230         9473             77     280.0       319       324
# 20          1230         9473             10     280.0       319       322
# 21          1230         9473             31     278.0       317       321
# 22          1230         9473             27     280.0       320       326
# 23          1230         9473             23     282.0       326       331
# 28          1230         9473              4     283.0       323       323
# 29          1230         9473             77     274.0       310       316
# 48          1230         9473             77     278.0       310       316
# 59          1230         9473             10     282.0       317       322
# 64          1230         9473             23     283.0       318       323
# 67          1230         9473             27     283.0       324       330
# 74          1230         9473              4     284.0       319       320
# 84          1230         9473             77     286.0       324       326
# 87          1230         9473             31     281.0       319       324
# 105         1230         9473             23     284.0       320       322
# 112         1230         9473              4     283.0       314       317
# 119         1230         9473             10     284.0       319       323
# 122         1230         9473             31     281.0       319       323
# 137         1230         9473             23     284.0       314       319
# 150         1230         9473             31     283.0       317       324
# 186         1230         9473             27     283.0       324       328
# 219         1230         9473             20     283.0       327       330
# 229         1230         9473             27     283.0       323       328
# 258         1230         9473             20     282.0       325       328
# 275         1230         9473              3     287.0       327       331
# 292         1230         9473             22     286.0       324       329
# 318         1230         9473             22     286.0       325       329
# 332         1230         9473             23     281.0       304       304
# 336         1230         9473             31     267.0       291       296
# 338         1230         9473             10     267.0       291       296
# 340         1230         9473              3     286.0       326       330
# 342         1230         9473             27     279.0       305       310
# 343         1230         9473             23       NaN       300       303
# 352         1230         9473             31     279.0       295       297
# 354         1230         9473             10     278.0       294       298
# 358         1230         9473             27     276.0       301       304
# 359         1230         9473             23     282.0       302       304
# 364         1230         9473             20     277.0       301       304
# 371         1230         9473             31     271.0       295       298
# 374         1230         9473             10       NaN       295       298
# 377         1230         9473             27     279.0       304       309
# 378         1230         9473             23     283.0       302       301
# 382         1230         9473             20     275.0       300       304
# 390         1230         9473             31     277.0       298       301
# 393         1230         9473             10     279.0       298       299
# 396         1230         9473             22     287.0       324       331
# 397         1230         9473             27     278.0       303       306
# 398         1230         9473             23       NaN       307       272
# 401         1230         9473             20     278.0       302       305
# 410         1230         9473             31     275.0       299       303
# 413         1230         9473             10       NaN       297       316
# 416         1230         9473             27     276.0       314       320
# 417         1230         9473             23       NaN       303       301
# 421         1230         9473             20     275.0       301       319
# 424         1230         9473              4     281.0       304       304
# 428         1230         9473             31     272.0       298       303
# 430         1230         9473              3     287.0       308       314
# 432         1230         9473             10     273.0       296       301
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 16   2024-03-07T13:31:48.172000        93.989           False
# 20   2024-03-07T13:32:29.329000        93.373           False
# 21   2024-03-07T13:32:35.453000        94.055           False
# 22   2024-03-07T13:32:41.761000        94.037           False
# 23   2024-03-07T13:32:45.995000        94.021           False
# 28   2024-03-07T13:33:19.622000        92.860           False
# 29   2024-03-07T13:33:22.162000        93.860           False
# 48   2024-03-07T13:34:55.978000        93.461           False
# 59   2024-03-07T13:36:05.973000        92.230           False
# 64   2024-03-07T13:36:27.674000        92.395           False
# 67   2024-03-07T13:36:41.064000        92.800           False
# 74   2024-03-07T13:37:11.268000        91.804           False
# 84   2024-03-07T13:38:23.063000        92.290           False
# 87   2024-03-07T13:38:35.059000        92.442           False
# 105  2024-03-07T13:40:17.269000        91.941           False
# 112  2024-03-07T13:41:08.293000        91.617           False
# 119  2024-03-07T13:41:55.680000        91.362           False
# 122  2024-03-07T13:42:30.707000        91.666           False
# 137  2024-03-07T13:44:04.626000        91.585           False
# 150  2024-03-07T13:46:22.383000        91.513           False
# 186  2024-03-07T13:57:58.928000        92.162           False
# 219  2024-03-07T14:02:51.819000        91.577           False
# 229  2024-03-07T14:04:10.500000        91.411           False
# 258  2024-03-07T14:07:15.120000        91.775           False
# 275  2024-03-07T14:09:39.064000        91.787           False
# 292  2024-03-07T14:12:09.665000        91.295           False
# 318  2024-03-07T14:18:31.341000        91.036           False
# 332  2024-03-07T14:20:46.676000        94.856           False
# 336  2024-03-07T14:21:44.095000        96.089           False
# 338  2024-03-07T14:21:58.347000        96.802           False
# 340  2024-03-07T14:22:09.213000        90.917           False
# 342  2024-03-07T14:22:16.612000        95.609           False
# 343  2024-03-07T14:22:21.412000        94.686           False
# 352  2024-03-07T14:23:20.166000        95.751           False
# 354  2024-03-07T14:23:35.204000        95.893           False
# 358  2024-03-07T14:23:52.322000        96.220           False
# 359  2024-03-07T14:23:56.189000        95.120           False
# 364  2024-03-07T14:24:17.604000        95.581           False
# 371  2024-03-07T14:24:57.007000        96.889           False
# 374  2024-03-07T14:25:10.980000        96.439           False
# 377  2024-03-07T14:25:28.631000        95.771           False
# 378  2024-03-07T14:25:31.404000        94.981           False
# 382  2024-03-07T14:25:53.331000        95.330           False
# 390  2024-03-07T14:26:32.923000        96.340           False
# 393  2024-03-07T14:26:47.445000        96.097           False
# 396  2024-03-07T14:27:03.283000        91.320           False
# 397  2024-03-07T14:27:04.225000        95.707           False
# 398  2024-03-07T14:27:06.269000        98.862           False
# 401  2024-03-07T14:27:28.542000        95.105           False
# 410  2024-03-07T14:28:09.145000        95.986           False
# 413  2024-03-07T14:28:23.626000        95.532           False
# 416  2024-03-07T14:28:39.981000        94.757           False
# 417  2024-03-07T14:28:45.091000        94.501           False
# 421  2024-03-07T14:29:03.954000        94.332           False
# 424  2024-03-07T14:29:22.749000        93.402           False
# 428  2024-03-07T14:29:45.127000        96.427           False
# 430  2024-03-07T14:29:52.494000        94.233           False
# 432  2024-03-07T14:29:59.968000        95.908           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 16              34.664             29.642             29.683
# 20              34.362             29.448             29.563
# 21              34.719             29.671             29.665
# 22              35.051             29.465             29.521
# 23              34.547             29.752             29.722
# 28              34.011             29.289             29.560
# 29              34.489             29.679             29.692
# 48              34.300             29.541             29.620
# 59              33.760             29.079             29.391
# 64              33.861             29.190             29.344
# 67              33.861             29.448             29.491
# 74              33.170             29.143             29.491
# 84              33.661             29.086             29.543
# 87              33.633             29.361             29.448
# 105             33.511             29.122             29.308
# 112             33.201             29.052             29.364
# 119             33.151             28.985             29.226
# 122             33.462             29.104             29.100
# 137             33.431             29.066             29.088
# 150             33.350             29.107             29.056
# 186             33.684             29.072             29.406
# 219             33.416             28.880             29.281
# 229             33.415             28.786             29.210
# 258             33.752             28.940             29.083
# 275             33.500             28.998             29.289
# 292             33.299             28.904             29.092
# 318             33.250             28.862             28.924
# 332             34.919             29.858             30.079
# 336             35.246             30.287             30.556
# 338             35.586             30.663             30.553
# 340             33.045             28.887             28.985
# 342             35.248             30.009             30.352
# 343             34.784             29.821             30.081
# 352             35.026             30.185             30.540
# 354             35.266             30.095             30.532
# 358             35.738             30.145             30.337
# 359             35.013             29.821             30.286
# 364             35.360             30.054             30.167
# 371             35.194             30.475             31.220
# 374             35.310             30.477             30.652
# 377             35.245             30.097             30.429
# 378             34.877             29.822             30.282
# 382             34.994             30.112             30.224
# 390             35.438             30.456             30.446
# 393             35.243             30.241             30.613
# 396             33.267             28.933             29.120
# 397             35.418             30.064             30.225
# 398             34.939             29.841             34.082
# 401             34.844             30.020             30.241
# 410             35.247             30.303             30.436
# 413             35.229             30.166             30.137
# 416             34.983             29.902             29.872
# 417             34.434             29.848             30.219
# 421             34.504             29.932             29.896
# 424             34.028             29.587             29.787
# 428             35.555             30.326             30.546
# 430             34.602             29.756             29.875
# 432             34.999             30.345             30.564
#
#                                      segments_sector_1  \
# 16   [2049, 2049, 2049, 2051, 2049, 2049, 2049, 204...
# 20   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 21   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 22   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 23   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 28   [2049, 2049, 2049, 2049, 2049, 2051, 2049, 205...
# 29   [None, 2048, 2049, 2051, 2049, 2049, 2049, 204...
# 48   [2048, 2049, 2048, 2048, 2048, 2049, 2049, 204...
# 59   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 64   [2049, 2051, 2049, 2048, 2049, 2049, 2049, 204...
# 67   [2049, 2049, 2049, 2051, 2049, 2049, 2049, 204...
# 74   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 205...
# 84   [None, 2049, 2049, 2048, 2049, 2049, 2049, 204...
# 87   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 105  [None, 2048, 2049, 2049, 2049, 2049, 2049, 204...
# 112  [None, 2048, 2048, 2049, 2048, 2051, 2048, 204...
# 119  [2048, 2048, 2049, 2051, 2049, 2049, 2049, 204...
# 122  [None, 2049, 2048, 2048, 2049, 2049, 2049, 204...
# 137  [None, 2048, 2048, 2049, 2049, 2049, 2048, 204...
# 150  [None, 2048, 2049, 2048, 2049, 2048, 2048, 204...
# 186  [2048, 2048, 2049, 2048, 2048, 2049, 2049, 204...
# 219  [2048, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 229  [2049, 2049, 2049, 2048, 2049, 2049, 2049, 204...
# 258  [None, 2048, 2048, 2048, 2048, 2048, 2049, 204...
# 275  [2048, 2049, 2049, 2048, 2049, 2048, 2048, 204...
# 292  [None, 2049, 2048, 2049, 2049, 2049, 2048, 204...
# 318  [None, 2048, 2048, 2049, 2049, 2049, 2049, 204...
# 332  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 336  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 338  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 340  [2048, 2048, 2048, 2049, 2049, 2049, 2049, 204...
# 342  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 343  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 352  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 354  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 358  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 359  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 364  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 371  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 374  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 377  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 378  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 382  [None, 2048, 2048, 2049, 2048, 2048, 2048, 204...
# 390  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 393  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 396  [None, 2049, 2048, 2048, 2048, 2048, 2048, 204...
# 397  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 398  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 401  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 410  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 413  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 416  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 417  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 421  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 424  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 428  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 430  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 432  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 16   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 20   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 21   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 22   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 23   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 28   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 29   [2048, 2049, 2048, 2049, 2049, 2049, 2048]
# 48   [2048, 2049, 2048, 2049, 2048, 2049, 2048]
# 59   [2049, 2049, 2049, 2049, 2049, 2049, 2048]
# 64   [2049, 2049, 2049, 2049, 2049, 2048, 2048]
# 67   [2049, 2049, 2049, 2049, 2048, 2048, 2048]
# 74   [2049, 2049, 2048, 2049, 2049, 2049, 2048]
# 84   [2049, 2049, 2049, 2049, 2048, 2049, 2049]
# 87   [2049, 2049, 2049, 2049, 2049, 2048, 2049]
# 105  [2049, 2049, 2048, 2048, 2048, 2049, 2048]
# 112  [2048, 2049, 2048, 2049, 2049, 2048, 2048]
# 119  [2048, 2049, 2048, 2049, 2048, 2048, 2048]
# 122  [2048, 2049, 2049, 2049, 2049, 2049, 2048]
# 137  [2048, 2049, 2048, 2048, 2049, 2049, 2048]
# 150  [2049, 2049, 2049, 2048, 2048, 2048, 2048]
# 186  [2048, 2049, 2048, 2049, 2048, 2048, 2048]
# 219  [2048, 2049, 2048, 2049, 2049, 2049, 2048]
# 229  [2049, 2049, 2048, 2049, 2049, 2048, 2048]
# 258  [2048, 2048, 2048, 2048, 2049, 2048, 2048]
# 275  [2049, 2048, 2048, 2048, 2048, 2048, 2048]
# 292  [2048, 2049, 2048, 2049, 2049, 2048, 2048]
# 318  [2048, 2048, 2049, 2049, 2049, 2049, 2048]
# 332  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 336  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 338  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 340  [2048, 2049, 2048, 2048, 2048, 2048, 2048]
# 342  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 343  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 352  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 354  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 358  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 359  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 364  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 371  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 374  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 377  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 378  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 382  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 390  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 393  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 396  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 397  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 398  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 401  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 410  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 413  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 416  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 417  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 421  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 424  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 428  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 430  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 432  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number compound  \
# 16   [2048, 2049, 2049, 2048, 2048, 2049, 2049, 204...           2   MEDIUM
# 20   [2048, 2048, 2048, 2048, 2048, 2049, 2049, 204...           2   MEDIUM
# 21   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2   MEDIUM
# 22   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2   MEDIUM
# 23   [2048, 2048, 2048, 2048, 2048, 2048, 2049, 204...           2   MEDIUM
# 28   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2   MEDIUM
# 29   [2049, 2049, 2049, 2048, 2048, 2048, 2048, 204...           3   MEDIUM
# 48   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           4   MEDIUM
# 59   [2048, 2048, 2048, 2048, 2048, 2049, 2048, 204...           4   MEDIUM
# 64   [2048, 2048, 2048, 2048, 2048, 2048, 2049, 204...           4   MEDIUM
# 67   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           4   MEDIUM
# 74   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           4   MEDIUM
# 84   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           6   MEDIUM
# 87   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           5   MEDIUM
# 105  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           6   MEDIUM
# 112  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           6   MEDIUM
# 119  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           7   MEDIUM
# 122  [2048, 2048, 2048, 2048, 2048, 2048, 2049, 204...           7   MEDIUM
# 137  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           8   MEDIUM
# 150  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           9   MEDIUM
# 186  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           7   MEDIUM
# 219  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           8   MEDIUM
# 229  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          10   MEDIUM
# 258  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          10   MEDIUM
# 275  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          14   MEDIUM
# 292  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          15   MEDIUM
# 318  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          18   MEDIUM
# 332  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          19   MEDIUM
# 336  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          20   MEDIUM
# 338  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          18   MEDIUM
# 340  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          19   MEDIUM
# 342  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          13   MEDIUM
# 343  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          20   MEDIUM
# 352  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          21   MEDIUM
# 354  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          19   MEDIUM
# 358  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          14   MEDIUM
# 359  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          21   MEDIUM
# 364  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          13   MEDIUM
# 371  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22   MEDIUM
# 374  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          20   MEDIUM
# 377  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          15   MEDIUM
# 378  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22   MEDIUM
# 382  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          14   MEDIUM
# 390  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          23   MEDIUM
# 393  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          21   MEDIUM
# 396  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22   MEDIUM
# 397  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          16   MEDIUM
# 398  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          23   MEDIUM
# 401  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          15   MEDIUM
# 410  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          24   MEDIUM
# 413  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22   MEDIUM
# 416  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          17   MEDIUM
# 417  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          24   MEDIUM
# 421  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          16   MEDIUM
# 424  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          24   MEDIUM
# 428  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          25   MEDIUM
# 430  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          23   MEDIUM
# 432  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          23   MEDIUM
#
#     name_acronym         full_name
# 16           BOT   Valtteri BOTTAS
# 20           GAS      Pierre GASLY
# 21           OCO      Esteban OCON
# 22           HUL   Nico HULKENBERG
# 23           ALB   Alexander ALBON
# 28           NOR      Lando NORRIS
# 29           BOT   Valtteri BOTTAS
# 48           BOT   Valtteri BOTTAS
# 59           GAS      Pierre GASLY
# 64           ALB   Alexander ALBON
# 67           HUL   Nico HULKENBERG
# 74           NOR      Lando NORRIS
# 84           BOT   Valtteri BOTTAS
# 87           OCO      Esteban OCON
# 105          ALB   Alexander ALBON
# 112          NOR      Lando NORRIS
# 119          GAS      Pierre GASLY
# 122          OCO      Esteban OCON
# 137          ALB   Alexander ALBON
# 150          OCO      Esteban OCON
# 186          HUL   Nico HULKENBERG
# 219          MAG   Kevin MAGNUSSEN
# 229          HUL   Nico HULKENBERG
# 258          MAG   Kevin MAGNUSSEN
# 275          RIC  Daniel RICCIARDO
# 292          TSU      Yuki TSUNODA
# 318          TSU      Yuki TSUNODA
# 332          ALB   Alexander ALBON
# 336          OCO      Esteban OCON
# 338          GAS      Pierre GASLY
# 340          RIC  Daniel RICCIARDO
# 342          HUL   Nico HULKENBERG
# 343          ALB   Alexander ALBON
# 352          OCO      Esteban OCON
# 354          GAS      Pierre GASLY
# 358          HUL   Nico HULKENBERG
# 359          ALB   Alexander ALBON
# 364          MAG   Kevin MAGNUSSEN
# 371          OCO      Esteban OCON
# 374          GAS      Pierre GASLY
# 377          HUL   Nico HULKENBERG
# 378          ALB   Alexander ALBON
# 382          MAG   Kevin MAGNUSSEN
# 390          OCO      Esteban OCON
# 393          GAS      Pierre GASLY
# 396          TSU      Yuki TSUNODA
# 397          HUL   Nico HULKENBERG
# 398          ALB   Alexander ALBON
# 401          MAG   Kevin MAGNUSSEN
# 410          OCO      Esteban OCON
# 413          GAS      Pierre GASLY
# 416          HUL   Nico HULKENBERG
# 417          ALB   Alexander ALBON
# 421          MAG   Kevin MAGNUSSEN
# 424          NOR      Lando NORRIS
# 428          OCO      Esteban OCON
# 430          RIC  Daniel RICCIARDO
# 432          GAS      Pierre GASLY

# %%
drivers_number = []
medium_dict = {}
for index,row in mediumTyres.iterrows():
    if row.driver_number not in drivers_number:
        medium_dict[row.driver_number] = []
        drivers_number.append(row.driver_number)

    medium_dict[row.driver_number].append(row)

arrayDataframes = []
for valor in medium_dict.values():
    arrayDataframes.append(pd.DataFrame(valor))

# %%
from matplotlib import pyplot as plt
print(len(arrayDataframes))
figure, axis = plt.subplots(len(arrayDataframes),figsize=(20,30))
i=0
for arr in arrayDataframes:
    arr.reset_index(drop=True, inplace=True)
    axis[(i)].plot( arr.lap_duration,marker ="o",color="yellow",label = str(arr.full_name[0])+" with medium tyres" )
    axis[i].set_xlabel("Lap time")
    axis[i].set_ylabel("Lap Time Seconds")
    axis[i].legend()
    i = i+1
# Out:
# 9

# %%
hardTyres = jointables.query('compound == "HARD" and lap_duration <100  and lap_duration >1 and is_pit_out_lap == False')
hardTyres
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 17          1230         9473             24     280.0       317       308
# 18          1230         9473             44     287.0       330       334
# 19          1230         9473             55     278.0       312       317
# 24          1230         9473             81     281.0       319       322
# 25          1230         9473             14     281.0       301       304
# ..           ...          ...            ...       ...       ...       ...
# 419         1230         9473             63     284.0       321       325
# 422         1230         9473              2     282.0       311       304
# 425         1230         9473             55     285.0       305       311
# 426         1230         9473             16     283.0       301       312
# 429         1230         9473              1       NaN       306       310
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 17   2024-03-07T13:32:03.946000        95.510           False
# 18   2024-03-07T13:32:08.593000        92.590           False
# 19   2024-03-07T13:32:25.970000        94.826           False
# 24   2024-03-07T13:32:53.048000        93.630           False
# 25   2024-03-07T13:33:00.606000        94.181           False
# ..                          ...           ...             ...
# 419  2024-03-07T14:28:55.103000        94.512           False
# 422  2024-03-07T14:29:12.517000        95.170           False
# 425  2024-03-07T14:29:25.115000        94.132           False
# 426  2024-03-07T14:29:35.060000        94.086           False
# 429  2024-03-07T14:29:48.866000        94.111           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 17              35.872             29.625             30.013
# 18              34.024             28.925             29.641
# 19              34.923             30.081             29.822
# 24              34.429             29.531             29.670
# 25              34.691             29.588             29.902
# ..                 ...                ...                ...
# 419             34.706             29.849             29.957
# 422             35.138             29.806             30.226
# 425             34.647             29.697             29.788
# 426             34.155             29.571             30.360
# 429             34.530             29.683             29.898
#
#                                      segments_sector_1  \
# 17   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 18   [2049, 2051, 2049, 2049, 2051, 2049, 2049, 204...
# 19   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 24   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 25   [2049, 2049, 2049, 2049, 2049, 2049, 2051, 204...
# ..                                                 ...
# 419  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 422  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 425  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 426  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 429  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 17   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 18   [2051, 2049, 2051, 2051, 2051, 2051, 2051]
# 19   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 24   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 25   [2049, 2049, 2049, 2049, 2051, 2049, 2049]
# ..                                          ...
# 419  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 422  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 425  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 426  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 429  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number compound  \
# 17   [2049, 2049, 2049, 2049, 2049, 2048, 2048, 204...           2     HARD
# 18   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2     HARD
# 19   [2049, 2051, 2049, 2049, 2049, 2048, 2049, 204...           2     HARD
# 24   [2049, 2049, 2049, 2049, 2049, 2048, 2048, 204...           2     HARD
# 25   [2049, 2049, 2049, 2049, 2049, 2048, 2048, 204...           2     HARD
# ..                                                 ...         ...      ...
# 419  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          21     HARD
# 422  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          25     HARD
# 425  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22     HARD
# 426  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22     HARD
# 429  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22     HARD
#
#     name_acronym        full_name
# 17           ZHO      ZHOU Guanyu
# 18           HAM   Lewis HAMILTON
# 19           SAI     Carlos SAINZ
# 24           PIA    Oscar PIASTRI
# 25           ALO  Fernando ALONSO
# ..           ...              ...
# 419          RUS   George RUSSELL
# 422          SAR   Logan SARGEANT
# 425          SAI     Carlos SAINZ
# 426          LEC  Charles LECLERC
# 429          VER   Max VERSTAPPEN
#
# [90 rows x 19 columns]

# %%
softTyres = jointables.query('compound == "SOFT" and lap_duration <100  and lap_duration >1 and is_pit_out_lap == False')
softTyres
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 176         1230         9473             77     281.0       322       325
# 181         1230         9473              4     284.0       318       326
# 184         1230         9473             23     286.0       319       326
# 187         1230         9473             77     283.0       322       326
# 191         1230         9473              2     284.0       321       325
# ..           ...          ...            ...       ...       ...       ...
# 408         1230         9473             18     276.0       307       316
# 412         1230         9473             11     283.0       314       312
# 418         1230         9473             77     280.0       303       307
# 423         1230         9473             24     280.0       298       305
# 431         1230         9473             11       NaN       310       309
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 176  2024-03-07T13:54:37.871000        91.475           False
# 181  2024-03-07T13:56:15.670000        90.424           False
# 184  2024-03-07T13:57:12.395000        90.747           False
# 187  2024-03-07T13:58:17.453000        91.321           False
# 191  2024-03-07T13:58:47.406000        91.435           False
# ..                          ...           ...             ...
# 408  2024-03-07T14:28:02.826000        94.617           False
# 412  2024-03-07T14:28:20.258000        94.893           False
# 418  2024-03-07T14:28:49.053000        95.581           False
# 423  2024-03-07T14:29:18.933000        95.472           False
# 431  2024-03-07T14:29:55.233000        94.796           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 176             33.593             28.890             28.992
# 181             32.697             28.782             28.945
# 184             33.056             28.760             28.931
# 187             33.368             28.832             29.121
# 191             33.397             29.009             29.029
# ..                 ...                ...                ...
# 408             34.621             30.081             29.915
# 412             35.195             29.899             29.799
# 418             35.191             30.044             30.346
# 423             35.097             30.025             30.350
# 431             34.932             29.893             29.971
#
#                                      segments_sector_1  \
# 176  [2048, 2048, 2049, 2049, 2049, 2049, 2049, 204...
# 181  [2048, 2048, 2049, 2051, 2049, 2051, 2049, 205...
# 184  [2048, 2048, 2048, 2049, 2049, 2049, 2049, 204...
# 187  [None, 2048, 2049, 2051, 2049, 2049, 2048, 204...
# 191  [2048, 2048, 2048, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 408  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 412  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 418  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 423  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 431  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 176  [2048, 2049, 2049, 2049, 2048, 2048, 2048]
# 181  [2049, 2049, 2049, 2049, 2048, 2048, 2048]
# 184  [2049, 2049, 2049, 2049, 2048, 2048, 2048]
# 187  [2048, 2049, 2048, 2049, 2049, 2048, 2048]
# 191  [2049, 2049, 2048, 2048, 2049, 2049, 2048]
# ..                                          ...
# 408  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 412  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 418  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 423  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 431  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number compound  \
# 176  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           9     SOFT
# 181  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           9     SOFT
# 184  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          11     SOFT
# 187  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          11     SOFT
# 191  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          11     SOFT
# ..                                                 ...         ...      ...
# 408  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          15     SOFT
# 412  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          20     SOFT
# 418  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          24     SOFT
# 423  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22     SOFT
# 431  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          21     SOFT
#
#     name_acronym        full_name
# 176          BOT  Valtteri BOTTAS
# 181          NOR     Lando NORRIS
# 184          ALB  Alexander ALBON
# 187          BOT  Valtteri BOTTAS
# 191          SAR   Logan SARGEANT
# ..           ...              ...
# 408          STR     Lance STROLL
# 412          PER     Sergio PEREZ
# 418          BOT  Valtteri BOTTAS
# 423          ZHO      ZHOU Guanyu
# 431          PER     Sergio PEREZ
#
# [69 rows x 19 columns]

# %%
drivers_number = []
soft_dict = {}
for index,row in softTyres.iterrows():
    if row.driver_number not in drivers_number:
        soft_dict[row.driver_number] = []
        drivers_number.append(row.driver_number)

    soft_dict[row.driver_number].append(row)

arrayDataframes = []
for valor in soft_dict.values():
    arrayDataframes.append(pd.DataFrame(valor))


from matplotlib import pyplot as plt
figure, axis = plt.subplots(len(arrayDataframes),figsize=(20,30))
i=0
for arr in arrayDataframes:
    arr.reset_index(drop=True, inplace=True)
    axis[(i)].plot( arr.lap_duration,marker ="o",color="red",label = str(arr.full_name[0])+" with soft tyres" )
    axis[i].set_xlabel("Lap time")
    axis[i].set_ylabel("Lap Time Seconds")
    axis[i].legend()
    i = i+1

# %%
def obtain_fastest_lap(driver,dataset,newdataset):
    fastest_lap = dataset.query("driver_number == @driver").lap_duration.min()
    team_name = dataset.query("driver_number == @driver").head(1).team_name.to_string(index=False)
    team_colour = dataset.query("driver_number == @driver").head(1).team_colour.to_string(index=False)
    name_acronym = dataset.query('driver_number == @driver').head(1).name_acronym.to_string(index=False)
    new_row = {'driver_number':driver,'fastest_lap':fastest_lap,'name_acronym': name_acronym, 'team_name':team_name,'team_colour':team_colour}
    newdataset =pd.concat([newdataset, pd.DataFrame([new_row])], ignore_index=True)
    return newdataset

# %%
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =obtain_fastest_lap(driver,practice1Cleaned,newdataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [39], line 2
#       1 newdataset = pd.DataFrame()
# ----> 2 for driver in drivers_list:
#       3     newdataset =obtain_fastest_lap(driver,practice1Cleaned,newdataset)
#
# NameError: name 'drivers_list' is not defined

# %% [markdown]
# ### Practice 2

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Bahrain
url = 'https://api.openf1.org/v1/laps?'
session_key = 'session_key=9474'
year = 'year=2024'
country_code = 'country_code=KSA'

urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
practice2 = pd.DataFrame(data)
practice2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1230         9474             81     263.0       276       301
# 1           1230         9474             24     260.0       296       281
# 2           1230         9474             23     277.0       301       307
# 3           1230         9474             10     265.0       311       301
# 4           1230         9474             77     262.0       304       274
# ..           ...          ...            ...       ...       ...       ...
# 523         1230         9474             55     272.0       189       192
# 524         1230         9474             24     278.0       240       292
# 525         1230         9474             10     278.0       293       287
# 526         1230         9474             77     278.0       175       255
# 527         1230         9474             11     282.0       296       287
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 0    2024-03-07T17:10:04.921000           NaN            True
# 1    2024-03-07T17:10:08.853000           NaN            True
# 2    2024-03-07T17:10:19.017000           NaN            True
# 3    2024-03-07T17:10:21.692000           NaN            True
# 4    2024-03-07T17:10:23.737000           NaN            True
# ..                          ...           ...             ...
# 523  2024-03-07T18:13:29.095000       150.715           False
# 524  2024-03-07T18:13:31.967000       142.413           False
# 525  2024-03-07T18:13:43.173000       135.051           False
# 526  2024-03-07T18:13:52.681000       147.359           False
# 527  2024-03-07T18:14:09.059000       134.590           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             31.941             33.236
# 1                  NaN             31.963             33.384
# 2                  NaN             32.360             32.386
# 3                  NaN             31.889             32.744
# 4                  NaN             31.797             36.830
# ..                 ...                ...                ...
# 523             64.683             41.182             44.850
# 524             63.306             41.211             37.896
# 525             65.155             30.520             39.376
# 526             58.387             41.820             47.152
# 527             70.567             29.912             34.111
#
#                                      segments_sector_1  \
# 0    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 1    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 2    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 3    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 4    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 523  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 524  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 525  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 526  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 527  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2049, 2049, 2049, 2049, 2049, 2051, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 523  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 524  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 525  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 526  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 527  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number
# 0    [2049, 2049, 2051, 2049, 2051, 2051, 2048, 204...           1
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           1
# 2    [2049, 2049, 2049, 2051, 2049, 2049, 2048, 204...           1
# 3    [2048, 2048, 2048, 2049, 2049, 2048, 2048, 204...           1
# 4    [2049, 2048, 2048, 2049, 2049, 2049, 2049, 204...           1
# ..                                                 ...         ...
# 523                                                 []          26
# 524                                                 []          27
# 525                                                 []          29
# 526                                                 []          27
# 527                                                 []          27
#
# [528 rows x 16 columns]

# %%
#Stints
url = 'https://api.openf1.org/v1/stints?'


urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
print(data)
stintInformation = pd.DataFrame(data)
# Out:
# [{'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 63, 'lap_start': 1, 'lap_end': 3, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 1, 'lap_start': 1, 'lap_end': 4, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 11, 'lap_start': 1, 'lap_end': 4, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 81, 'lap_start': 1, 'lap_end': 5, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 4, 'lap_start': 1, 'lap_end': 6, 'compound': 'HARD', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 20, 'lap_start': 1, 'lap_end': 6, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 77, 'lap_start': 1, 'lap_end': 7, 'compound': 'HARD', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 2, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 14, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 16, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 18, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 23, 'lap_start': 1, 'lap_end': 8, 'compound': 'HARD', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 24, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 31, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 55, 'lap_start': 1, 'lap_end': 8, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 10, 'lap_start': 1, 'lap_end': 9, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 22, 'lap_start': 1, 'lap_end': 9, 'compound': 'SOFT', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 27, 'lap_start': 1, 'lap_end': 9, 'compound': 'HARD', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 44, 'lap_start': 1, 'lap_end': 9, 'compound': 'MEDIUM', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 1, 'driver_number': 3, 'lap_start': 1, 'lap_end': 11, 'compound': 'SOFT', 'tyre_age_at_start': 0}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 2, 'driver_number': 63, 'lap_start': 4, 'lap_end': 9, 'compound': 'MEDIUM', 'tyre_age_at_start': 2}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 2, 'driver_number': 11, 'lap_start': 5, 'lap_end': 7, 'compound': 'MEDIUM', 'tyre_age_at_start': 3}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 2, 'driver_number': 1, 'lap_start': 5, 'lap_end': 9, 'compound': 'MEDIUM', 'tyre_age_at_start': 3}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 2, 'driver_number': 81, 'lap_start': 6, 'lap_end': 9, 'compound': 'MEDIUM', 'tyre_age_at_start': 4}, {'meeting_key': 1230, 'session_key': 9474, 'stint_number': 2, 'driver_number': 4, 'lap_start': 7, 'lap_end': 9, 'compound': 'SOFT', 'tyre_age_at_start': 0}, {'meeting_key': 12 ...

# %%
# Name of the drivers
# Currently, I am using F1 2023 data because F1 2024 does not include the colours and the team name
url = 'https://api.openf1.org/v1/drivers?'

urltotal = url+session_key

response = urlopen(urltotal)
drivers = json.loads(response.read().decode('utf-8'))
drivers = pd.DataFrame(drivers).dropna()
drivers
# Out:
#     session_key  meeting_key broadcast_name country_code first_name  \
# 0          9474         1230   M VERSTAPPEN          NED        Max
# 1          9474         1230     L SARGEANT          USA      Logan
# 2          9474         1230    D RICCIARDO          AUS     Daniel
# 3          9474         1230       L NORRIS          GBR      Lando
# 4          9474         1230        P GASLY          FRA     Pierre
# 5          9474         1230        S PEREZ          MEX     Sergio
# 6          9474         1230       F ALONSO          ESP   Fernando
# 7          9474         1230      C LECLERC          MON    Charles
# 8          9474         1230       L STROLL          CAN      Lance
# 9          9474         1230    K MAGNUSSEN          DEN      Kevin
# 10         9474         1230      Y TSUNODA          JPN       Yuki
# 11         9474         1230        A ALBON          THA  Alexander
# 12         9474         1230         G ZHOU          CHN     Guanyu
# 13         9474         1230   N HULKENBERG          GER       Nico
# 14         9474         1230         E OCON          FRA    Esteban
# 15         9474         1230     L HAMILTON          GBR      Lewis
# 16         9474         1230        C SAINZ          ESP     Carlos
# 17         9474         1230      G RUSSELL          GBR     George
# 18         9474         1230       V BOTTAS          FIN   Valtteri
# 19         9474         1230      O PIASTRI          AUS      Oscar
#
#            full_name                                       headshot_url  \
# 0     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 1     Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 2   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 3       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 4       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 5       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 6    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 7    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 8       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 9    Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 10      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 11   Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 12       ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 13   Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 14      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 15    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 16      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 17    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 18   Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 19     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  driver_number  \
# 0   Verstappen              1
# 1     Sargeant              2
# 2    Ricciardo              3
# 3       Norris              4
# 4        Gasly             10
# 5        Perez             11
# 6       Alonso             14
# 7      Leclerc             16
# 8       Stroll             18
# 9    Magnussen             20
# 10     Tsunoda             22
# 11       Albon             23
# 12        Zhou             24
# 13  Hulkenberg             27
# 14        Ocon             31
# 15    Hamilton             44
# 16       Sainz             55
# 17     Russell             63
# 18      Bottas             77
# 19     Piastri             81
#
#                                           team_colour        team_name  \
# 0                                              3671c6  Red Bull Racing
# 1                                              64c4ff         Williams
# 2                                              6692ff               RB
# 3                                              ff8000          McLaren
# 4                                              ff87bc           Alpine
# 5                                              3671c6  Red Bull Racing
# 6                                              229971     Aston Martin
# 7                                              e8002d          Ferrari
# 8                                              229971     Aston Martin
# 9                                              b6babd     Haas F1 Team
# 10                                             6692ff               RB
# 11                                             64c4ff         Williams
# 12  5200000000000000190003903645130092385429788960...      Kick Sauber
# 13                                             b6babd     Haas F1 Team
# 14                                             ff87bc           Alpine
# 15                                             27f4d2         Mercedes
# 16                                             e8002d          Ferrari
# 17                                             27f4d2         Mercedes
# 18  5200000000000000190003903645130092385429788960...      Kick Sauber
# 19                                             ff8000          McLaren
#
#    name_acronym
# 0           VER
# 1           SAR
# 2           RIC
# 3           NOR
# 4           GAS
# 5           PER
# 6           ALO
# 7           LEC
# 8           STR
# 9           MAG
# 10          TSU
# 11          ALB
# 12          ZHO
# 13          HUL
# 14          OCO
# 15          HAM
# 16          SAI
# 17          RUS
# 18          BOT
# 19          PIA

# %%
stintsDataFrame = pd.DataFrame()
for index,row in stintInformation.iterrows():
    number_driver = row.driver_number
    acronym_driver = drivers.query('driver_number == @number_driver').name_acronym.to_string(index=False)
    full_name = drivers.query('driver_number == @number_driver').full_name.to_string(index=False)
    team_name = drivers.query('driver_number == @number_driver').team_name.to_string(index=False)
    team_colour	 = drivers.query('driver_number == @number_driver').team_colour.to_string(index=False)
    print("-")
    print(row)
    tyre_age_at_start = row['tyre_age_at_start']
    print(tyre_age_at_start)
    if row.lap_start != row.lap_end:
        contador = row.lap_start
        while contador <= row.lap_end :
            new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':contador,'name_acronym':acronym_driver,'full_name':full_name,'team_name':team_name,'team_colour':team_colour,'tyre_age_at_start':tyre_age_at_start}
            #stintsDataFrame=stintsDataFrame.append(new_row, ignore_index=True)
            stintsDataFrame = pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)
            contador+=1
    else:
    
        new_row = {'driver_number':row.driver_number,'compound':row.compound,'lap_number':row.lap_start,'name_acronym':acronym_driver,'full_name':full_name,'full_name':full_name,'team_name':team_name,'team_colour':team_colour, 'tyre_age_at_start':tyre_age_at_start}
        #stintsDataFrame= stintsDataFrame.append(new_row, ignore_index=True)
        stintsDataFrame =pd.concat([stintsDataFrame, pd.DataFrame([new_row])], ignore_index=True)
# Out:
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            63
# lap_start                 1
# lap_end                   3
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 0, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number             1
# lap_start                 1
# lap_end                   4
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 1, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            11
# lap_start                 1
# lap_end                   4
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 2, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            81
# lap_start                 1
# lap_end                   5
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 3, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            1
# driver_number           4
# lap_start               1
# lap_end                 6
# compound             HARD
# tyre_age_at_start       0
# Name: 4, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            20
# lap_start                 1
# lap_end                   6
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 5, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            1
# driver_number          77
# lap_start               1
# lap_end                 7
# compound             HARD
# tyre_age_at_start       0
# Name: 6, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number             2
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 7, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            14
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 8, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            16
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 9, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            18
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 10, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            1
# driver_number          23
# lap_start               1
# lap_end                 8
# compound             HARD
# tyre_age_at_start       0
# Name: 11, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            24
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 12, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            31
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 13, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            55
# lap_start                 1
# lap_end                   8
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 14, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            10
# lap_start                 1
# lap_end                   9
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 15, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            1
# driver_number          22
# lap_start               1
# lap_end                 9
# compound             SOFT
# tyre_age_at_start       0
# Name: 16, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            1
# driver_number          27
# lap_start               1
# lap_end                 9
# compound             HARD
# tyre_age_at_start       0
# Name: 17, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              1
# driver_number            44
# lap_start                 1
# lap_end                   9
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 18, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            1
# driver_number           3
# lap_start               1
# lap_end                11
# compound             SOFT
# tyre_age_at_start       0
# Name: 19, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              2
# driver_number            63
# lap_start                 4
# lap_end                   9
# compound             MEDIUM
# tyre_age_at_start         2
# Name: 20, dtype: object
# 2
# -
# meeting_key            1230
# session_key            9474
# stint_number              2
# driver_number            11
# lap_start                 5
# lap_end                   7
# compound             MEDIUM
# tyre_age_at_start         3
# Name: 21, dtype: object
# 3
# -
# meeting_key            1230
# session_key            9474
# stint_number              2
# driver_number             1
# lap_start                 5
# lap_end                   9
# compound             MEDIUM
# tyre_age_at_start         3
# Name: 22, dtype: object
# 3
# -
# meeting_key            1230
# session_key            9474
# stint_number              2
# driver_number            81
# lap_start                 6
# lap_end                   9
# compound             MEDIUM
# tyre_age_at_start         4
# Name: 23, dtype: object
# 4
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number           4
# lap_start               7
# lap_end                 9
# compound             SOFT
# tyre_age_at_start       0
# Name: 24, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          20
# lap_start               7
# lap_end                11
# compound             SOFT
# tyre_age_at_start       0
# Name: 25, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          11
# lap_start               8
# lap_end                10
# compound             SOFT
# tyre_age_at_start       0
# Name: 26, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          77
# lap_start               8
# lap_end                14
# compound             SOFT
# tyre_age_at_start       0
# Name: 27, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          16
# lap_start               9
# lap_end                11
# compound             SOFT
# tyre_age_at_start       0
# Name: 28, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          55
# lap_start               9
# lap_end                12
# compound             SOFT
# tyre_age_at_start       0
# Name: 29, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          23
# lap_start               9
# lap_end                13
# compound             SOFT
# tyre_age_at_start       0
# Name: 30, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number           2
# lap_start               9
# lap_end                14
# compound             SOFT
# tyre_age_at_start       0
# Name: 31, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          14
# lap_start               9
# lap_end                14
# compound             SOFT
# tyre_age_at_start       0
# Name: 32, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          18
# lap_start               9
# lap_end                14
# compound             SOFT
# tyre_age_at_start       0
# Name: 33, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          24
# lap_start               9
# lap_end                15
# compound             SOFT
# tyre_age_at_start       0
# Name: 34, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          31
# lap_start               9
# lap_end                16
# compound             SOFT
# tyre_age_at_start       0
# Name: 35, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          27
# lap_start              10
# lap_end                12
# compound             SOFT
# tyre_age_at_start       0
# Name: 36, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number           4
# lap_start              10
# lap_end                14
# compound             SOFT
# tyre_age_at_start       3
# Name: 37, dtype: object
# 3
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          22
# lap_start              10
# lap_end                14
# compound             SOFT
# tyre_age_at_start       0
# Name: 38, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          44
# lap_start              10
# lap_end                14
# compound             SOFT
# tyre_age_at_start       0
# Name: 39, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number           1
# lap_start              10
# lap_end                15
# compound             SOFT
# tyre_age_at_start       0
# Name: 40, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          63
# lap_start              10
# lap_end                16
# compound             SOFT
# tyre_age_at_start       0
# Name: 41, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          81
# lap_start              10
# lap_end                16
# compound             SOFT
# tyre_age_at_start       0
# Name: 42, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number          10
# lap_start              10
# lap_end                17
# compound             SOFT
# tyre_age_at_start       0
# Name: 43, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number            11
# lap_start                11
# lap_end                  28
# compound             MEDIUM
# tyre_age_at_start         6
# Name: 44, dtype: object
# 6
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          16
# lap_start              12
# lap_end                13
# compound             SOFT
# tyre_age_at_start       3
# Name: 45, dtype: object
# 3
# -
# meeting_key          1230
# session_key          9474
# stint_number            2
# driver_number           3
# lap_start              12
# lap_end                17
# compound             SOFT
# tyre_age_at_start       0
# Name: 46, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          20
# lap_start              12
# lap_end                25
# compound             SOFT
# tyre_age_at_start       0
# Name: 47, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          55
# lap_start              13
# lap_end                17
# compound             SOFT
# tyre_age_at_start       4
# Name: 48, dtype: object
# 4
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          27
# lap_start              13
# lap_end                23
# compound             HARD
# tyre_age_at_start       8
# Name: 49, dtype: object
# 8
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          23
# lap_start              14
# lap_end                14
# compound             SOFT
# tyre_age_at_start       5
# Name: 50, dtype: object
# 5
# -
# meeting_key          1230
# session_key          9474
# stint_number            4
# driver_number          16
# lap_start              14
# lap_end                23
# compound             SOFT
# tyre_age_at_start       5
# Name: 51, dtype: object
# 5
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number           2
# lap_start              15
# lap_end                15
# compound             SOFT
# tyre_age_at_start       6
# Name: 52, dtype: object
# 6
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          77
# lap_start              15
# lap_end                15
# compound             SOFT
# tyre_age_at_start       7
# Name: 53, dtype: object
# 7
# -
# meeting_key          1230
# session_key          9474
# stint_number            4
# driver_number           4
# lap_start              15
# lap_end                16
# compound             SOFT
# tyre_age_at_start       8
# Name: 54, dtype: object
# 8
# -
# meeting_key            1230
# session_key            9474
# stint_number              3
# driver_number            44
# lap_start                15
# lap_end                  20
# compound             MEDIUM
# tyre_age_at_start         8
# Name: 55, dtype: object
# 8
# -
# meeting_key            1230
# session_key            9474
# stint_number              3
# driver_number            18
# lap_start                15
# lap_end                  25
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 56, dtype: object
# 7
# -
# meeting_key            1230
# session_key            9474
# stint_number              3
# driver_number            14
# lap_start                15
# lap_end                  29
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 57, dtype: object
# 7
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number          22
# lap_start              15
# lap_end                29
# compound             SOFT
# tyre_age_at_start       5
# Name: 58, dtype: object
# 5
# -
# meeting_key          1230
# session_key          9474
# stint_number            4
# driver_number          23
# lap_start              15
# lap_end                29
# compound             HARD
# tyre_age_at_start       0
# Name: 59, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number             1
# lap_start                16
# lap_end                  28
# compound             MEDIUM
# tyre_age_at_start         0
# Name: 60, dtype: object
# 0
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number             2
# lap_start                16
# lap_end                  28
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 61, dtype: object
# 7
# -
# meeting_key            1230
# session_key            9474
# stint_number              3
# driver_number            24
# lap_start                16
# lap_end                  28
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 62, dtype: object
# 7
# -
# meeting_key          1230
# session_key          9474
# stint_number            4
# driver_number          77
# lap_start              16
# lap_end                28
# compound             HARD
# tyre_age_at_start       6
# Name: 63, dtype: object
# 6
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number            63
# lap_start                17
# lap_end                  19
# compound             MEDIUM
# tyre_age_at_start         8
# Name: 64, dtype: object
# 8
# -
# meeting_key          1230
# session_key          9474
# stint_number            5
# driver_number           4
# lap_start              17
# lap_end                24
# compound             HARD
# tyre_age_at_start       5
# Name: 65, dtype: object
# 5
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number            81
# lap_start                17
# lap_end                  25
# compound             MEDIUM
# tyre_age_at_start         8
# Name: 66, dtype: object
# 8
# -
# meeting_key            1230
# session_key            9474
# stint_number              3
# driver_number            31
# lap_start                17
# lap_end                  28
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 67, dtype: object
# 7
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number            55
# lap_start                18
# lap_end                  27
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 68, dtype: object
# 7
# -
# meeting_key          1230
# session_key          9474
# stint_number            3
# driver_number           3
# lap_start              18
# lap_end                30
# compound             SOFT
# tyre_age_at_start       6
# Name: 69, dtype: object
# 6
# -
# meeting_key            1230
# session_key            9474
# stint_number              3
# driver_number            10
# lap_start                18
# lap_end                  30
# compound             MEDIUM
# tyre_age_at_start         8
# Name: 70, dtype: object
# 8
# -
# meeting_key            1230
# session_key            9474
# stint_number              5
# driver_number            63
# lap_start                20
# lap_end                  25
# compound             MEDIUM
# tyre_age_at_start        11
# Name: 71, dtype: object
# 11
# -
# meeting_key            1230
# session_key            9474
# stint_number              4
# driver_number            44
# lap_start                21
# lap_end                  23
# compound             MEDIUM
# tyre_age_at_start        14
# Name: 72, dtype: object
# 14
# -
# meeting_key            1230
# session_key            9474
# stint_number              5
# driver_number            16
# lap_start                24
# lap_end                  26
# compound             MEDIUM
# tyre_age_at_start         7
# Name: 73, dtype: object
# 7
# -
# meeting_key          1230
# session_key          9474
# stint_number            4
# driver_number          27
# lap_start              24
# lap_end                27
# compound             SOFT
# tyre_age_at_start       0
# Name: 74, dtype: object
# 0
# -
# meeting_key          1230
# session_key          9474
# stint_number            4
# driver_number          18
# lap_start              26
# lap_end                28
# compound             SOFT
# tyre_age_at_start       6
# Name: 75, dtype: object
# 6
# -
# meeting_key          1230
# session_key          9474
# stint_number            5
# driver_number          81
# lap_start              26
# lap_end                28
# compound             SOFT
# tyre_age_at_start       0
# Name: 76, dtype: object
# 0

# %% [markdown]
# ### Qualyfing

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Abu Dhabi
url = 'https://api.openf1.org/v1/laps?'
session_key = 'session_key=9476'
year = 'year=2024'
country_code = 'country_code=KSA'

urltotal = url+session_key

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
qualyfing = pd.DataFrame(data)
qualyfing
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1230         9476             20     260.0     285.0     118.0
# 1           1230         9476              2     277.0     300.0     290.0
# 2           1230         9476             27     263.0     302.0     290.0
# 3           1230         9476             77     262.0     300.0     249.0
# 4           1230         9476             31     265.0     304.0     312.0
# ..           ...          ...            ...       ...       ...       ...
# 311         1230         9476             22     227.0     207.0     215.0
# 312         1230         9476             11     252.0     202.0     204.0
# 313         1230         9476             16     214.0     214.0     214.0
# 314         1230         9476             14     259.0     171.0     191.0
# 315         1230         9476             18     263.0     191.0     214.0
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 0    2024-03-08T17:00:03.107000           NaN            True
# 1    2024-03-08T17:00:08.588000           NaN            True
# 2    2024-03-08T17:00:14.230000           NaN            True
# 3    2024-03-08T17:00:16.119000           NaN            True
# 4    2024-03-08T17:00:21.836000           NaN            True
# ..                          ...           ...             ...
# 311  2024-03-08T18:05:00.131000           NaN           False
# 312  2024-03-08T18:05:06.085000       132.524           False
# 313  2024-03-08T18:05:22.342000       119.409           False
# 314  2024-03-08T18:05:37.608000       125.809           False
# 315  2024-03-08T18:05:46.206000       121.043           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             32.622             36.455
# 1                  NaN             33.443             32.414
# 2                  NaN             31.689             36.590
# 3                  NaN             31.699             37.409
# 4                  NaN             32.105             33.364
# ..                 ...                ...                ...
# 311             41.796             36.828                NaN
# 312             46.526             38.560             47.438
# 313             40.960             36.641             41.808
# 314             42.473             36.302             47.034
# 315             39.367             38.139             43.537
#
#                                      segments_sector_1  \
# 0    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 1    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 2    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 3    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# 4    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 311  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 312  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 313  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 314  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 315  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 311  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 312  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 313  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 314  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 315  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_3  lap_number
# 0    [2049, 2049, 2051, 2051, 2049, 2051, 2049, 204...           1
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2048, 204...           1
# 2    [2051, 2049, 2049, 2051, 2051, 2049, 2048, 204...           1
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...           1
# 4    [2049, 2049, 2049, 2048, 2049, 2049, 2049, 204...           1
# ..                                                 ...         ...
# 311                                                 []          18
# 312                                                 []          19
# 313                                                 []          23
# 314                                                 []          17
# 315                                                 []          19
#
# [316 rows x 16 columns]

# %%
# To obtain a specific circuit. In this case, I will obtain the data about Abu Dhabi
url = 'https://api.openf1.org/v1/car_data?'

urltotal = url+session_key+'&speed>1'+'&n_gear>0'

response = urlopen(urltotal)
data = json.loads(response.read().decode('utf-8'))
qualyfing_car_data = pd.DataFrame(data)

# %%
# Name of the drivers
# Currently, I am using F1 2023 data because F1 2024 does not include the colours and the team name
url = 'https://api.openf1.org/v1/drivers?'
urltotal = url+session_key

response = urlopen(urltotal)
drivers = json.loads(response.read().decode('utf-8'))
drivers = pd.DataFrame(drivers)
drivers
# Out:
#     session_key  meeting_key broadcast_name country_code first_name  \
# 0          9475         1230   M VERSTAPPEN          NED        Max
# 1          9475         1230     L SARGEANT          USA      Logan
# 2          9475         1230    D RICCIARDO          AUS     Daniel
# 3          9475         1230       L NORRIS          GBR      Lando
# 4          9475         1230        P GASLY          FRA     Pierre
# 5          9475         1230        S PEREZ          MEX     Sergio
# 6          9475         1230       F ALONSO          ESP   Fernando
# 7          9475         1230      C LECLERC          MON    Charles
# 8          9475         1230       L STROLL          CAN      Lance
# 9          9475         1230    K MAGNUSSEN          DEN      Kevin
# 10         9475         1230      Y TSUNODA          JPN       Yuki
# 11         9475         1230        A ALBON          THA  Alexander
# 12         9475         1230         G ZHOU          CHN     Guanyu
# 13         9475         1230   N HULKENBERG          GER       Nico
# 14         9475         1230         E OCON          FRA    Esteban
# 15         9475         1230      O BEARMAN          GBR     Oliver
# 16         9475         1230     L HAMILTON          GBR      Lewis
# 17         9475         1230      G RUSSELL          GBR     George
# 18         9475         1230       V BOTTAS          FIN   Valtteri
# 19         9475         1230      O PIASTRI          AUS      Oscar
#
#            full_name                                       headshot_url  \
# 0     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 1     Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 2   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 3       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 4       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 5       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 6    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 7    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 8       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 9    Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 10      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 11   Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 12       ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 13   Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 14      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 15    Oliver BEARMAN                                               None
# 16    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 17    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 18   Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 19     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  driver_number  \
# 0   Verstappen              1
# 1     Sargeant              2
# 2    Ricciardo              3
# 3       Norris              4
# 4        Gasly             10
# 5        Perez             11
# 6       Alonso             14
# 7      Leclerc             16
# 8       Stroll             18
# 9    Magnussen             20
# 10     Tsunoda             22
# 11       Albon             23
# 12        Zhou             24
# 13  Hulkenberg             27
# 14        Ocon             31
# 15     Bearman             38
# 16    Hamilton             44
# 17     Russell             63
# 18      Bottas             77
# 19     Piastri             81
#
#                                           team_colour        team_name  \
# 0                                              3671c6  Red Bull Racing
# 1                                              64c4ff         Williams
# 2                                              6692ff               RB
# 3                                              ff8000          McLaren
# 4                                              ff87bc           Alpine
# 5                                              3671c6  Red Bull Racing
# 6                                              229971     Aston Martin
# 7                                              e8002d          Ferrari
# 8                                              229971     Aston Martin
# 9                                              b6babd     Haas F1 Team
# 10                                             6692ff               RB
# 11                                             64c4ff         Williams
# 12  5200000000000000190003903645130092385429788960...      Kick Sauber
# 13                                             b6babd     Haas F1 Team
# 14                                             ff87bc           Alpine
# 15                                             e8002d          Ferrari
# 16                                             27f4d2         Mercedes
# 17                                             27f4d2         Mercedes
# 18  5200000000000000190003903645130092385429788960...      Kick Sauber
# 19                                             ff8000          McLaren
#
#    name_acronym
# 0           VER
# 1           SAR
# 2           RIC
# 3           NOR
# 4           GAS
# 5           PER
# 6           ALO
# 7           LEC
# 8           STR
# 9           MAG
# 10          TSU
# 11          ALB
# 12          ZHO
# 13          HUL
# 14          OCO
# 15          BEA
# 16          HAM
# 17          RUS
# 18          BOT
# 19          PIA

# %%
qualyfing_car_data
# Out:
#         meeting_key  session_key  driver_number                        date  \
# 0              1230         9476             23  2024-03-08T16:48:33.116000
# 1              1230         9476              2  2024-03-08T16:48:34.356000
# 2              1230         9476              2  2024-03-08T16:48:34.755000
# 3              1230         9476              2  2024-03-08T16:48:34.915000
# 4              1230         9476              2  2024-03-08T16:48:35.195000
# ...             ...          ...            ...                         ...
# 134499         1230         9476             18  2024-03-08T18:07:43.051000
# 134500         1230         9476             18  2024-03-08T18:07:43.211000
# 134501         1230         9476             18  2024-03-08T18:07:43.371000
# 134502         1230         9476             18  2024-03-08T18:07:43.851000
# 134503         1230         9476             18  2024-03-08T18:07:44.251000
#
#          rpm  speed  n_gear  throttle  drs  brake
# 0       4718      2       1         0    8      0
# 1       5121     46       1         0    8      0
# 2       5014     45       1         0    8      0
# 3       5028     45       1         0    8      0
# 4       4940     44       1         0    8      0
# ...      ...    ...     ...       ...  ...    ...
# 134499  8738     80       1         1    8    100
# 134500  8415     74       1         2    8    100
# 134501  7732     71       1         4    8    100
# 134502  6598     61       1         0    8    100
# 134503  4516     54       1         0    8    100
#
# [134504 rows x 10 columns]

# %%
qualyfing.query("is_pit_out_lap == False ").describe()
# Out:
#        meeting_key  session_key  driver_number    i1_speed    i2_speed  \
# count        223.0        223.0     223.000000  217.000000  216.000000
# mean        1230.0       9476.0      27.937220  267.428571  282.458333
# std            0.0          0.0      23.906643   31.737577   50.923455
# min         1230.0       9476.0       1.000000  133.000000   82.000000
# 25%         1230.0       9476.0      11.000000  255.000000  247.750000
# 50%         1230.0       9476.0      20.000000  270.000000  294.000000
# 75%         1230.0       9476.0      38.000000  291.000000  325.000000
# max         1230.0       9476.0      81.000000  295.000000  331.000000
#
#          st_speed  lap_duration  duration_sector_1  duration_sector_2  \
# count  217.000000     213.00000         217.000000         216.000000
# mean   291.493088     103.30554          37.575627          31.955259
# std     47.726470      14.27287           6.062854           4.275108
# min     63.000000      87.47200          31.763000          27.800000
# 25%    269.000000      88.94600          32.386000          28.116500
# 50%    303.000000     102.99000          36.102000          31.248500
# 75%    330.000000     117.04200          41.834000          35.238750
# max    338.000000     132.52400          57.071000          47.508000
#
#        duration_sector_3  lap_number
# count         213.000000  223.000000
# mean           33.706545    9.695067
# std             5.654325    5.830668
# min            27.909000    2.000000
# 25%            28.391000    5.000000
# 50%            33.158000    9.000000
# 75%            37.977000   14.000000
# max            47.856000   24.000000

# %%
cleanLapsQualyfing = pd.DataFrame()
cleanLapsQualyfing = qualyfing.query("lap_duration >1 & is_pit_out_lap == False & lap_duration <103.3")

# %%
cleanLapsQualyfing
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 14          1230         9476             20     289.0     329.0     334.0
# 15          1230         9476              2     290.0     324.0     332.0
# 16          1230         9476             27     290.0     331.0     338.0
# 17          1230         9476             77     291.0     325.0     328.0
# 18          1230         9476             10     271.0     303.0     293.0
# ..           ...          ...            ...       ...       ...       ...
# 302         1230         9476             22     293.0     325.0     330.0
# 303         1230         9476             11     295.0     326.0     331.0
# 304         1230         9476             16     291.0     326.0     329.0
# 306         1230         9476             14     292.0     325.0     329.0
# 307         1230         9476             18     291.0     324.0     327.0
#
#                      date_start  lap_duration  is_pit_out_lap  \
# 14   2024-03-08T17:01:56.784000        89.528           False
# 15   2024-03-08T17:02:04.861000        89.696           False
# 16   2024-03-08T17:02:11.082000        89.173           False
# 17   2024-03-08T17:02:15.619000        89.719           False
# 18   2024-03-08T17:02:19.567000        99.332           False
# ..                          ...           ...             ...
# 302  2024-03-08T18:03:31.942000        88.547           False
# 303  2024-03-08T18:03:38.310000        87.832           False
# 304  2024-03-08T18:03:55.926000        87.791           False
# 306  2024-03-08T18:04:09.835000        87.846           False
# 307  2024-03-08T18:04:17.767000        88.572           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 14              32.865             28.272             28.391
# 15              32.770             28.376             28.550
# 16              32.645             28.129             28.399
# 17              32.917             28.292             28.510
# 18              36.102             31.543             31.687
# ..                 ...                ...                ...
# 302             32.180             28.110             28.257
# 303             31.878             27.892             28.062
# 304             31.933             27.842             28.016
# 306             31.840             27.823             28.183
# 307             31.943             28.012             28.617
#
#                                      segments_sector_1  \
# 14   [2049, 2049, 2049, 2049, 2051, 2049, 2049, 204...
# 15   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 16   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 17   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 18   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 302  [2049, 2049, 2048, 2049, 2049, 2048, 2049, 204...
# 303  [2049, 2048, 2049, 2049, 2049, 2048, 2048, 204...
# 304  [2048, 2049, 2048, 2049, 2048, 2049, 2049, 204...
# 306  [2049, 2048, 2048, 2049, 2049, 2051, 2049, 204...
# 307  [2049, 2049, 2049, 2048, 2049, 2049, 2049, 204...
#
#                               segments_sector_2  \
# 14   [2049, 2049, 2051, 2049, 2049, 2049, 2049]
# 15   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 16   [2051, 2049, 2049, 2049, 2049, 2051, 2051]
# 17   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 18   [2049, 2049, 2049, 2048, 2049, 2049, 2049]
# ..                                          ...
# 302  [2049, 2049, 2048, 2049, 2049, 2049, 2049]
# 303  [2051, 2048, 2051, 2048, 2048, 2049, 2049]
# 304  [2049, 2051, 2049, 2049, 2049, 2049, 2049]
# 306  [2048, 2048, 2048, 2051, 2048, 2048, 2048]
# 307  [2049, 2048, 2048, 2049, 2049, 2049, 2049]
#
#                                      segments_sector_3  lap_number
# 14   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2
# 15   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2
# 16   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2
# 17   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...           2
# 18   [2049, 2049, 2049, 2049, 2049, 2051, 2048, 204...           2
# ..                                                 ...         ...
# 302  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          17
# 303  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          18
# 304  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          22
# 306  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          16
# 307  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...          18
#
# [107 rows x 16 columns]

# %%
def obtain_information_qualy(driver,dataset,newdataset):
    fastest_lap = dataset.query("driver_number == @driver").lap_duration.min()
    fastest_lap_absolute = dataset.lap_duration.min()
    delta = fastest_lap - fastest_lap_absolute
    st_speed = dataset.query("driver_number == @driver").st_speed.min()
    new_row = {'driver_number':driver,'fastest_lap':fastest_lap,'delta': delta,'st_speed':st_speed}
    newdataset =pd.concat([newdataset, pd.DataFrame([new_row])], ignore_index=True)
    return newdataset

# %%
newdataset
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Qualy deltas

# %%
drivers_list = list(cleanLapsQualyfing['driver_number'].unique())
print(len(drivers_list))
# Out:
# 19

# %%
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =obtain_information_qualy(driver,cleanLapsQualyfing,newdataset)

# %%
newdataset
# Out:
#     driver_number  fastest_lap  delta  st_speed
# 0              20       89.020  1.548     293.0
# 1               2       89.526  2.054     329.0
# 2              27       89.055  1.583     308.0
# 3              77       89.179  1.707     296.0
# 4              10       89.479  2.007     293.0
# 5              31       89.475  2.003     313.0
# 6              81       88.089  0.617     323.0
# 7              23       88.980  1.508     328.0
# 8               4       88.132  0.660     207.0
# 9              14       87.846  0.374     329.0
# 10             18       88.250  0.778     292.0
# 11             38       88.642  1.170     329.0
# 12             44       88.460  0.988     297.0
# 13             63       88.316  0.844     329.0
# 14             16       87.791  0.319     329.0
# 15             11       87.807  0.335     329.0
# 16              1       87.472  0.000     329.0
# 17              3       89.025  1.553     330.0
# 18             22       88.547  1.075     303.0

# %%
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables
# Out:
#     driver_number  fastest_lap  delta  st_speed  session_key  meeting_key  \
# 0              20       89.020  1.548     293.0         9475         1230
# 1               2       89.526  2.054     329.0         9475         1230
# 2              27       89.055  1.583     308.0         9475         1230
# 3              77       89.179  1.707     296.0         9475         1230
# 4              10       89.479  2.007     293.0         9475         1230
# 5              31       89.475  2.003     313.0         9475         1230
# 6              81       88.089  0.617     323.0         9475         1230
# 7              23       88.980  1.508     328.0         9475         1230
# 8               4       88.132  0.660     207.0         9475         1230
# 9              14       87.846  0.374     329.0         9475         1230
# 10             18       88.250  0.778     292.0         9475         1230
# 11             38       88.642  1.170     329.0         9475         1230
# 12             44       88.460  0.988     297.0         9475         1230
# 13             63       88.316  0.844     329.0         9475         1230
# 14             16       87.791  0.319     329.0         9475         1230
# 15             11       87.807  0.335     329.0         9475         1230
# 16              1       87.472  0.000     329.0         9475         1230
# 17              3       89.025  1.553     330.0         9475         1230
# 18             22       88.547  1.075     303.0         9475         1230
#
#    broadcast_name country_code first_name         full_name  \
# 0     K MAGNUSSEN          DEN      Kevin   Kevin MAGNUSSEN
# 1      L SARGEANT          USA      Logan    Logan SARGEANT
# 2    N HULKENBERG          GER       Nico   Nico HULKENBERG
# 3        V BOTTAS          FIN   Valtteri   Valtteri BOTTAS
# 4         P GASLY          FRA     Pierre      Pierre GASLY
# 5          E OCON          FRA    Esteban      Esteban OCON
# 6       O PIASTRI          AUS      Oscar     Oscar PIASTRI
# 7         A ALBON          THA  Alexander   Alexander ALBON
# 8        L NORRIS          GBR      Lando      Lando NORRIS
# 9        F ALONSO          ESP   Fernando   Fernando ALONSO
# 10       L STROLL          CAN      Lance      Lance STROLL
# 11      O BEARMAN          GBR     Oliver    Oliver BEARMAN
# 12     L HAMILTON          GBR      Lewis    Lewis HAMILTON
# 13      G RUSSELL          GBR     George    George RUSSELL
# 14      C LECLERC          MON    Charles   Charles LECLERC
# 15        S PEREZ          MEX     Sergio      Sergio PEREZ
# 16   M VERSTAPPEN          NED        Max    Max VERSTAPPEN
# 17    D RICCIARDO          AUS     Daniel  Daniel RICCIARDO
# 18      Y TSUNODA          JPN       Yuki      Yuki TSUNODA
#
#                                          headshot_url   last_name  \
# 0   https://media.formula1.com/d_driver_fallback_i...   Magnussen
# 1   https://media.formula1.com/d_driver_fallback_i...    Sargeant
# 2   https://media.formula1.com/d_driver_fallback_i...  Hulkenberg
# 3   https://media.formula1.com/d_driver_fallback_i...      Bottas
# 4   https://media.formula1.com/d_driver_fallback_i...       Gasly
# 5   https://media.formula1.com/d_driver_fallback_i...        Ocon
# 6   https://media.formula1.com/d_driver_fallback_i...     Piastri
# 7   https://media.formula1.com/d_driver_fallback_i...       Albon
# 8   https://media.formula1.com/d_driver_fallback_i...      Norris
# 9   https://media.formula1.com/d_driver_fallback_i...      Alonso
# 10  https://media.formula1.com/d_driver_fallback_i...      Stroll
# 11                                               None     Bearman
# 12  https://media.formula1.com/d_driver_fallback_i...    Hamilton
# 13  https://media.formula1.com/d_driver_fallback_i...     Russell
# 14  https://media.formula1.com/d_driver_fallback_i...     Leclerc
# 15  https://media.formula1.com/d_driver_fallback_i...       Perez
# 16  https://media.formula1.com/d_driver_fallback_i...  Verstappen
# 17  https://media.formula1.com/d_driver_fallback_i...   Ricciardo
# 18  https://media.formula1.com/d_driver_fallback_i...     Tsunoda
#
#                                           team_colour        team_name  \
# 0                                              b6babd     Haas F1 Team
# 1                                              64c4ff         Williams
# 2                                              b6babd     Haas F1 Team
# 3   5200000000000000190003903645130092385429788960...      Kick Sauber
# 4                                              ff87bc           Alpine
# 5                                              ff87bc           Alpine
# 6                                              ff8000          McLaren
# 7                                              64c4ff         Williams
# 8                                              ff8000          McLaren
# 9                                              229971     Aston Martin
# 10                                             229971     Aston Martin
# 11                                             e8002d          Ferrari
# 12                                             27f4d2         Mercedes
# 13                                             27f4d2         Mercedes
# 14                                             e8002d          Ferrari
# 15                                             3671c6  Red Bull Racing
# 16                                             3671c6  Red Bull Racing
# 17                                             6692ff               RB
# 18                                             6692ff               RB
#
#    name_acronym
# 0           MAG
# 1           SAR
# 2           HUL
# 3           BOT
# 4           GAS
# 5           OCO
# 6           PIA
# 7           ALB
# 8           NOR
# 9           ALO
# 10          STR
# 11          BEA
# 12          HAM
# 13          RUS
# 14          LEC
# 15          PER
# 16          VER
# 17          RIC
# 18          TSU

# %%
jointables.sort_values(ascending=False,by='delta').plot.barh('name_acronym','delta')
# Out:
# <Axes: ylabel='name_acronym'>

# %%
jointables.sort_values(ascending=False,by='st_speed').plot.bar('name_acronym','st_speed')
# Out:
# <Axes: xlabel='name_acronym'>

# %% [markdown]
# ## Qualyfing 1

# %%
mergequaly = pd.merge(cleanLapsQualyfing,drivers,on=['driver_number'])

# %%
mergequaly
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 0             1230           9476             20     289.0     329.0
# 1             1230           9476             20     292.0     331.0
# 2             1230           9476             20     291.0     330.0
# 3             1230           9476             20     291.0     329.0
# 4             1230           9476             20     270.0     307.0
# ..             ...            ...            ...       ...       ...
# 102           1230           9476             22     293.0     325.0
# 103           1230           9476             22     264.0     292.0
# 104           1230           9476             22     293.0     327.0
# 105           1230           9476             22     292.0     324.0
# 106           1230           9476             22     293.0     325.0
#
#      st_speed                  date_start  lap_duration  is_pit_out_lap  \
# 0       334.0  2024-03-08T17:01:56.784000        89.528           False
# 1       334.0  2024-03-08T17:05:22.831000        89.069           False
# 2       333.0  2024-03-08T17:13:32.597000        89.086           False
# 3       332.0  2024-03-08T17:36:51.444000        89.020           False
# 4       293.0  2024-03-08T17:38:20.410000       102.375           False
# ..        ...                         ...           ...             ...
# 102     331.0  2024-03-08T17:37:00.352000        88.659           False
# 103     303.0  2024-03-08T17:38:28.850000       102.990           False
# 104     332.0  2024-03-08T17:44:02.525000        88.564           False
# 105     330.0  2024-03-08T17:55:30.458000        88.973           False
# 106     330.0  2024-03-08T18:03:31.942000        88.547           False
#
#      duration_sector_1  ...  meeting_key_y  broadcast_name country_code  \
# 0               32.865  ...           1230     K MAGNUSSEN          DEN
# 1               32.494  ...           1230     K MAGNUSSEN          DEN
# 2               32.509  ...           1230     K MAGNUSSEN          DEN
# 3               32.514  ...           1230     K MAGNUSSEN          DEN
# 4               36.567  ...           1230     K MAGNUSSEN          DEN
# ..                 ...  ...            ...             ...          ...
# 102             32.217  ...           1230       Y TSUNODA          JPN
# 103             37.020  ...           1230       Y TSUNODA          JPN
# 104             32.268  ...           1230       Y TSUNODA          JPN
# 105             32.410  ...           1230       Y TSUNODA          JPN
# 106             32.180  ...           1230       Y TSUNODA          JPN
#
#     first_name        full_name  \
# 0        Kevin  Kevin MAGNUSSEN
# 1        Kevin  Kevin MAGNUSSEN
# 2        Kevin  Kevin MAGNUSSEN
# 3        Kevin  Kevin MAGNUSSEN
# 4        Kevin  Kevin MAGNUSSEN
# ..         ...              ...
# 102       Yuki     Yuki TSUNODA
# 103       Yuki     Yuki TSUNODA
# 104       Yuki     Yuki TSUNODA
# 105       Yuki     Yuki TSUNODA
# 106       Yuki     Yuki TSUNODA
#
#                                           headshot_url  last_name  \
# 0    https://media.formula1.com/d_driver_fallback_i...  Magnussen
# 1    https://media.formula1.com/d_driver_fallback_i...  Magnussen
# 2    https://media.formula1.com/d_driver_fallback_i...  Magnussen
# 3    https://media.formula1.com/d_driver_fallback_i...  Magnussen
# 4    https://media.formula1.com/d_driver_fallback_i...  Magnussen
# ..                                                 ...        ...
# 102  https://media.formula1.com/d_driver_fallback_i...    Tsunoda
# 103  https://media.formula1.com/d_driver_fallback_i...    Tsunoda
# 104  https://media.formula1.com/d_driver_fallback_i...    Tsunoda
# 105  https://media.formula1.com/d_driver_fallback_i...    Tsunoda
# 106  https://media.formula1.com/d_driver_fallback_i...    Tsunoda
#
#      team_colour     team_name name_acronym
# 0         b6babd  Haas F1 Team          MAG
# 1         b6babd  Haas F1 Team          MAG
# 2         b6babd  Haas F1 Team          MAG
# 3         b6babd  Haas F1 Team          MAG
# 4         b6babd  Haas F1 Team          MAG
# ..           ...           ...          ...
# 102       6692ff            RB          TSU
# 103       6692ff            RB          TSU
# 104       6692ff            RB          TSU
# 105       6692ff            RB          TSU
# 106       6692ff            RB          TSU
#
# [107 rows x 27 columns]

# %%
# Q1 data
mergequalyQ1 =mergequaly.query("date_start <'2024-03-08T17:18:03.464000'").sort_values(by='lap_duration')
isFastestLap = []
for index,row in mergequalyQ1.iterrows():
    driver = row.driver_number
    fastest_lap = mergequalyQ1.query("driver_number == @driver").lap_duration.min()
    if row.lap_duration == fastest_lap:
        isFastestLap.append(True)
    else:
        isFastestLap.append(False)

# %%
mergequalyQ1['isFastestLap'] = isFastestLap
mergequalyQ1
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 91            1230           9476              1     294.0     327.0
# 51            1230           9476             18     293.0     322.0
# 79            1230           9476             16     290.0     327.0
# 90            1230           9476              1     295.0     326.0
# 85            1230           9476             11     293.0     324.0
# 78            1230           9476             16     289.0     326.0
# 45            1230           9476             14     292.0     325.0
# 72            1230           9476             63     292.0     324.0
# 25            1230           9476             81     292.0     324.0
# 84            1230           9476             11     291.0     326.0
# 37            1230           9476              4     290.0     322.0
# 44            1230           9476             14     290.0     324.0
# 57            1230           9476             38     290.0     325.0
# 101           1230           9476             22     293.0     327.0
# 63            1230           9476             44     291.0     327.0
# 77            1230           9476             16     289.0     325.0
# 11            1230           9476             27     291.0     330.0
# 97            1230           9476              3     292.0     328.0
# 1             1230           9476             20     292.0     331.0
# 2             1230           9476             20     291.0     330.0
# 33            1230           9476             23     292.0     323.0
# 49            1230           9476             18     288.0     322.0
# 64            1230           9476             44     293.0     327.0
# 58            1230           9476             38     288.0     325.0
# 8             1230           9476             27     290.0     331.0
# 14            1230           9476             77     291.0     326.0
# 96            1230           9476              3     291.0     326.0
# 24            1230           9476             81     290.0     322.0
# 100           1230           9476             22     291.0     326.0
# 36            1230           9476              4     289.0     318.0
# 9             1230           9476             27     290.0     328.0
# 61            1230           9476             44     291.0     325.0
# 71            1230           9476             63     292.0     326.0
# 26            1230           9476             81     291.0     322.0
# 23            1230           9476             31     292.0     322.0
# 18            1230           9476             10     289.0     322.0
# 7             1230           9476              2     287.0     325.0
# 0             1230           9476             20     289.0     329.0
# 6             1230           9476              2     290.0     325.0
# 32            1230           9476             23     289.0     328.0
# 13            1230           9476             77     291.0     326.0
# 5             1230           9476              2     290.0     324.0
# 12            1230           9476             77     291.0     325.0
# 17            1230           9476             10     289.0     320.0
# 21            1230           9476             31     291.0     325.0
# 22            1230           9476             31     290.0     325.0
# 56            1230           9476             38     287.0     323.0
# 50            1230           9476             18     291.0     325.0
# 38            1230           9476              4     290.0     304.0
# 16            1230           9476             10     271.0     303.0
# 20            1230           9476             31     273.0     311.0
# 19            1230           9476             10     280.0     303.0
# 15            1230           9476             77     292.0     259.0
# 10            1230           9476             27     264.0     305.0
# 62            1230           9476             44     270.0     290.0
#
#      st_speed                  date_start  lap_duration  is_pit_out_lap  \
# 91      333.0  2024-03-08T17:16:04.311000        88.171           False
# 51      328.0  2024-03-08T17:16:41.551000        88.250           False
# 79      330.0  2024-03-08T17:13:27.780000        88.318           False
# 90      330.0  2024-03-08T17:07:55.755000        88.491           False
# 85      329.0  2024-03-08T17:15:54.306000        88.638           False
# 78      329.0  2024-03-08T17:08:04.856000        88.668           False
# 45      329.0  2024-03-08T17:08:12.436000        88.706           False
# 72      329.0  2024-03-08T17:10:55.510000        88.749           False
# 25      325.0  2024-03-08T17:05:56.443000        88.755           False
# 84      330.0  2024-03-08T17:07:34.560000        88.761           False
# 37      325.0  2024-03-08T17:06:13.968000        88.805           False
# 44      329.0  2024-03-08T17:02:59.343000        88.876           False
# 57      330.0  2024-03-08T17:06:49.531000        88.984           False
# 101     331.0  2024-03-08T17:16:21.706000        88.988           False
# 63      332.0  2024-03-08T17:10:33.720000        88.994           False
# 77      329.0  2024-03-08T17:04:33.759000        89.004           False
# 11      332.0  2024-03-08T17:13:38.387000        89.055           False
# 97      332.0  2024-03-08T17:16:14.759000        89.065           False
# 1       334.0  2024-03-08T17:05:22.831000        89.069           False
# 2       333.0  2024-03-08T17:13:32.597000        89.086           False
# 33      328.0  2024-03-08T17:06:04.867000        89.107           False
# 49      323.0  2024-03-08T17:03:08.898000        89.130           False
# 64      332.0  2024-03-08T17:16:09.634000        89.156           False
# 58      329.0  2024-03-08T17:10:16.779000        89.160           False
# 8       338.0  2024-03-08T17:02:11.082000        89.173           False
# 14      328.0  2024-03-08T17:13:42.772000        89.179           False
# 96      330.0  2024-03-08T17:08:24.355000        89.198           False
# 24      324.0  2024-03-08T17:02:28.897000        89.210           False
# 100     330.0  2024-03-08T17:08:44.320000        89.214           False
# 36      323.0  2024-03-08T17:02:49.703000        89.241           False
# 9       332.0  2024-03-08T17:05:38.215000        89.357           False
# 61      330.0  2024-03-08T17:03:35.151000        89.362           False
# 71      331.0  2024-03-08T17:03:40.870000        89.411           False
# 26      323.0  2024-03-08T17:14:08.300000        89.458           False
# 23      330.0  2024-03-08T17:16:46.486000        89.475           False
# 18      327.0  2024-03-08T17:07:24.912000        89.479           False
# 7       330.0  2024-03-08T17:15:19.135000        89.526           False
# 0       334.0  2024-03-08T17:01:56.784000        89.528           False
# 6       329.0  2024-03-08T17:07:46.278000        89.540           False
# 32      331.0  2024-03-08T17:02:34.004000        89.551           False
# 13      329.0  2024-03-08T17:05:43.954000        89.634           False
# 5       332.0  2024-03-08T17:02:04.861000        89.696           False
# 12      328.0  2024-03-08T17:02:15.619000        89.719           False
# 17      327.0  2024-03-08T17:03:58.987000        89.723           False
# 21      332.0  2024-03-08T17:04:02.298000        89.813           False
# 22      330.0  2024-03-08T17:07:29.632000        89.826           False
# 56      329.0  2024-03-08T17:03:23.938000        90.136           False
# 50      292.0  2024-03-08T17:08:32.517000        96.234           False
# 38      207.0  2024-03-08T17:14:02.088000        98.606           False
# 16      293.0  2024-03-08T17:02:19.567000        99.332           False
# 20      313.0  2024-03-08T17:02:22.628000        99.710           False
# 19      296.0  2024-03-08T17:14:45.743000       100.921           False
# 15      296.0  2024-03-08T17:17:07.458000       101.949           False
# 10      308.0  2024-03-08T17:07:07.436000       102.532           False
# 62      317.0  2024-03-08T17:05:04.451000       102.766           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 91              31.953  ...    M VERSTAPPEN           NED        Max
# 51              32.047  ...        L STROLL           CAN      Lance
# 79              32.100  ...       C LECLERC           MON    Charles
# 90              32.081  ...    M VERSTAPPEN           NED        Max
# 85              32.081  ...         S PEREZ           MEX     Sergio
# 78              32.233  ...       C LECLERC           MON    Charles
# 45              32.092  ...        F ALONSO           ESP   Fernando
# 72              32.386  ...       G RUSSELL           GBR     George
# 25              32.137  ...       O PIASTRI           AUS      Oscar
# 84              32.232  ...         S PEREZ           MEX     Sergio
# 37              32.202  ...        L NORRIS           GBR      Lando
# 44              32.358  ...        F ALONSO           ESP   Fernando
# 57              32.439  ...       O BEARMAN           GBR     Oliver
# 101             32.414  ...       Y TSUNODA           JPN       Yuki
# 63              32.521  ...      L HAMILTON           GBR      Lewis
# 77              32.522  ...       C LECLERC           MON    Charles
# 11              32.530  ...    N HULKENBERG           GER       Nico
# 97              32.463  ...     D RICCIARDO           AUS     Daniel
# 1               32.494  ...     K MAGNUSSEN           DEN      Kevin
# 2               32.509  ...     K MAGNUSSEN           DEN      Kevin
# 33              32.284  ...         A ALBON           THA  Alexander
# 49              32.210  ...        L STROLL           CAN      Lance
# 64              32.558  ...      L HAMILTON           GBR      Lewis
# 58              32.449  ...       O BEARMAN           GBR     Oliver
# 8               32.645  ...    N HULKENBERG           GER       Nico
# 14              32.479  ...        V BOTTAS           FIN   Valtteri
# 96              32.466  ...     D RICCIARDO           AUS     Daniel
# 24              32.411  ...       O PIASTRI           AUS      Oscar
# 100             32.478  ...       Y TSUNODA           JPN       Yuki
# 36              32.458  ...        L NORRIS           GBR      Lando
# 9               32.614  ...    N HULKENBERG           GER       Nico
# 61              32.565  ...      L HAMILTON           GBR      Lewis
# 71              32.657  ...       G RUSSELL           GBR     George
# 26              32.390  ...       O PIASTRI           AUS      Oscar
# 23              32.655  ...          E OCON           FRA    Esteban
# 18              32.518  ...         P GASLY           FRA     Pierre
# 7               32.691  ...      L SARGEANT           USA      Logan
# 0               32.865  ...     K MAGNUSSEN           DEN      Kevin
# 6               32.594  ...      L SARGEANT           USA      Logan
# 32              32.633  ...         A ALBON           THA  Alexander
# 13              32.823  ...        V BOTTAS           FIN   Valtteri
# 5               32.770  ...      L SARGEANT           USA      Logan
# 12              32.917  ...        V BOTTAS           FIN   Valtteri
# 17              32.620  ...         P GASLY           FRA     Pierre
# 21              32.644  ...          E OCON           FRA    Esteban
# 22              32.777  ...          E OCON           FRA    Esteban
# 56              33.008  ...       O BEARMAN           GBR     Oliver
# 50              32.322  ...        L STROLL           CAN      Lance
# 38              32.225  ...        L NORRIS           GBR      Lando
# 16              36.102  ...         P GASLY           FRA     Pierre
# 20              36.193  ...          E OCON           FRA    Esteban
# 19              36.045  ...         P GASLY           FRA     Pierre
# 15              32.527  ...        V BOTTAS           FIN   Valtteri
# 10              37.156  ...    N HULKENBERG           GER       Nico
# 62              37.084  ...      L HAMILTON           GBR      Lewis
#
#             full_name                                       headshot_url  \
# 91     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 51       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 79    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 90     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 85       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 78    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 45    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 72     George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 25      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 84       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 37       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 44    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 57     Oliver BEARMAN                                               None
# 101      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 63     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 77    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 11    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 97   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 1     Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 2     Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 33    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 49       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 64     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 58     Oliver BEARMAN                                               None
# 8     Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 14    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 96   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 24      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 100      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 36       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 9     Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 61     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 71     George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 26      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 23       Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 18       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 7      Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 0     Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 6      Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 32    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 13    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 5      Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
# 12    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 17       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 21       Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 22       Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 56     Oliver BEARMAN                                               None
# 50       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 38       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 16       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 20       Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 19       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 15    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 10    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 62     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name                                        team_colour  \
# 91   Verstappen                                             3671c6
# 51       Stroll                                             229971
# 79      Leclerc                                             e8002d
# 90   Verstappen                                             3671c6
# 85        Perez                                             3671c6
# 78      Leclerc                                             e8002d
# 45       Alonso                                             229971
# 72      Russell                                             27f4d2
# 25      Piastri                                             ff8000
# 84        Perez                                             3671c6
# 37       Norris                                             ff8000
# 44       Alonso                                             229971
# 57      Bearman                                             e8002d
# 101     Tsunoda                                             6692ff
# 63     Hamilton                                             27f4d2
# 77      Leclerc                                             e8002d
# 11   Hulkenberg                                             b6babd
# 97    Ricciardo                                             6692ff
# 1     Magnussen                                             b6babd
# 2     Magnussen                                             b6babd
# 33        Albon                                             64c4ff
# 49       Stroll                                             229971
# 64     Hamilton                                             27f4d2
# 58      Bearman                                             e8002d
# 8    Hulkenberg                                             b6babd
# 14       Bottas  5200000000000000190003903645130092385429788960...
# 96    Ricciardo                                             6692ff
# 24      Piastri                                             ff8000
# 100     Tsunoda                                             6692ff
# 36       Norris                                             ff8000
# 9    Hulkenberg                                             b6babd
# 61     Hamilton                                             27f4d2
# 71      Russell                                             27f4d2
# 26      Piastri                                             ff8000
# 23         Ocon                                             ff87bc
# 18        Gasly                                             ff87bc
# 7      Sargeant                                             64c4ff
# 0     Magnussen                                             b6babd
# 6      Sargeant                                             64c4ff
# 32        Albon                                             64c4ff
# 13       Bottas  5200000000000000190003903645130092385429788960...
# 5      Sargeant                                             64c4ff
# 12       Bottas  5200000000000000190003903645130092385429788960...
# 17        Gasly                                             ff87bc
# 21         Ocon                                             ff87bc
# 22         Ocon                                             ff87bc
# 56      Bearman                                             e8002d
# 50       Stroll                                             229971
# 38       Norris                                             ff8000
# 16        Gasly                                             ff87bc
# 20         Ocon                                             ff87bc
# 19        Gasly                                             ff87bc
# 15       Bottas  5200000000000000190003903645130092385429788960...
# 10   Hulkenberg                                             b6babd
# 62     Hamilton                                             27f4d2
#
#            team_name name_acronym isFastestLap
# 91   Red Bull Racing          VER         True
# 51      Aston Martin          STR         True
# 79           Ferrari          LEC         True
# 90   Red Bull Racing          VER        False
# 85   Red Bull Racing          PER         True
# 78           Ferrari          LEC        False
# 45      Aston Martin          ALO         True
# 72          Mercedes          RUS         True
# 25           McLaren          PIA         True
# 84   Red Bull Racing          PER        False
# 37           McLaren          NOR         True
# 44      Aston Martin          ALO        False
# 57           Ferrari          BEA         True
# 101               RB          TSU         True
# 63          Mercedes          HAM         True
# 77           Ferrari          LEC        False
# 11      Haas F1 Team          HUL         True
# 97                RB          RIC         True
# 1       Haas F1 Team          MAG         True
# 2       Haas F1 Team          MAG        False
# 33          Williams          ALB         True
# 49      Aston Martin          STR        False
# 64          Mercedes          HAM        False
# 58           Ferrari          BEA        False
# 8       Haas F1 Team          HUL        False
# 14       Kick Sauber          BOT         True
# 96                RB          RIC        False
# 24           McLaren          PIA        False
# 100               RB          TSU        False
# 36           McLaren          NOR        False
# 9       Haas F1 Team          HUL        False
# 61          Mercedes          HAM        False
# 71          Mercedes          RUS        False
# 26           McLaren          PIA        False
# 23            Alpine          OCO         True
# 18            Alpine          GAS         True
# 7           Williams          SAR         True
# 0       Haas F1 Team          MAG        False
# 6           Williams          SAR        False
# 32          Williams          ALB        False
# 13       Kick Sauber          BOT        False
# 5           Williams          SAR        False
# 12       Kick Sauber          BOT        False
# 17            Alpine          GAS        False
# 21            Alpine          OCO        False
# 22            Alpine          OCO        False
# 56           Ferrari          BEA        False
# 50      Aston Martin          STR        False
# 38           McLaren          NOR        False
# 16            Alpine          GAS        False
# 20            Alpine          OCO        False
# 19            Alpine          GAS        False
# 15       Kick Sauber          BOT        False
# 10      Haas F1 Team          HUL        False
# 62          Mercedes          HAM        False
#
# [55 rows x 28 columns]

# %%
mergequalyQ1 =mergequalyQ1.query("date_start <'2024-03-08T17:18:03.464000'and isFastestLap == True").sort_values(by='lap_duration')
mergequalyQ1
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 91            1230           9476              1     294.0     327.0
# 51            1230           9476             18     293.0     322.0
# 79            1230           9476             16     290.0     327.0
# 85            1230           9476             11     293.0     324.0
# 45            1230           9476             14     292.0     325.0
# 72            1230           9476             63     292.0     324.0
# 25            1230           9476             81     292.0     324.0
# 37            1230           9476              4     290.0     322.0
# 57            1230           9476             38     290.0     325.0
# 101           1230           9476             22     293.0     327.0
# 63            1230           9476             44     291.0     327.0
# 11            1230           9476             27     291.0     330.0
# 97            1230           9476              3     292.0     328.0
# 1             1230           9476             20     292.0     331.0
# 33            1230           9476             23     292.0     323.0
# 14            1230           9476             77     291.0     326.0
# 23            1230           9476             31     292.0     322.0
# 18            1230           9476             10     289.0     322.0
# 7             1230           9476              2     287.0     325.0
#
#      st_speed                  date_start  lap_duration  is_pit_out_lap  \
# 91      333.0  2024-03-08T17:16:04.311000        88.171           False
# 51      328.0  2024-03-08T17:16:41.551000        88.250           False
# 79      330.0  2024-03-08T17:13:27.780000        88.318           False
# 85      329.0  2024-03-08T17:15:54.306000        88.638           False
# 45      329.0  2024-03-08T17:08:12.436000        88.706           False
# 72      329.0  2024-03-08T17:10:55.510000        88.749           False
# 25      325.0  2024-03-08T17:05:56.443000        88.755           False
# 37      325.0  2024-03-08T17:06:13.968000        88.805           False
# 57      330.0  2024-03-08T17:06:49.531000        88.984           False
# 101     331.0  2024-03-08T17:16:21.706000        88.988           False
# 63      332.0  2024-03-08T17:10:33.720000        88.994           False
# 11      332.0  2024-03-08T17:13:38.387000        89.055           False
# 97      332.0  2024-03-08T17:16:14.759000        89.065           False
# 1       334.0  2024-03-08T17:05:22.831000        89.069           False
# 33      328.0  2024-03-08T17:06:04.867000        89.107           False
# 14      328.0  2024-03-08T17:13:42.772000        89.179           False
# 23      330.0  2024-03-08T17:16:46.486000        89.475           False
# 18      327.0  2024-03-08T17:07:24.912000        89.479           False
# 7       330.0  2024-03-08T17:15:19.135000        89.526           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 91              31.953  ...    M VERSTAPPEN           NED        Max
# 51              32.047  ...        L STROLL           CAN      Lance
# 79              32.100  ...       C LECLERC           MON    Charles
# 85              32.081  ...         S PEREZ           MEX     Sergio
# 45              32.092  ...        F ALONSO           ESP   Fernando
# 72              32.386  ...       G RUSSELL           GBR     George
# 25              32.137  ...       O PIASTRI           AUS      Oscar
# 37              32.202  ...        L NORRIS           GBR      Lando
# 57              32.439  ...       O BEARMAN           GBR     Oliver
# 101             32.414  ...       Y TSUNODA           JPN       Yuki
# 63              32.521  ...      L HAMILTON           GBR      Lewis
# 11              32.530  ...    N HULKENBERG           GER       Nico
# 97              32.463  ...     D RICCIARDO           AUS     Daniel
# 1               32.494  ...     K MAGNUSSEN           DEN      Kevin
# 33              32.284  ...         A ALBON           THA  Alexander
# 14              32.479  ...        V BOTTAS           FIN   Valtteri
# 23              32.655  ...          E OCON           FRA    Esteban
# 18              32.518  ...         P GASLY           FRA     Pierre
# 7               32.691  ...      L SARGEANT           USA      Logan
#
#             full_name                                       headshot_url  \
# 91     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 51       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 79    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 85       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 45    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 72     George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 25      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 37       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 57     Oliver BEARMAN                                               None
# 101      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 63     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 11    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 97   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
# 1     Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 33    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 14    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 23       Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 18       Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 7      Logan SARGEANT  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name                                        team_colour  \
# 91   Verstappen                                             3671c6
# 51       Stroll                                             229971
# 79      Leclerc                                             e8002d
# 85        Perez                                             3671c6
# 45       Alonso                                             229971
# 72      Russell                                             27f4d2
# 25      Piastri                                             ff8000
# 37       Norris                                             ff8000
# 57      Bearman                                             e8002d
# 101     Tsunoda                                             6692ff
# 63     Hamilton                                             27f4d2
# 11   Hulkenberg                                             b6babd
# 97    Ricciardo                                             6692ff
# 1     Magnussen                                             b6babd
# 33        Albon                                             64c4ff
# 14       Bottas  5200000000000000190003903645130092385429788960...
# 23         Ocon                                             ff87bc
# 18        Gasly                                             ff87bc
# 7      Sargeant                                             64c4ff
#
#            team_name name_acronym isFastestLap
# 91   Red Bull Racing          VER         True
# 51      Aston Martin          STR         True
# 79           Ferrari          LEC         True
# 85   Red Bull Racing          PER         True
# 45      Aston Martin          ALO         True
# 72          Mercedes          RUS         True
# 25           McLaren          PIA         True
# 37           McLaren          NOR         True
# 57           Ferrari          BEA         True
# 101               RB          TSU         True
# 63          Mercedes          HAM         True
# 11      Haas F1 Team          HUL         True
# 97                RB          RIC         True
# 1       Haas F1 Team          MAG         True
# 33          Williams          ALB         True
# 14       Kick Sauber          BOT         True
# 23            Alpine          OCO         True
# 18            Alpine          GAS         True
# 7           Williams          SAR         True
#
# [19 rows x 28 columns]

# %%
def obtain_difference_regard_reference(row,reference,newdataset):
    difference_sector_1 = row.duration_sector_1 - reference.duration_sector_1.iloc[0]
    difference_sector_2 = row.duration_sector_2 - reference.duration_sector_2.iloc[0]
    difference_sector_3 = row.duration_sector_3 - reference.duration_sector_3.iloc[0]
    lap_duration = row.lap_duration - reference.lap_duration.iloc[0]
    new_row = {'driver_number':row.driver_number,'lap_duration':lap_duration,'difference_sector_1':difference_sector_1 ,'difference_sector_2':difference_sector_2,'difference_sector_3':difference_sector_3,'name_acronym':row.name_acronym   }
    
    newdataset =pd.concat([newdataset, pd.DataFrame([new_row])], ignore_index=True)
    return newdataset

# %%
#Reference
P15 = mergequalyQ1[14:15]
P15
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 33           1230           9476             23     292.0     323.0     328.0
#
#                     date_start  lap_duration  is_pit_out_lap  \
# 33  2024-03-08T17:06:04.867000        89.107           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 33             32.284  ...         A ALBON           THA  Alexander
#
#           full_name                                       headshot_url  \
# 33  Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
#
#     last_name  team_colour  team_name name_acronym isFastestLap
# 33      Albon       64c4ff   Williams          ALB         True
#
# [1 rows x 28 columns]

# %%
print(
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)
# Out:
# Sector 1:  32.284 Sector 2:  28.293 Sector 3:  28.53

# %%
newdataset2 = pd.DataFrame()
for index,row in mergequalyQ1[15::].iterrows():
    newdataset2 = obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             77         0.072                0.195                0.048
# 1             31         0.368                0.371               -0.043
# 2             10         0.372                0.234                0.076
# 3              2         0.419                0.407                0.090
#
#    difference_sector_3 name_acronym
# 0               -0.171          BOT
# 1                0.040          OCO
# 2                0.062          GAS
# 3               -0.078          SAR

# %%
# Datos de la Q2
mergequalyQ2 =mergequaly.query("date_start >'2024-03-08T17:18:20.464000' and date_start <'2024-03-08T17:45:03.464000'").sort_values(by='lap_duration')

# %%
mergequalyQ2
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 93            1230           9476              1     295.0     327.0
# 92            1230           9476              1     293.0     327.0
# 81            1230           9476             16     290.0     325.0
# 46            1230           9476             14     291.0     327.0
# 80            1230           9476             16     290.0     325.0
# 29            1230           9476             81     290.0     321.0
# 75            1230           9476             63     293.0     325.0
# 87            1230           9476             11     292.0     325.0
# 40            1230           9476              4     290.0     318.0
# 28            1230           9476             81     290.0     320.0
# 86            1230           9476             11     292.0     327.0
# 104           1230           9476             22     293.0     327.0
# 52            1230           9476             18     290.0     324.0
# 41            1230           9476              4     291.0     323.0
# 68            1230           9476             44     293.0     327.0
# 73            1230           9476             63     294.0     324.0
# 74            1230           9476             63     294.0     326.0
# 60            1230           9476             38     291.0     327.0
# 39            1230           9476              4     292.0     322.0
# 102           1230           9476             22     293.0     325.0
# 65            1230           9476             44     293.0     325.0
# 59            1230           9476             38     290.0     324.0
# 27            1230           9476             81     291.0     320.0
# 66            1230           9476             44     292.0     327.0
# 35            1230           9476             23     290.0     328.0
# 3             1230           9476             20     291.0     329.0
# 98            1230           9476              3     291.0     327.0
# 99            1230           9476              3     292.0     328.0
# 34            1230           9476             23     290.0     326.0
# 53            1230           9476             18     292.0     277.0
# 67            1230           9476             44     267.0     295.0
# 4             1230           9476             20     270.0     307.0
# 103           1230           9476             22     264.0     292.0
#
#      st_speed                  date_start  lap_duration  is_pit_out_lap  \
# 93      331.0  2024-03-08T17:44:12.467000        88.033           False
# 92      329.0  2024-03-08T17:36:28.850000        88.078           False
# 81      330.0  2024-03-08T17:44:20.251000        88.112           False
# 46      331.0  2024-03-08T17:36:34.966000        88.122           False
# 80      330.0  2024-03-08T17:37:11.226000        88.179           False
# 29      325.0  2024-03-08T17:43:01.640000        88.343           False
# 75      331.0  2024-03-08T17:43:19.483000        88.448           False
# 87      331.0  2024-03-08T17:43:42.932000        88.467           False
# 40      322.0  2024-03-08T17:40:23.554000        88.479           False
# 28      325.0  2024-03-08T17:39:42.087000        88.483           False
# 86      330.0  2024-03-08T17:36:10.510000        88.539           False
# 104     332.0  2024-03-08T17:44:02.525000        88.564           False
# 52      328.0  2024-03-08T17:36:44.432000        88.578           False
# 41      327.0  2024-03-08T17:43:48.711000        88.582           False
# 68      332.0  2024-03-08T17:43:07.401000        88.606           False
# 73      329.0  2024-03-08T17:27:06.681000        88.608           False
# 74      331.0  2024-03-08T17:36:05.305000        88.635           False
# 60      331.0  2024-03-08T17:44:06.894000        88.642           False
# 39      325.0  2024-03-08T17:27:20.693000        88.643           False
# 102     331.0  2024-03-08T17:37:00.352000        88.659           False
# 65      330.0  2024-03-08T17:26:58.740000        88.680           False
# 59      329.0  2024-03-08T17:40:32.086000        88.915           False
# 27      326.0  2024-03-08T17:27:14.656000        88.918           False
# 66      330.0  2024-03-08T17:35:58.990000        88.946           False
# 35      330.0  2024-03-08T17:42:42.293000        88.980           False
# 3       332.0  2024-03-08T17:36:51.444000        89.020           False
# 98      331.0  2024-03-08T17:36:18.703000        89.025           False
# 99      333.0  2024-03-08T17:43:56.099000        89.047           False
# 34      330.0  2024-03-08T17:37:17.650000        89.409           False
# 53      301.0  2024-03-08T17:44:26.075000        97.837           False
# 67      297.0  2024-03-08T17:37:27.330000       102.132           False
# 4       293.0  2024-03-08T17:38:20.410000       102.375           False
# 103     303.0  2024-03-08T17:38:28.850000       102.990           False
#
#      duration_sector_1  ...  meeting_key_y  broadcast_name country_code  \
# 93              31.892  ...           1230    M VERSTAPPEN          NED
# 92              31.976  ...           1230    M VERSTAPPEN          NED
# 81              32.109  ...           1230       C LECLERC          MON
# 46              31.964  ...           1230        F ALONSO          ESP
# 80              32.040  ...           1230       C LECLERC          MON
# 29              32.061  ...           1230       O PIASTRI          AUS
# 75              32.470  ...           1230       G RUSSELL          GBR
# 87              32.209  ...           1230         S PEREZ          MEX
# 40              32.068  ...           1230        L NORRIS          GBR
# 28              32.068  ...           1230       O PIASTRI          AUS
# 86              32.254  ...           1230         S PEREZ          MEX
# 104             32.268  ...           1230       Y TSUNODA          JPN
# 52              32.083  ...           1230        L STROLL          CAN
# 41              32.168  ...           1230        L NORRIS          GBR
# 68              32.499  ...           1230      L HAMILTON          GBR
# 73              32.344  ...           1230       G RUSSELL          GBR
# 74              32.451  ...           1230       G RUSSELL          GBR
# 60              32.255  ...           1230       O BEARMAN          GBR
# 39              32.103  ...           1230        L NORRIS          GBR
# 102             32.217  ...           1230       Y TSUNODA          JPN
# 65              32.341  ...           1230      L HAMILTON          GBR
# 59              32.361  ...           1230       O BEARMAN          GBR
# 27              32.321  ...           1230       O PIASTRI          AUS
# 66              32.547  ...           1230      L HAMILTON          GBR
# 35              32.484  ...           1230         A ALBON          THA
# 3               32.514  ...           1230     K MAGNUSSEN          DEN
# 98              32.595  ...           1230     D RICCIARDO          AUS
# 99              32.622  ...           1230     D RICCIARDO          AUS
# 34              32.595  ...           1230         A ALBON          THA
# 53              32.020  ...           1230        L STROLL          CAN
# 67              36.589  ...           1230      L HAMILTON          GBR
# 4               36.567  ...           1230     K MAGNUSSEN          DEN
# 103             37.020  ...           1230       Y TSUNODA          JPN
#
#     first_name         full_name  \
# 93         Max    Max VERSTAPPEN
# 92         Max    Max VERSTAPPEN
# 81     Charles   Charles LECLERC
# 46    Fernando   Fernando ALONSO
# 80     Charles   Charles LECLERC
# 29       Oscar     Oscar PIASTRI
# 75      George    George RUSSELL
# 87      Sergio      Sergio PEREZ
# 40       Lando      Lando NORRIS
# 28       Oscar     Oscar PIASTRI
# 86      Sergio      Sergio PEREZ
# 104       Yuki      Yuki TSUNODA
# 52       Lance      Lance STROLL
# 41       Lando      Lando NORRIS
# 68       Lewis    Lewis HAMILTON
# 73      George    George RUSSELL
# 74      George    George RUSSELL
# 60      Oliver    Oliver BEARMAN
# 39       Lando      Lando NORRIS
# 102       Yuki      Yuki TSUNODA
# 65       Lewis    Lewis HAMILTON
# 59      Oliver    Oliver BEARMAN
# 27       Oscar     Oscar PIASTRI
# 66       Lewis    Lewis HAMILTON
# 35   Alexander   Alexander ALBON
# 3        Kevin   Kevin MAGNUSSEN
# 98      Daniel  Daniel RICCIARDO
# 99      Daniel  Daniel RICCIARDO
# 34   Alexander   Alexander ALBON
# 53       Lance      Lance STROLL
# 67       Lewis    Lewis HAMILTON
# 4        Kevin   Kevin MAGNUSSEN
# 103       Yuki      Yuki TSUNODA
#
#                                           headshot_url   last_name  \
# 93   https://media.formula1.com/d_driver_fallback_i...  Verstappen
# 92   https://media.formula1.com/d_driver_fallback_i...  Verstappen
# 81   https://media.formula1.com/d_driver_fallback_i...     Leclerc
# 46   https://media.formula1.com/d_driver_fallback_i...      Alonso
# 80   https://media.formula1.com/d_driver_fallback_i...     Leclerc
# 29   https://media.formula1.com/d_driver_fallback_i...     Piastri
# 75   https://media.formula1.com/d_driver_fallback_i...     Russell
# 87   https://media.formula1.com/d_driver_fallback_i...       Perez
# 40   https://media.formula1.com/d_driver_fallback_i...      Norris
# 28   https://media.formula1.com/d_driver_fallback_i...     Piastri
# 86   https://media.formula1.com/d_driver_fallback_i...       Perez
# 104  https://media.formula1.com/d_driver_fallback_i...     Tsunoda
# 52   https://media.formula1.com/d_driver_fallback_i...      Stroll
# 41   https://media.formula1.com/d_driver_fallback_i...      Norris
# 68   https://media.formula1.com/d_driver_fallback_i...    Hamilton
# 73   https://media.formula1.com/d_driver_fallback_i...     Russell
# 74   https://media.formula1.com/d_driver_fallback_i...     Russell
# 60                                                None     Bearman
# 39   https://media.formula1.com/d_driver_fallback_i...      Norris
# 102  https://media.formula1.com/d_driver_fallback_i...     Tsunoda
# 65   https://media.formula1.com/d_driver_fallback_i...    Hamilton
# 59                                                None     Bearman
# 27   https://media.formula1.com/d_driver_fallback_i...     Piastri
# 66   https://media.formula1.com/d_driver_fallback_i...    Hamilton
# 35   https://media.formula1.com/d_driver_fallback_i...       Albon
# 3    https://media.formula1.com/d_driver_fallback_i...   Magnussen
# 98   https://media.formula1.com/d_driver_fallback_i...   Ricciardo
# 99   https://media.formula1.com/d_driver_fallback_i...   Ricciardo
# 34   https://media.formula1.com/d_driver_fallback_i...       Albon
# 53   https://media.formula1.com/d_driver_fallback_i...      Stroll
# 67   https://media.formula1.com/d_driver_fallback_i...    Hamilton
# 4    https://media.formula1.com/d_driver_fallback_i...   Magnussen
# 103  https://media.formula1.com/d_driver_fallback_i...     Tsunoda
#
#      team_colour        team_name name_acronym
# 93        3671c6  Red Bull Racing          VER
# 92        3671c6  Red Bull Racing          VER
# 81        e8002d          Ferrari          LEC
# 46        229971     Aston Martin          ALO
# 80        e8002d          Ferrari          LEC
# 29        ff8000          McLaren          PIA
# 75        27f4d2         Mercedes          RUS
# 87        3671c6  Red Bull Racing          PER
# 40        ff8000          McLaren          NOR
# 28        ff8000          McLaren          PIA
# 86        3671c6  Red Bull Racing          PER
# 104       6692ff               RB          TSU
# 52        229971     Aston Martin          STR
# 41        ff8000          McLaren          NOR
# 68        27f4d2         Mercedes          HAM
# 73        27f4d2         Mercedes          RUS
# 74        27f4d2         Mercedes          RUS
# 60        e8002d          Ferrari          BEA
# 39        ff8000          McLaren          NOR
# 102       6692ff               RB          TSU
# 65        27f4d2         Mercedes          HAM
# 59        e8002d          Ferrari          BEA
# 27        ff8000          McLaren          PIA
# 66        27f4d2         Mercedes          HAM
# 35        64c4ff         Williams          ALB
# 3         b6babd     Haas F1 Team          MAG
# 98        6692ff               RB          RIC
# 99        6692ff               RB          RIC
# 34        64c4ff         Williams          ALB
# 53        229971     Aston Martin          STR
# 67        27f4d2         Mercedes          HAM
# 4         b6babd     Haas F1 Team          MAG
# 103       6692ff               RB          TSU
#
# [33 rows x 27 columns]

# %%
isFastestLap = []
for index,row in mergequalyQ2.iterrows():
    driver = row.driver_number
    fastest_lap = mergequalyQ2.query("driver_number == @driver").lap_duration.min()
    if row.lap_duration == fastest_lap:
        isFastestLap.append(True)
    else:
        isFastestLap.append(False)
        
mergequalyQ2['isFastestLap'] = isFastestLap

# %%
mergequalyQ2 =mergequalyQ2.query("isFastestLap == True ").sort_values(by='lap_duration')
mergequalyQ2
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 93            1230           9476              1     295.0     327.0
# 81            1230           9476             16     290.0     325.0
# 46            1230           9476             14     291.0     327.0
# 29            1230           9476             81     290.0     321.0
# 75            1230           9476             63     293.0     325.0
# 87            1230           9476             11     292.0     325.0
# 40            1230           9476              4     290.0     318.0
# 104           1230           9476             22     293.0     327.0
# 52            1230           9476             18     290.0     324.0
# 68            1230           9476             44     293.0     327.0
# 60            1230           9476             38     291.0     327.0
# 35            1230           9476             23     290.0     328.0
# 3             1230           9476             20     291.0     329.0
# 98            1230           9476              3     291.0     327.0
#
#      st_speed                  date_start  lap_duration  is_pit_out_lap  \
# 93      331.0  2024-03-08T17:44:12.467000        88.033           False
# 81      330.0  2024-03-08T17:44:20.251000        88.112           False
# 46      331.0  2024-03-08T17:36:34.966000        88.122           False
# 29      325.0  2024-03-08T17:43:01.640000        88.343           False
# 75      331.0  2024-03-08T17:43:19.483000        88.448           False
# 87      331.0  2024-03-08T17:43:42.932000        88.467           False
# 40      322.0  2024-03-08T17:40:23.554000        88.479           False
# 104     332.0  2024-03-08T17:44:02.525000        88.564           False
# 52      328.0  2024-03-08T17:36:44.432000        88.578           False
# 68      332.0  2024-03-08T17:43:07.401000        88.606           False
# 60      331.0  2024-03-08T17:44:06.894000        88.642           False
# 35      330.0  2024-03-08T17:42:42.293000        88.980           False
# 3       332.0  2024-03-08T17:36:51.444000        89.020           False
# 98      331.0  2024-03-08T17:36:18.703000        89.025           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 93              31.892  ...    M VERSTAPPEN           NED        Max
# 81              32.109  ...       C LECLERC           MON    Charles
# 46              31.964  ...        F ALONSO           ESP   Fernando
# 29              32.061  ...       O PIASTRI           AUS      Oscar
# 75              32.470  ...       G RUSSELL           GBR     George
# 87              32.209  ...         S PEREZ           MEX     Sergio
# 40              32.068  ...        L NORRIS           GBR      Lando
# 104             32.268  ...       Y TSUNODA           JPN       Yuki
# 52              32.083  ...        L STROLL           CAN      Lance
# 68              32.499  ...      L HAMILTON           GBR      Lewis
# 60              32.255  ...       O BEARMAN           GBR     Oliver
# 35              32.484  ...         A ALBON           THA  Alexander
# 3               32.514  ...     K MAGNUSSEN           DEN      Kevin
# 98              32.595  ...     D RICCIARDO           AUS     Daniel
#
#             full_name                                       headshot_url  \
# 93     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 81    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 46    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 29      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 75     George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 87       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 40       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 104      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 52       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 68     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 60     Oliver BEARMAN                                               None
# 35    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 3     Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 98   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name  team_colour        team_name name_acronym isFastestLap
# 93   Verstappen       3671c6  Red Bull Racing          VER         True
# 81      Leclerc       e8002d          Ferrari          LEC         True
# 46       Alonso       229971     Aston Martin          ALO         True
# 29      Piastri       ff8000          McLaren          PIA         True
# 75      Russell       27f4d2         Mercedes          RUS         True
# 87        Perez       3671c6  Red Bull Racing          PER         True
# 40       Norris       ff8000          McLaren          NOR         True
# 104     Tsunoda       6692ff               RB          TSU         True
# 52       Stroll       229971     Aston Martin          STR         True
# 68     Hamilton       27f4d2         Mercedes          HAM         True
# 60      Bearman       e8002d          Ferrari          BEA         True
# 35        Albon       64c4ff         Williams          ALB         True
# 3     Magnussen       b6babd     Haas F1 Team          MAG         True
# 98    Ricciardo       6692ff               RB          RIC         True
#
# [14 rows x 28 columns]

# %%
P10 = mergequalyQ2[9:10]

newdataset2 = pd.DataFrame()
for index,row in mergequalyQ2[10::].iterrows():
    newdataset2 = obtain_difference_regard_reference(row,P10,newdataset2)

# %%
newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             38         0.036               -0.244                0.188
# 1             23         0.374               -0.015                0.198
# 2             20         0.414                0.015                0.234
# 3              3         0.419                0.096                0.265
#
#    difference_sector_3 name_acronym
# 0                0.092          BEA
# 1                0.191          ALB
# 2                0.165          MAG
# 3                0.058          RIC

# %%
# Datos de la Q3
mergequalyQ3 =mergequaly.query(" date_start >'2024-03-08T17:45:03.464000'").sort_values(by='lap_duration')

# %%
isFastestLap = []
for index,row in mergequalyQ3.iterrows():
    driver = row.driver_number
    fastest_lap = mergequalyQ3.query("driver_number == @driver").lap_duration.min()
    if row.lap_duration == fastest_lap:
        isFastestLap.append(True)
    else:
        isFastestLap.append(False)
        
mergequalyQ3['isFastestLap'] = isFastestLap

# %%
mergequalyQ3 =mergequalyQ3.query("isFastestLap == True ").sort_values(by='lap_duration')

# %%
P1 = mergequalyQ3[::1]

newdataset2 = pd.DataFrame()
for index,row in mergequalyQ3[1::].iterrows():
    newdataset2 = obtain_difference_regard_reference(row,P1,newdataset2)

# %%
newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             16         0.319                0.170                0.042
# 1             11         0.335                0.181                0.066
# 2             14         0.374                0.077                0.023
# 3             81         0.617                0.231                0.088
# 4              4         0.660                0.117                0.222
# 5             63         0.844                0.530                0.084
# 6             44         0.988                0.656                0.079
# 7             22         1.075                0.417                0.310
# 8             18         1.100                0.180                0.212
#
#    difference_sector_3 name_acronym
# 0                0.107          LEC
# 1                0.088          PER
# 2                0.274          ALO
# 3                0.298          PIA
# 4                0.321          NOR
# 5                0.230          RUS
# 6                0.253          HAM
# 7                0.348          TSU
# 8                0.708          STR

# %% [markdown]
# ## Comparaison beetween Bearman and Hamilton in Q2

# %%
mergequalyQ2
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 93            1230           9476              1     295.0     327.0
# 81            1230           9476             16     290.0     325.0
# 46            1230           9476             14     291.0     327.0
# 29            1230           9476             81     290.0     321.0
# 75            1230           9476             63     293.0     325.0
# 87            1230           9476             11     292.0     325.0
# 40            1230           9476              4     290.0     318.0
# 104           1230           9476             22     293.0     327.0
# 52            1230           9476             18     290.0     324.0
# 68            1230           9476             44     293.0     327.0
# 60            1230           9476             38     291.0     327.0
# 35            1230           9476             23     290.0     328.0
# 3             1230           9476             20     291.0     329.0
# 98            1230           9476              3     291.0     327.0
#
#      st_speed                  date_start  lap_duration  is_pit_out_lap  \
# 93      331.0  2024-03-08T17:44:12.467000        88.033           False
# 81      330.0  2024-03-08T17:44:20.251000        88.112           False
# 46      331.0  2024-03-08T17:36:34.966000        88.122           False
# 29      325.0  2024-03-08T17:43:01.640000        88.343           False
# 75      331.0  2024-03-08T17:43:19.483000        88.448           False
# 87      331.0  2024-03-08T17:43:42.932000        88.467           False
# 40      322.0  2024-03-08T17:40:23.554000        88.479           False
# 104     332.0  2024-03-08T17:44:02.525000        88.564           False
# 52      328.0  2024-03-08T17:36:44.432000        88.578           False
# 68      332.0  2024-03-08T17:43:07.401000        88.606           False
# 60      331.0  2024-03-08T17:44:06.894000        88.642           False
# 35      330.0  2024-03-08T17:42:42.293000        88.980           False
# 3       332.0  2024-03-08T17:36:51.444000        89.020           False
# 98      331.0  2024-03-08T17:36:18.703000        89.025           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 93              31.892  ...    M VERSTAPPEN           NED        Max
# 81              32.109  ...       C LECLERC           MON    Charles
# 46              31.964  ...        F ALONSO           ESP   Fernando
# 29              32.061  ...       O PIASTRI           AUS      Oscar
# 75              32.470  ...       G RUSSELL           GBR     George
# 87              32.209  ...         S PEREZ           MEX     Sergio
# 40              32.068  ...        L NORRIS           GBR      Lando
# 104             32.268  ...       Y TSUNODA           JPN       Yuki
# 52              32.083  ...        L STROLL           CAN      Lance
# 68              32.499  ...      L HAMILTON           GBR      Lewis
# 60              32.255  ...       O BEARMAN           GBR     Oliver
# 35              32.484  ...         A ALBON           THA  Alexander
# 3               32.514  ...     K MAGNUSSEN           DEN      Kevin
# 98              32.595  ...     D RICCIARDO           AUS     Daniel
#
#             full_name                                       headshot_url  \
# 93     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 81    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 46    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 29      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 75     George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 87       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 40       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 104      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 52       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 68     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 60     Oliver BEARMAN                                               None
# 35    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 3     Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 98   Daniel RICCIARDO  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name  team_colour        team_name name_acronym isFastestLap
# 93   Verstappen       3671c6  Red Bull Racing          VER         True
# 81      Leclerc       e8002d          Ferrari          LEC         True
# 46       Alonso       229971     Aston Martin          ALO         True
# 29      Piastri       ff8000          McLaren          PIA         True
# 75      Russell       27f4d2         Mercedes          RUS         True
# 87        Perez       3671c6  Red Bull Racing          PER         True
# 40       Norris       ff8000          McLaren          NOR         True
# 104     Tsunoda       6692ff               RB          TSU         True
# 52       Stroll       229971     Aston Martin          STR         True
# 68     Hamilton       27f4d2         Mercedes          HAM         True
# 60      Bearman       e8002d          Ferrari          BEA         True
# 35        Albon       64c4ff         Williams          ALB         True
# 3     Magnussen       b6babd     Haas F1 Team          MAG         True
# 98    Ricciardo       6692ff               RB          RIC         True
#
# [14 rows x 28 columns]

# %%
bestQ2LapBearman = qualyfing_car_data.query("driver_number==38 and date>='2024-03-08T17:44:06.894000'").reset_index()
bestQ2LapBearman
# Out:
#       index  meeting_key  session_key  driver_number  \
# 0    100629         1230         9476             38
# 1    100642         1230         9476             38
# 2    100655         1230         9476             38
# 3    100668         1230         9476             38
# 4    100681         1230         9476             38
# ..      ...          ...          ...            ...
# 802  109272         1230         9476             38
# 803  109275         1230         9476             38
# 804  109278         1230         9476             38
# 805  109281         1230         9476             38
# 806  109284         1230         9476             38
#
#                            date    rpm  speed  n_gear  throttle  drs  brake
# 0    2024-03-08T17:44:06.966000  11019    310       8       100   12      0
# 1    2024-03-08T17:44:07.367000  11134    314       8       100   12      0
# 2    2024-03-08T17:44:07.526000  11166    313       8       100   12      0
# 3    2024-03-08T17:44:07.886000  11249    315       8       100   12      0
# 4    2024-03-08T17:44:08.166000  11312    318       8       100   12      0
# ..                          ...    ...    ...     ...       ...  ...    ...
# 802  2024-03-08T17:47:38.007000   3294     46       1         0    8    100
# 803  2024-03-08T17:47:38.207000   3527     44       1         0    8    100
# 804  2024-03-08T17:47:38.407000   3473     43       1         0    8    100
# 805  2024-03-08T17:47:38.847000   3774     38       1         0    8    100
# 806  2024-03-08T17:47:39.007000   4048     38       1         0    8    100
#
# [807 rows x 11 columns]

# %%
bestQ2LapHamilton = qualyfing_car_data.query("driver_number==44 and date>='2024-03-08T17:43:07.401000' and date<'2024-03-08T17:46:37.401000' ").reset_index()
bestQ2LapHamilton
# Out:
#       index  meeting_key  session_key  driver_number  \
# 0     97707         1230         9476             44
# 1     97720         1230         9476             44
# 2     97733         1230         9476             44
# 3     97746         1230         9476             44
# 4     97759         1230         9476             44
# ..      ...          ...          ...            ...
# 772  107590         1230         9476             44
# 773  107600         1230         9476             44
# 774  107610         1230         9476             44
# 775  107620         1230         9476             44
# 776  107630         1230         9476             44
#
#                            date    rpm  speed  n_gear  throttle  drs  brake
# 0    2024-03-08T17:43:07.645000  11207    314       8       100   12      0
# 1    2024-03-08T17:43:08.086000  11273    316       8       100   12      0
# 2    2024-03-08T17:43:08.286000  11303    318       8       100   12      0
# 3    2024-03-08T17:43:08.486000  11364    318       8       100   12      0
# 4    2024-03-08T17:43:08.846000  11442    321       8       100   12      0
# ..                          ...    ...    ...     ...       ...  ...    ...
# 772  2024-03-08T17:46:30.926000   6580     77       2         0    8      0
# 773  2024-03-08T17:46:31.166000   7352     74       2         0    8    100
# 774  2024-03-08T17:46:31.486000   8079     70       1         0    8    100
# 775  2024-03-08T17:46:31.646000   7254     68       1         0    8    100
# 776  2024-03-08T17:46:31.887000   6920     62       1         0    8    100
#
# [777 rows x 11 columns]

# %%
# Name of the drivers
# Currently, I am using F1 2023 data because F1 2024 does not include the colours and the team name
url = 'https://api.openf1.org/v1/location?'
print(session_key)
urltotal = url+session_key+"&driver_number=38&date>=2024-03-08T17:43:07.401000&date<2024-03-08T17:46:37.401000"

response = urlopen(urltotal)
location = json.loads(response.read().decode('utf-8'))
location = pd.DataFrame(location)
location
# Out:
# session_key=9476
#      meeting_key  session_key  driver_number                        date  \
# 0           1230         9476             38  2024-03-08T17:43:07.449000
# 1           1230         9476             38  2024-03-08T17:43:07.769000
# 2           1230         9476             38  2024-03-08T17:43:08.069000
# 3           1230         9476             38  2024-03-08T17:43:08.249000
# 4           1230         9476             38  2024-03-08T17:43:08.469000
# ..           ...          ...            ...                         ...
# 832         1230         9476             38  2024-03-08T17:46:35.749000
# 833         1230         9476             38  2024-03-08T17:46:35.949000
# 834         1230         9476             38  2024-03-08T17:46:36.130000
# 835         1230         9476             38  2024-03-08T17:46:36.370000
# 836         1230         9476             38  2024-03-08T17:46:36.569000
#
#         x      y    z
# 0   -5611  15379  117
# 1   -5648  15316  116
# 2   -5697  15205  115
# 3   -5720  15135  115
# 4   -5756  14973  115
# ..    ...    ...  ...
# 832 -4100  18415  115
# 833 -4108  18277  115
# 834 -4121  18153  114
# 835 -4148  17988  114
# 836 -4179  17852  114
#
# [837 rows x 7 columns]

# %%
location[0:50]
# Out:
#     meeting_key  session_key  driver_number                        date     x  \
# 0          1230         9476             38  2024-03-08T17:43:07.449000 -5611
# 1          1230         9476             38  2024-03-08T17:43:07.769000 -5648
# 2          1230         9476             38  2024-03-08T17:43:08.069000 -5697
# 3          1230         9476             38  2024-03-08T17:43:08.249000 -5720
# 4          1230         9476             38  2024-03-08T17:43:08.469000 -5756
# 5          1230         9476             38  2024-03-08T17:43:08.829000 -5772
# 6          1230         9476             38  2024-03-08T17:43:09.089000 -5783
# 7          1230         9476             38  2024-03-08T17:43:09.269000 -5788
# 8          1230         9476             38  2024-03-08T17:43:09.429000 -5791
# 9          1230         9476             38  2024-03-08T17:43:09.589000 -5794
# 10         1230         9476             38  2024-03-08T17:43:09.909000 -5795
# 11         1230         9476             38  2024-03-08T17:43:10.129000 -5792
# 12         1230         9476             38  2024-03-08T17:43:10.469000 -5788
# 13         1230         9476             38  2024-03-08T17:43:10.649000 -5782
# 14         1230         9476             38  2024-03-08T17:43:10.910000 -5769
# 15         1230         9476             38  2024-03-08T17:43:11.069000 -5757
# 16         1230         9476             38  2024-03-08T17:43:11.410000 -5709
# 17         1230         9476             38  2024-03-08T17:43:11.750000 -5654
# 18         1230         9476             38  2024-03-08T17:43:12.210000 -5592
# 19         1230         9476             38  2024-03-08T17:43:12.389000 -5553
# 20         1230         9476             38  2024-03-08T17:43:12.550000 -5515
# 21         1230         9476             38  2024-03-08T17:43:12.810000 -5435
# 22         1230         9476             38  2024-03-08T17:43:13.090000 -5378
# 23         1230         9476             38  2024-03-08T17:43:13.270000 -5326
# 24         1230         9476             38  2024-03-08T17:43:13.589000 -5232
# 25         1230         9476             38  2024-03-08T17:43:13.989000 -5162
# 26         1230         9476             38  2024-03-08T17:43:14.269000 -5099
# 27         1230         9476             38  2024-03-08T17:43:14.589000 -5058
# 28         1230         9476             38  2024-03-08T17:43:14.769000 -5043
# 29         1230         9476             38  2024-03-08T17:43:14.949000 -5022
# 30         1230         9476             38  2024-03-08T17:43:15.169000 -5002
# 31         1230         9476             38  2024-03-08T17:43:15.509000 -4982
# 32         1230         9476             38  2024-03-08T17:43:15.669000 -4977
# 33         1230         9476             38  2024-03-08T17:43:15.849000 -4973
# 34         1230         9476             38  2024-03-08T17:43:16.069000 -4968
# 35         1230         9476             38  2024-03-08T17:43:16.169000 -4964
# 36         1230         9476             38  2024-03-08T17:43:16.449000 -4950
# 37         1230         9476             38  2024-03-08T17:43:16.709000 -4928
# 38         1230         9476             38  2024-03-08T17:43:16.870000 -4897
# 39         1230         9476             38  2024-03-08T17:43:17.229000 -4863
# 40         1230         9476             38  2024-03-08T17:43:17.410000 -4831
# 41         1230         9476             38  2024-03-08T17:43:17.650000 -4779
# 42         1230         9476             38  2024-03-08T17:43:17.849000 -4727
# 43         1230         9476             38  2024-03-08T17:43:18.089000 -4654
# 44         1230         9476             38  2024-03-08T17:43:18.369000 -4534
# 45         1230         9476             38  2024-03-08T17:43:18.589000 -4418
# 46         1230         9476             38  2024-03-08T17:43:18.949000 -4312
# 47         1230         9476             38  2024-03-08T17:43:19.050000 -4277
# 48         1230         9476             38  2024-03-08T17:43:19.370000 -4175
# 49         1230         9476             38  2024-03-08T17:43:19.530000 -4125
#
#         y    z
# 0   15379  117
# 1   15316  116
# 2   15205  115
# 3   15135  115
# 4   14973  115
# 5   14854  115
# 6   14740  116
# 7   14660  116
# 8   14587  115
# 9   14513  116
# 10  14359  116
# 11  14187  117
# 12  14071  119
# 13  13975  120
# 14  13833  121
# 15  13744  122
# 16  13481  124
# 17  13271  124
# 18  13083  124
# 19  12978  124
# 20  12884  123
# 21  12694  121
# 22  12562  120
# 23  12440  119
# 24  12203  117
# 25  11997  116
# 26  11772  115
# 27  11594  114
# 28  11515  115
# 29  11389  116
# 30  11235  117
# 31  10992  119
# 32  10876  121
# 33  10745  123
# 34  10583  124
# 35  10510  124
# 36  10304  126
# 37  10111  128
# 38   9903  128
# 39   9725  129
# 40   9592  128
# 41   9415  127
# 42   9270  127
# 43   9099  126
# 44   8863  123
# 45   8668  120
# 46   8494  118
# 47   8432  118
# 48   8234  116
# 49   8123  116

# %%
#plt.scatter(x, y)
plt.plot(bestQ2LapBearman.index, bestQ2LapBearman.rpm)
plt.title("RPM Bearman's Lap")
plt.xlabel("x")
plt.ylabel("rpm")
plt.show()
figure.tight_layout()
