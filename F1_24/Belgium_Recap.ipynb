# %%
from F1_library import libraryF1dataNotebook as libraryDataF1
import pandas as pd

# %% [markdown]
# # FORMULA 1 ROLEX BELGIAN GRAND PRIX 2024
# The Belgian Grand Prix (French: Grand Prix de Belgique; Dutch: Grote Prijs van België; German: Großer Preis von Belgien) is a motor racing event which forms part of the Formula One World Championship. The first national race of Belgium was held in 1925 at the Spa region's race course, an area of the country that had been associated with motor sport since the very early years of racing. To accommodate Grand Prix motor racing, the Circuit de Spa-Francorchamps race course was built in 1921 but until 1924 it was used only for motorcycle racing. After the 1923 success of the new 24 hours of Le Mans in France, the Spa 24 Hours, a similar 24-hour endurance race, was run at the Spa track.
#
# Since its inception, Spa-Francorchamps has been known for its unpredictable weather. At one stage in its history it had rained at the Belgian Grand Prix for twenty years in a row. Frequently drivers confront a part of the course that is clear and bright while another stretch is rainy and slippery.
#
# The Belgian Grand Prix was designated the European Grand Prix six times between 1925 and 1973, when this title was an honorary designation given each year to one Grand Prix race in Europe. It is one of the most popular races on the Formula One calendar, due to the scenic and historical Spa-Francorchamps circuit being a favourite of drivers and fans.
# Source: Wikipedia

# %% [markdown]
# ## Upgrades
# In this section those upgrades brought by the teams will be shown.
# <table>
# <tr>
#     <td>
#     Team
#     </td>
#     <td>
#     Updated component
#     </td>
#     <td>
#     Upgrade type
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Rear Corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Front Corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Ferrari
#     </td>
#     <td>
#     Floor Body
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Front Wing
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor Fences
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Diffuser
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Beam Wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Beam wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Front corner
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Cooling Louvres
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     BWT Alpine
#     </td>
#     <td>
#     Rear Corner
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Williams
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Sidepod Inlet
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Rear Suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Mirror
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Headrest
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# </table>

# %% [markdown]
# ## Obtain session information

# %%
libraryDataF1.obtain_information('sessions',year=2024,country_acronym='BEL')
# Out:
#    session_key session_name                 date_start  \
# 0         9567   Practice 1  2024-07-26T11:30:00+00:00
# 1         9568   Practice 2  2024-07-26T15:00:00+00:00
#
#                     date_end gmt_offset session_type  meeting_key  \
# 0  2024-07-26T12:30:00+00:00   02:00:00     Practice         1242
# 1  2024-07-26T16:00:00+00:00   02:00:00     Practice         1242
#
#             location  country_key country_code country_name  circuit_key  \
# 0  Spa-Francorchamps           16          BEL      Belgium            7
# 1  Spa-Francorchamps           16          BEL      Belgium            7
#
#   circuit_short_name  year
# 0  Spa-Francorchamps  2024
# 1  Spa-Francorchamps  2024

# %% [markdown]
# ## Free Practice 1
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9567)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9567)
drivers = libraryDataF1.obtain_information('drivers',session_key=9567)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1242         9567              1     234.0       129     207.0
# 1           1242         9567              2     305.0       170     223.0
# 2           1242         9567              3     308.0       185     229.0
# 3           1242         9567              4     294.0       176     251.0
# 4           1242         9567             10     301.0       155     244.0
# ..           ...          ...            ...       ...       ...       ...
# 413         1242         9567              4     313.0       187     289.0
# 414         1242         9567             16     224.0       157     184.0
# 415         1242         9567             55     312.0       173     297.0
# 416         1242         9567             81     245.0       137     229.0
# 417         1242         9567             16     307.0       187     301.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-07-26T11:30:21.029000+00:00           NaN            True
# 1    2024-07-26T11:34:15.629000+00:00           NaN            True
# 2    2024-07-26T11:30:57.739000+00:00           NaN            True
# 3    2024-07-26T11:31:10.307000+00:00           NaN            True
# 4    2024-07-26T11:30:54.611000+00:00           NaN            True
# ..                                ...           ...             ...
# 413         2024-07-26T12:33:57+00:00       152.276           False
# 414  2024-07-26T12:31:20.307000+00:00       161.678           False
# 415  2024-07-26T12:34:15.133000+00:00       140.565           False
# 416  2024-07-26T12:33:28.607000+00:00       168.650           False
# 417  2024-07-26T12:34:01.952000+00:00       159.609           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             63.720             38.405
# 1                  NaN             59.275             32.310
# 2                  NaN             56.192             48.276
# 3                  NaN             57.149             43.989
# 4                  NaN             63.889             39.081
# ..                 ...                ...                ...
# 413             63.736             51.768             36.772
# 414             47.206             60.669             53.803
# 415             51.067             52.829             36.669
# 416             68.801             56.946             42.903
# 417             66.901             54.700             38.008
#
#                                     segments_sector_1  \
# 0    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                                ...
# 413  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 414  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 415  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 416  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 417  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 413  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 414  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 415  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 416  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 417  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_3  lap_number compound  \
# 0    [2051, 2051, 2049, 2049, 2051, 2051, 2048]           1     HARD
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2048]           1     HARD
# 2    [2048, 2048, 2049, 2049, 2049, 2049, 2049]           1     HARD
# 3       [2051, 2051, 2051, 2051, 2051, 2049, 0]           1   MEDIUM
# 4       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1   MEDIUM
# ..                                          ...         ...      ...
# 413                                          []          24   MEDIUM
# 414  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          24   MEDIUM
# 415                                          []          24     SOFT
# 416                                          []          24   MEDIUM
# 417                                          []          25   MEDIUM
#
#     name_acronym         full_name        team_name
# 0            VER    Max VERSTAPPEN  Red Bull Racing
# 1            SAR    Logan SARGEANT         Williams
# 2            RIC  Daniel RICCIARDO               RB
# 3            NOR      Lando NORRIS          McLaren
# 4            GAS      Pierre GASLY           Alpine
# ..           ...               ...              ...
# 413          NOR      Lando NORRIS          McLaren
# 414          LEC   Charles LECLERC          Ferrari
# 415          SAI      Carlos SAINZ          Ferrari
# 416          PIA     Oscar PIASTRI          McLaren
# 417          LEC   Charles LECLERC          Ferrari
#
# [418 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",114)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",114)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",114)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#            full_name compound  duration_sector_1  duration_sector_2  \
# 96    Max VERSTAPPEN     HARD             30.875             44.971
# 217  Charles LECLERC   MEDIUM             30.731             44.783
# 153   Max VERSTAPPEN     SOFT             30.777             44.046
#
#      duration_sector_3  lap_duration
# 96              28.678       104.524
# 217             28.792       104.306
# 153             28.549       103.372

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. Also, each sector will be commented. As we can see in the free practice, these data  are not very representative due to the changing conditions.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 183             30.348   Alexander ALBON     SOFT       104.099          10
# 174             30.364  Daniel RICCIARDO     SOFT       104.950          10
# 201             30.383      Yuki TSUNODA     SOFT       105.624          11
# 135             30.416    Logan SARGEANT     SOFT       105.311           8
# 169             30.545    George RUSSELL     SOFT       104.225           9
# 148             30.588    Lewis HAMILTON     SOFT       104.279           8
# 209             30.618     Oscar PIASTRI     SOFT       103.903          11
# 175             30.659      Lando NORRIS     SOFT       104.415          10
# 216             30.721   Fernando ALONSO     SOFT       104.921          12
# 147             30.724   Nico HULKENBERG     SOFT       105.645           8
# 217             30.731   Charles LECLERC   MEDIUM       104.306          12
# 180             30.772      Lance STROLL     SOFT       104.814          10
# 153             30.777    Max VERSTAPPEN     SOFT       103.372           9
# 203             30.782       ZHOU Guanyu   MEDIUM       105.995          11
# 158             30.799      Sergio PEREZ     SOFT       104.329           9
# 162             30.814   Kevin MAGNUSSEN     SOFT       106.371           9
# 252             30.860      Pierre GASLY     SOFT       104.833          14
# 246             30.964   Valtteri BOTTAS     HARD       118.798          13
# 225             30.971      Carlos SAINZ     SOFT       104.574          12

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 153             44.046    Max VERSTAPPEN     SOFT       103.372           9
# 209             44.675     Oscar PIASTRI     SOFT       103.903          11
# 217             44.783   Charles LECLERC   MEDIUM       104.306          12
# 225             44.819      Carlos SAINZ     SOFT       104.574          12
# 158             44.895      Sergio PEREZ     SOFT       104.329           9
# 226             44.935    George RUSSELL     SOFT       104.407          12
# 216             45.098   Fernando ALONSO     SOFT       104.921          12
# 148             45.136    Lewis HAMILTON     SOFT       104.279           8
# 252             45.167      Pierre GASLY     SOFT       104.833          14
# 218             45.265      Lance STROLL     SOFT       104.699          12
# 175             45.367      Lando NORRIS     SOFT       104.415          10
# 170             45.400   Valtteri BOTTAS     HARD       105.155           9
# 183             45.407   Alexander ALBON     SOFT       104.099          10
# 147             46.109   Nico HULKENBERG     SOFT       105.645           8
# 200             46.148   Kevin MAGNUSSEN     SOFT       105.812          11
# 174             46.215  Daniel RICCIARDO     SOFT       104.950          10
# 241             46.264       ZHOU Guanyu   MEDIUM       105.999          13
# 135             46.271    Logan SARGEANT     SOFT       105.311           8
# 201             46.531      Yuki TSUNODA     SOFT       105.624          11
# 14              86.032      Esteban OCON   MEDIUM           NaN           1

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 183             28.344   Alexander ALBON     SOFT       104.099          10
# 171             28.348     Oscar PIASTRI     SOFT       104.078           9
# 174             28.371  Daniel RICCIARDO     SOFT       104.950          10
# 175             28.389      Lando NORRIS     SOFT       104.415          10
# 20              28.477    Max VERSTAPPEN     HARD       104.706           2
# 239             28.489      Yuki TSUNODA     SOFT       105.564          13
# 148             28.555    Lewis HAMILTON     SOFT       104.279           8
# 169             28.601    George RUSSELL     SOFT       104.225           9
# 200             28.606   Kevin MAGNUSSEN     SOFT       105.812          11
# 178             28.616   Fernando ALONSO     SOFT       105.097          10
# 135             28.624    Logan SARGEANT     SOFT       105.311           8
# 218             28.633      Lance STROLL     SOFT       104.699          12
# 158             28.635      Sergio PEREZ     SOFT       104.329           9
# 214             28.749      Pierre GASLY     SOFT       105.350          12
# 170             28.767   Valtteri BOTTAS     HARD       105.155           9
# 225             28.784      Carlos SAINZ     SOFT       104.574          12
# 217             28.792   Charles LECLERC   MEDIUM       104.306          12
# 147             28.812   Nico HULKENBERG     SOFT       105.645           8
# 241             28.840       ZHOU Guanyu   MEDIUM       105.999          13
# 14              57.738      Esteban OCON   MEDIUM           NaN           1

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration >108  and lap_duration <= 114").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# MEDIUM      110.548333
# SOFT        110.553264
# HARD        110.611882

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 108
MAXIMUM_SECONDS = 115

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 37')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 6          1242         9567             1              1          1        8
# 25         1242         9567             2              1          9       11
# 43         1242         9567             3              1         12       19
# 64         1242         9567             4              1         20       24
#
#    compound  tyre_age_at_start
# 6      HARD                  0
# 25     SOFT                  0
# 43     SOFT                  3
# 64     HARD                  7

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 210  Max VERSTAPPEN     SOFT  2024-07-26T12:10:17.973000+00:00          12
# 229  Max VERSTAPPEN     SOFT  2024-07-26T12:12:07.275000+00:00          13
# 248  Max VERSTAPPEN     SOFT  2024-07-26T12:13:57.016000+00:00          14
# 267  Max VERSTAPPEN     SOFT  2024-07-26T12:15:46.482000+00:00          15
# 286  Max VERSTAPPEN     SOFT  2024-07-26T12:17:36.718000+00:00          16
# 306  Max VERSTAPPEN     SOFT  2024-07-26T12:19:26.567000+00:00          17
# 363  Max VERSTAPPEN     HARD  2024-07-26T12:25:21.618000+00:00          20
# 379  Max VERSTAPPEN     HARD  2024-07-26T12:27:10.157000+00:00          21
# 393  Max VERSTAPPEN     HARD  2024-07-26T12:28:59.067000+00:00          22
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 210             31.890             47.968             29.546       109.404
# 229             31.991             47.941             29.655       109.587
# 248             31.927             48.005             29.566       109.498
# 267             31.894             48.564             29.846       110.304
# 286             31.819             48.386             29.651       109.856
# 306             32.022             48.621             29.740       110.383
# 363             31.622             47.720             29.160       108.502
# 379             31.610             48.059             29.308       108.977
# 393             31.246             48.323             29.326       108.895

# %%
libraryDataF1.getinfolongruns(jointables2,37,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 17         1242         9567             1             55          1       10
# 19         1242         9567             1             16          1       11
# 37         1242         9567             2             55         11       15
# 40         1242         9567             2             16         12       15
# 58         1242         9567             3             55         16       25
# 59         1242         9567             3             16         16       26
#
#    compound  tyre_age_at_start
# 17   MEDIUM                  0
# 19   MEDIUM                  0
# 37     SOFT                  0
# 40   MEDIUM                  0
# 58     SOFT                  5
# 59   MEDIUM                 10

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 27   Charles LECLERC   MEDIUM  2024-07-26T11:33:04.643000+00:00           2
# 255  Charles LECLERC   MEDIUM  2024-07-26T12:06:50.946000+00:00          14
# 294  Charles LECLERC   MEDIUM  2024-07-26T12:16:13.530000+00:00          16
# 313  Charles LECLERC   MEDIUM  2024-07-26T12:18:02.170000+00:00          17
# 332  Charles LECLERC   MEDIUM  2024-07-26T12:19:51.776000+00:00          18
# 351  Charles LECLERC   MEDIUM  2024-07-26T12:21:41.883000+00:00          19
# 369  Charles LECLERC   MEDIUM  2024-07-26T12:23:32.196000+00:00          20
# 407  Charles LECLERC   MEDIUM  2024-07-26T12:29:28.761000+00:00          23
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 27              31.984             47.580             29.502       109.066
# 255             30.913             45.058             38.070       114.041
# 294             31.692             47.517             29.423       108.632
# 313             31.894             48.015             29.716       109.625
# 332             31.930             48.541             29.745       110.216
# 351             31.944             48.545             29.724       110.213
# 369             31.915             48.949             29.656       110.520
# 407             32.015             49.292             30.118       111.425

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 35   Carlos SAINZ   MEDIUM  2024-07-26T11:32:47.162000+00:00           2
# 263  Carlos SAINZ     SOFT  2024-07-26T12:09:25.163000+00:00          14
# 302  Carlos SAINZ     SOFT  2024-07-26T12:19:00.657000+00:00          16
# 321  Carlos SAINZ     SOFT  2024-07-26T12:20:49.644000+00:00          17
# 340  Carlos SAINZ     SOFT  2024-07-26T12:22:39.362000+00:00          18
# 359  Carlos SAINZ     SOFT  2024-07-26T12:24:29.085000+00:00          19
# 375  Carlos SAINZ     SOFT  2024-07-26T12:26:18.796000+00:00          20
# 389  Carlos SAINZ     SOFT  2024-07-26T12:28:08.644000+00:00          21
# 401  Carlos SAINZ     SOFT  2024-07-26T12:29:59.340000+00:00          22
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 35              31.989             47.043             29.268       108.300
# 263             31.018             45.100             35.324       111.442
# 302             32.128             47.398             29.397       108.923
# 321             31.997             48.104             29.617       109.718
# 340             31.996             48.077             29.731       109.804
# 359             31.876             48.216             29.658       109.750
# 375             31.893             48.406             29.476       109.775
# 389             31.876             49.228             29.546       110.650
# 401             31.440             49.495             30.057       110.992

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 2          1242         9567             1             63          1        3
# 5          1242         9567             1             44          1        7
# 21         1242         9567             2             63          4        8
# 24         1242         9567             2             44          8       11
# 26         1242         9567             3             63          9       11
# 39         1242         9567             4             63         12       14
# 42         1242         9567             3             44         12       16
# 55         1242         9567             5             63         15       24
# 60         1242         9567             4             44         17       22
#
#    compound  tyre_age_at_start
# 2    MEDIUM                  0
# 5    MEDIUM                  0
# 21   MEDIUM                  2
# 24     SOFT                  0
# 26     SOFT                  0
# 39     SOFT                  3
# 42   MEDIUM                  6
# 55   MEDIUM                  7
# 60   MEDIUM                 11

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 2          1242         9567             1             63          1        3
# 5          1242         9567             1             44          1        7
# 21         1242         9567             2             63          4        8
# 24         1242         9567             2             44          8       11
# 26         1242         9567             3             63          9       11
# 39         1242         9567             4             63         12       14
# 42         1242         9567             3             44         12       16
# 55         1242         9567             5             63         15       24
# 60         1242         9567             4             44         17       22
#
#    compound  tyre_age_at_start
# 2    MEDIUM                  0
# 5    MEDIUM                  0
# 21   MEDIUM                  2
# 24     SOFT                  0
# 26     SOFT                  0
# 39     SOFT                  3
# 42   MEDIUM                  6
# 55   MEDIUM                  7
# 60   MEDIUM                 11

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
#
eting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 1         1242         9567             1             31          1        2
#
#   compound  tyre_age_at_start
# 1   MEDIUM                  0

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %%
libraryDataF1.getinfolongruns(jointables2,61,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 45 or driver_number == 23')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 15         1242         9567             1             23          1        9
# 32         1242         9567             2             23         10       12
# 46         1242         9567             3             23         13       22
#
#    compound  tyre_age_at_start
# 15     HARD                  0
# 32     SOFT                  0
# 46     SOFT                  3

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 240  Alexander ALBON     SOFT  2024-07-26T12:17:47.771000+00:00          13
# 259  Alexander ALBON     SOFT  2024-07-26T12:19:36.262000+00:00          14
# 278  Alexander ALBON     SOFT  2024-07-26T12:21:25.616000+00:00          15
# 298  Alexander ALBON     SOFT  2024-07-26T12:23:15.939000+00:00          16
# 317  Alexander ALBON     SOFT  2024-07-26T12:25:05.834000+00:00          17
# 336  Alexander ALBON     SOFT  2024-07-26T12:26:56.016000+00:00          18
# 355  Alexander ALBON     SOFT  2024-07-26T12:28:46.582000+00:00          19
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 240             31.238             48.062             29.227       108.527
# 259             31.255             48.778             29.380       109.413
# 278             31.136             49.633             29.507       110.276
# 298             31.090             49.388             29.385       109.863
# 317             31.525             49.277             29.462       110.264
# 336             31.567             49.554             29.438       110.559
# 355             31.633             49.930             29.477       111.040

# %%
libraryDataF1.getinfolongruns(jointables2,45,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 10         1242         9567             1             77          1        8
# 16         1242         9567             1             24          1       10
# 31         1242         9567             2             77          9       14
# 38         1242         9567             2             24         11       16
# 54         1242         9567             3             77         15       22
# 63         1242         9567             3             24         17       24
#
#    compound  tyre_age_at_start
# 10     HARD                  0
# 16   MEDIUM                  0
# 31     HARD                  0
# 38   MEDIUM                  0
# 54     HARD                  7
# 63   MEDIUM                  9

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#        full_name compound                        date_start  lap_number  \
# 32   ZHOU Guanyu   MEDIUM  2024-07-26T11:32:29.248000+00:00           2
# 318  ZHOU Guanyu   MEDIUM  2024-07-26T12:22:02.377000+00:00          17
# 337  ZHOU Guanyu   MEDIUM  2024-07-26T12:23:54.045000+00:00          18
# 356  ZHOU Guanyu   MEDIUM  2024-07-26T12:25:46.770000+00:00          19
# 373  ZHOU Guanyu   MEDIUM  2024-07-26T12:27:39.700000+00:00          20
# 387  ZHOU Guanyu   MEDIUM  2024-07-26T12:29:32.483000+00:00          21
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 32              31.609             48.451             29.411       109.471
# 318             31.823             49.972             29.914       111.709
# 337             32.322             50.351             30.070       112.743
# 356             32.283             50.495             30.100       112.878
# 373             32.242             50.529             30.010       112.781
# 387             32.253             51.172             30.088       113.513

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 284  Valtteri BOTTAS     HARD  2024-07-26T12:21:57.779000+00:00          15
# 323  Valtteri BOTTAS     HARD  2024-07-26T12:25:51.171000+00:00          17
# 342  Valtteri BOTTAS     HARD  2024-07-26T12:27:42.427000+00:00          18
# 361  Valtteri BOTTAS     HARD  2024-07-26T12:29:34.421000+00:00          19
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
#
# 15      Carlos SAINZ     SOFT    109.928222  31.801444  47.896333  30.230444
# 8       Lance STROLL     HARD    111.081400  31.671800  49.065400  30.344200
# 16    George RUSSELL   MEDIUM    110.750500  31.683125  48.610000  30.457375
# 2   Daniel RICCIARDO     SOFT    111.721000  31.361800  49.798000  30.561200
# 7    Charles LECLERC   MEDIUM    110.467250  31.785875  47.937125  30.744250
# 5       Sergio PEREZ     SOFT    111.602875  31.867125  48.579875  31.155875
# 13   Nico HULKENBERG   MEDIUM    112.370625  31.627625  49.472500  31.270500
# 6    Fernando ALONSO     SOFT    111.415000  31.621000  48.158400  31.635600

# %% [markdown]
# ## Free Practice 2
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9568)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9568)
drivers = libraryDataF1.obtain_information('drivers',session_key=9568)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1242         9568             10     303.0       168     233.0
# 1           1242         9568              1     210.0       157     161.0
# 2           1242         9568             24     284.0       141     247.0
# 3           1242         9568              3     287.0       146     206.0
# 4           1242         9568             11     284.0       103     252.0
# ..           ...          ...            ...       ...       ...       ...
# 459         1242         9568              1       NaN       195     299.0
# 460         1242         9568             63     328.0       193     307.0
# 461         1242         9568             77     319.0       182     308.0
# 462         1242         9568             11     277.0       194     264.0
# 463         1242         9568             55     306.0       195     304.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-07-26T15:00:29.879000+00:00           NaN            True
# 1    2024-07-26T15:00:34.405000+00:00           NaN            True
# 2    2024-07-26T15:00:38.164000+00:00           NaN            True
# 3    2024-07-26T15:00:44.772000+00:00           NaN            True
# 4    2024-07-26T15:00:53.437000+00:00           NaN            True
# ..                                ...           ...             ...
# 459  2024-07-26T16:03:59.908000+00:00       140.251           False
# 460  2024-07-26T16:04:06.102000+00:00       141.277           False
# 461  2024-07-26T16:04:06.705000+00:00       147.945           False
# 462  2024-07-26T16:04:19.894000+00:00       140.393           False
# 463  2024-07-26T16:04:20.399000+00:00       140.888           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             60.128             31.942
# 1                  NaN             67.849             34.627
# 2                  NaN             63.234             43.611
# 3                  NaN             62.769             41.065
# 4                  NaN             68.423             45.676
# ..                 ...                ...                ...
# 459             52.535             51.185             36.531
# 460             55.524             50.697             35.056
# 461             54.690             57.268             35.987
# 462             54.033             51.246             35.114
# 463             56.338             49.599             34.951
#
#                                     segments_sector_1  \
# 0    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                                ...
# 459  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 460  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 461  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 462  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 463  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 459  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 460  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 461  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 462  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 463  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_3  lap_number compound  \
# 0       [2049, 2051, 2051, 2051, 2051, 2051, 0]           1   MEDIUM
# 1    [2051, 2049, 2049, 2049, 2051, 2051, 2048]           1   MEDIUM
# 2       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1     HARD
# 3       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1   MEDIUM
# 4       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1   MEDIUM
# ..                                          ...         ...      ...
# 459                                          []          26     SOFT
# 460                                          []          24   MEDIUM
# 461                                          []          24   MEDIUM
# 462                                          []          24   MEDIUM
# 463                                          []          25     SOFT
#
#     name_acronym         full_name        team_name
# 0            GAS      Pierre GASLY           Alpine
# 1            VER    Max VERSTAPPEN  Red Bull Racing
# 2            ZHO       ZHOU Guanyu      Kick Sauber
# 3            RIC  Daniel RICCIARDO               RB
# 4            PER      Sergio PEREZ  Red Bull Racing
# ..           ...               ...              ...
# 459          VER    Max VERSTAPPEN  Red Bull Racing
# 460          RUS    George RUSSELL         Mercedes
# 461          BOT   Valtteri BOTTAS      Kick Sauber
# 462          PER      Sergio PEREZ  Red Bull Racing
# 463          SAI      Carlos SAINZ          Ferrari
#
# [464 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",114)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",114)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",114)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#            full_name compound  duration_sector_1  duration_sector_2  \
# 29   Nico HULKENBERG     HARD             30.525             46.198
# 81    Max VERSTAPPEN   MEDIUM             30.373             44.549
# 188     Lando NORRIS     SOFT             30.238             43.782
#
#      duration_sector_3  lap_duration
# 29              28.676       105.399
# 81              28.417       103.339
# 188             28.240       102.260

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.Due to changing conditions, only a part of the free practice were important and this part will be taken into consideration.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. As I said in the previous section, the changing conditions made that the data obtained in this section are not representatives.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 153             30.118      Yuki TSUNODA     SOFT       104.348           9
# 186             30.135      Esteban OCON     SOFT       103.401           9
# 152             30.141  Daniel RICCIARDO     SOFT       103.823           8
# 171             30.143   Charles LECLERC     SOFT       102.837           8
# 180             30.156      Lance STROLL     SOFT       115.503          10
# 184             30.174      Pierre GASLY     SOFT       103.829          11
# 133             30.191   Nico HULKENBERG     SOFT       103.846           6
# 128             30.199     Oscar PIASTRI     SOFT       102.475           5
# 161             30.224   Kevin MAGNUSSEN     SOFT       103.485           7
# 188             30.238      Lando NORRIS     SOFT       102.260           8
# 175             30.260       ZHOU Guanyu     SOFT       104.302           9
# 63              30.276      Carlos SAINZ   MEDIUM       103.788           4
# 137             30.281    Max VERSTAPPEN     SOFT       102.477           8
# 193             30.292   Valtteri BOTTAS     SOFT       103.675          11
# 24              30.293   Alexander ALBON   MEDIUM       104.407           2
# 135             30.312    George RUSSELL     SOFT       103.290           8
# 207             30.328   Fernando ALONSO     SOFT       103.538          13
# 147             30.425    Logan SARGEANT     SOFT       104.226           8
# 155             30.442      Sergio PEREZ     SOFT       103.504           8
# 116             30.491    Lewis HAMILTON     SOFT       103.742           7

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 188             43.782      Lando NORRIS     SOFT       102.260           8
# 137             43.904    Max VERSTAPPEN     SOFT       102.477           8
# 128             43.949     Oscar PIASTRI     SOFT       102.475           5
# 171             44.144   Charles LECLERC     SOFT       102.837           8
# 123             44.342      Carlos SAINZ     SOFT       103.098           7
# 190             44.378    Lewis HAMILTON     SOFT       103.519          12
# 135             44.458    George RUSSELL     SOFT       103.290           8
# 155             44.525      Sergio PEREZ     SOFT       103.504           8
# 207             44.767   Fernando ALONSO     SOFT       103.538          13
# 144             44.828      Lance STROLL     SOFT       103.532           8
# 194             44.876   Kevin MAGNUSSEN     SOFT       103.864           9
# 186             44.980      Esteban OCON     SOFT       103.401           9
# 193             45.033   Valtteri BOTTAS     SOFT       103.675          11
# 146             45.053   Alexander ALBON     SOFT       103.892           7
# 133             45.215   Nico HULKENBERG     SOFT       103.846           6
# 184             45.232      Pierre GASLY     SOFT       103.829          11
# 147             45.262    Logan SARGEANT     SOFT       104.226           8
# 152             45.286  Daniel RICCIARDO     SOFT       103.823           8
# 175             45.438       ZHOU Guanyu     SOFT       104.302           9
# 153             45.760      Yuki TSUNODA     SOFT       104.348           9

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 188             28.240      Lando NORRIS     SOFT       102.260           8
# 18              28.286    Max VERSTAPPEN   MEDIUM       103.456           2
# 186             28.286      Esteban OCON     SOFT       103.401           9
# 161             28.299   Kevin MAGNUSSEN     SOFT       103.485           7
# 128             28.327     Oscar PIASTRI     SOFT       102.475           5
# 193             28.350   Valtteri BOTTAS     SOFT       103.675          11
# 24              28.361   Alexander ALBON   MEDIUM       104.407           2
# 167             28.382   Fernando ALONSO     SOFT       103.745          10
# 152             28.396  Daniel RICCIARDO     SOFT       103.823           8
# 123             28.416      Carlos SAINZ     SOFT       103.098           7
# 184             28.423      Pierre GASLY     SOFT       103.829          11
# 133             28.440   Nico HULKENBERG     SOFT       103.846           6
# 190             28.453    Lewis HAMILTON     SOFT       103.519          12
# 153             28.470      Yuki TSUNODA     SOFT       104.348           9
# 144             28.476      Lance STROLL     SOFT       103.532           8
# 197             28.517       ZHOU Guanyu     SOFT       104.871          11
# 135             28.520    George RUSSELL     SOFT       103.290           8
# 155             28.537      Sergio PEREZ     SOFT       103.504           8
# 147             28.539    Logan SARGEANT     SOFT       104.226           8
# 171             28.550   Charles LECLERC     SOFT       102.837           8

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False  and lap_duration>107 and lap_duration <= 114").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# MEDIUM      110.448491
# SOFT        110.474866
# HARD        111.044600

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 107
MAXIMUM_SECONDS = 114

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
#
# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration > 79  and lap_duration <= 84").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Long laps

# %%
MINIMUN_SECONDS = 77
MAXIMUM_SECONDS = 84

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)

# %% [markdown]
# ## Qualyfing
# ### Set up
# First of all, it is neccesary to obtain the data about the qualyfing
# #### Race control
# This section has been added in order to know which laps has been deleted and knowing what happened on track during this session. As every laptime that has been deleted were slow laps, none of them were removed.

# %%
libraryDataF1.obtain_information('race_control',session_key=9562)

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9562)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9562)
drivers = libraryDataF1.obtain_information('drivers',session_key=9562)

# %% [markdown]
# To obtain a better analysis, those laptimes deleted will be removed from this analysis in order to obtain the data with valid values. So that,taking into account the race control table, it will be neccesary to consult the qualyfing data to obtain the ids.

# %%
# laptimes_deleted = [115.370,96.993,109.924,104.377,102.586,128.082,95.902,102.051]
# driver_number_lap_deleted = [4,63,1,24,22,14,55,23]

# for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
#     try:
#         id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
#         qualyfing = qualyfing.drop(id_deleted)
#     except:
#         print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]

# %% [markdown]
# In this case, the fastest lap is 75.227 seconds (1.15.227= so that to obtain the competitve laps the fastest lap will be multiplied by 1.07 (80.49 seconds) due to, according to the rules all the drivers have to do unless one lap within this gap.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration < 80.49")
competitiveLaps

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session
# In this chart we can see the deltas with compared with the fastest lap of the session that it could be different than the pole.

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %% [markdown]
# ### Speed trap

# %% [markdown]
# #### Maximum speed per drivers

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %% [markdown]
# ### Maximum speed per teams

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","st_speed",top_speed)

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])
mergequaly

# %% [markdown]
# In order to know when each session finished, race control dataset will be consulted.

# %%
maximumDateQ1 = "date_start <'2024-07-20T14:36:00+00:00'"
maximumDateQ2 = "date_start <'2024-07-20T14:59:00+00:00' and date_start >'2024-07-20T14:36:00+00:00'"
maximumDateQ3 = "date_start >'2024-07-20T14:59:00+00:00'"

# %% [markdown]
# ### Qualyfing 1
# In this session the surprise came from Sergio Perez that was knocked-out in this section. In the next sesssion, we will see what happened with Perez.

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver,I will do a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap. As we can see in Qualyfing 1, the qualy was very crazy, with tricky conditions at the beginning of the session. The track was wet but not to much affording to the drivers made their laps with slicks. Sergio Perez risked a bit more and touched the kerb and, with this conditions, he spun and crashed. THis incident provoked a red flag. After the red flag the session was restarted with a lot of drivers improving their times as we can see with Ricciardo being the fastest in this session. Unfortunately some drivers made their lap at the beginning, as we can see with Rusell.

# %%
#Reference
P15 = q1Data[14:15]
P15

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)

# %%
q1Data[15::]

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk
# I bring this section in order to know where the driver at risk lost his chances to improve in the qualyfing.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[0:14].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 2
# In this session, both Ferrari were knocked-out in Q2.

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.
# Hamilton was very close to be knocked-out of Q2 but his third sector saved him. The last turn saved Hamilton because before to the enter of the last turn, Hulkenberg was in Q3 but the good traction of the Mercedes, afforded him to enter in Q3.

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[0:9].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.
# Even though the gap among the top three are so close, Norris marked his best lap in his first attemp. Piastri improved in his second attemp but it was not enough to beat Norris.
# Note: All this analysis can be checked in F1 tempo

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %% [markdown]
# #### Best sector per driver of the session (in general)

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ## Race
# ### Obtain setup

# %%
race = libraryDataF1.obtain_information('laps',session_key=9566)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9566)
drivers = libraryDataF1.obtain_information('drivers',session_key=9558)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)

# %%
raceLaps = race.query("is_pit_out_lap == False")
jointables = pd.merge(raceLaps,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# #### Obtain data tyres

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'HARD',87)

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'MEDIUM',87)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'SOFT',87)

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >82 and lap_duration <= 87").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Race pace

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >82 and lap_duration <= 87").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Mean race pace per sector
# In this section, we can see the pace shown per each team in each sector sorted ascending.

# %% [markdown]
# #### Sector 1

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >82 and lap_duration <= 87").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 2

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >82 and lap_duration <= 87").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 3

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False and lap_duration >82 and lap_duration <= 87").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Comparaison beetween drivers

# %% [markdown]
# #### Red Bull Racing

# %%
race.query("driver_number== 1 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 11 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Ferrari

# %%
race.query("driver_number== 16 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 55 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### McLaren

# %%
race.query("driver_number== 4 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 81 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Mercedes

# %%
race.query("driver_number== 44 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 63 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Aston Martin

# %%
race.query("driver_number== 14 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 18 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Haas F1 Team

# %%
race.query("driver_number== 20 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 27 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### RB

# %%
race.query("driver_number== 3 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 22 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Williams

# %%
race.query("driver_number== 2 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 23 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Alpine

# %%
race.query("driver_number== 10 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 31 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# #### Kick Sauber

# %%
race.query("driver_number== 24 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %%
race.query("driver_number== 77 and lap_duration >82 and lap_duration <= 87").lap_duration.mean()

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 82
MAXIMUM_SECONDS = 87

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')

# %%
libraryDataF1.getinfolongruns(jointables,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')

# %%
libraryDataF1.getinfolongruns(jointables,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 14 or driver_number == 18')

# %%
libraryDataF1.getinfolongruns(jointables,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 4 or driver_number == 81')

# %%
libraryDataF1.getinfolongruns(jointables,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas F1 Team

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 23 or driver_number == 2')

# %%
libraryDataF1.getinfolongruns(jointables,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ### Pits
# Before to finish the analysis, I added the Pits sections where it can see how much time teams spent in the box.

# %%
pit = libraryDataF1.obtain_information('pit',session_key=9566)

# %%
jointables = pd.merge(drivers,pit,on=['driver_number']).query("pit_duration<120")
jointables
pit_duration = pd.DataFrame(jointables.groupby('team_name')['pit_duration'].mean().sort_values(ascending=True))
pit_duration
