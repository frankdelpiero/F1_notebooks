# %%
from F1_library import libraryF1dataNotebook as libraryDataF1
import pandas as pd

# %% [markdown]
# # FORMULA 1 QATAR AIRWAYS AZERBAIJAN GRAND PRIX 2024
# The first Formula One Grand Prix to be held in Azerbaijan was the 2016 European Grand Prix, which took place at the Baku City Circuit. A year later, in 2017, the same venue hosted the first Azerbaijan Grand Prix. The race was held on 25 June and was one of five races to be held on a street circuit during the 2017 Formula One season, along with the Singapore, Monaco, Australian and Canadian Grands Prix. The first Azerbaijan Grand Prix winner was Daniel Ricciardo of Red Bull, grabbing his first win of the 2017 campaign during Sunday's Azerbaijan Grand Prix.
#
#
# The 2018 Azerbaijan Grand Prix and Baku city walls behind
# The 2018 Azerbaijan Grand Prix took place on 29 April as the 4th round of the season and was won by Lewis Hamilton.
#
# The 2019 Azerbaijan Grand Prix was held on 28 April as the 4th round of the season and was won by Valtteri Bottas. In March 2020, the 2020 race was postponed due to the COVID-19 pandemic, before being cancelled later in the year. The 2021 Azerbaijan Grand Prix featured as the 6th round of the season, and the race was won by Sergio Pérez after Max Verstappen, who led a majority of the race, was struck by tyre failure. The 2022 Azerbaijan Grand Prix was won by Verstappen.
#
# The 2023 Azerbaijan Grand Prix became the first Grand Prix to implement a new format, featuring a new qualifying session called "sprint shootout" which determined the grid for one of the six sprints in the 2023 season. Sergio Pérez became the first driver to win the Azerbaijan Grand Prix twice, following his win in 2021, securing a victory in the race and also in the sprint. For the 2024 event, the Azerbaijan Grand Prix was moved to September, swapping positions with the Japanese Grand Prix.
#
#
# Source: Wikipedia

# %% [markdown]
# ## Upgrades
# In this section those upgrades brought by the teams will be shown.
# <table>
#
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Rear Corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# </table>

# %% [markdown]
# ## Obtain session information

# %%
libraryDataF1.obtain_information('sessions',year=2024,country_acronym='AZE')
# Out:
#    session_key session_name                 date_start  \
# 0         9591   Practice 1  2024-09-13T09:30:00+00:00
# 1         9592   Practice 2  2024-09-13T13:00:00+00:00
#
#                     date_end gmt_offset session_type  meeting_key location  \
# 0  2024-09-13T10:30:00+00:00   04:00:00     Practice         1245     Baku
# 1  2024-09-13T14:00:00+00:00   04:00:00     Practice         1245     Baku
#
#    country_key country_code country_name  circuit_key circuit_short_name  year
# 0           30          AZE   Azerbaijan          144               Baku  2024
# 1           30          AZE   Azerbaijan          144               Baku  2024

# %% [markdown]
# ## Free Practice 1
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9591)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9591)
drivers = libraryDataF1.obtain_information('drivers',session_key=9591)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1245         9591             23     135.0       NaN     240.0
# 1           1245         9591             18     151.0     184.0     309.0
# 2           1245         9591             81     151.0     165.0     304.0
# 3           1245         9591             31     144.0     153.0     289.0
# 4           1245         9591              3     159.0     179.0     303.0
# ..           ...          ...            ...       ...       ...       ...
# 365         1245         9591              3     156.0     194.0     303.0
# 366         1245         9591             22     118.0     146.0     227.0
# 367         1245         9591             14     170.0     168.0     312.0
# 368         1245         9591             44     184.0     184.0     304.0
# 369         1245         9591             27     182.0     187.0     293.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-09-13T09:30:03.115000+00:00           NaN            True
# 1    2024-09-13T09:30:07.831000+00:00           NaN            True
# 2    2024-09-13T09:30:11.198000+00:00           NaN            True
# 3    2024-09-13T09:30:15.142000+00:00           NaN            True
# 4    2024-09-13T09:30:20.513000+00:00           NaN            True
# ..                                ...           ...             ...
# 365  2024-09-13T10:34:03.524000+00:00       152.855           False
# 366  2024-09-13T10:34:09.268000+00:00       176.972           False
# 367  2024-09-13T10:34:14.502000+00:00       149.300           False
# 368  2024-09-13T10:34:25.283000+00:00       151.423           False
# 369  2024-09-13T10:34:40.931000+00:00       127.110           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN                NaN                NaN
# 1                  NaN             50.855             27.251
# 2                  NaN             54.854             26.739
# 3                  NaN             60.536             36.639
# 4                  NaN             49.010             27.302
# ..                 ...                ...                ...
# 365             69.574             50.938             32.343
# 366             74.725             60.994             41.253
# 367             69.320             47.812             32.168
# 368             73.708             46.224             31.491
# 369             45.813             48.163             33.134
#
#                                     segments_sector_1  \
# 0    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2064, 2064, 2051, 2049, 2049, 2049, 2049, 2049]
# ..                                                ...
# 365  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 366  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 367  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 368  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 369  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 205...
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2049, 2051, 2051, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 365  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 366  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 367  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 368  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 369  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_3  lap_number compound  \
# 0       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1   MEDIUM
# 1    [2049, 2051, 2051, 2051, 2051, 2051, 2051]           1   MEDIUM
# 2       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1   MEDIUM
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049]           1     HARD
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]           1   MEDIUM
# ..                                          ...         ...      ...
# 365                                          []          23   MEDIUM
# 366                                          []          21     SOFT
# 367                                          []          19     SOFT
# 368                                          []          19     SOFT
# 369                                          []          20   MEDIUM
#
#     name_acronym         full_name     team_name
# 0            ALB   Alexander ALBON      Williams
# 1            STR      Lance STROLL  Aston Martin
# 2            PIA     Oscar PIASTRI       McLaren
# 3            OCO      Esteban OCON        Alpine
# 4            RIC  Daniel RICCIARDO            RB
# ..           ...               ...           ...
# 365          RIC  Daniel RICCIARDO            RB
# 366          TSU      Yuki TSUNODA            RB
# 367          ALO   Fernando ALONSO  Aston Martin
# 368          HAM    Lewis HAMILTON      Mercedes
# 369          HUL   Nico HULKENBERG  Haas F1 Team
#
# [370 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",110)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",110)

# %% [markdown]
# ### Hard tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables2,"HARD",110)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#           full_name compound  duration_sector_1  duration_sector_2  \
# 74     Pierre GASLY     HARD             39.243             45.184
# 258    Carlos SAINZ   MEDIUM             37.652             43.102
# 336  Max VERSTAPPEN     SOFT             37.434             42.577
#
#      duration_sector_3  lap_duration
# 74              25.470       109.897
# 258             25.419       106.173
# 336             25.535       105.546

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. Also, each sector will be commented. As we can see in the free practice, these data  are not very representative due to the changing conditions.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 336             37.434    Max VERSTAPPEN     SOFT       105.546          19
# 323             37.438      Carlos SAINZ     SOFT       106.189          19
# 329             37.461      Sergio PEREZ     SOFT       105.922          15
# 163             37.505   Charles LECLERC   MEDIUM           NaN          11
# 210             37.541      Lando NORRIS     SOFT       106.027           9
# 320             37.625    Lewis HAMILTON     SOFT       126.595          16
# 267             37.722     Oscar PIASTRI     SOFT       112.196          12
# 197             37.792  Daniel RICCIARDO     SOFT       106.687          13
# 200             37.864    Oliver BEARMAN     SOFT       106.973          13
# 260             37.874   Fernando ALONSO     SOFT       106.452          13
# 268             37.954      Yuki TSUNODA     SOFT       136.521          15
# 255             37.972    George RUSSELL   MEDIUM       106.516          13
# 198             38.150   Nico HULKENBERG     SOFT       107.135          10
# 327             38.232   Valtteri BOTTAS     SOFT       107.678          16
# 328             38.268      Lance STROLL     SOFT       134.058          15
# 296             38.353   Alexander ALBON     SOFT       108.234          15
# 165             38.773  Franco COLAPINTO   MEDIUM           NaN           8
# 301             38.825      Pierre GASLY   MEDIUM       108.712          17
# 224             38.933       ZHOU Guanyu   MEDIUM       109.052          11
# 118             40.351      Esteban OCON     HARD       170.099           3

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 336             42.577    Max VERSTAPPEN     SOFT       105.546          19
# 329             42.921      Sergio PEREZ     SOFT       105.922          15
# 207             42.949     Oscar PIASTRI     SOFT       106.282           9
# 134             43.058   Charles LECLERC   MEDIUM       106.608           9
# 230             43.078    Lewis HAMILTON     SOFT       105.859          11
# 258             43.102      Carlos SAINZ   MEDIUM       106.173          16
# 210             43.191      Lando NORRIS     SOFT       106.027           9
# 200             43.279    Oliver BEARMAN     SOFT       106.973          13
# 255             43.316    George RUSSELL   MEDIUM       106.516          13
# 197             43.321  Daniel RICCIARDO     SOFT       106.687          13
# 198             43.369   Nico HULKENBERG     SOFT       107.135          10
# 191             43.385  Franco COLAPINTO   MEDIUM       107.901          10
# 276             43.527   Valtteri BOTTAS     SOFT       107.640          13
# 262             43.537      Lance STROLL   MEDIUM       107.184          12
# 260             43.570   Fernando ALONSO     SOFT       106.452          13
# 156             43.715      Yuki TSUNODA   MEDIUM       107.716           9
# 195             43.779   Alexander ALBON   MEDIUM       107.955          10
# 264             44.416      Pierre GASLY   MEDIUM       109.055          15
# 274             44.580       ZHOU Guanyu     SOFT       109.340          14
# 106             48.138      Esteban OCON     HARD       958.192           2

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 260             25.008   Fernando ALONSO     SOFT       106.452          13
# 230             25.109    Lewis HAMILTON     SOFT       105.859          11
# 262             25.225      Lance STROLL   MEDIUM       107.184          12
# 255             25.228    George RUSSELL   MEDIUM       106.516          13
# 211             25.235      Pierre GASLY   MEDIUM       109.477          12
# 210             25.295      Lando NORRIS     SOFT       106.027           9
# 191             25.315  Franco COLAPINTO   MEDIUM       107.901          10
# 276             25.349   Valtteri BOTTAS     SOFT       107.640          13
# 224             25.370       ZHOU Guanyu   MEDIUM       109.052          11
# 41              25.408   Charles LECLERC   MEDIUM       108.340           3
# 292             25.411      Sergio PEREZ     SOFT       106.272          13
# 258             25.419      Carlos SAINZ   MEDIUM       106.173          16
# 207             25.422     Oscar PIASTRI     SOFT       106.282           9
# 336             25.535    Max VERSTAPPEN     SOFT       105.546          19
# 197             25.574  Daniel RICCIARDO     SOFT       106.687          13
# 195             25.611   Alexander ALBON   MEDIUM       107.955          10
# 198             25.616   Nico HULKENBERG     SOFT       107.135          10
# 203             25.723      Yuki TSUNODA   MEDIUM       107.708          12
# 200             25.830    Oliver BEARMAN     SOFT       106.973          13
# 106             27.326      Esteban OCON     HARD       958.192           2

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration > 106.5 and lap_duration <=109").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# SOFT        107.269750
# MEDIUM      107.902278

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 106.5
MAXIMUM_SECONDS = 109

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0          1245         9591             1              1          1        2
# 9          1245         9591             1             11          1        7
# 23         1245         9591             2              1          3        7
# 30         1245         9591             2             11          8       10
# 35         1245         9591             3              1          8       12
# 46         1245         9591             3             11         10       13
# 58         1245         9591             4              1         13       15
# 62         1245         9591             4             11         13       18
# 73         1245         9591             5              1         16       22
#
#    compound  tyre_age_at_start
# 0      SOFT                  0
# 9    MEDIUM                  0
# 23   MEDIUM                  0
# 30     SOFT                  0
# 35   MEDIUM                  5
# 46     SOFT                  2
# 58   MEDIUM                 10
# 62     SOFT                  5
# 73     SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 46   Max VERSTAPPEN   MEDIUM  2024-09-13T09:35:09.732000+00:00           3
# 81   Max VERSTAPPEN   MEDIUM  2024-09-13T09:39:31.104000+00:00           5
# 127  Max VERSTAPPEN   MEDIUM  2024-09-13T09:49:48.934000+00:00           8
# 155  Max VERSTAPPEN   MEDIUM  2024-09-13T09:54:07.412000+00:00          10
# 227  Max VERSTAPPEN   MEDIUM  2024-09-13T10:09:13.551000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 46              38.813             44.196             25.655       108.664
# 81              38.181             43.322             25.711       107.214
# 127             38.011             43.196             25.651       106.858
# 155             37.859             43.103             25.676       106.638
# 227             38.209             44.058             25.669       107.936

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 201  Sergio PEREZ     SOFT  2024-09-13T10:07:00.546000+00:00          10
# 202  Sergio PEREZ     SOFT  2024-09-13T10:07:00.546000+00:00          10
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 201              37.72             43.278             25.588       106.586
# 202              37.72             43.278             25.588       106.586

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 11         1245         9591             1             16          1        7
# 15         1245         9591             1             55          1        7
# 37         1245         9591             2             16          8       12
# 41         1245         9591             2             55          8       13
# 61         1245         9591             3             55         13       16
# 74         1245         9591             4             55         16       22
#
#    compound  tyre_age_at_start
# 11   MEDIUM                  0
# 15   MEDIUM                  0
# 37   MEDIUM                  6
# 41   MEDIUM                  6
# 61   MEDIUM                 11
# 74     SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 41   Charles LECLERC   MEDIUM  2024-09-13T09:34:40.316000+00:00           3
# 77   Charles LECLERC   MEDIUM  2024-09-13T09:39:05.269000+00:00           5
# 134  Charles LECLERC   MEDIUM  2024-09-13T09:51:10.654000+00:00           9
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 41              38.797             44.135             25.408       108.340
# 77              38.034             43.434             26.033       107.501
# 134             37.813             43.058             25.737       106.608

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 80   Carlos SAINZ   MEDIUM  2024-09-13T09:39:21.923000+00:00           5
# 153  Carlos SAINZ   MEDIUM  2024-09-13T09:53:51.761000+00:00          10
# 205  Carlos SAINZ   MEDIUM  2024-09-13T10:07:13.481000+00:00          13
# 206  Carlos SAINZ   MEDIUM  2024-09-13T10:07:13.481000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 80              38.509             44.313             25.546       108.368
# 153             38.109             43.814             25.825       107.748
# 205             37.918             43.749             25.537       107.204
# 206             37.918             43.749             25.537       107.204

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 12')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 6          1245         9591             1             44          1        6
# 28         1245         9591             2             44          7       10
# 50         1245         9591             3             44         11       13
# 69         1245         9591             4             44         14       20
#
#    compound  tyre_age_at_start
# 6    MEDIUM                  0
# 28   MEDIUM                  5
# 50     SOFT                  0
# 69     SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#          full_name compound                        date_start  lap_number  \
# 50  Lewis HAMILTON   MEDIUM  2024-09-13T09:35:44.879000+00:00           3
#
#     duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 50             38.321              43.83             25.467       107.618

# %%
libraryDataF1.getinfolongruns(jointables2,12,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 1          1245         9591             1              4          1        2
# 18         1245         9591             1             81          1        7
# 22         1245         9591             2              4          3        5
# 25         1245         9591             3              4          6        8
# 29         1245         9591             2             81          8        9
# 43         1245         9591             4              4          9       11
# 44         1245         9591             3             81          9       11
# 53         1245         9591             4             81         12       13
# 57         1245         9591             5              4         12       19
# 67         1245         9591             5             81         14       19
#
#    compound  tyre_age_at_start
# 1    MEDIUM                  0
# 18   MEDIUM                  0
# 22   MEDIUM                  1
# 25   MEDIUM                  4
# 29     SOFT                  0
# 43     SOFT                  0
# 44     SOFT                  1
# 53     SOFT                  4
# 57   MEDIUM                  7
# 67   MEDIUM                  0

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 79   Lando NORRIS   MEDIUM  2024-09-13T09:39:16.630000+00:00           3
# 161  Lando NORRIS   MEDIUM  2024-09-13T09:54:32.122000+00:00           6
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 79              38.943             44.075             25.540       108.558
# 161             38.217             43.462             25.567       107.246

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#          full_name compound                        date_start  lap_number  \
# 59   Oscar PIASTRI   MEDIUM  2024-09-13T09:36:42.669000+00:00           4
# 303  Oscar PIASTRI   MEDIUM  2024-09-13T10:25:35.310000+00:00          14
# 317  Oscar PIASTRI   MEDIUM  2024-09-13T10:27:23.762000+00:00          15
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 59              38.461             43.903             25.866       108.230
# 303             39.003             44.252             25.681       108.936
# 317             38.998             44.227             25.664       108.889

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 10         1245         9591             1             14          1        7
# 19         1245         9591             1             18          1        8
# 31         1245         9591             2             14          8       10
# 38         1245         9591             2             18          8       12
# 45         1245         9591             3             14         10       12
# 56         1245         9591             3             18         12       16
# 65         1245         9591             4             14         13       20
#
#    compound  tyre_age_at_start
# 10   MEDIUM                  0
# 19   MEDIUM                  0
# 31   MEDIUM                  6
# 38   MEDIUM                  6
# 45   MEDIUM                  8
# 56     SOFT                  0
# 65     SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 193  Fernando ALONSO   MEDIUM  2024-09-13T10:06:23.712000+00:00          10
# 194  Fernando ALONSO   MEDIUM  2024-09-13T10:06:23.712000+00:00          10
# 322  Fernando ALONSO     SOFT  2024-09-13T10:27:54.129000+00:00          16
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 193             38.525             44.162             25.241       107.928
# 194             38.525             44.162             25.241       107.928
# 322             37.918             43.953             25.187       107.058

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 262  Lance STROLL   MEDIUM  2024-09-13T10:21:24.450000+00:00          12
# 263  Lance STROLL     SOFT  2024-09-13T10:21:24.450000+00:00          12
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 262             38.422             43.537             25.225       107.184
# 263             38.422             43.537             25.225       107.184

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 7          1245         9591             1              3          1        7
# 12         1245         9591             1             22          1        7
# 36         1245         9591             2              3          8       12
# 39         1245         9591             2             22          8       12
# 55         1245         9591             3             22         12       15
# 59         1245         9591             3              3         13       16
# 72         1245         9591             4             22         15       22
# 75         1245         9591             4              3         17       24
#
#    compound  tyre_age_at_start
# 7    MEDIUM                  0
# 12   MEDIUM                  0
# 36   MEDIUM                  6
# 39   MEDIUM                  0
# 55     SOFT                  0
# 59     SOFT                  0
# 72     SOFT                  3
# 75   MEDIUM                 11

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#             full_name compound                        date_start  lap_number  \
# 125  Daniel RICCIARDO   MEDIUM  2024-09-13T09:49:39.779000+00:00           8
# 197  Daniel RICCIARDO     SOFT  2024-09-13T10:06:38.021000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 125             38.375             43.688             25.676       107.739
# 197             37.792             43.321             25.574       106.687

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 75   Yuki TSUNODA   MEDIUM  2024-09-13T09:38:53.970000+00:00           5
# 156  Yuki TSUNODA   MEDIUM  2024-09-13T09:54:12.367000+00:00           9
# 203  Yuki TSUNODA   MEDIUM  2024-09-13T10:07:07.087000+00:00          12
# 204  Yuki TSUNODA     SOFT  2024-09-13T10:07:07.087000+00:00          12
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 75              38.655             44.290             25.842       108.787
# 156             38.258             43.715             25.743       107.716
# 203             38.008             43.977             25.723       107.708
# 204             38.008             43.977             25.723       107.708

# %% [markdown]
# #### Haas

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 5          1245         9591             1             27          1        6
# 27         1245         9591             2             27          7        9
# 48         1245         9591             3             27         10       13
# 70         1245         9591             4             27         14       21
#
#    compound  tyre_age_at_start
# 5    MEDIUM                  0
# 27   MEDIUM                  5
# 48     SOFT                  0
# 70   MEDIUM                  8

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
#
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9584)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9584)
drivers = libraryDataF1.obtain_information('drivers',session_key=9584)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",88)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",88)

# %% [markdown]
# ### Hard tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables2,"HARD",88)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.Due to changing conditions, only a part of the free practice were important and this part will be taken into consideration.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. As I said in the previous section, the changing conditions made that the data obtained in this section are not representatives.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False  and lap_duration>84 and lap_duration <=88").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 84.73
MAXIMUM_SECONDS = 89

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 43 or driver_number == 23')

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,43,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)

# %% [markdown]
# #### Long runs mean

# %%
longruns_summary = libraryDataF1.obtainMeanLongRuns(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Mean pace per compound

# %%
libraryDataF1.showDataLongRuns(longruns_summary,"MEDIUM","mean_lap_time",['driver','mean_lap_time'])

# %%
libraryDataF1.showDataLongRuns(longruns_summary,"SOFT","mean_lap_time",['driver','mean_lap_time'])

# %%
libraryDataF1.showDataLongRuns(longruns_summary,"HARD","mean_lap_time",['driver','mean_lap_time'])

# %% [markdown]
# ## Free Practice 3
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9585)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9585)
drivers = libraryDataF1.obtain_information('drivers',session_key=9585)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",88)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",88)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration <88 and lap_duration > 84").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Long laps

# %%
MINIMUN_SECONDS = 84
MAXIMUM_SECONDS = 88

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)

# %% [markdown]
# ## Predictions

# %%
# Free Practice 3
practice = libraryDataF1.obtain_information('laps',session_key=9585)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9585)
drivers = libraryDataF1.obtain_information('drivers',session_key=9585)

stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice3 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# Free Practice 2
practice = libraryDataF1.obtain_information('laps',session_key=9584)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9584)
drivers = libraryDataF1.obtain_information('drivers',session_key=9584)


stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# ### Qualyfing prediction

# %%
qualy_simulation = libraryDataF1.qualyfing_prediction([jointablesfreepractice3,jointablesfreepractice2],drivers,0.02,0.02,0.08)
qualy_simulation.sort_values(by='qualy_lap_time')

# %% [markdown]
# ### Race prediction

# %%
race_simulation = libraryDataF1.race_prediction(jointablesfreepractice2,drivers,84,88.8)
race_simulation.groupby('team').mean().sort_values(by='mean_lap_duration')

# %% [markdown]
# ## Qualyfing
# ### Set up
# First of all, it is neccesary to obtain the data about the qualyfing
# #### Race control
# This section has been added in order to know which laps has been deleted and knowing what happened on track during this session. As every laptime that has been deleted were slow laps, none of them were removed.

# %%
libraryDataF1.obtain_information('race_control',session_key=9586)

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9586)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9586)
drivers = libraryDataF1.obtain_information('drivers',session_key=9586)

# %%
laptimes_deleted = [110.311,82.531]
driver_number_lap_deleted = [81,43]

for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
    try:
        id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
        qualyfing = qualyfing.drop(id_deleted)
    except:
        print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]

# %% [markdown]
# In this case, the fastest lap is 79.327 seconds (1.19.327= so that to obtain the competitve laps the fastest lap will be multiplied by 1.07 84.87989 seconds) due to, according to the rules all the drivers have to do unless one lap within this gap.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration <= 84.87")
competitiveLaps

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session
# In this chart we can see the deltas with compared with the fastest lap of the session that it could be different than the pole.

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %% [markdown]
# ### Speed trap

# %% [markdown]
# #### Maximum speed per drivers

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %% [markdown]
# ### Maximum speed per teams

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","st_speed",top_speed)

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])
mergequaly

# %% [markdown]
# In order to know when each session finished, race control dataset will be consulted.

# %%
maximumDateQ1 = "date_start <'2024-08-31T14:29:00+00:00'"
maximumDateQ2 = "date_start <'2024-08-31T14:52:00+00:00' and date_start >'2024-08-31T14:29:00+00:00'"
maximumDateQ3 = "date_start >'2024-08-31T14:52:00+00:00'"

# %% [markdown]
# ### Qualyfing 1

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver,I will do a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.
# With the new alphast, some drivers used two compounds to make their fastest lap. Using F1 tempo to watch the telemetry alongside the section where I comment the gap difference among the drivers eliminated compared to the driver that finished in a risk position to be eliminated.
# Before the lesmos,Zhou was the fastest followed by Ricciardo, Stroll, Colapinto and Bottas. After the lesmos, Zhou lost his gap being only faster than Bottas. After the Serraglio straight we can observe that the Williams was the fastest,reaching 335 km/h and Colapinto cut his gap.After this straight, Stroll had the best second sector of this group but , unfortunately, he lost his gap in the third sector.
# Pdte: Colapinto's laptime was his fastest laptime. In his second attemp, he got wrong in the exit of the second lesmo

# %%
#Reference
P15 = q1Data[14:15]
P15

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)

# %%
q1Data[15::]

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk
# I bring this section in order to know where the driver at risk lost his chances to improve in the qualyfing.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[0:14].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 2

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.
# Differences are usually narrow but, in this case, were pretty narrow. In the exit of turn 1,Ricciardo was the fastest and, since then, the fight was between Ricciardo and Hulkenberg being the Australian the fastest.
# Alonso that was 1.5 tenths behind then, cut his gap thanks to the second DRS zone.being only 0.084 slower than Hulkenberg- In case of Ricciardo, he lost his lap in this straight Since the exit of the chicane of the secondd sector, Alonso was the fastest being in front of Hulkenberg but in the last turn, Hulkenberg cut the enough gap to pass to Q3.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[0:9].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the poleman compared to the drivers eliminated.
# McLaren had an extra in Monza that this one was showed in Qualyfing with McLaren achiving 1-2 in Qualy.As we can see, even though,Norris's first sector was the slowest of the group but his second sector was astonishing being only Piastri the unique driver that was in his tenth and his thrid sector, only Russell was able to be in his time.

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %% [markdown]
# #### Best sector per driver of the session (in general)

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ## Race
# ### Obtain setup

# %%
race = libraryDataF1.obtain_information('laps',session_key=9590)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9590)
drivers = libraryDataF1.obtain_information('drivers',session_key=9590)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)

# %%
raceLaps = race.query("is_pit_out_lap == False")
jointables = pd.merge(raceLaps,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# #### Obtain data tyres

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'HARD',86)

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'MEDIUM',86)

# %% [markdown]
# ### Soft tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables,'SOFT',86)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >81 and lap_duration <=88").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Race pace

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >81 and lap_duration <=88").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Mean race pace per sector
# In this section, we can see the pace shown per each team in each sector sorted ascending.

# %% [markdown]
# #### Sector 1

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >81 and lap_duration <=88").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 2

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >81 and lap_duration <=88").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 3

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False and lap_duration >81 and lap_duration <=88").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Comparaison beetween drivers

# %% [markdown]
# #### Red Bull Racing

# %%
race.query("driver_number== 1 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 11 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Ferrari

# %%
race.query("driver_number== 16 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 55 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### McLaren

# %%
race.query("driver_number== 4 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 81 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Mercedes

# %%
race.query("driver_number== 44 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 63 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Aston Martin

# %%
race.query("driver_number== 14 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 18 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Haas F1 Team

# %%
race.query("driver_number== 20 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 27 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### RB

# %%
race.query("driver_number== 3 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 22 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Williams

# %%
race.query("driver_number== 2 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 23 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Alpine

# %%
race.query("driver_number== 10 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 31 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# #### Kick Sauber

# %%
race.query("driver_number== 24 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %%
race.query("driver_number== 77 and lap_duration >81 and lap_duration <=88").lap_duration.mean()

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 81.8
MAXIMUM_SECONDS = 87.5

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')

# %%
libraryDataF1.getinfolongruns(jointables,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')

# %%
libraryDataF1.getinfolongruns(jointables,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 14 or driver_number == 18')

# %%
libraryDataF1.getinfolongruns(jointables,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 4 or driver_number == 81')

# %%
libraryDataF1.getinfolongruns(jointables,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas F1 Team

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 23 or driver_number == 43')

# %%
libraryDataF1.getinfolongruns(jointables,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,43,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ### Pits
# Before to finish the analysis, I added the Pits sections where it can see how much time teams spent in the box.

# %%
pit = libraryDataF1.obtain_information('pit',session_key=9590)

# %%
jointables = pd.merge(drivers,pit,on=['driver_number']).query("pit_duration<120")
jointables
pit_duration = pd.DataFrame(jointables.groupby('team_name')['pit_duration'].mean().sort_values(ascending=True))
pit_duration
