# %%
from F1_library import libraryF1dataNotebook as libraryDataF1
import pandas as pd

# %% [markdown]
# # FORMULA 1 HEINEKEN DUTCH GRAND PRIX 2024
# The Dutch Grand Prix, officially Grote Prijs van Nederland, is a single-seater motor race held at the Zandvoort circuit in the Netherlands between 1948 and 1985, and returning in 2021. It was valid for the Formula 1 World Championship, on an interrupted basis, between 1952 and 1985.
#
# The Zandvoort circuit was the focus of motor racing for many decades in the Netherlands. The town of Zandvoort is located on the North Sea coast. It is close to the tulip capital Haarlem. During the 1930s there were several competitions on street circuits, but it was during the German invasion that the racing vocation of Zandvoort was initiated. It is said that the mayor, in a desperate attempt to prevent the townspeople from ending up in labour camps, agreed to have a straight track built right through the centre of town that could be used for parades at the end of the war. This road was later connected to other roads giving access to defensive positions on the coast.
#
# After the end of the war, several of these roads were extended and interlaced, forming a racing circuit designed by officials of the Royal Dutch Motorcycle Association and advised by Sammy Davis, winner of the 1927 24 Hours of Le Mans. The first race was held in 1948, with the title of the Zandvoort Grand Prix, won by Prince Bira of Thailand in an old Maserati ahead of British drivers Tony Rolt and Reg Parnell. The following year the competition was run under Formula 1 rules and was won by Gigi Villoresi in an Alfa Romeo. In 1950, the race was renamed the Dutch Grand Prix and in 1952, it became part of the world championship.
#
# In the 1970s, two drivers died: Piers Courage in 1970 at the "Honderlwak" corner and the promising Roger Williamson in 1973 at the same corner. From then on it was part of the world championship calendar until the 1980s. It was a circuit where driving could make the difference. Winners included Jim Clark, Jackie Stewart and Niki Lauda. In 1979 Gilles Villeneuve had to drive an entire lap on three wheels. The Tarzan corner at the end of the main straight was always the ideal place to overtake other drivers.
#
# In 2019, it was announced that the Grand Prix will once again be part of the Formula 1 calendar, being held at the Zandvoort Circuit.
# Source: Wikipedia

# %% [markdown]
# ## Upgrades (not updated)
# In this section those upgrades brought by the teams will be shown.
# <table>
# <tr>
#     <td>
#     Team
#     </td>
#     <td>
#     Updated component
#     </td>
#     <td>
#     Upgrade type
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Coke/Engine cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Mirror stays
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Williams
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Williams
#     </td>
#     <td>
#     Sidepot inlet
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Williams
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Williams
#     </td>
#     <td>
#     Central air intake
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Front Wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Nose
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Front suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Front corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Front corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Front suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Floor edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Rear wing
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     McLaren
#     </td>
#     <td>
#     Beam Wing
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
#
# </table>

# %% [markdown]
# ## Obtain session information

# %%
libraryDataF1.obtain_information('sessions',year=2024,country_acronym='NED')
# Out:
#    session_key session_name                 date_start  \
# 0         9575   Practice 1  2024-08-23T10:30:00+00:00
# 1         9576   Practice 2  2024-08-23T14:00:00+00:00
#
#                     date_end gmt_offset session_type  meeting_key   location  \
# 0  2024-08-23T11:30:00+00:00   02:00:00     Practice         1243  Zandvoort
# 1  2024-08-23T15:00:00+00:00   02:00:00     Practice         1243  Zandvoort
#
#    country_key country_code country_name  circuit_key circuit_short_name  year
# 0          133          NED  Netherlands           55          Zandvoort  2024
# 1          133          NED  Netherlands           55          Zandvoort  2024

# %% [markdown]
# ## Free Practice 1
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9575)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9575)
drivers = libraryDataF1.obtain_information('drivers',session_key=9575)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1243         9575              1     268.0       261       NaN
# 1           1243         9575              2     224.0       215       NaN
# 2           1243         9575              3     221.0       242       NaN
# 3           1243         9575              4     265.0       251       NaN
# 4           1243         9575             10     245.0       206       NaN
# ..           ...          ...            ...       ...       ...       ...
# 290         1243         9575             63     272.0       158     326.0
# 291         1243         9575              4     174.0       212     265.0
# 292         1243         9575             27     193.0       151     241.0
# 293         1243         9575             63     291.0       262     211.0
# 294         1243         9575             27     186.0       199     229.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-08-23T10:58:31.624000+00:00           NaN            True
# 1                                None           NaN            True
# 2    2024-08-23T11:00:11.683000+00:00           NaN            True
# 3    2024-08-23T10:50:51.903000+00:00           NaN            True
# 4    2024-08-23T10:31:10.380000+00:00           NaN            True
# ..                                ...           ...             ...
# 290  2024-08-23T11:30:01.598000+00:00       106.537           False
# 291  2024-08-23T11:33:36.392000+00:00       101.396           False
# 292  2024-08-23T11:30:42.467000+00:00       149.354           False
# 293  2024-08-23T11:31:48.224000+00:00       114.161           False
# 294  2024-08-23T11:33:11.829000+00:00       108.717           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             31.145             26.105
# 1                  NaN             36.161             38.757
# 2                  NaN             34.109             27.650
# 3                  NaN             31.579             32.753
# 4                  NaN             34.375             29.537
# ..                 ...                ...                ...
# 290             25.002             34.846             46.689
# 291             32.724             36.970             31.702
# 292             30.575             39.597             79.182
# 293             49.957             26.894             37.310
# 294             30.528             34.537             43.652
#
#                                     segments_sector_1  \
# 0    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 1    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 2    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 3    [2064, 2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 4    [2064, 2064, 2064, 2049, 2049, 2049, 2051, 2051]
# ..                                                ...
# 290  [None, 2048, 2048, 2050, 2048, 2048, 2050, 2048]
# 291  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 292  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 293  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 294  [None, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                     segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2051, 2051, 2051, 2051, 2051, 2049, 2051, 2049]
# ..                                                ...
# 290  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 291  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 292  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 293  [2048, 2048, 2048, 2048, 2048, 2048, 2050, 2048]
# 294  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                               segments_sector_3  lap_number      compound  \
# 0    [2048, 2048, 2051, 2051, 2051, 2051, 2051]           1  INTERMEDIATE
# 1    [2049, 2048, 2048, 2049, 2049, 2049, 2064]           1           WET
# 2    [2048, 2049, 2048, 2048, 2048, 2048, 2064]           1           WET
# 3    [2048, 2048, 2048, 2048, 2049, 2049, 2049]           1           WET
# 4    [2048, 2048, 2048, 2048, 2048, 2048, 2064]           1           WET
# ..                                          ...         ...           ...
# 290  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          16          SOFT
# 291                                          []          17          SOFT
# 292  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          17          SOFT
# 293                                          []          17          SOFT
# 294                                          []          18          SOFT
#
#     name_acronym         full_name        team_name
# 0            VER    Max VERSTAPPEN  Red Bull Racing
# 1            SAR    Logan SARGEANT         Williams
# 2            RIC  Daniel RICCIARDO               RB
# 3            NOR      Lando NORRIS          McLaren
# 4            GAS      Pierre GASLY           Alpine
# ..           ...               ...              ...
# 290          RUS    George RUSSELL         Mercedes
# 291          NOR      Lando NORRIS          McLaren
# 292          HUL   Nico HULKENBERG     Haas F1 Team
# 293          RUS    George RUSSELL         Mercedes
# 294          HUL   Nico HULKENBERG     Haas F1 Team
#
# [295 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",80)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",80)

# %% [markdown]
# ### Hard tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables2,"HARD",80)

# %% [markdown]
# ### Intermediate tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"INTERMEDIATE",100)

# %% [markdown]
# ### Wet tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"WET",120)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#            full_name      compound  duration_sector_1  duration_sector_2  \
# 238  Nico HULKENBERG  INTERMEDIATE             26.221             26.963
# 259     Carlos SAINZ        MEDIUM             24.978             26.080
# 278     Lando NORRIS          SOFT             24.630             25.931
# 74   Alexander ALBON           WET             28.424             29.377
#
#      duration_sector_3  lap_duration
# 238             22.755        75.939
# 259             22.016        73.074
# 278             21.761        72.322
# 74              25.021        82.822

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. Also, each sector will be commented. As we can see in the free practice, these data  are not very representative due to the changing conditions.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1          full_name compound  lap_duration  lap_number
# 278             24.630       Lando NORRIS     SOFT        72.322          15
# 207             24.778     Max VERSTAPPEN     SOFT        72.523          11
# 164             24.821     Lewis HAMILTON     SOFT        73.217           8
# 244             24.927      Oscar PIASTRI     SOFT        73.354          12
# 259             24.978       Carlos SAINZ   MEDIUM        73.074          13
# 290             25.002     George RUSSELL     SOFT       106.537          16
# 217             25.187    Alexander ALBON     SOFT        73.159          11
# 289             25.214    Nico HULKENBERG     SOFT        73.563          16
# 214             25.227       Lance STROLL     SOFT        74.151          11
# 252             25.241    Kevin MAGNUSSEN     SOFT        73.597          13
# 249             25.243    Fernando ALONSO     SOFT        94.715          13
# 255             25.280        ZHOU Guanyu     SOFT        73.965          13
# 189             25.484     Logan SARGEANT     SOFT        89.109          10
# 213             25.552    Charles LECLERC   MEDIUM        74.306          11
# 192             25.559       Sergio PEREZ     SOFT        74.279          10
# 276             25.569  Robert SHWARTZMAN     SOFT        74.658          14
# 197             25.737       Yuki TSUNODA     SOFT        74.418          10
# 257             25.790       Esteban OCON     SOFT        75.796          13
# 152             25.975       Pierre GASLY     SOFT       104.696           8
# 209             26.057   Daniel RICCIARDO     SOFT        76.231          11

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2          full_name      compound  lap_duration  \
# 202             25.915     Lewis HAMILTON          SOFT        73.006
# 278             25.931       Lando NORRIS          SOFT        72.322
# 207             25.967     Max VERSTAPPEN          SOFT        72.523
# 217             25.968    Alexander ALBON          SOFT        73.159
# 255             26.050        ZHOU Guanyu          SOFT        73.965
# 243             26.069     George RUSSELL          SOFT        73.766
# 259             26.080       Carlos SAINZ        MEDIUM        73.074
# 271             26.134    Nico HULKENBERG          SOFT        73.763
# 212             26.192    Fernando ALONSO          SOFT        74.467
# 197             26.220       Yuki TSUNODA          SOFT        74.418
# 252             26.236    Kevin MAGNUSSEN          SOFT        73.597
# 205             26.236      Oscar PIASTRI          SOFT        73.230
# 214             26.363       Lance STROLL          SOFT        74.151
# 192             26.380       Sergio PEREZ          SOFT        74.279
# 213             26.525    Charles LECLERC        MEDIUM        74.306
# 276             26.627  Robert SHWARTZMAN          SOFT        74.658
# 257             26.811       Esteban OCON          SOFT        75.796
# 189             26.894     Logan SARGEANT          SOFT        89.109
# 209             27.098   Daniel RICCIARDO          SOFT        76.231
# 67              28.846       Pierre GASLY  INTERMEDIATE        82.036
#
#      lap_number
# 202          10
# 278          15
# 207          11
# 217          11
# 255          13
# 243          12
# 259          13
# 271          14
# 212          11
# 197          10
# 252          13
# 205          10
# 214          11
# 192          10
# 213          11
# 276          14
# 257          13
# 189          10
# 209          11
# 67            4

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3          full_name      compound  lap_duration  \
# 278             21.761       Lando NORRIS          SOFT        72.322
# 207             21.778     Max VERSTAPPEN          SOFT        72.523
# 274             21.919     George RUSSELL          SOFT        73.142
# 244             21.919      Oscar PIASTRI          SOFT        73.354
# 217             22.004    Alexander ALBON          SOFT        73.159
# 289             22.011    Nico HULKENBERG          SOFT        73.563
# 259             22.016       Carlos SAINZ        MEDIUM        73.074
# 252             22.120    Kevin MAGNUSSEN          SOFT        73.597
# 164             22.124     Lewis HAMILTON          SOFT        73.217
# 213             22.229    Charles LECLERC        MEDIUM        74.306
# 192             22.340       Sergio PEREZ          SOFT        74.279
# 197             22.461       Yuki TSUNODA          SOFT        74.418
# 276             22.462  Robert SHWARTZMAN          SOFT        74.658
# 214             22.561       Lance STROLL          SOFT        74.151
# 212             22.606    Fernando ALONSO          SOFT        74.467
# 255             22.635        ZHOU Guanyu          SOFT        73.965
# 149             22.868     Logan SARGEANT          SOFT        75.605
# 220             22.978       Esteban OCON          SOFT        76.400
# 209             23.076   Daniel RICCIARDO          SOFT        76.231
# 67              24.994       Pierre GASLY  INTERMEDIATE        82.036
#
#      lap_number
# 278          15
# 207          11
# 274          14
# 244          12
# 217          11
# 289          16
# 259          13
# 252          13
# 164           8
# 213          11
# 192          10
# 197          10
# 276          14
# 214          11
# 212          11
# 255          13
# 149           8
# 220          11
# 209          11
# 67            4

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration >78  and lap_duration <=72.5").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
# Empty DataFrame
# Columns: [lap_duration]
# Index: []

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 72
MAXIMUM_SECONDS = 79

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 10         1243         9575             1             11          1        3
# 16         1243         9575             1              1          1        5
# 30         1243         9575             2             11          4        5
# 44         1243         9575             3             11          6       13
# 45         1243         9575             2              1          6       14
#
#         compound  tyre_age_at_start
# 10           WET                  0
# 16  INTERMEDIATE                  0
# 30  INTERMEDIATE                  0
# 44          SOFT                  0
# 45          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 107  Max VERSTAPPEN     SOFT  2024-08-23T11:21:49.140000+00:00           6
# 148  Max VERSTAPPEN     SOFT  2024-08-23T11:24:57.178000+00:00           8
# 207  Max VERSTAPPEN     SOFT  2024-08-23T11:29:45.859000+00:00          11
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 107             26.018             26.873             23.152        76.043
# 148             25.522             26.081             22.678        74.281
# 207             24.778             25.967             21.778        72.523

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 112  Sergio PEREZ     SOFT  2024-08-23T11:24:12.551000+00:00           6
# 153  Sergio PEREZ     SOFT  2024-08-23T11:27:04.062000+00:00           8
# 192  Sergio PEREZ     SOFT  2024-08-23T11:29:58.611000+00:00          10
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 112             26.695             26.914             23.376        76.985
# 153             25.747             26.524             22.887        75.158
# 192             25.559             26.380             22.340        74.279

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 2          1243         9575             1             16          1        2
# 6          1243         9575             1             55          1        2
# 24         1243         9575             2             55          3        4
# 25         1243         9575             2             16          3        6
# 38         1243         9575             3             55          4        7
# 47         1243         9575             3             16          7        8
# 55         1243         9575             4             16          8       10
# 58         1243         9575             4             55          8       16
# 66         1243         9575             5             16         11       16
#
#         compound  tyre_age_at_start
# 2            WET                  0
# 6            WET                  0
# 24           WET                  1
# 25           WET                  1
# 38  INTERMEDIATE                  0
# 47  INTERMEDIATE                  0
# 55        MEDIUM                  0
# 58        MEDIUM                  0
# 66        MEDIUM                  3

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name      compound                        date_start  \
# 155  Charles LECLERC  INTERMEDIATE  2024-08-23T11:22:15.204000+00:00
# 156  Charles LECLERC        MEDIUM  2024-08-23T11:22:15.204000+00:00
# 213  Charles LECLERC        MEDIUM  2024-08-23T11:27:15.829000+00:00
#
#      lap_number  duration_sector_1  duration_sector_2  duration_sector_3  \
# 155           8             26.793             27.638             23.154
# 156           8             26.793             27.638             23.154
# 213          11             25.552             26.525             22.229
#
#      lap_duration
# 155        77.585
# 156        77.585
# 213        74.306

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 165  Carlos SAINZ   MEDIUM  2024-08-23T11:22:19.903000+00:00           8
# 184  Carlos SAINZ   MEDIUM  2024-08-23T11:23:36.261000+00:00           9
# 203  Carlos SAINZ   MEDIUM  2024-08-23T11:24:51.208000+00:00          10
# 259  Carlos SAINZ   MEDIUM  2024-08-23T11:29:34.795000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 165             26.388             27.173             22.815        76.376
# 184             25.829             26.559             22.585        74.973
# 203             25.693             26.875             22.564        75.132
# 259             24.978             26.080             22.016        73.074

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 17         1243         9575             1             44          1        5
# 18         1243         9575             1             63          1        5
# 43         1243         9575             2             63          6        8
# 46         1243         9575             2             44          6       14
# 62         1243         9575             3             63          9       18
#
#         compound  tyre_age_at_start
# 17  INTERMEDIATE                  0
# 18           WET                  0
# 43  INTERMEDIATE                  0
# 46          SOFT                  0
# 62          SOFT                  0

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 17         1243         9575             1             44          1        5
# 18         1243         9575             1             63          1        5
# 43         1243         9575             2             63          6        8
# 46         1243         9575             2             44          6       14
# 62         1243         9575             3             63          9       18
#
#         compound  tyre_age_at_start
# 17  INTERMEDIATE                  0
# 18           WET                  0
# 43  INTERMEDIATE                  0
# 46          SOFT                  0
# 62          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 122  Lewis HAMILTON     SOFT  2024-08-23T11:22:41.731000+00:00           6
# 164  Lewis HAMILTON     SOFT  2024-08-23T11:25:35.742000+00:00           8
# 202  Lewis HAMILTON     SOFT  2024-08-23T11:28:42.937000+00:00          10
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 122             26.258             26.682             23.119        76.059
# 164             24.821             26.272             22.124        73.217
# 202             24.884             25.915             22.207        73.006

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 185  George RUSSELL     SOFT  2024-08-23T11:19:26.273000+00:00           9
# 204  George RUSSELL     SOFT  2024-08-23T11:20:44.067000+00:00          10
# 243  George RUSSELL     SOFT  2024-08-23T11:23:45.644000+00:00          12
# 274  George RUSSELL     SOFT  2024-08-23T11:26:47.844000+00:00          14
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 185             26.951             27.614             23.320        77.885
# 204             26.115             27.084             22.701        75.900
# 243             25.476             26.069             22.221        73.766
# 274             25.085             26.138             21.919        73.142

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 1          1243         9575             1              4          1        2
# 15         1243         9575             1             81          1        3
# 22         1243         9575             2              4          3        4
# 32         1243         9575             2             81          4        5
# 40         1243         9575             3              4          5        7
# 42         1243         9575             3             81          5       15
# 59         1243         9575             4              4          8       18
#
#         compound  tyre_age_at_start
# 1            WET                  0
# 15           WET                  0
# 22           WET                  1
# 32  INTERMEDIATE                  0
# 40  INTERMEDIATE                  0
# 42          SOFT                  0
# 59          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 151  Lando NORRIS     SOFT  2024-08-23T11:19:00.370000+00:00           8
# 191  Lando NORRIS     SOFT  2024-08-23T11:21:55.651000+00:00          10
# 229  Lando NORRIS     SOFT  2024-08-23T11:25:02.132000+00:00          12
# 278  Lando NORRIS     SOFT  2024-08-23T11:29:52.855000+00:00          15
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 151             26.871             27.295             23.201        77.367
# 191             25.672             26.575             22.272        74.519
# 229             24.984             25.964             21.870        72.818
# 278             24.630             25.931             21.761        72.322

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#          full_name      compound                        date_start  \
# 104  Oscar PIASTRI  INTERMEDIATE  2024-08-23T11:19:06.480000+00:00
# 105  Oscar PIASTRI          SOFT  2024-08-23T11:19:06.480000+00:00
# 125  Oscar PIASTRI          SOFT  2024-08-23T11:20:24.707000+00:00
# 167  Oscar PIASTRI          SOFT  2024-08-23T11:23:13.789000+00:00
# 205  Oscar PIASTRI          SOFT  2024-08-23T11:26:04.931000+00:00
# 244  Oscar PIASTRI          SOFT  2024-08-23T11:29:02.222000+00:00
#
#      lap_number  duration_sector_1  duration_sector_2  duration_sector_3  \
# 104           5             26.978             27.898             23.439
# 105           5             26.978             27.898             23.439
# 125           6             25.889             27.099             22.983
# 167           8             25.432             26.511             22.350
# 205          10             25.015             26.236             21.979
# 244          12             24.927             26.508             21.919
#
#      lap_duration
# 104        78.315
# 105        78.315
# 125        75.971
# 167        74.293
# 205        73.230
# 244        73.354

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 11         1243         9575             1             14          1        3
# 12         1243         9575             1             18          1        3
# 35         1243         9575             2             14          4        6
# 36         1243         9575             2             18          4        6
# 52         1243         9575             3             18          7       15
# 54         1243         9575             3             14          7       16
#
#         compound  tyre_age_at_start
# 11           WET                  0
# 12           WET                  0
# 35  INTERMEDIATE                  0
# 36  INTERMEDIATE                  0
# 52          SOFT                  0
# 54          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 154  Fernando ALONSO     SOFT  2024-08-23T11:21:07.170000+00:00           8
# 174  Fernando ALONSO     SOFT  2024-08-23T11:22:24.472000+00:00           9
# 212  Fernando ALONSO     SOFT  2024-08-23T11:25:21.200000+00:00          11
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 154             26.740             27.231             23.323        77.294
# 174             26.024             26.719             22.950        75.693
# 212             25.669             26.192             22.606        74.467

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 135  Lance STROLL     SOFT  2024-08-23T11:21:18.425000+00:00           7
# 157  Lance STROLL     SOFT  2024-08-23T11:22:36.222000+00:00           8
# 214  Lance STROLL     SOFT  2024-08-23T11:26:56.266000+00:00          11
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 135             26.437             27.281             24.055        77.773
# 157             25.663             27.002             23.072        75.737
# 214             25.227             26.363             22.561        74.151

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 8          1243         9575             1              3          1        3
# 13         1243         9575             1             22          1        3
# 28         1243         9575             2             22          3        7
# 39         1243         9575             2              3          4        8
# 57         1243         9575             3             22          8       14
# 60         1243         9575             3              3          9       16
#
#         compound  tyre_age_at_start
# 8            WET                  0
# 13           WET                  0
# 28  INTERMEDIATE                  0
# 39  INTERMEDIATE                  0
# 57          SOFT                  0
# 60          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#             full_name compound                        date_start  lap_number  \
# 209  Daniel RICCIARDO     SOFT  2024-08-23T11:25:24.252000+00:00          11
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 209             26.057             27.098             23.076        76.231

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 159  Yuki TSUNODA     SOFT  2024-08-23T11:24:19.415000+00:00           8
# 197  Yuki TSUNODA     SOFT  2024-08-23T11:27:24.477000+00:00          10
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 159             26.637             27.271             23.378        77.286
# 197             25.737             26.220             22.461        74.418

# %% [markdown]
# #### Haas

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 3          1243         9575             1             20          1        2
# 5          1243         9575             1             27          1        2
# 20         1243         9575             2             20          3        3
# 29         1243         9575             2             27          3        7
# 31         1243         9575             3             20          4        5
# 41         1243         9575             4             20          5        8
# 56         1243         9575             3             27          8       10
# 61         1243         9575             5             20          9       16
# 65         1243         9575             4             27         11       12
# 68         1243         9575             5             27         12       19
#
#         compound  tyre_age_at_start
# 3            WET                  0
# 5            WET                  0
# 20           WET                  0
# 29           WET                  1
# 31           WET                  2
# 41  INTERMEDIATE                  0
# 56  INTERMEDIATE                  0
# 61          SOFT                  0
# 65  INTERMEDIATE                  3
# 68          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 177  Kevin MAGNUSSEN     SOFT  2024-08-23T11:22:32.739000+00:00           9
# 196  Kevin MAGNUSSEN     SOFT  2024-08-23T11:23:49.396000+00:00          10
# 252  Kevin MAGNUSSEN     SOFT  2024-08-23T11:29:23.936000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 177             26.197             27.081             23.109        76.387
# 196             25.748             26.678             23.362        75.788
# 252             25.241             26.236             22.120        73.597

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name      compound                        date_start  \
# 238  Nico HULKENBERG  INTERMEDIATE  2024-08-23T11:23:19.204000+00:00
# 239  Nico HULKENBERG          SOFT  2024-08-23T11:23:19.204000+00:00
# 271  Nico HULKENBERG          SOFT  2024-08-23T11:26:22.129000+00:00
# 289  Nico HULKENBERG          SOFT  2024-08-23T11:29:28.924000+00:00
#
#      lap_number  duration_sector_1  duration_sector_2  duration_sector_3  \
# 238          12             26.221             26.963             22.755
# 239          12             26.221             26.963             22.755
# 271          14             25.433             26.134             22.196
# 289          16             25.214             26.338             22.011
#
#      lap_duration
# 238        75.939
# 239        75.939
# 271        73.763
# 289        73.563

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 31 or driver_number == 10')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 9          1243         9575             1             10          1        3
# 19         1243         9575             1             31          1        9
# 34         1243         9575             2             10          4        6
# 48         1243         9575             3             10          7        9
# 64         1243         9575             2             31         10       16
#
#         compound  tyre_age_at_start
# 9            WET                  0
# 19  INTERMEDIATE                  0
# 34  INTERMEDIATE                  0
# 48          SOFT                  0
# 64          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 201  Esteban OCON     SOFT  2024-08-23T11:24:25.084000+00:00          10
# 220  Esteban OCON     SOFT  2024-08-23T11:25:43.343000+00:00          11
# 257  Esteban OCON     SOFT  2024-08-23T11:28:50.705000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 201             27.220             27.751             23.237        78.208
# 220             26.399             27.023             22.978        76.400
# 257             25.790             26.811             23.195        75.796

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 2 or driver_number == 23')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0          1243         9575             1              2          1        2
# 14         1243         9575             1             23          1        3
# 21         1243         9575             2              2          3        4
# 23         1243         9575             2             23          3        4
# 33         1243         9575             3              2          4        6
# 37         1243         9575             3             23          4        7
# 51         1243         9575             4              2          7       13
# 53         1243         9575             4             23          7       15
#
#         compound  tyre_age_at_start
# 0            WET                  0
# 14           WET                  0
# 21           WET                  1
# 23           WET                  1
# 33  INTERMEDIATE                  0
# 37  INTERMEDIATE                  0
# 51          SOFT                  0
# 53          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name      compound                        date_start  \
# 138  Alexander ALBON  INTERMEDIATE  2024-08-23T11:21:58.856000+00:00
# 139  Alexander ALBON          SOFT  2024-08-23T11:21:58.856000+00:00
# 179  Alexander ALBON          SOFT  2024-08-23T11:24:46.238000+00:00
# 217  Alexander ALBON          SOFT  2024-08-23T11:27:43.114000+00:00
#
#      lap_number  duration_sector_1  duration_sector_2  duration_sector_3  \
# 138           7             26.840             27.224             23.440
# 139           7             26.840             27.224             23.440
# 179           9             25.408             26.605             22.351
# 217          11             25.187             25.968             22.004
#
#      lap_duration
# 138        77.504
# 139        77.504
# 179        74.364
# 217        73.159

# %%
libraryDataF1.getinfolongruns(jointables2,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 128  Logan SARGEANT     SOFT  2024-08-23T11:24:08.335000+00:00           7
# 149  Logan SARGEANT     SOFT  2024-08-23T11:25:26.340000+00:00           8
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 128             26.702             27.623             23.788        78.113
# 149             25.747             26.990             22.868        75.605

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 4          1243         9575             1             24          1        2
# 26         1243         9575             2             24          3        6
# 49         1243         9575             3             24          7        9
# 63         1243         9575             4             24         10       16
#
#         compound  tyre_age_at_start
# 4            WET                  0
# 26           WET                  1
# 49  INTERMEDIATE                  0
# 63          SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#        full_name compound                        date_start  lap_number  \
# 199  ZHOU Guanyu     SOFT  2024-08-23T11:25:07.224000+00:00          10
# 255  ZHOU Guanyu     SOFT  2024-08-23T11:29:48.880000+00:00          13
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 199             27.427             26.883             23.798        78.108
# 255             25.280             26.050             22.635        73.965

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by
#
#     name_acronym         full_name     team_name
# 0            GAS      Pierre GASLY        Alpine
# 1            SAR    Logan SARGEANT      Williams
# 2            BOT   Valtteri BOTTAS   Kick Sauber
# 3            RUS    George RUSSELL      Mercedes
# 4            ALB   Alexander ALBON      Williams
# ..           ...               ...           ...
# 592          MAG   Kevin MAGNUSSEN  Haas F1 Team
# 593          RIC  Daniel RICCIARDO            RB
# 594          ZHO       ZHOU Guanyu   Kick Sauber
# 595          LEC   Charles LECLERC       Ferrari
# 596          OCO      Esteban OCON        Alpine
#
# [597 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",81)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",81)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",81)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#            full_name compound  duration_sector_1  duration_sector_2  \
# 214  Kevin MAGNUSSEN     HARD             24.558             25.338
# 166   Lewis HAMILTON   MEDIUM             24.655             25.526
# 222   George RUSSELL     SOFT             24.331             24.945
#
#      duration_sector_3  lap_duration
# 214             21.534        71.430
# 166             21.652        71.833
# 222             21.426        70.702

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.Due to changing conditions, only a part of the free practice were important and this part will be taken into consideration.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. As I said in the previous section, the changing conditions made that the data obtained in this section are not representatives.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 224             24.259    Lewis HAMILTON     SOFT        70.813          11
# 183             24.313      Lando NORRIS     SOFT        70.961           9
# 222             24.331    George RUSSELL     SOFT        70.702          12
# 196             24.396     Oscar PIASTRI     SOFT        70.763          10
# 185             24.426      Sergio PEREZ     SOFT        71.581          11
# 266             24.448   Kevin MAGNUSSEN     SOFT        71.489          14
# 181             24.470    Max VERSTAPPEN     SOFT        70.986           8
# 260             24.486      Lance STROLL     SOFT        71.576          14
# 216             24.504   Fernando ALONSO     SOFT        71.416          12
# 244             24.519   Charles LECLERC     SOFT        71.443          12
# 242             24.523   Alexander ALBON     SOFT        71.550          13
# 213             24.544      Pierre GASLY     SOFT        71.644          11
# 217             24.546      Yuki TSUNODA     SOFT        71.374          11
# 189             24.640       ZHOU Guanyu     SOFT        71.934          11
# 186             24.668    Logan SARGEANT     SOFT        71.818           9
# 221             24.765  Daniel RICCIARDO     SOFT        71.630          12
# 264             24.782      Esteban OCON     SOFT        72.061          14
# 182             24.874   Valtteri BOTTAS     SOFT        72.206           9
# 133             24.900      Carlos SAINZ   MEDIUM        94.668           7
# 68              25.413   Nico HULKENBERG   MEDIUM        73.296           4

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 222             24.945    George RUSSELL     SOFT        70.702          12
# 196             25.037     Oscar PIASTRI     SOFT        70.763          10
# 224             25.038    Lewis HAMILTON     SOFT        70.813          11
# 181             25.142    Max VERSTAPPEN     SOFT        70.986           8
# 183             25.168      Lando NORRIS     SOFT        70.961           9
# 216             25.252   Fernando ALONSO     SOFT        71.416          12
# 217             25.268      Yuki TSUNODA     SOFT        71.374          11
# 221             25.276  Daniel RICCIARDO     SOFT        71.630          12
# 214             25.338   Kevin MAGNUSSEN     HARD        71.430          11
# 185             25.382      Sergio PEREZ     SOFT        71.581          11
# 260             25.396      Lance STROLL     SOFT        71.576          14
# 213             25.398      Pierre GASLY     SOFT        71.644          11
# 244             25.424   Charles LECLERC     SOFT        71.443          12
# 187             25.444   Alexander ALBON     HARD        71.639          10
# 189             25.469       ZHOU Guanyu     SOFT        71.934          11
# 186             25.485    Logan SARGEANT     SOFT        71.818           9
# 264             25.533      Esteban OCON     SOFT        72.061          14
# 182             25.562   Valtteri BOTTAS     SOFT        72.206           9
# 133             25.783      Carlos SAINZ   MEDIUM        94.668           7
# 139             25.969   Nico HULKENBERG   MEDIUM        73.336           7

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 196             21.330     Oscar PIASTRI     SOFT        70.763          10
# 181             21.374    Max VERSTAPPEN     SOFT        70.986           8
# 222             21.426    George RUSSELL     SOFT        70.702          12
# 183             21.480      Lando NORRIS     SOFT        70.961           9
# 244             21.500   Charles LECLERC     SOFT        71.443          12
# 224             21.516    Lewis HAMILTON     SOFT        70.813          11
# 261             21.527   Fernando ALONSO     SOFT        71.357          15
# 214             21.534   Kevin MAGNUSSEN     HARD        71.430          11
# 242             21.555   Alexander ALBON     SOFT        71.550          13
# 217             21.560      Yuki TSUNODA     SOFT        71.374          11
# 221             21.589  Daniel RICCIARDO     SOFT        71.630          12
# 186             21.665    Logan SARGEANT     SOFT        71.818           9
# 229             21.685   Valtteri BOTTAS     SOFT        72.233          12
# 260             21.694      Lance STROLL     SOFT        71.576          14
# 213             21.702      Pierre GASLY     SOFT        71.644          11
# 264             21.746      Esteban OCON     SOFT        72.061          14
# 185             21.773      Sergio PEREZ     SOFT        71.581          11
# 189             21.825       ZHOU Guanyu     SOFT        71.934          11
# 66              21.848      Carlos SAINZ   MEDIUM        73.108           4
# 68              21.874   Nico HULKENBERG   MEDIUM        73.296           4

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False  and lap_duration>74.5 and lap_duration <=79").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# HARD         76.593000
# MEDIUM       76.665988
# SOFT         76.734888

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 74.5
MAXIMUM_SECONDS = 79.8

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 2          1243         9576             1              1          1        4
# 5          1243         9576             1             11          1        5
# 22         1243         9576             2              1          5        7
# 24         1243         9576             2             11          5       10
# 29         1243         9576             3              1          8       10
# 40         1243         9576             3             11         11       16
# 46         1243         9576             4              1         11       21
# 58         1243         9576             4             11         16       30
# 74         1243         9576             5              1         22       34
#
#    compound  tyre_age_at_start
# 2    MEDIUM                  0
# 5    MEDIUM                  0
# 22   MEDIUM                  3
# 24   MEDIUM                  3
# 29     SOFT                  0
# 40     SOFT                  0
# 46   MEDIUM                  0
# 58   MEDIUM                  9
# 74     SOFT                  3

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 268  Max VERSTAPPEN   MEDIUM  2024-08-23T14:33:20.296000+00:00          11
# 275  Max VERSTAPPEN   MEDIUM  2024-08-23T14:34:36.815000+00:00          12
# 278  Max VERSTAPPEN   MEDIUM  2024-08-23T14:35:53.434000+00:00          13
# 280  Max VERSTAPPEN   MEDIUM  2024-08-23T14:37:09.793000+00:00          14
# 285  Max VERSTAPPEN   MEDIUM  2024-08-23T14:38:25.875000+00:00          15
# 293  Max VERSTAPPEN   MEDIUM  2024-08-23T14:39:41.672000+00:00          16
# 304  Max VERSTAPPEN   MEDIUM  2024-08-23T14:40:57.368000+00:00          17
# 318  Max VERSTAPPEN   MEDIUM  2024-08-23T14:42:13.144000+00:00          18
# 334  Max VERSTAPPEN   MEDIUM  2024-08-23T14:43:30.227000+00:00          19
# 394  Max VERSTAPPEN     SOFT  2024-08-23T14:48:01.016000+00:00          22
# 412  Max VERSTAPPEN     SOFT  2024-08-23T14:49:16.516000+00:00          23
# 429  Max VERSTAPPEN     SOFT  2024-08-23T14:50:31.890000+00:00          24
# 447  Max VERSTAPPEN     SOFT  2024-08-23T14:51:47.062000+00:00          25
# 465  Max VERSTAPPEN     SOFT  2024-08-23T14:53:02.079000+00:00          26
# 500  Max VERSTAPPEN     SOFT  2024-08-23T14:55:38.481000+00:00          28
# 517  Max VERSTAPPEN     SOFT  2024-08-23T14:56:54.138000+00:00          29
# 533  Max VERSTAPPEN     SOFT  2024-08-23T14:58:09.831000+00:00          30
# 549  Max VERSTAPPEN     SOFT  2024-08-23T14:59:25.689000+00:00          31
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 268             26.193             27.297             23.091        76.581
# 275             26.294             27.388             22.898        76.580
# 278             26.074             27.416             22.825        76.315
# 280             25.924             27.365             22.782        76.071
# 285             25.875             27.203             22.771        75.849
# 293             25.825             27.203             22.726        75.754
# 304             25.892             27.081             22.792        75.765
# 318             25.807             28.208             23.029        77.044
# 334             25.729             27.457             25.562        78.748
# 394             25.801             27.051             22.674        75.526
# 412             25.637             27.260             22.537        75.434
# 429             25.525             27.092             22.434        75.051
# 447             25.593             27.083             22.457        75.133
# 465             25.570             27.324             22.520        75.414
# 500             25.783             27.321             22.612        75.716
# 517             25.626             27.441             22.580        75.647
# 533             25.521             27.815             22.576        75.912
# 549             25.459             27.095             22.615        75.169

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
#
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 27              25.896             26.293             22.437        74.626
# 316             26.108             26.937             23.105        76.150
# 330             26.027             27.243             23.076        76.346
# 346             26.417             27.352             23.023        76.792
# 363             26.145             27.491             23.026        76.662
# 382             26.142             27.594             23.136        76.872
# 400             26.214             27.736             23.136        77.086
# 418             26.184             27.590             23.078        76.852
# 435             26.181             27.711             23.251        77.143
# 453             26.338             27.996             23.495        77.829
# 471             27.007             27.978             23.348        78.333
# 490             26.301             27.996             23.237        77.534
# 507             26.253             28.168             23.370        77.791
# 523             26.360             27.986             23.321        77.667
# 540             26.479             28.348             23.485        78.312
# 558             27.260             28.298             23.426        78.984

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 16   Pierre GASLY     HARD  2024-08-23T14:01:27.193000+00:00           2
# 322  Pierre GASLY     HARD  2024-08-23T14:42:40.267000+00:00          18
# 338  Pierre GASLY     HARD  2024-08-23T14:43:57.316000+00:00          19
# 356  Pierre GASLY     HARD  2024-08-23T14:45:13.686000+00:00          20
# 374  Pierre GASLY     HARD  2024-08-23T14:46:30.143000+00:00          21
# 392  Pierre GASLY     HARD  2024-08-23T14:47:46.889000+00:00          22
# 410  Pierre GASLY     HARD  2024-08-23T14:49:03.092000+00:00          23
# 428  Pierre GASLY     HARD  2024-08-23T14:50:19.716000+00:00          24
# 446  Pierre GASLY     HARD  2024-08-23T14:51:36.103000+00:00          25
# 464  Pierre GASLY     HARD  2024-08-23T14:52:53.159000+00:00          26
# 481  Pierre GASLY     HARD  2024-08-23T14:54:10.639000+00:00          27
# 498  Pierre GASLY     HARD  2024-08-23T14:55:27.455000+00:00          28
# 515  Pierre GASLY     HARD  2024-08-23T14:56:44.490000+00:00          29
# 531  Pierre GASLY     HARD  2024-08-23T14:58:01.725000+00:00          30
# 548  Pierre GASLY     HARD  2024-08-23T14:59:20.190000+00:00          31
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 16              26.161             26.260             22.682        75.103
# 322             26.329             27.506             23.295        77.130
# 338             26.095             27.115             23.064        76.274
# 356             25.967             27.455             23.078        76.500
# 374             26.391             27.341             23.037        76.769
# 392             25.896             27.320             22.943        76.159
# 410             26.124             27.530             22.959        76.613
# 428             25.979             27.403             23.002        76.384
# 446             26.170             27.711             23.165        77.046
# 464             26.299             28.045             23.158        77.502
# 481             26.045             27.621             23.103        76.769
# 498             26.069             27.905             23.187        77.161
# 515             26.099             27.864             23.179        77.142
# 531             26.057             27.889             24.587        78.533
# 548             26.152             27.996             24.226        78.374

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 2 or driver_number == 23')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 9          1243         9576             1              2          1        8
# 13         1243         9576             1             23          1       10
# 33         1243         9576             2              2          9       14
# 35         1243         9576             2             23         10       12
# 50         1243         9576             3             23         13       15
# 54         1243         9576             3              2         15       18
# 57         1243         9576             4             23         16       17
# 69         1243         9576             5             23         18       34
# 70         1243         9576             4              2         19       33
#
#    compound  tyre_age_at_start
# 9    MEDIUM                  0
# 13     HARD                  0
# 33     SOFT                  0
# 35     SOFT                  0
# 50     SOFT                  3
# 54     SOFT                  6
# 57     SOFT                  6
# 69     HARD                  8
# 70   MEDIUM                  0

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
#
# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)
# Out:
#               driver compound  lap_duration    sector1    sector2    sector3
# 15    George RUSSELL     SOFT     76.012273  25.821091  27.365182  22.826000
# 0     Max VERSTAPPEN   MEDIUM     75.983833  25.784889  27.338889  22.860056
# 1     Logan SARGEANT   MEDIUM     76.768615  26.191769  27.488923  23.087923
# 10      Yuki TSUNODA     HARD     76.621154  26.108462  27.397538  23.115154
# 9    Kevin MAGNUSSEN     SOFT     77.119333  26.188733  27.774533  23.156067
# 11   Alexander ALBON     HARD     76.537733  25.941600  27.429733  23.166400
# 16   Valtteri BOTTAS     SOFT     77.241333  26.356750  27.707417  23.177167
# 13      Esteban OCON     SOFT     77.186187  26.332000  27.669812  23.184375
# 3       Lando NORRIS   MEDIUM     75.884632  25.431579  27.242632  23.210421
# 4       Pierre GASLY     HARD     76.897267  26.122200  27.530733  23.244333
# 8       Lance STROLL     SOFT     76.940909  26.076091  27.583636  23.281182
# 7    Charles LECLERC   MEDIUM     76.741200  25.931600  27.466067  23.343533
# 6    Fernando ALONSO     SOFT     76.752800  25.929300  27.447400  23.376100
# 14    Lewis HAMILTON   MEDIUM     76.738000  25.907833  27.327417  23.502750
# 12       ZHOU Guanyu   MEDIUM     78.430214  26.932286  27.992571  23.505357
# 2   Daniel RICCIARDO     SOFT     77.210000  26.213214  27.459929  23.536857
# 17     Oscar PIASTRI     SOFT     76.433437  25.665625  27.228437  23.539375
# 5       Sergio PEREZ   MEDIUM     76.847154  25.970538  27.294538  23.582077

# %% [markdown]
# #### Long runs mean

# %%
longruns_summary = libraryDataF1.obtainMeanLongRuns(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Mean pace per compound

# %%
libraryDataF1.showDataLongRuns(longruns_summary,"MEDIUM","mean_lap_time",['driver','mean_lap_time'])
# Out:
#           driver  mean_lap_time
# 3       L NORRIS         75.940
# 0   M VERSTAPPEN         76.523
# 14    L HAMILTON         76.706
# 7      C LECLERC         76.828
# 5        S PEREZ         76.872
# 1     L SARGEANT         76.889
# 12        G ZHOU         78.430

# %%
libraryDataF1.showDataLongRuns(longruns_summary,"SOFT","mean_lap_time",['driver','mean_lap_time'])
# Out:
#          driver  mean_lap_time
# 15    G RUSSELL         76.012
# 17    O PIASTRI         76.636
# 6      F ALONSO         76.894
# 8      L STROLL         77.071
# 2   D RICCIARDO         77.210
# 9   K MAGNUSSEN         77.300
# 13       E OCON         77.357
# 16     V BOTTAS         77.503

# %%
libraryDataF1.showDataLongRuns(longruns_summary,"HARD","mean_lap_time",['driver','mean_lap_time'])
# Out:
#        driver  mean_lap_time
# 11    A ALBON         76.384
# 10  Y TSUNODA         76.621
# 4     P GASLY         76.897

# %% [markdown]
# ## Free Practice 3
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9569)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9569)
drivers = libraryDataF1.obtain_information('drivers',session_key=9569)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Intermediate tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"INTERMEDIATE",140)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration <134").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Long laps

# %%
MINIMUN_SECONDS = 120
MAXIMUM_SECONDS = 134

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)

# %% [markdown]
# ## Predictions

# %%
# Free Practice 1
practice = libraryDataF1.obtain_information('laps',session_key=9567)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9567)
drivers = libraryDataF1.obtain_information('drivers',session_key=9567)

stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice1 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# Free Practice 2
practice = libraryDataF1.obtain_information('laps',session_key=9576)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9576)
drivers = libraryDataF1.obtain_information('drivers',session_key=9576)

stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# ### Qualyfing prediction

# %%
qualy_simulation = libraryDataF1.qualyfing_prediction([jointablesfreepractice2,jointablesfreepractice2],drivers,0.06,0.03,0.05)
qualy_simulation.sort_values(by='qualy_lap_time')
# Out:
#               team  qualy_lap_time  mean_sector_1  mean_sector_2  \
# 5     Aston Martin       71.759289      24.542200      25.499375
# 9         Mercedes       71.839250      24.532250      25.603000
# 3          McLaren       71.846114      24.390500      25.682900
# 7     Haas F1 Team       71.864867      24.521333      25.642333
# 1         Williams       71.901571      24.568750      25.625250
# 6          Ferrari       72.074283      24.619333      25.664200
# 2               RB       72.240000      24.771750      25.596250
# 4           Alpine       72.405786      24.753750      25.749750
# 0  Red Bull Racing       72.503040      24.605500      25.897111
# 8      Kick Sauber       72.567143      24.855000      25.783000
#
#    mean_sector_3
# 5      21.717714
# 9      21.704000
# 3      21.772714
# 7      21.701200
# 1      21.707571
# 6      21.790750
# 2      21.872000
# 4      21.902286
# 0      22.000429
# 8      21.929143

# %% [markdown]
# ### Race prediction

# %%
race_simulation = libraryDataF1.race_prediction(jointablesfreepractice2,drivers,74.5,79.8)
race_simulation.groupby('team').mean().sort_values(by='mean_lap_duration')
# Out:
#                  mean_lap_duration  mean_sector_1  mean_sector_2  \
# team
# McLaren                  76.159035      25.548602      27.235535
# Mercedes                 76.375136      25.864462      27.346299
# Red Bull Racing          76.415494      25.877714      27.316714
# Williams                 76.653174      26.066685      27.459328
# Ferrari                  76.741200      25.931600      27.466067
# Aston Martin             76.846855      26.002695      27.515518
# RB                       76.915577      26.160838      27.428734
# Alpine                   77.041727      26.227100      27.600273
# Haas F1 Team             77.119333      26.188733      27.774533
# Kick Sauber              77.835774      26.644518      27.849994
#
#                  mean_sector_3
# team
# McLaren              23.374898
# Mercedes             23.164375
# Red Bull Racing      23.221066
# Williams             23.127162
# Ferrari              23.343533
# Aston Martin         23.328641
# RB                   23.326005
# Alpine               23.214354
# Haas F1 Team         23.156067
# Kick Sauber          23.341262

# %% [markdown]
# ## Qualyfing
# ### Set up
# First of all, it is neccesary to obtain the data about the qualyfing
# #### Race control
# This section has been added in order to know which laps has been deleted and knowing what happened on track during this session. As every laptime that has been deleted were slow laps, none of them were removed.

# %%
libraryDataF1.obtain_information('race_control',session_key=9570)

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9570)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9570)
drivers = libraryDataF1.obtain_information('drivers',session_key=9570)

# %% [markdown]
# To obtain a better analysis, those laptimes deleted will be removed from this analysis in order to obtain the data with valid values. So that,taking into account the race control table, it will be neccesary to consult the qualyfing data to obtain the ids.

# %%
# laptimes_deleted = [115.370,96.993,109.924,104.377,102.586,128.082,95.902,102.051]
# driver_number_lap_deleted = [4,63,1,24,22,14,55,23]

# for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
#     try:
#         id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
#         qualyfing = qualyfing.drop(id_deleted)
#     except:
#         print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]

# %% [markdown]
# Due to changing climate conditions, I will not apply the 107% rule to filter those laps that are within. So, I will choose the fastest laps of the last classified. Zhou was the slowest and the slowest of his fast attemps will be the threshold to filter those valid laps. The new threshold will be 1.57.775(117.775)

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration <= 117.775")
competitiveLaps

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session
# In this chart we can see the deltas with compared with the fastest lap of the session that it could be different than the pole.

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %% [markdown]
# ### Speed trap

# %% [markdown]
# #### Maximum speed per drivers

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %% [markdown]
# ### Maximum speed per teams

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","st_speed",top_speed)

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])
mergequaly

# %% [markdown]
# In order to know when each session finished, race control dataset will be consulted.

# %%
maximumDateQ1 = "date_start <'2024-07-27T14:25:00+00:00'"
maximumDateQ2 = "date_start <'2024-07-27T14:48:00+00:00' and date_start >'2024-07-27T14:25:00+00:00'"
maximumDateQ3 = "date_start >'2024-07-27T14:48:00+00:00'"

# %% [markdown]
# ### Qualyfing 1
# In this session both Hasses were out with Tsunoda,Sargeant and Zhou.

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver,I will do a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap. Track was soaked even though it was not raining.The new track alphast did not help to dry the track. With these conditions, drivers improved their fastest laps in each attemp. Hence the difference in each sector are big. As we can see in the table referred to the comparaison with the driver eliminated, everybody except Tsunoda was faster than Stroll. In the second sector, Stroll was able to secure his pass to Q2 being 8 tenths faster than Hulkenberg.

# %%
#Reference
P15 = q1Data[14:15]
P15

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)

# %%
q1Data[15::]

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk
# I bring this section in order to know where the driver at risk lost his chances to improve in the qualyfing.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[0:14].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 2
# In this session, we did not have any surprise with Checo passing to Q3.

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.
# As we were able to see in Q1, the second sector was crucial to pass to Q3. In the Checo's case he lost 2 tenths with Albon in the sector 1 and 3 tenths in the third sector but his second sector was enough to pass to Q3 but the gap was very close.3 militenths.

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[0:9].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.
# The sector that was crucial was the second, so that those teams that bet for a specification oriented towards downforce was very important.
# Note: All this analysis can be checked in F1 tempo

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %% [markdown]
# #### Best sector per driver of the session (in general)

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ## Race
# ### Obtain setup

# %%
race = libraryDataF1.obtain_information('laps',session_key=9574)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9574)
drivers = libraryDataF1.obtain_information('drivers',session_key=9574)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)

# %%
raceLaps = race.query("is_pit_out_lap == False")
jointables = pd.merge(raceLaps,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# #### Obtain data tyres

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'HARD',112.5)

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'MEDIUM',112.5)

# %% [markdown]
# ### Soft tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables,'SOFT',114)

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >94 and lap_duration <=112.5").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Race pace

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >94 and lap_duration <=112.5").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Mean race pace per sector
# In this section, we can see the pace shown per each team in each sector sorted ascending.

# %% [markdown]
# #### Sector 1

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >94 and lap_duration <=112.5").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 2

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >94 and lap_duration <=112.5").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 3

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False and lap_duration >94 and lap_duration <=112.5").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Comparaison beetween drivers

# %% [markdown]
# #### Red Bull Racing

# %%
race.query("driver_number== 1 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 11 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Ferrari

# %%
race.query("driver_number== 16 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 55 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### McLaren

# %%
race.query("driver_number== 4 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 81 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Mercedes

# %%
race.query("driver_number== 44 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 63 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Aston Martin

# %%
race.query("driver_number== 14 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 18 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Haas F1 Team

# %%
race.query("driver_number== 20 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 27 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### RB

# %%
race.query("driver_number== 3 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 22 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Williams

# %%
race.query("driver_number== 2 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 23 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Alpine

# %%
race.query("driver_number== 10 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 31 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# #### Kick Sauber

# %%
race.query("driver_number== 24 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %%
race.query("driver_number== 77 and lap_duration>94 and lap_duration <=112.5").lap_duration.mean()

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 94
MAXIMUM_SECONDS = 112.5

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')

# %%
libraryDataF1.getinfolongruns(jointables,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')

# %%
libraryDataF1.getinfolongruns(jointables,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 14 or driver_number == 18')

# %%
libraryDataF1.getinfolongruns(jointables,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 4 or driver_number == 81')

# %%
libraryDataF1.getinfolongruns(jointables,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas F1 Team

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 23 or driver_number == 2')

# %%
libraryDataF1.getinfolongruns(jointables,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ### Pits
# Before to finish the analysis, I added the Pits sections where it can see how much time teams spent in the box.

# %%
pit = libraryDataF1.obtain_information('pit',session_key=9574)

# %%
jointables = pd.merge(drivers,pit,on=['driver_number']).query("pit_duration<120")
jointables
pit_duration = pd.DataFrame(jointables.groupby('team_name')['pit_duration'].mean().sort_values(ascending=True))
pit_duration
