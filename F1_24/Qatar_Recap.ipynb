# %%
from F1_library import libraryF1dataNotebook as libraryDataF1
import pandas as pd
import numpy as np
import fastf1 as ff1

from fastf1 import utils
from matplotlib import pyplot as plt

# %% [markdown]
# # FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2024
# The Qatar Grand Prix (Arabic: جائزة قطر الكبرى) is a Formula One motor racing event which is held in Qatar. It was held for the first time on 21 November as part of the 2021 championship at the Lusail International Circuit, and after not taking place during the 2022 season due to the 2022 FIFA World Cup taking place in Qatar, it rejoined the calendar in 2023 under a 10-year contract. The race was established as the fourth full-night race (as opposed to day or day-to-night races) on the Formula One calendar, following the Singapore, Bahrain and Sakhir Grands Prix.
# Source: Wikipedia

# %% [markdown]
# ## Upgrades
# In this section those upgrades brought by the teams will be shown.
# <table>
# <tr>
#     <td>
#     Team
#     </td>
#     <td>
#     Updated component
#     </td>
#     <td>
#     Upgrade type
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Alpine
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Alpine
#     </td>
#     <td>
#     Nose
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
#
# </tr>
# </table>

# %% [markdown]
# ## Obtain session information

# %%
libraryDataF1.obtain_information('sessions',year=2024,country_acronym='QAT')
# Out:
#    session_key       session_name                 date_start  \
# 0         9645         Practice 1  2024-11-29T13:30:00+00:00
# 1         9650  Sprint Qualifying  2024-11-29T17:30:00+00:00
# 2         9654             Sprint  2024-11-30T14:00:00+00:00
# 3         9646         Qualifying  2024-11-30T18:00:00+00:00
#
#                     date_end gmt_offset session_type  meeting_key location  \
# 0  2024-11-29T14:30:00+00:00   03:00:00     Practice         1251   Lusail
# 1  2024-11-29T18:14:00+00:00   03:00:00   Qualifying         1251   Lusail
# 2  2024-11-30T15:00:00+00:00   03:00:00         Race         1251   Lusail
# 3  2024-11-30T19:00:00+00:00   03:00:00   Qualifying         1251   Lusail
#
#    country_key country_code country_name  circuit_key circuit_short_name  year
# 0          149          QAT        Qatar          150             Lusail  2024
# 1          149          QAT        Qatar          150             Lusail  2024
# 2          149          QAT        Qatar          150             Lusail  2024
# 3          149          QAT        Qatar          150             Lusail  2024

# %% [markdown]
# ## Free Practice 1
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9645)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9645)
drivers = libraryDataF1.obtain_information('drivers',session_key=9645)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1251         9645             31     214.0       265     119.0
# 1           1251         9645             10     210.0       265     144.0
# 2           1251         9645             77     211.0       254     159.0
# 3           1251         9645             22     213.0       244     118.0
# 4           1251         9645             55     203.0       262     138.0
# ..           ...          ...            ...       ...       ...       ...
# 535         1251         9645             27     228.0       266     248.0
# 536         1251         9645             63     224.0       271     252.0
# 537         1251         9645             30     223.0       268     258.0
# 538         1251         9645              4     158.0       239     249.0
# 539         1251         9645             23     199.0       265     259.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-11-29T13:30:15.031000+00:00           NaN            True
# 1    2024-11-29T13:30:23.210000+00:00           NaN            True
# 2    2024-11-29T13:30:27.926000+00:00           NaN            True
# 3    2024-11-29T13:30:37.320000+00:00           NaN            True
# 4    2024-11-29T13:30:53.488000+00:00           NaN            True
# ..                                ...           ...             ...
# 535  2024-11-29T14:33:33.916000+00:00       121.139           False
# 536  2024-11-29T14:33:37.941000+00:00           NaN           False
# 537  2024-11-29T14:33:39.531000+00:00       127.025           False
# 538  2024-11-29T14:33:44.563000+00:00       140.793           False
# 539  2024-11-29T14:33:51.606000+00:00       116.654           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             33.116             29.693
# 1                  NaN             34.034             28.741
# 2                  NaN             33.286             28.831
# 3                  NaN             35.814             30.408
# 4                  NaN             34.780             29.709
# ..                 ...                ...                ...
# 535             57.908             30.921             32.310
# 536             69.995             30.260                NaN
# 537             63.641             32.242             31.142
# 538             75.496             34.389             30.908
# 539             55.864             29.749             31.041
#
#                                      segments_sector_1  \
# 0    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 204...
# 1    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 204...
# 2    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 205...
# 3    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 535  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 536  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 537  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 538  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 539  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 0    [2049, 2049, 2051, 2049, 2049, 2051, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 2    [2051, 2049, 2049, 2051, 2051, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 535  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 536  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 537  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 538  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 539  [2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                               segments_sector_3  lap_number compound  \
# 0       [2049, 2049, 2049, 2049, 2051, 2051, 0]           1  UNKNOWN
# 1       [2049, 2049, 2051, 2049, 2051, 2049, 0]           1   MEDIUM
# 2    [2049, 2049, 2049, 2051, 2049, 2051, 2048]           1   MEDIUM
# 3    [2051, 2051, 2051, 2049, 2051, 2049, 2049]           1   MEDIUM
# 4       [2049, 2049, 2049, 2049, 2049, 2049, 0]           1     HARD
# ..                                          ...         ...      ...
# 535                                          []          27     SOFT
# 536                                          []          27   MEDIUM
# 537                                          []          29     SOFT
# 538                                          []          24   MEDIUM
# 539                                          []          29     HARD
#
#     name_acronym        full_name     team_name
# 0            OCO     Esteban OCON        Alpine
# 1            GAS     Pierre GASLY        Alpine
# 2            BOT  Valtteri BOTTAS   Kick Sauber
# 3            TSU     Yuki TSUNODA            RB
# 4            SAI     Carlos SAINZ       Ferrari
# ..           ...              ...           ...
# 535          HUL  Nico HULKENBERG  Haas F1 Team
# 536          RUS   George RUSSELL      Mercedes
# 537          LAW      Liam LAWSON          None
# 538          NOR     Lando NORRIS       McLaren
# 539          ALB  Alexander ALBON      Williams
#
# [540 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",88)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",88)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",88)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#            full_name compound  duration_sector_1  duration_sector_2  \
# 291     Carlos SAINZ     HARD             30.756             28.145
# 420     Lance STROLL   MEDIUM             30.884             27.847
# 482  Charles LECLERC     SOFT             30.334             27.701
# 378     Esteban OCON  UNKNOWN             31.620             28.427
#
#      duration_sector_3  lap_duration
# 291             24.167        83.068
# 420             24.368        83.099
# 482             23.918        81.953
# 378             24.861        84.908

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. Also, each sector will be commented. As we can see in the free practice, these data  are not very representative due to the changing conditions.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin().dropna()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 450             30.272      Lando NORRIS     SOFT        82.378          20
# 482             30.334   Charles LECLERC     SOFT        81.953          27
# 444             30.354     Oscar PIASTRI     SOFT        82.425          21
# 487             30.532      Carlos SAINZ     SOFT        82.535          28
# 448             30.659    Lewis HAMILTON     SOFT        83.188          22
# 483             30.717   Nico HULKENBERG     SOFT        83.245          24
# 430             30.730    George RUSSELL     SOFT        83.160          23
# 463             30.730   Alexander ALBON     SOFT        83.161          25
# 485             30.757      Yuki TSUNODA     SOFT        83.045          25
# 452             30.771   Valtteri BOTTAS     SOFT        83.433          24
# 426             30.811    Max VERSTAPPEN     SOFT        83.213          22
# 423             30.869   Fernando ALONSO     SOFT        83.227          20
# 420             30.884      Lance STROLL   MEDIUM        83.099          20
# 494             30.909   Kevin MAGNUSSEN     SOFT        83.715          25
# 453             30.935       Liam LAWSON     SOFT        83.831          24
# 434             30.956      Sergio PEREZ     SOFT        84.039          22
# 497             30.988       ZHOU Guanyu     SOFT        83.880          25
# 316             31.033      Pierre GASLY   MEDIUM        83.729          15
# 459             31.145      Esteban OCON   MEDIUM        88.139          18
# 442             31.228  Franco COLAPINTO     SOFT        84.200          25

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 490             27.650   Valtteri BOTTAS     SOFT        83.064          27
# 482             27.701   Charles LECLERC     SOFT        81.953          27
# 463             27.791   Alexander ALBON     SOFT        83.161          25
# 483             27.842   Nico HULKENBERG     SOFT        83.245          24
# 420             27.847      Lance STROLL   MEDIUM        83.099          20
# 485             27.893      Yuki TSUNODA     SOFT        83.045          25
# 487             27.915      Carlos SAINZ     SOFT        82.535          28
# 450             27.973      Lando NORRIS     SOFT        82.378          20
# 444             28.007     Oscar PIASTRI     SOFT        82.425          21
# 426             28.017    Max VERSTAPPEN     SOFT        83.213          22
# 494             28.022   Kevin MAGNUSSEN     SOFT        83.715          25
# 468             28.027       ZHOU Guanyu     SOFT        83.988          23
# 448             28.029    Lewis HAMILTON     SOFT        83.188          22
# 423             28.049   Fernando ALONSO     SOFT        83.227          20
# 316             28.114      Pierre GASLY   MEDIUM        83.729          15
# 480             28.121       Liam LAWSON     SOFT        83.562          26
# 430             28.176    George RUSSELL     SOFT        83.160          23
# 459             28.283      Esteban OCON   MEDIUM        88.139          18
# 434             28.310      Sergio PEREZ     SOFT        84.039          22
# 442             28.322  Franco COLAPINTO     SOFT        84.200          25

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 482             23.918   Charles LECLERC     SOFT        81.953          27
# 444             24.064     Oscar PIASTRI     SOFT        82.425          21
# 487             24.088      Carlos SAINZ     SOFT        82.535          28
# 450             24.133      Lando NORRIS     SOFT        82.378          20
# 430             24.254    George RUSSELL     SOFT        83.160          23
# 423             24.309   Fernando ALONSO     SOFT        83.227          20
# 469             24.344      Pierre GASLY   MEDIUM        83.620          25
# 420             24.368      Lance STROLL   MEDIUM        83.099          20
# 121             24.384    Max VERSTAPPEN   MEDIUM        83.885           7
# 480             24.394       Liam LAWSON     SOFT        83.562          26
# 485             24.395      Yuki TSUNODA     SOFT        83.045          25
# 448             24.500    Lewis HAMILTON     SOFT        83.188          22
# 400             24.534      Esteban OCON   MEDIUM        84.280          15
# 401             24.551   Alexander ALBON     SOFT        83.465          22
# 418             24.569   Nico HULKENBERG     SOFT        83.427          21
# 130             24.579      Sergio PEREZ   MEDIUM        84.995           7
# 490             24.629   Valtteri BOTTAS     SOFT        83.064          27
# 465             24.636   Kevin MAGNUSSEN     SOFT        83.729          23
# 442             24.650  Franco COLAPINTO     SOFT        84.200          25
# 497             24.762       ZHOU Guanyu     SOFT        83.880          25

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False and lap_duration > 85 and lap_duration <=88").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# SOFT         85.564500
# UNKNOWN      86.046333
# HARD         86.371069
# MEDIUM       86.441093

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 85
MAXIMUM_SECONDS = 88

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 1          1251         9645             1              1          1        6
# 2          1251         9645             1             11          1        6
# 21         1251         9645             2              1          7        9
# 22         1251         9645             2             11          7       11
# 30         1251         9645             3              1         10       21
# 38         1251         9645             3             11         12       21
# 58         1251         9645             4              1         22       24
# 59         1251         9645             4             11         22       24
# 76         1251         9645             5              1         25       27
# 77         1251         9645             5             11         25       27
#
#    compound  tyre_age_at_start
# 1    MEDIUM                  0
# 2    MEDIUM                  0
# 21   MEDIUM                  0
# 22   MEDIUM                  0
# 30   MEDIUM                  0
# 38   MEDIUM                  0
# 58     SOFT                  0
# 59     SOFT                  0
# 76   MEDIUM                  0
# 77   MEDIUM                  0

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
#

# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 0          1251         9645             1             10          1        4
# 16         1251         9645             1             31          1       11
# 20         1251         9645             2             10          5       12
# 31         1251         9645             2             31         11       18
# 44         1251         9645             3             10         13       24
# 48         1251         9645             3             31         18       19
# 53         1251         9645             4             31         20       22
# 83         1251         9645             4             10         25       29
#
#    compound  tyre_age_at_start
# 0    MEDIUM                  0
# 16  UNKNOWN                  0
# 20   MEDIUM                  0
# 31   MEDIUM                  0
# 44   MEDIUM                  0
# 48     SOFT                  0
# 53   MEDIUM                  0
# 83   MEDIUM                  0

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 46   Esteban OCON  UNKNOWN  2024-11-29T13:35:18.125000+00:00           4
# 88   Esteban OCON  UNKNOWN  2024-11-29T13:39:00.018000+00:00           6
# 126  Esteban OCON  UNKNOWN  2024-11-29T13:42:46.260000+00:00           8
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 46              32.333             29.111             25.589        87.033
# 88              31.900             28.786             25.132        85.818
# 126             31.635             28.683             24.970        85.288

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 78   Pierre GASLY   MEDIUM  2024-11-29T13:38:02.581000+00:00           5
# 333  Pierre GASLY   MEDIUM  2024-11-29T14:08:45.487000+00:00          16
# 350  Pierre GASLY   MEDIUM  2024-11-29T14:10:12.535000+00:00          17
# 365  Pierre GASLY   MEDIUM  2024-11-29T14:11:39.197000+00:00          18
# 375  Pierre GASLY   MEDIUM  2024-11-29T14:13:05.141000+00:00          19
# 384  Pierre GASLY   MEDIUM  2024-11-29T14:14:30.965000+00:00          20
# 388  Pierre GASLY   MEDIUM  2024-11-29T14:15:56.597000+00:00          21
# 392  Pierre GASLY   MEDIUM  2024-11-29T14:17:22.156000+00:00          22
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 78              31.965             28.754             24.933        85.652
# 333             32.134             29.279             25.647        87.060
# 350             32.434             28.991             25.225        86.650
# 365             32.083             28.616             25.230        85.929
# 375             32.005             28.754             25.094        85.853
# 384             31.962             28.680             24.919        85.561
# 388             31.980             28.712             24.809        85.501
# 392             32.127             29.399             24.965        86.491

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 43 or driver_number == 23')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 15         1251         9645             1             23          1       11
# 17         1251         9645             1             43          1       11
# 37         1251         9645             2             23         12       20
# 39         1251         9645             2             43         12       21
# 54         1251         9645             3             23         21       21
# 61         1251         9645             4             23         22       24
# 62         1251         9645             3             43         22       24
# 78         1251         9645             5             23         25       27
# 79         1251         9645             4             43         25       27
# 86         1251         9645             6             23         28       30
# 87         1251         9645             5             43         28       30
#
#    compound  tyre_age_at_start
# 15     HARD                  0
# 17     HARD                  0
# 37     HARD                  0
# 39     HARD                  0
# 54     HARD                  0
# 61     SOFT                  0
# 62     SOFT                  0
# 78     SOFT                  0
# 79     SOFT                  0
# 86     HARD                  0
# 87     HARD                  0

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
#
# 17           None       None
# 18           None       None
# 19           None       None
# 20  DOUBLE YELLOW       None
# 21  DOUBLE YELLOW       None
# 22  DOUBLE YELLOW       None
# 23  DOUBLE YELLOW       None
# 24  DOUBLE YELLOW       None
#
#                                               message driver_number   scope  \
# 0                         GREEN LIGHT - PIT EXIT OPEN          None   Track
# 1   CAR 30 (LAW) TIME 1:24.293 DELETED - TRACK LIM...          None    None
# 2                                      CHEQUERED FLAG          None   Track
# 3            FIRST CAR TO TAKE THE FLAG - CAR 4 (NOR)          None    None
# 4   FIA STEWARDS: SQ1 INCIDENT INVOLVING CARS 20 (...          None    None
# 5   FIA STEWARDS: SQ1 INCIDENT INVOLVING CARS 20 (...          None    None
# 6                         GREEN LIGHT - PIT EXIT OPEN          None   Track
# 7   CAR 20 (MAG) TIME 1:22.901 DELETED - TRACK LIM...          None    None
# 8   CAR 81 (PIA) TIME 1:22.050 DELETED - TRACK LIM...          None    None
# 9                                      CHEQUERED FLAG          None   Track
# 10          FIRST CAR TO TAKE THE FLAG - CAR 23 (ALB)          None    None
# 11  FIA STEWARDS: SQ2 INCIDENT INVOLVING CARS 30 (...          None    None
# 12  FIA STEWARDS: SQ2 INCIDENT INVOLVING CARS 30 (...          None    None
# 13                        GREEN LIGHT - PIT EXIT OPEN          None   Track
# 14                                     CHEQUERED FLAG          None   Track
# 15  CAR 81 (PIA) TIME 1:21.238 DELETED - TRACK LIM...          None    None
# 16           FIRST CAR TO TAKE THE FLAG - CAR 1 (VER)          None    None
# 17  CAR 30 (LAW) TIME 1:22.082 DELETED - TRACK LIM...          None    None
# 18  FIA STEWARDS: SQ3 INCIDENT INVOLVING CAR 44 (H...          None    None
# 19  FIA STEWARDS: SQ3 INCIDENT INVOLVING CAR 44 (H...          None    None
# 20                    DOUBLE YELLOW IN TRACK SECTOR 7          None  Sector
# 21                   DOUBLE YELLOW IN TRACK SECTOR 15          None  Sector
# 22                    DOUBLE YELLOW IN TRACK SECTOR 5          None  Sector
# 23                    DOUBLE YELLOW IN TRACK SECTOR 4          None  Sector
# 24                   DOUBLE YELLOW IN TRACK SECTOR 14          None  Sector
#
#     sector
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     7.0
# 21    15.0
# 22     5.0
# 23     4.0
# 24    14.0

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9650)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9650)
drivers = libraryDataF1.obtain_information('drivers',session_key=9650)

# %% [markdown]
# In race control dataset, I can see a lot of laptimes deleted, principally for track limits. Those laps deleted ,within the 107%, were deleted from dataset in order to obtain only the valid laps for the analysis.

# %%
laptimes_deleted = [84.293,82.901,82.050,81.238,82.082]
driver_number_lap_deleted = [30,20,81,81,30]

for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
    try:
        id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
        qualyfing = qualyfing.drop(id_deleted)
    except:
        print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 246         1251         9650              4       251       287       316
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 246  2024-11-29T18:09:14.746000+00:00        81.012           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 246             29.923             27.335             23.754
#
#                                      segments_sector_1  \
# 246  [2049, 2049, 2049, 2051, 2051, 2049, 2049, 204...
#
#                               segments_sector_2  \
# 246  [2051, 2051, 2051, 2049, 2049, 2049, 2049]
#
#                               segments_sector_3  lap_number
# 246  [2048, 2048, 2048, 2048, 2048, 2048, 2048]          14

# %% [markdown]
# The fastest lap is 81.012 seconds (1.21.012= so that to obtain the competitve laps the fastest lap will be multiplied by 1.07 (86.68 seconds) due to, according to the rules all the drivers have to do unless one lap within this gap.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration < 86.68")
competitiveLaps
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 9           1251         9650             20       245       287       316
# 13          1251         9650             18       246       288       317
# 14          1251         9650             24       242       287       316
# 15          1251         9650             77       249       286       317
# 17          1251         9650             55       247       288       318
# ..           ...          ...            ...       ...       ...       ...
# 268         1251         9650             63       252       291       319
# 269         1251         9650             44       250       290       320
# 271         1251         9650             55       249       288       319
# 273         1251         9650             16       254       288       319
# 274         1251         9650             10       248       287       323
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 9    2024-11-29T17:31:36.923000+00:00        83.750           False
# 13   2024-11-29T17:32:01.494000+00:00        83.984           False
# 14   2024-11-29T17:32:06.770000+00:00        84.661           False
# 15   2024-11-29T17:32:11.337000+00:00        83.407           False
# 17   2024-11-29T17:32:17.133000+00:00        83.543           False
# ..                                ...           ...             ...
# 268  2024-11-29T18:13:09.223000+00:00        81.075           False
# 269  2024-11-29T18:13:15.960000+00:00        81.559           False
# 271  2024-11-29T18:13:26.820000+00:00        81.281           False
# 273  2024-11-29T18:13:32.342000+00:00        81.308           False
# 274  2024-11-29T18:13:37.248000+00:00        81.978           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 9               31.064             28.211             24.475
# 13              31.239             28.269             24.476
# 14              31.461             28.272             24.928
# 15              30.792             27.915             24.700
# 17              30.997             28.140             24.406
# ..                 ...                ...                ...
# 268             29.899             27.439             23.737
# 269             29.995             27.623             23.941
# 271             30.052             27.464             23.765
# 273             29.951             27.531             23.826
# 274             30.293             27.561             24.124
#
#                                      segments_sector_1  \
# 9    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 13   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 14   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 15   [2049, 2049, 2049, 2051, 2051, 2049, 2049, 204...
# 17   [2049, 2049, 2049, 2049, 2049, 2051, 2049, 204...
# ..                                                 ...
# 268  [None, 2048, 2048, 2049, 2049, 2048, 2049, 204...
# 269  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 271  [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 273  [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 274  [2049, 2049, 2051, 2048, 2049, 2049, 2049, 204...
#
#                               segments_sector_2  \
# 9    [2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 13   [2049, 2049, 2049, 2049, 2051, 2049, 2049]
# 14   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 15   [2051, 2051, 2051, 2051, 2049, 2049, 2049]
# 17   [2049, 2049, 2049, 2049, 2049, 2051, 2051]
# ..                                          ...
# 268  [2048, 2049, 2049, 2048, 2049, 2049, 2048]
# 269  [2049, 2048, 2048, 2049, 2048, 2049, 2049]
# 271  [2049, 2049, 2049, 2049, 2051, 2049, 2049]
# 273  [2049, 2048, 2049, 2049, 2048, 2048, 2049]
# 274  [2049, 2049, 2049, 2048, 2049, 2049, 2049]
#
#                               segments_sector_3  lap_number
# 9       [2048, 2048, 2048, 2048, 2048, 2048, 0]           2
# 13   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           2
# 14   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           2
# 15   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           2
# 17   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           2
# ..                                          ...         ...
# 268  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          15
# 269  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          18
# 271  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          18
# 273  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          17
# 274  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          18
#
# [98 rows x 16 columns]

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)
# Out:
#     driver_number  fastest_lap  delta  st_speed  i1_speed  i2_speed  \
# 13              4       81.012  0.000       316       247       287
# 15             63       81.075  0.063       319       246       290
# 14             81       81.171  0.159       318       246       286
# 4              55       81.281  0.269       317       247       287
# 5              16       81.308  0.296       314       248       287
# 8               1       81.315  0.303       320       245       289
# 17             44       81.474  0.462       319       248       290
# 10             10       81.978  0.966       319       244       286
# 9              27       82.088  1.076       318       246       288
# 19             30       82.393  1.381       314       246       286
# 18             14       82.433  1.421       320       243       288
# 3              77       82.506  1.494       317       247       286
# 1              18       82.522  1.510       317       246       288
# 7              23       82.526  1.514       315       243       287
# 0              20       82.560  1.548       316       245       287
# 12             11       82.718  1.706       322       246       288
# 16             22       82.722  1.710       319       249       287
# 11             31       82.906  1.894       320       240       286
# 2              24       82.948  1.936       316       242       286
# 6              43       83.423  2.411       313       238       287
#
#     session_key  meeting_key broadcast_name country_code first_name  \
# 13         9650         1251       L NORRIS          GBR      Lando
# 15         9650         1251      G RUSSELL          GBR     George
# 14         9650         1251      O PIASTRI          AUS      Oscar
# 4          9650         1251        C SAINZ          ESP     Carlos
# 5          9650         1251      C LECLERC          MON    Charles
# 8          9650         1251   M VERSTAPPEN          NED        Max
# 17         9650         1251     L HAMILTON          GBR      Lewis
# 10         9650         1251        P GASLY          FRA     Pierre
# 9          9650         1251   N HULKENBERG          GER       Nico
# 19         9650         1251       L LAWSON         None       None
# 18         9650         1251       F ALONSO          ESP   Fernando
# 3          9650         1251       V BOTTAS          FIN   Valtteri
# 1          9650         1251       L STROLL          CAN      Lance
# 7          9650         1251        A ALBON          THA  Alexander
# 0          9650         1251    K MAGNUSSEN          DEN      Kevin
# 12         9650         1251        S PEREZ          MEX     Sergio
# 16         9650         1251      Y TSUNODA          JPN       Yuki
# 11         9650         1251         E OCON          FRA    Esteban
# 2          9650         1251         G ZHOU          CHN     Guanyu
# 6          9650         1251    F COLAPINTO         None       None
#
#            full_name                                       headshot_url  \
# 13      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 15    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 14     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 4       Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 5    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 8     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 17    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 10      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 9    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 19       Liam LAWSON                                               None
# 18   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 3    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 1       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 7    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 0    Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 12      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 16      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 11      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 2        ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 6   Franco COLAPINTO                                               None
#
#      last_name team_colour        team_name name_acronym
# 13      Norris      FF8000          McLaren          NOR
# 15     Russell      27F4D2         Mercedes          RUS
# 14     Piastri      FF8000          McLaren          PIA
# 4        Sainz      E80020          Ferrari          SAI
# 5      Leclerc      E80020          Ferrari          LEC
# 8   Verstappen      3671C6  Red Bull Racing          VER
# 17    Hamilton      27F4D2         Mercedes          HAM
# 10       Gasly      0093cc           Alpine          GAS
# 9   Hulkenberg      B6BABD     Haas F1 Team          HUL
# 19        None        None             None          LAW
# 18      Alonso      229971     Aston Martin          ALO
# 3       Bottas      52E252      Kick Sauber          BOT
# 1       Stroll      229971     Aston Martin          STR
# 7        Albon      64C4FF         Williams          ALB
# 0    Magnussen      B6BABD     Haas F1 Team          MAG
# 12       Perez      3671C6  Red Bull Racing          PER
# 16     Tsunoda      6692FF               RB          TSU
# 11        Ocon      0093cc           Alpine          OCO
# 2         Zhou      52E252      Kick Sauber          ZHO
# 6         None        None             None          COL

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])

# %%
# In order to know when each session finished, race control dataset will be consulted.
maximumDateQ1 = "date_start <'2024-11-29T17:49:00+00:00'"
maximumDateQ2 = "date_start <'2024-11-29T18:06:00+00:00' and date_start >='2024-11-29T17:49:00+00:00'"
maximumDateQ3 = "date_start >'2024-11-29T18:06:00+00:00'"

# %% [markdown]
# ### Sprint Qualyfing 1

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 65           1251           9650              4       250       288       319
# 19           1251           9650             55       251       287       321
# 74           1251           9650             63       249       290       322
# 39           1251           9650              1       250       290       325
# 83           1251           9650             44       250       290       324
# 24           1251           9650             16       252       288       321
# 70           1251           9650             81       251       287       319
# 89           1251           9650             14       248       289       324
# 14           1251           9650             77       249       286       320
# 6            1251           9650             18       248       288       321
# 2            1251           9650             20       248       288       323
# 46           1251           9650             27       249       288       324
# 51           1251           9650             10       245       287       322
# 93           1251           9650             30       249       287       322
# 34           1251           9650             23       244       287       320
# 62           1251           9650             11       246       288       322
# 80           1251           9650             22       249       287       323
# 59           1251           9650             31       246       286       320
# 11           1251           9650             24       246       286       323
# 31           1251           9650             43       243       287       318
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 65  2024-11-29T17:40:41.422000+00:00        81.356           False
# 19  2024-11-29T17:41:03.292000+00:00        81.838           False
# 74  2024-11-29T17:38:16.060000+00:00        82.021           False
# 39  2024-11-29T17:41:47.693000+00:00        82.033           False
# 83  2024-11-29T17:41:39.264000+00:00        82.151           False
# 24  2024-11-29T17:35:52.508000+00:00        82.156           False
# 70  2024-11-29T17:37:54.456000+00:00        82.218           False
# 89  2024-11-29T17:40:57.731000+00:00        82.499           False
# 14  2024-11-29T17:41:18.622000+00:00        82.506           False
# 6   2024-11-29T17:40:34.164000+00:00        82.522           False
# 2   2024-11-29T17:40:46.852000+00:00        82.560           False
# 46  2024-11-29T17:40:51.928000+00:00        82.569           False
# 51  2024-11-29T17:36:52.814000+00:00        82.586           False
# 93  2024-11-29T17:41:13.167000+00:00        82.705           False
# 34  2024-11-29T17:41:35.156000+00:00        82.705           False
# 62  2024-11-29T17:41:07.973000+00:00        82.718           False
# 80  2024-11-29T17:41:51.802000+00:00        82.722           False
# 59  2024-11-29T17:40:22.873000+00:00        82.906           False
# 11  2024-11-29T17:41:42.215000+00:00        82.948           False
# 31  2024-11-29T17:41:31.648000+00:00        83.423           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 65             29.989  ...        L NORRIS           GBR      Lando
# 19             30.255  ...         C SAINZ           ESP     Carlos
# 74             30.397  ...       G RUSSELL           GBR     George
# 39             30.348  ...    M VERSTAPPEN           NED        Max
# 83             30.217  ...      L HAMILTON           GBR      Lewis
# 24             30.330  ...       C LECLERC           MON    Charles
# 70             30.383  ...       O PIASTRI           AUS      Oscar
# 89             30.555  ...        F ALONSO           ESP   Fernando
# 14             30.294  ...        V BOTTAS           FIN   Valtteri
# 6              30.515  ...        L STROLL           CAN      Lance
# 2              30.525  ...     K MAGNUSSEN           DEN      Kevin
# 46             30.480  ...    N HULKENBERG           GER       Nico
# 51             30.615  ...         P GASLY           FRA     Pierre
# 93             30.660  ...        L LAWSON          None       None
# 34             30.687  ...         A ALBON           THA  Alexander
# 62             30.865  ...         S PEREZ           MEX     Sergio
# 80             30.620  ...       Y TSUNODA           JPN       Yuki
# 59             30.688  ...          E OCON           FRA    Esteban
# 11             30.594  ...          G ZHOU           CHN     Guanyu
# 31             30.996  ...     F COLAPINTO          None       None
#
#            full_name                                       headshot_url  \
# 65      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 19      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 74    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 39    Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 83    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 24   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 70     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 89   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 14   Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 6       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 2    Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 46   Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 51      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 93       Liam LAWSON                                               None
# 34   Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 62      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 80      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 59      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
# 11       ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 31  Franco COLAPINTO                                               None
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 65      Norris       FF8000          McLaren          NOR         True
# 19       Sainz       E80020          Ferrari          SAI         True
# 74     Russell       27F4D2         Mercedes          RUS         True
# 39  Verstappen       3671C6  Red Bull Racing          VER         True
# 83    Hamilton       27F4D2         Mercedes          HAM         True
# 24     Leclerc       E80020          Ferrari          LEC         True
# 70     Piastri       FF8000          McLaren          PIA         True
# 89      Alonso       229971     Aston Martin          ALO         True
# 14      Bottas       52E252      Kick Sauber          BOT         True
# 6       Stroll       229971     Aston Martin          STR         True
# 2    Magnussen       B6BABD     Haas F1 Team          MAG         True
# 46  Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 51       Gasly       0093cc           Alpine          GAS         True
# 93        None         None             None          LAW         True
# 34       Albon       64C4FF         Williams          ALB         True
# 62       Perez       3671C6  Red Bull Racing          PER         True
# 80     Tsunoda       6692FF               RB          TSU         True
# 59        Ocon       0093cc           Alpine          OCO         True
# 11        Zhou       52E252      Kick Sauber          ZHO         True
# 31        None         None             None          COL         True
#
# [20 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P15 = q1Data[14:15]
P15
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 34           1251           9650             23       244       287       320
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 34  2024-11-29T17:41:35.156000+00:00        82.705           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 34             30.687  ...         A ALBON           THA  Alexander
#
#           full_name                                       headshot_url  \
# 34  Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
#
#     last_name  team_colour  team_name name_acronym isFastestLap
# 34      Albon       64C4FF   Williams          ALB         True
#
# [1 rows x 28 columns]

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Alexander ALBON Sector 1:  30.687 Sector 2:  27.668 Sector 3:  24.35

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 =  libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             11         0.013                0.178                0.147
# 1             22         0.017               -0.067                0.198
# 2             31         0.201                0.001                0.164
# 3             24         0.243               -0.093                0.188
# 4             43         0.718                0.309                0.292
#
#    difference_sector_3 name_acronym
# 0               -0.312          PER
# 1               -0.114          TSU
# 2                0.036          OCO
# 3                0.148          ZHO
# 4                0.117          COL

# %% [markdown]
# ### Best sector per driver

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# NOR                      29.989
# HAM                      30.217
# SAI                      30.255
# BOT                      30.294
# LEC                      30.330
# VER                      30.348
# PIA                      30.383
# RUS                      30.397
# HUL                      30.480
# STR                      30.515
# MAG                      30.525
# ALO                      30.555
# ZHO                      30.594
# GAS                      30.615
# TSU                      30.620
# LAW                      30.660
# ALB                      30.687
# OCO                      30.688
# PER                      30.865
# COL                      30.996

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# NOR                      27.474
# RUS                      27.662
# ALB                      27.668
# BOT                      27.676
# MAG                      27.678
# GAS                      27.728
# SAI                      27.735
# HAM                      27.737
# VER                      27.757
# LEC                      27.787
# PER                      27.815
# HUL                      27.820
# ALO                      27.827
# OCO                      27.832
# PIA                      27.835
# ZHO                      27.856
# TSU                      27.866
# STR                      27.916
# LAW                      27.918
# COL                      27.960

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# SAI                      23.848
# NOR                      23.893
# VER                      23.928
# RUS                      23.962
# PIA                      24.000
# PER                      24.038
# LEC                      24.039
# STR                      24.091
# ALO                      24.117
# LAW                      24.127
# HAM                      24.197
# TSU                      24.236
# GAS                      24.243
# HUL                      24.269
# ALB                      24.350
# MAG                      24.357
# OCO                      24.386
# COL                      24.467
# ZHO                      24.498
# BOT                      24.536

# %% [markdown]
# ### Sprint Qualyfing 2

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 67           1251           9650              4       249       288       319
# 75           1251           9650             63       252       291       321
# 71           1251           9650             81       248       288       323
# 85           1251           9650             44       251       291       323
# 42           1251           9650              1       251       291       321
# 21           1251           9650             55       252       288       318
# 26           1251           9650             16       253       289       318
# 48           1251           9650             27       249       289       325
# 54           1251           9650             10       246       287       322
# 96           1251           9650             30       250       287       317
# 91           1251           9650             14       243       290       321
# 36           1251           9650             23       246       287       316
# 16           1251           9650             77       247       287       321
# 8            1251           9650             18       246       289       321
# 3            1251           9650             20       246       289       326
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 67  2024-11-29T17:55:19.136000+00:00        81.231           False
# 75  2024-11-29T17:54:43.140000+00:00        81.488           False
# 71  2024-11-29T17:56:15.819000+00:00        81.548           False
# 85  2024-11-29T17:58:10.770000+00:00        81.734           False
# 42  2024-11-29T17:57:18.761000+00:00        81.784           False
# 21  2024-11-29T17:54:21.913000+00:00        81.809           False
# 26  2024-11-29T17:54:28.858000+00:00        81.818           False
# 48  2024-11-29T17:58:02.401000+00:00        82.318           False
# 54  2024-11-29T17:58:17.211000+00:00        82.352           False
# 96  2024-11-29T17:57:56.499000+00:00        82.393           False
# 91  2024-11-29T17:56:58.185000+00:00        82.433           False
# 36  2024-11-29T17:57:47.464000+00:00        82.526           False
# 16  2024-11-29T17:57:58.811000+00:00        82.538           False
# 8   2024-11-29T17:56:36.538000+00:00        82.599           False
# 3   2024-11-29T17:58:05.701000+00:00        82.738           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 67             30.058  ...        L NORRIS           GBR      Lando
# 75             30.130  ...       G RUSSELL           GBR     George
# 71             30.021  ...       O PIASTRI           AUS      Oscar
# 85             30.071  ...      L HAMILTON           GBR      Lewis
# 42             30.356  ...    M VERSTAPPEN           NED        Max
# 21             30.220  ...         C SAINZ           ESP     Carlos
# 26             30.212  ...       C LECLERC           MON    Charles
# 48             30.487  ...    N HULKENBERG           GER       Nico
# 54             30.333  ...         P GASLY           FRA     Pierre
# 96             30.410  ...        L LAWSON          None       None
# 91             30.597  ...        F ALONSO           ESP   Fernando
# 36             30.584  ...         A ALBON           THA  Alexander
# 16             30.373  ...        V BOTTAS           FIN   Valtteri
# 8              30.550  ...        L STROLL           CAN      Lance
# 3              30.653  ...     K MAGNUSSEN           DEN      Kevin
#
#           full_name                                       headshot_url  \
# 67     Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 75   George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 71    Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 85   Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 42   Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 21     Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 26  Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 48  Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 54     Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 96      Liam LAWSON                                               None
# 91  Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 36  Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 16  Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 8      Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 3   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 67      Norris       FF8000          McLaren          NOR         True
# 75     Russell       27F4D2         Mercedes          RUS         True
# 71     Piastri       FF8000          McLaren          PIA         True
# 85    Hamilton       27F4D2         Mercedes          HAM         True
# 42  Verstappen       3671C6  Red Bull Racing          VER         True
# 21       Sainz       E80020          Ferrari          SAI         True
# 26     Leclerc       E80020          Ferrari          LEC         True
# 48  Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 54       Gasly       0093cc           Alpine          GAS         True
# 96        None         None             None          LAW         True
# 91      Alonso       229971     Aston Martin          ALO         True
# 36       Albon       64C4FF         Williams          ALB         True
# 16      Bottas       52E252      Kick Sauber          BOT         True
# 8       Stroll       229971     Aston Martin          STR         True
# 3    Magnussen       B6BABD     Haas F1 Team          MAG         True
#
# [15 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Liam LAWSON Sector 1:  30.41 Sector 2:  27.84 Sector 3:  24.143

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             14         0.040                0.187               -0.095
# 1             23         0.133                0.174               -0.269
# 2             77         0.145               -0.037               -0.121
# 3             18         0.206                0.140                0.080
# 4             20         0.345                0.243               -0.033
#
#    difference_sector_3 name_acronym
# 0               -0.052          ALO
# 1                0.228          ALB
# 2                0.303          BOT
# 3               -0.014          STR
# 4                0.135          MAG

# %% [markdown]
# ### Best sector per driver

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# PIA                      30.021
# NOR                      30.058
# HAM                      30.071
# RUS                      30.130
# LEC                      30.212
# SAI                      30.220
# GAS                      30.333
# VER                      30.356
# BOT                      30.373
# LAW                      30.410
# HUL                      30.487
# STR                      30.550
# ALB                      30.584
# ALO                      30.597
# MAG                      30.653

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# NOR                      27.355
# RUS                      27.495
# ALB                      27.571
# VER                      27.633
# PIA                      27.634
# HUL                      27.646
# SAI                      27.704
# BOT                      27.719
# HAM                      27.733
# ALO                      27.745
# LEC                      27.794
# MAG                      27.807
# LAW                      27.840
# STR                      27.920
# GAS                      27.947

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# VER                      23.795
# LEC                      23.812
# NOR                      23.818
# RUS                      23.863
# SAI                      23.885
# PIA                      23.893
# HAM                      23.930
# GAS                      24.072
# ALO                      24.091
# STR                      24.129
# LAW                      24.143
# HUL                      24.185
# MAG                      24.278
# ALB                      24.371
# BOT                      24.446

# %% [markdown]
# ### Sprint Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 68           1251           9650              4       251       287       316
# 77           1251           9650             63       252       291       319
# 72           1251           9650             81       252       287       320
# 22           1251           9650             55       249       288       319
# 28           1251           9650             16       254       288       319
# 43           1251           9650              1       252       290       321
# 86           1251           9650             44       250       290       322
# 56           1251           9650             10       248       287       323
# 49           1251           9650             27       249       289       320
# 97           1251           9650             30       246       286       314
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 68  2024-11-29T18:09:14.746000+00:00        81.012           False
# 77  2024-11-29T18:13:09.223000+00:00        81.075           False
# 72  2024-11-29T18:09:22.274000+00:00        81.171           False
# 22  2024-11-29T18:13:26.820000+00:00        81.281           False
# 28  2024-11-29T18:13:32.342000+00:00        81.308           False
# 43  2024-11-29T18:09:42.493000+00:00        81.315           False
# 86  2024-11-29T18:09:58.246000+00:00        81.474           False
# 56  2024-11-29T18:13:37.248000+00:00        81.978           False
# 49  2024-11-29T18:12:09.153000+00:00        82.088           False
# 97  2024-11-29T18:07:50.817000+00:00        82.577           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 68             29.923  ...        L NORRIS           GBR      Lando
# 77             29.899  ...       G RUSSELL           GBR     George
# 72             29.975  ...       O PIASTRI           AUS      Oscar
# 22             30.052  ...         C SAINZ           ESP     Carlos
# 28             29.951  ...       C LECLERC           MON    Charles
# 43             30.068  ...    M VERSTAPPEN           NED        Max
# 86             29.886  ...      L HAMILTON           GBR      Lewis
# 56             30.293  ...         P GASLY           FRA     Pierre
# 49             30.375  ...    N HULKENBERG           GER       Nico
# 97             30.547  ...        L LAWSON          None       None
#
#           full_name                                       headshot_url  \
# 68     Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 77   George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 72    Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 22     Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 28  Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 43   Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 86   Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 56     Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 49  Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 97      Liam LAWSON                                               None
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 68      Norris       FF8000          McLaren          NOR         True
# 77     Russell       27F4D2         Mercedes          RUS         True
# 72     Piastri       FF8000          McLaren          PIA         True
# 22       Sainz       E80020          Ferrari          SAI         True
# 28     Leclerc       E80020          Ferrari          LEC         True
# 43  Verstappen       3671C6  Red Bull Racing          VER         True
# 86    Hamilton       27F4D2         Mercedes          HAM         True
# 56       Gasly       0093cc           Alpine          GAS         True
# 49  Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 97        None         None             None          LAW         True
#
# [10 rows x 28 columns]

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Lando NORRIS Sector 1:  29.923 Sector 2:  27.335 Sector 3:  23.754

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             63         0.063               -0.024                0.104
# 1             81         0.159                0.052                0.036
# 2             55         0.269                0.129                0.129
# 3             16         0.296                0.028                0.196
# 4              1         0.303                0.145                0.183
# 5             44         0.462               -0.037                0.249
# 6             10         0.966                0.370                0.226
# 7             27         1.076                0.452                0.163
# 8             30         1.565                0.624                0.503
#
#    difference_sector_3 name_acronym
# 0               -0.017          RUS
# 1                0.071          PIA
# 2                0.011          SAI
# 3                0.072          LEC
# 4               -0.025          VER
# 5                0.250          HAM
# 6                0.370          GAS
# 7                0.461          HUL
# 8                0.438          LAW

# %% [markdown]
# ### Best sector per driver

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# HAM                      29.886
# RUS                      29.899
# NOR                      29.923
# LEC                      29.951
# PIA                      29.975
# SAI                      30.052
# VER                      30.068
# GAS                      30.293
# HUL                      30.375
# LAW                      30.547

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# NOR                      27.335
# PIA                      27.371
# RUS                      27.439
# SAI                      27.464
# HUL                      27.498
# VER                      27.518
# LEC                      27.531
# GAS                      27.561
# HAM                      27.584
# LAW                      27.838

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# VER                      23.729
# RUS                      23.737
# NOR                      23.754
# SAI                      23.765
# PIA                      23.825
# LEC                      23.826
# HAM                      24.004
# GAS                      24.124
# LAW                      24.192
# HUL                      24.215

# %% [markdown]
# ### Best sector in the session

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# HAM                      29.886
# RUS                      29.899
# NOR                      29.923
# LEC                      29.951
# PIA                      29.975
# VER                      30.033
# SAI                      30.052
# GAS                      30.293
# BOT                      30.294
# HUL                      30.375
# LAW                      30.410
# STR                      30.515
# MAG                      30.525
# ALO                      30.555
# ALB                      30.584
# ZHO                      30.594
# TSU                      30.620
# OCO                      30.688
# PER                      30.750
# COL                      30.996

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# NOR                      27.335
# PIA                      27.371
# RUS                      27.439
# SAI                      27.464
# HUL                      27.498
# VER                      27.518
# LEC                      27.531
# GAS                      27.561
# ALB                      27.571
# HAM                      27.584
# BOT                      27.676
# MAG                      27.678
# ALO                      27.745
# PER                      27.815
# OCO                      27.832
# LAW                      27.838
# ZHO                      27.856
# TSU                      27.866
# STR                      27.916
# COL                      27.960

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# VER                      23.712
# RUS                      23.737
# NOR                      23.754
# SAI                      23.765
# LEC                      23.812
# PIA                      23.825
# HAM                      23.930
# PER                      24.038
# GAS                      24.072
# ALO                      24.091
# STR                      24.091
# HUL                      24.095
# LAW                      24.127
# TSU                      24.180
# MAG                      24.278
# ALB                      24.350
# OCO                      24.371
# BOT                      24.446
# COL                      24.467
# ZHO                      24.498

# %% [markdown]
# ## Predictions

# %%
# Free Practice 1
practice = libraryDataF1.obtain_information('laps',session_key=9650)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9650)
drivers = libraryDataF1.obtain_information('drivers',session_key=9650)

stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointablesfreepractice1 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# Free Practice 2
# practice = libraryDataF1.obtain_information('laps',session_key=9600)
# stintInformation = libraryDataF1.obtain_information('stints',session_key=9600)
# drivers = libraryDataF1.obtain_information('drivers',session_key=9600)


# stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
# jointablesfreepractice2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# Free Practice 3
# practice = libraryDataF1.obtain_information('laps',session_key=9591)
# stintInformation = libraryDataF1.obtain_information('stints',session_key=9591)
# drivers = libraryDataF1.obtain_information('drivers',session_key=9591)

# stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
# jointablesfreepractice1 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# ### Qualyfing prediction

# %%
qualy_simulation = libraryDataF1.qualyfing_prediction([jointablesfreepractice1,jointablesfreepractice1],drivers,0.05,0.07,0.08)
qualy_simulation.sort_values(by='qualy_lap_time')
# Out:
# /home/frank/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:320: RuntimeWarning: Mean of empty slice.
#   sector1= dataset.query("team_name == @team and duration_sector_1 <=  @threshold_sector1").duration_sector_1.values.mean()
# /home/frank/.local/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/frank/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:321: RuntimeWarning: Mean of empty slice.
#   sector2 = dataset.query("team_name == @team and duration_sector_2 <=  @threshold_sector2").duration_sector_2.values.mean()
# /home/frank/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:322: RuntimeWarning: Mean of empty slice.
#   sector3 = dataset.query("team_name == @team and duration_sector_3 <=  @threshold_sector3").duration_sector_3.values.mean()
# /home/frank/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:320: RuntimeWarning: Mean of empty slice.
#   sector1= dataset.query("team_name == @team and duration_sector_1 <=  @threshold_sector1").duration_sector_1.values.mean()
# /home/frank/.local/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/frank/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:321: RuntimeWarning: Mean of empty slice.
#   sector2 = dataset.query("team_name == @team and duration_sector_2 <=  @threshold_sector2").duration_sector_2.values.mean()
# /home/frank/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:322: RuntimeWarning: Mean of empty slice.
#   sector3 = dataset.query("team_name == @team and duration_sector_3 <=  @threshold_sector3").duration_sector_3.values.mean()
#                team  qualy_lap_time  mean_sector_1  mean_sector_2  \
# 1           McLaren       81.053267      29.904667       27.35340
# 10         Mercedes       81.248650      29.892500       27.53040
# 4           Ferrari       81.366450      30.001500       27.55220
# 0   Red Bull Racing       81.398333      30.050500       27.60250
# 5      Haas F1 Team       82.132500      30.375000       27.58000
# 2            Alpine       82.138750      30.313000       27.71975
# 3      Aston Martin       82.484167      30.532500       27.85200
# 8       Kick Sauber       82.549250      30.333500       27.73975
# 7          Williams       82.564000      30.584000       27.61950
# 6                RB       82.666000      30.620000       27.86600
# 9              None             NaN            NaN            NaN
#
#     mean_sector_3
# 1       23.795200
# 10      23.825750
# 4       23.812750
# 0       23.745333
# 5       24.177500
# 2       24.106000
# 3       24.099667
# 8       24.476000
# 7       24.360500
# 6       24.180000
# 9             NaN

# %% [markdown]
# ### Race prediction

# %%
race_simulation = libraryDataF1.race_prediction(jointablesfreepractice1,drivers,85,92)
race_simulation.groupby('team').mean().sort_values(by='mean_lap_duration')
# Out:
#                  mean_lap_duration  mean_sector_1  mean_sector_2  \
# team
# Mercedes                    91.423         33.041         31.306
# Alpine                         NaN            NaN            NaN
# Aston Martin                   NaN            NaN            NaN
# Ferrari                        NaN            NaN            NaN
# Haas F1 Team                   NaN            NaN            NaN
# Kick Sauber                    NaN            NaN            NaN
# McLaren                        NaN            NaN            NaN
# RB                             NaN            NaN            NaN
# Red Bull Racing                NaN            NaN            NaN
# Williams                       NaN            NaN            NaN
#
#                  mean_sector_3
# team
# Mercedes                27.076
# Alpine                     NaN
# Aston Martin               NaN
# Ferrari                    NaN
# Haas F1 Team               NaN
# Kick Sauber                NaN
# McLaren                    NaN
# RB                         NaN
# Red Bull Racing            NaN
# Williams                   NaN

# %% [markdown]
# ## Sprint

# %%
race = libraryDataF1.obtain_information('laps',session_key=9654)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9654)
drivers = libraryDataF1.obtain_information('drivers',session_key=9654)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables = pd.merge(race,stintsDataFrame,on=['lap_number','driver_number'])
jointables
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1251         9654              1     232.0       290     247.0
# 1           1251         9654              4     232.0       283     236.0
# 2           1251         9654             10     230.0       283     254.0
# 3           1251         9654             11     220.0       280     133.0
# 4           1251         9654             14     228.0       285     266.0
# ..           ...          ...            ...       ...       ...       ...
# 377         1251         9654             44     246.0       288     305.0
# 378         1251         9654             55     245.0       290     324.0
# 379         1251         9654             63     248.0       291       NaN
# 380         1251         9654             77     234.0       286     298.0
# 381         1251         9654             81       NaN       287     302.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0                                None           NaN           False
# 1                                None           NaN           False
# 2                                None           NaN           False
# 3                                None           NaN           False
# 4                                None           NaN           False
# ..                                ...           ...             ...
# 377  2024-11-30T14:29:12.358000+00:00        84.356           False
# 378  2024-11-30T14:29:07.530000+00:00        84.741           False
# 379  2024-11-30T14:29:06.617000+00:00        84.799           False
# 380  2024-11-30T14:29:28.871000+00:00        85.529           False
# 381  2024-11-30T14:29:06.036000+00:00        84.994           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             30.114             26.101
# 1                  NaN             28.975             25.659
# 2                  NaN             30.047             25.902
# 3                  NaN             31.832             26.160
# 4                  NaN             30.284             25.997
# ..                 ...                ...                ...
# 377             31.269             28.859             24.228
# 378             31.117             29.120             24.504
# 379             31.333             29.178             24.288
# 380             31.916             28.768             24.845
# 381             31.493             28.800             24.701
#
#                                      segments_sector_1  \
# 0    [2048, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 1    [2048, 0, 2049, 2051, 2051, 2051, 2049, 2051, ...
# 2    [2048, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 3    [2064, 2064, 2049, 2049, 2049, 2049, 2049, 204...
# 4    [2048, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 377  [None, 2048, 2048, 2048, 2049, 2048, 2048, 204...
# 378  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 379  [None, 2048, 2048, 2048, 2048, 2048, 2049, 204...
# 380  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
# 381  [None, 2048, 2048, 2048, 2048, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 0    [2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 1    [2051, 2049, 2051, 2051, 2049, 2051, 2049]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 377  [2048, 2048, 2049, 2049, 2048, 2048, 2048]
# 378  [2048, 2048, 2048, 2051, 2048, 2048, 2048]
# 379  [2048, 2048, 2048, 2048, 2048, 2048, 2051]
# 380  [2048, 2048, 2048, 2048, 2048, 2048, 2049]
# 381  [2048, 2048, 2049, 2048, 2048, 2048, 2048]
#
#                               segments_sector_3  lap_number compound  \
# 0    [2049, 2049, 2049, 2049, 2049, 2048, 2049]           1   MEDIUM
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049]           1   MEDIUM
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049]           1   MEDIUM
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049]           1   MEDIUM
# 4    [2049, 2049, 2049, 2049, 2049, 2048, 2048]           1   MEDIUM
# ..                                          ...         ...      ...
# 377        [2048, 2048, 2048, 2048, 2048, 0, 0]          19   MEDIUM
# 378     [2048, 2048, 2048, 2048, 2048, 2048, 0]          19   MEDIUM
# 379  [2048, 2048, 2048, 2048, 2048, 2048, 2048]          19   MEDIUM
# 380              [2048, 2048, 2048, 0, 0, 0, 0]          19   MEDIUM
# 381  [2048, 2048, 2048, 2048, 2048, 2048, 2048]          19   MEDIUM
#
#     name_acronym        full_name        team_name
# 0            VER   Max VERSTAPPEN  Red Bull Racing
# 1            NOR     Lando NORRIS          McLaren
# 2            GAS     Pierre GASLY           Alpine
# 3            PER     Sergio PEREZ  Red Bull Racing
# 4            ALO  Fernando ALONSO     Aston Martin
# ..           ...              ...              ...
# 377          HAM   Lewis HAMILTON         Mercedes
# 378          SAI     Carlos SAINZ          Ferrari
# 379          RUS   George RUSSELL         Mercedes
# 380          BOT  Valtteri BOTTAS      Kick Sauber
# 381          PIA    Oscar PIASTRI          McLaren
#
# [382 rows x 20 columns]

# %% [markdown]
# ### Pace per compound

# %%
libraryDataF1.obtain_data_tyres(jointables,"MEDIUM",89)

# %% [markdown]
# ### Top speed captured in the speed trap

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=89").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  lap_duration
# team_name
# McLaren             85.225360
# Mercedes            85.334625
# Ferrari             85.440552
# Haas F1 Team        85.599536
# Red Bull Racing     85.906552
# Alpine              86.281632
# Aston Martin        86.303261
# Kick Sauber         86.505667
# Williams            86.522100
# RB                  86.829400

# %% [markdown]
# ### Race pace per teams

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=89").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  duration_sector_1
# team_name
# McLaren                  31.556280
# Mercedes                 31.561917
# Ferrari                  31.568759
# Haas F1 Team             31.704893
# Red Bull Racing          31.809621
# Aston Martin             31.964130
# Alpine                   32.051421
# Kick Sauber              32.064048
# Williams                 32.068500
# RB                       32.229900

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=89").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  duration_sector_2
# team_name
# McLaren                  28.935680
# Haas F1 Team             29.030107
# Kick Sauber              29.120381
# Mercedes                 29.209292
# Red Bull Racing          29.233414
# Ferrari                  29.243828
# Alpine                   29.259053
# Aston Martin             29.319348
# Williams                 29.350233
# RB                       29.436300

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <=89").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace
# Out:
#                  duration_sector_3
# team_name
# Mercedes                 24.563417
# Ferrari                  24.627966
# McLaren                  24.733400
# Red Bull Racing          24.863517
# Haas F1 Team             24.864536
# Alpine                   24.971158
# Aston Martin             25.019783
# Williams                 25.103367
# RB                       25.163200
# Kick Sauber              25.321238

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 84
MAXIMUM_SECONDS = 89

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 1          1251         9654             1             11          1       15
# 2          1251         9654             1              1          1       20
# 21         1251         9654             2             11         15       20
#
#    compound  tyre_age_at_start
# 1    MEDIUM                 11
# 2    MEDIUM                  8
# 21   MEDIUM                 21

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 20   Max VERSTAPPEN   MEDIUM  2024-11-30T14:05:01.618000+00:00           2
# 40   Max VERSTAPPEN   MEDIUM  2024-11-30T14:06:29.109000+00:00           3
# 60   Max VERSTAPPEN   MEDIUM  2024-11-30T14:07:55.732000+00:00           4
# 80   Max VERSTAPPEN   MEDIUM  2024-11-30T14:09:22.198000+00:00           5
# 100  Max VERSTAPPEN   MEDIUM  2024-11-30T14:10:48.422000+00:00           6
# 120  Max VERSTAPPEN   MEDIUM  2024-11-30T14:12:14.452000+00:00           7
# 140  Max VERSTAPPEN   MEDIUM  2024-11-30T14:13:40.356000+00:00           8
# 160  Max VERSTAPPEN   MEDIUM  2024-11-30T14:15:05.557000+00:00           9
# 180  Max VERSTAPPEN   MEDIUM  2024-11-30T14:16:31.665000+00:00          10
# 200  Max VERSTAPPEN   MEDIUM  2024-11-30T14:17:56.932000+00:00          11
# 221  Max VERSTAPPEN   MEDIUM  2024-11-30T14:19:22.403000+00:00          12
# 241  Max VERSTAPPEN   MEDIUM  2024-11-30T14:20:47.776000+00:00          13
# 261  Max VERSTAPPEN   MEDIUM  2024-11-30T14:22:12.964000+00:00          14
# 281  Max VERSTAPPEN   MEDIUM  2024-11-30T14:23:37.944000+00:00          15
# 302  Max VERSTAPPEN   MEDIUM  2024-11-30T14:25:02.637000+00:00          16
# 322  Max VERSTAPPEN   MEDIUM  2024-11-30T14:26:27.329000+00:00          17
# 342  Max VERSTAPPEN   MEDIUM  2024-11-30T14:27:51.843000+00:00          18
# 362  Max VERSTAPPEN   MEDIUM  2024-11-30T14:29:16.413000+00:00          19
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
#
# 19         9646         1251  2024-11-30T18:34:27+00:00    Other
# 20         9646         1251  2024-11-30T18:40:00+00:00     Flag
# 21         9646         1251  2024-11-30T18:40:05+00:00    Other
# 22         9646         1251  2024-11-30T18:42:45+00:00    Other
# 23         9646         1251  2024-11-30T18:42:59+00:00    Other
# 24         9646         1251  2024-11-30T18:48:00+00:00     Flag
# 25         9646         1251  2024-11-30T18:52:11+00:00    Other
# 26         9646         1251  2024-11-30T19:00:00+00:00     Flag
# 27         9646         1251  2024-11-30T19:00:06+00:00    Other
# 28         9646         1251  2024-11-30T19:03:07+00:00    Other
# 29         9646         1251  2024-11-30T19:03:28+00:00    Other
# 30         9646         1251  2024-11-30T19:03:51+00:00    Other
# 31         9646         1251  2024-11-30T19:04:13+00:00     Flag
# 32         9646         1251  2024-11-30T19:04:13+00:00     Flag
# 33         9646         1251  2024-11-30T19:04:14+00:00     Flag
# 34         9646         1251  2024-11-30T19:04:14+00:00     Flag
# 35         9646         1251  2024-11-30T19:04:14+00:00     Flag
# 36         9646         1251  2024-11-30T19:04:15+00:00    Other
# 37         9646         1251  2024-11-30T19:04:17+00:00     Flag
# 38         9646         1251  2024-11-30T19:04:17+00:00     Flag
# 39         9646         1251  2024-11-30T19:04:17+00:00     Flag
#
#              flag lap_number  \
# 0            None       None
# 1            None       None
# 2            None       None
# 3           GREEN       None
# 4            None       None
# 5            None       None
# 6            None       None
# 7            None       None
# 8            None       None
# 9            None       None
# 10      CHEQUERED       None
# 11           None       None
# 12           None       None
# 13           None       None
# 14           None       None
# 15          GREEN       None
# 16           None       None
# 17           None       None
# 18           None       None
# 19           None       None
# 20      CHEQUERED       None
# 21           None       None
# 22           None       None
# 23           None       None
# 24          GREEN       None
# 25           None       None
# 26      CHEQUERED       None
# 27           None       None
# 28           None       None
# 29           None       None
# 30           None       None
# 31  DOUBLE YELLOW       None
# 32  DOUBLE YELLOW       None
# 33  DOUBLE YELLOW       None
# 34  DOUBLE YELLOW       None
# 35  DOUBLE YELLOW       None
# 36           None       None
# 37  DOUBLE YELLOW       None
# 38  DOUBLE YELLOW       None
# 39  DOUBLE YELLOW       None
#
#                                               message driver_number   scope  \
# 0        RISK OF RAIN FOR F1 QUALIFYING SESSION IS 0%          None    None
# 1             PINK HEAD PADDING MATERIAL MUST BE USED          None    None
# 2             PINK HEAD PADDING MATERIAL MUST BE USED          None    None
# 3                         GREEN LIGHT - PIT EXIT OPEN          None   Track
# 4   CAR 20 (MAG) TIME 1:23.505 DELETED - TRACK LIM...          None    None
# 5   CAR 43 (COL) TIME 1:23.535 DELETED - TRACK LIM...          None    None
# 6   CAR 23 (ALB) TIME 1:22.873 DELETED - TRACK LIM...          None    None
# 7   CAR 18 (STR) LAP DELETED - TRACK LIMITS AT TUR...          None    None
# 8   CAR 20 (MAG) LAP DELETED - TRACK LIMITS AT TUR...          None    None
# 9   CAR 4 (NOR) TIME 1:21.437 DELETED - TRACK LIMI...          None    None
# 10                                     CHEQUERED FLAG          None   Track
# 11          FIRST CAR TO TAKE THE FLAG - CAR 43 (COL)          None    None
# 12  CAR 14 (ALO) LAP DELETED - TRACK LIMITS AT TUR...          None    None
# 13  FIA STEWARDS: Q1 INCIDENT INVOLVING CARS 24 (Z...          None    None
# 14  FIA STEWARDS: Q1 INCIDENT INVOLVING CARS 24 (Z...          None    None
# 15                        GREEN LIGHT - PIT EXIT OPEN          None   Track
# 16  CAR 11 (PER) LAP DELETED - TRACK LIMITS AT TUR...          None    None
# 17  CAR 14 (ALO) LAP DELETED - TRACK LIMITS AT TUR...          None    None
# 18  INCIDENT INVOLVING CAR 55 (SAI) NOTED - UNSAFE...          None    None
# 19  FIA STEWARDS: INCIDENT INVOLVING CAR 55 (SAI) ...          None    None
# 20                                     CHEQUERED FLAG          None   Track
# 21          FIRST CAR TO TAKE THE FLAG - CAR 24 (ZHO)          None    None
# 22  FIA STEWARDS: Q2 INCIDENT INVOLVING CARS 16 (L...          None    None
# 23  FIA STEWARDS: Q2 INCIDENT INVOLVING CARS 16 (L...          None    None
# 24                        GREEN LIGHT - PIT EXIT OPEN          None   Track
# 25  CAR 14 (ALO) TIME 1:21.320 DELETED - TRACK LIM...          None    None
# 26                                     CHEQUERED FLAG          None   Track
# 27          FIRST CAR TO TAKE THE FLAG - CAR 55 (SAI)          None    None
# 28  FIA STEWARDS: Q3 INCIDENT INVOLVING CAR 1 (VER...          None    None
# 29  FIA STEWARDS: Q3 INCIDENT INVOLVING CAR 1 (VER...          None    None
# 30  FIA STEWARDS: Q1 INCIDENT INVOLVING CARS 24 (Z...          None    None
# 31                    DOUBLE YELLOW IN TRACK SECTOR 7          None  Sector
# 32                   DOUBLE YELLOW IN TRACK SECTOR 11          None  Sector
# 33                   DOUBLE YELLOW IN TRACK SECTOR 15          None  Sector
# 34                   DOUBLE YELLOW IN TRACK SECTOR 19          None  Sector
# 35                   DOUBLE YELLOW IN TRACK SECTOR 17          None  Sector
# 36  FIA STEWARDS: Q2 INCIDENT INVOLVING CARS 16 (L...          None    None
# 37                    DOUBLE YELLOW IN TRACK SECTOR 5          None  Sector
# 38                   DOUBLE YELLOW IN TRACK SECTOR 10          None  Sector
# 39                   DOUBLE YELLOW IN TRACK SECTOR 12          None  Sector
#
#     sector
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     7.0
# 32    11.0
# 33    15.0
# 34    19.0
# 35    17.0
# 36     NaN
# 37     5.0
# 38    10.0
# 39    12.0

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9646)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9646)
drivers = libraryDataF1.obtain_information('drivers',session_key=9646)

# %%
drivers.loc[drivers['driver_number']==30,'team_colour'] = '6692FF'
drivers.loc[drivers['driver_number']==43,'team_colour'] = '64C4FF'

# %%
session = ff1.get_session(2024, 'Qatar', 'Q')
session.load()
session.laps["LapTimeSeconds"] = session.laps["LapTime"].dt.total_seconds()
# Out:
# core           INFO 	Loading data for Qatar Grand Prix - Qualifying [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '63', '4', '81', '16', '44', '55', '14', '11', '20', '10', '24', '77', '22', '18', '23', '30', '27', '43', '31']

# %%
laptimes_deleted = [83.505,83.525,82.873,81.437,81.320]
driver_number_lap_deleted = [20,43,23,4,14]

for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
    try:
        id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
        qualyfing = qualyfing.drop(id_deleted)
    except:
        print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")
# Out:
# Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 361         1251         9646              1       253       288     322.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 361  2024-11-30T18:59:28.120000+00:00         80.52           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 361             29.598             27.353             23.569
#
#                                      segments_sector_1  \
# 361  [2049, 2049, 2049, 2048, 2048, 2049, 2048, 205...
#
#                               segments_sector_2  \
# 361  [2049, 2048, 2048, 2048, 2051, 2048, 2048]
#
#                               segments_sector_3  lap_number
# 361  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          21

# %% [markdown]
# In this case, the fastest lap is 80.52 seconds (1.20.52= so that to obtain the competitve laps the fastest lap will be multiplied by 1.07 86.15 seconds) due to, according to the rules all the drivers have to do unless one lap within this gap.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration <= 86.15")
competitiveLaps
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 16          1251         9646             24       248       286     315.0
# 18          1251         9646             77       249       285     316.0
# 23          1251         9646             18       251       287     318.0
# 27          1251         9646             14       248       288     320.0
# 30          1251         9646             43       244       285     313.0
# ..           ...          ...            ...       ...       ...       ...
# 359         1251         9646             14       251       288     323.0
# 360         1251         9646             63       254       288     320.0
# 361         1251         9646              1       253       288     322.0
# 362         1251         9646             11       252       287     324.0
# 363         1251         9646             44       255       289     321.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 16   2024-11-30T18:01:52.757000+00:00        83.593           False
# 18   2024-11-30T18:01:57.509000+00:00        82.753           False
# 23   2024-11-30T18:02:20.962000+00:00        82.384           False
# 27   2024-11-30T18:02:35.931000+00:00        82.478           False
# 30   2024-11-30T18:02:54.477000+00:00        83.535           False
# ..                                ...           ...             ...
# 359  2024-11-30T18:59:17.505000+00:00        81.251           False
# 360  2024-11-30T18:59:22.182000+00:00        80.842           False
# 361  2024-11-30T18:59:28.120000+00:00        80.520           False
# 362  2024-11-30T18:59:32.527000+00:00        81.425           False
# 363  2024-11-30T18:59:39.004000+00:00        81.038           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 16              30.932             28.116             24.545
# 18              30.498             27.934             24.321
# 23              30.555             27.781             24.048
# 27              30.443             28.024             24.011
# 30              30.935             28.064             24.536
# ..                 ...                ...                ...
# 359             29.879             27.636             23.736
# 360             29.649             27.571             23.622
# 361             29.598             27.353             23.569
# 362             30.045             27.557             23.823
# 363             29.747             27.574             23.717
#
#                                      segments_sector_1  \
# 16   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 18   [2049, 2049, 2049, 2051, 2049, 2051, 2049, 204...
# 23   [2049, 2049, 2049, 2049, 2049, 2049, 2051, 205...
# 27   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# 30   [2049, 2049, 2049, 2049, 2049, 2049, 2049, 204...
# ..                                                 ...
# 359  [2049, 2051, 2049, 2049, 2048, 2048, 2048, 204...
# 360  [None, 2049, 2049, 2049, 2048, 2048, 2048, 204...
# 361  [2049, 2049, 2049, 2048, 2048, 2049, 2048, 205...
# 362  [None, 2049, 2051, 2049, 2049, 2049, 2049, 204...
# 363  [None, 2049, 2049, 2049, 2049, 2048, 2048, 204...
#
#                               segments_sector_2  \
# 16   [2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 18   [2049, 2049, 2051, 2051, 2049, 2051, 2049]
# 23   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 27   [2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 30   [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 359  [2049, 2049, 2049, 2049, 2048, 2049, 2049]
# 360  [2048, 2048, 2048, 2048, 2049, 2048, 2048]
# 361  [2049, 2048, 2048, 2048, 2051, 2048, 2048]
# 362  [2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 363  [2051, 2049, 2048, 2048, 2049, 2048, 2048]
#
#                               segments_sector_3  lap_number
# 16      [2048, 2048, 2048, 2048, 2048, 2048, 0]           2
# 18   [2048, 2048, 2048, 2048, 2048, 2048, 2048]           2
# 23   [2048, 2048, 2048, 2048, 2048, 2048, 2064]           2
# 27   [2048, 2048, 2048, 2048, 2048, 2048, 2064]           2
# 30      [2048, 2048, 2048, 2048, 2048, 2048, 0]           2
# ..                                          ...         ...
# 359  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          18
# 360  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          27
# 361  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          21
# 362  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          21
# 363  [2048, 2048, 2048, 2048, 2048, 2048, 2064]          26
#
# [106 rows x 16 columns]

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)
# Out:
#     driver_number  fastest_lap  delta  st_speed  i1_speed  i2_speed  \
# 9               1       80.520  0.000     319.0       250       288
# 15             63       80.575  0.055     312.0       252       288
# 8               4       80.772  0.252     315.0       247       287
# 12             81       80.829  0.309     313.0       250       285
# 5              16       80.852  0.332     313.0       249       285
# 14             44       81.011  0.491     319.0       252       288
# 17             55       81.041  0.521     314.0       251       286
# 3              14       81.208  0.688     320.0       248       288
# 13             20       81.387  0.867     316.0       243       285
# 6              11       81.425  0.905     320.0       248       286
# 18             10       81.437  0.917     320.0       246       286
# 0              24       81.501  0.981     315.0       247       285
# 1              77       81.731  1.211     316.0       247       285
# 10             22       81.771  1.251     316.0       248       285
# 2              18       81.911  1.391     318.0       248       287
# 16             23       82.390  1.870     316.0       245       284
# 11             30       82.411  1.891     318.0       248       285
# 7              27       82.442  1.922     315.0       237       286
# 4              43       82.594  2.074     313.0       244       285
# 19             31       82.714  2.194     320.0       244       286
#
#     session_key  meeting_key broadcast_name country_code first_name  \
# 9          9646         1251   M VERSTAPPEN          NED        Max
# 15         9646         1251      G RUSSELL          GBR     George
# 8          9646         1251       L NORRIS          GBR      Lando
# 12         9646         1251      O PIASTRI          AUS      Oscar
# 5          9646         1251      C LECLERC          MON    Charles
# 14         9646         1251     L HAMILTON          GBR      Lewis
# 17         9646         1251        C SAINZ          ESP     Carlos
# 3          9646         1251       F ALONSO          ESP   Fernando
# 13         9646         1251    K MAGNUSSEN          DEN      Kevin
# 6          9646         1251        S PEREZ          MEX     Sergio
# 18         9646         1251        P GASLY          FRA     Pierre
# 0          9646         1251         G ZHOU          CHN     Guanyu
# 1          9646         1251       V BOTTAS          FIN   Valtteri
# 10         9646         1251      Y TSUNODA          JPN       Yuki
# 2          9646         1251       L STROLL          CAN      Lance
# 16         9646         1251        A ALBON          THA  Alexander
# 11         9646         1251       L LAWSON         None       None
# 7          9646         1251   N HULKENBERG          GER       Nico
# 4          9646         1251    F COLAPINTO         None       None
# 19         9646         1251         E OCON          FRA    Esteban
#
#            full_name                                       headshot_url  \
# 9     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 15    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 8       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 12     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 5    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 14    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 17      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 3    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 13   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 6       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 18      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 0        ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 1    Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 10      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 2       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 16   Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 11       Liam LAWSON                                               None
# 7    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 4   Franco COLAPINTO                                               None
# 19      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name team_colour        team_name name_acronym
# 9   Verstappen      3671C6  Red Bull Racing          VER
# 15     Russell      27F4D2         Mercedes          RUS
# 8       Norris      FF8000          McLaren          NOR
# 12     Piastri      FF8000          McLaren          PIA
# 5      Leclerc      E80020          Ferrari          LEC
# 14    Hamilton      27F4D2         Mercedes          HAM
# 17       Sainz      E80020          Ferrari          SAI
# 3       Alonso      229971     Aston Martin          ALO
# 13   Magnussen      B6BABD     Haas F1 Team          MAG
# 6        Perez      3671C6  Red Bull Racing          PER
# 18       Gasly      0093cc           Alpine          GAS
# 0         Zhou      52E252      Kick Sauber          ZHO
# 1       Bottas      52E252      Kick Sauber          BOT
# 10     Tsunoda      6692FF               RB          TSU
# 2       Stroll      229971     Aston Martin          STR
# 16       Albon      64C4FF         Williams          ALB
# 11        None      6692FF             None          LAW
# 7   Hulkenberg      B6BABD     Haas F1 Team          HUL
# 4         None      64C4FF             None          COL
# 19        Ocon      0093cc           Alpine          OCO

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session
# In this chart we can see the deltas with compared with the fastest lap of the session that it could be different than the pole.

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %% [markdown]
# ### Speed trap

# %% [markdown]
# #### Maximum speed per drivers

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %% [markdown]
# ### Maximum speed per teams

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","st_speed",top_speed)

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])
mergequaly
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 0             1251           9646             24       248       286
# 1             1251           9646             24       247       286
# 2             1251           9646             24       249       287
# 3             1251           9646             24       251       286
# 4             1251           9646             24       251       286
# ..             ...            ...            ...       ...       ...
# 101           1251           9646             10       247       287
# 102           1251           9646             10       249       287
# 103           1251           9646             10       249       286
# 104           1251           9646             31       244       286
# 105           1251           9646             31       246       286
#
#      st_speed                        date_start  lap_duration  is_pit_out_lap  \
# 0       315.0  2024-11-30T18:01:52.757000+00:00        83.593           False
# 1       320.0  2024-11-30T18:05:12.353000+00:00        82.713           False
# 2         NaN  2024-11-30T18:13:41.582000+00:00        82.172           False
# 3       317.0  2024-11-30T18:17:05.579000+00:00        82.103           False
# 4       315.0  2024-11-30T18:28:50.655000+00:00        81.884           False
# ..        ...                               ...           ...             ...
# 101     321.0  2024-11-30T18:17:53.246000+00:00        81.843           False
# 102       NaN  2024-11-30T18:30:03.133000+00:00        81.437           False
# 103     322.0  2024-11-30T18:38:52.641000+00:00        81.944           False
# 104     320.0  2024-11-30T18:08:38.684000+00:00        83.167           False
# 105       NaN  2024-11-30T18:16:50.825000+00:00        82.714           False
#
#      duration_sector_1  ...  meeting_key_y  broadcast_name country_code  \
# 0               30.932  ...           1251          G ZHOU          CHN
# 1               30.371  ...           1251          G ZHOU          CHN
# 2               30.093  ...           1251          G ZHOU          CHN
# 3               30.079  ...           1251          G ZHOU          CHN
# 4               30.122  ...           1251          G ZHOU          CHN
# ..                 ...  ...            ...             ...          ...
# 101             30.151  ...           1251         P GASLY          FRA
# 102             30.062  ...           1251         P GASLY          FRA
# 103             30.206  ...           1251         P GASLY          FRA
# 104             30.632  ...           1251          E OCON          FRA
# 105             30.537  ...           1251          E OCON          FRA
#
#     first_name     full_name  \
# 0       Guanyu   ZHOU Guanyu
# 1       Guanyu   ZHOU Guanyu
# 2       Guanyu   ZHOU Guanyu
# 3       Guanyu   ZHOU Guanyu
# 4       Guanyu   ZHOU Guanyu
# ..         ...           ...
# 101     Pierre  Pierre GASLY
# 102     Pierre  Pierre GASLY
# 103     Pierre  Pierre GASLY
# 104    Esteban  Esteban OCON
# 105    Esteban  Esteban OCON
#
#                                           headshot_url  last_name  \
# 0    https://media.formula1.com/d_driver_fallback_i...       Zhou
# 1    https://media.formula1.com/d_driver_fallback_i...       Zhou
# 2    https://media.formula1.com/d_driver_fallback_i...       Zhou
# 3    https://media.formula1.com/d_driver_fallback_i...       Zhou
# 4    https://media.formula1.com/d_driver_fallback_i...       Zhou
# ..                                                 ...        ...
# 101  https://media.formula1.com/d_driver_fallback_i...      Gasly
# 102  https://media.formula1.com/d_driver_fallback_i...      Gasly
# 103  https://media.formula1.com/d_driver_fallback_i...      Gasly
# 104  https://media.formula1.com/d_driver_fallback_i...       Ocon
# 105  https://media.formula1.com/d_driver_fallback_i...       Ocon
#
#      team_colour    team_name name_acronym
# 0         52E252  Kick Sauber          ZHO
# 1         52E252  Kick Sauber          ZHO
# 2         52E252  Kick Sauber          ZHO
# 3         52E252  Kick Sauber          ZHO
# 4         52E252  Kick Sauber          ZHO
# ..           ...          ...          ...
# 101       0093cc       Alpine          GAS
# 102       0093cc       Alpine          GAS
# 103       0093cc       Alpine          GAS
# 104       0093cc       Alpine          OCO
# 105       0093cc       Alpine          OCO
#
# [106 rows x 27 columns]

# %% [markdown]
# In order to know when each session finished, race control dataset will be consulted.

# %%
maximumDateQ1 = "date_start <'2024-11-30T18:25:00+00:00'"
maximumDateQ2 = "date_start <'2024-11-30T18:48:00+00:00' and date_start >'2024-11-30T18:25:00+00:00'"
maximumDateQ3 = "date_start >'2024-11-30T18:48:00+00:00'"

# %% [markdown]
# ### Qualyfing 1

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 84            1251           9646             63       253       289
# 26            1251           9646             16       255       286
# 94            1251           9646             55       251       287
# 42            1251           9646              4       251       288
# 47            1251           9646              1       250       288
# 17            1251           9646             14       249       289
# 75            1251           9646             44       253       290
# 34            1251           9646             11       251       287
# 62            1251           9646             81       250       286
# 101           1251           9646             10       247       287
# 69            1251           9646             20       250       287
# 9             1251           9646             77       249       286
# 13            1251           9646             18       249       287
# 3             1251           9646             24       251       286
# 55            1251           9646             22       250       286
# 91            1251           9646             23       249       285
# 59            1251           9646             30       248       285
# 39            1251           9646             27       249       286
# 22            1251           9646             43       247       285
# 105           1251           9646             31       246       286
#
#      st_speed                        date_start  lap_duration  is_pit_out_lap  \
# 84      319.0  2024-11-30T18:17:43.457000+00:00        81.241           False
# 26      318.0  2024-11-30T18:16:55.946000+00:00        81.278           False
# 94      320.0  2024-11-30T18:17:26.385000+00:00        81.447           False
# 42      319.0  2024-11-30T18:07:10.477000+00:00        81.578           False
# 47      320.0  2024-11-30T18:13:33.982000+00:00        81.579           False
# 17      322.0  2024-11-30T18:07:50.277000+00:00        81.608           False
# 75      323.0  2024-11-30T18:12:18.451000+00:00        81.637           False
# 34      323.0  2024-11-30T18:17:08.911000+00:00        81.675           False
# 62      315.0  2024-11-30T18:11:53.581000+00:00        81.821           False
# 101     321.0  2024-11-30T18:17:53.246000+00:00        81.843           False
# 69      319.0  2024-11-30T18:16:33.135000+00:00        81.891           False
# 9       319.0  2024-11-30T18:17:13.355000+00:00        81.927           False
# 13      323.0  2024-11-30T18:07:40.711000+00:00        82.011           False
# 3       317.0  2024-11-30T18:17:05.579000+00:00        82.103           False
# 55      320.0  2024-11-30T18:17:38.787000+00:00        82.364           False
# 91      318.0  2024-11-30T18:16:44.323000+00:00        82.390           False
# 59      318.0  2024-11-30T18:07:32.511000+00:00        82.411           False
# 39      315.0  2024-11-30T18:11:23.255000+00:00        82.442           False
# 22      317.0  2024-11-30T18:16:39.651000+00:00        82.594           False
# 105       NaN  2024-11-30T18:16:50.825000+00:00        82.714           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 84              29.885  ...       G RUSSELL           GBR     George
# 26              29.827  ...       C LECLERC           MON    Charles
# 94              30.008  ...         C SAINZ           ESP     Carlos
# 42              30.028  ...        L NORRIS           GBR      Lando
# 47              29.967  ...    M VERSTAPPEN           NED        Max
# 17              30.024  ...        F ALONSO           ESP   Fernando
# 75              30.083  ...      L HAMILTON           GBR      Lewis
# 34              30.021  ...         S PEREZ           MEX     Sergio
# 62              30.282  ...       O PIASTRI           AUS      Oscar
# 101             30.151  ...         P GASLY           FRA     Pierre
# 69              30.233  ...     K MAGNUSSEN           DEN      Kevin
# 9               30.130  ...        V BOTTAS           FIN   Valtteri
# 13              30.211  ...        L STROLL           CAN      Lance
# 3               30.079  ...          G ZHOU           CHN     Guanyu
# 55              30.419  ...       Y TSUNODA           JPN       Yuki
# 91              30.259  ...         A ALBON           THA  Alexander
# 59              30.291  ...        L LAWSON          None       None
# 39              30.495  ...    N HULKENBERG           GER       Nico
# 22              30.474  ...     F COLAPINTO          None       None
# 105             30.537  ...          E OCON           FRA    Esteban
#
#             full_name                                       headshot_url  \
# 84     George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 26    Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 94       Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 42       Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 47     Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 17    Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 75     Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 34       Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 62      Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 101      Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 69    Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 9     Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 13       Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
# 3         ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 55       Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 91    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 59        Liam LAWSON                                               None
# 39    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 22   Franco COLAPINTO                                               None
# 105      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name  team_colour        team_name name_acronym isFastestLap
# 84      Russell       27F4D2         Mercedes          RUS         True
# 26      Leclerc       E80020          Ferrari          LEC         True
# 94        Sainz       E80020          Ferrari          SAI         True
# 42       Norris       FF8000          McLaren          NOR         True
# 47   Verstappen       3671C6  Red Bull Racing          VER         True
# 17       Alonso       229971     Aston Martin          ALO         True
# 75     Hamilton       27F4D2         Mercedes          HAM         True
# 34        Perez       3671C6  Red Bull Racing          PER         True
# 62      Piastri       FF8000          McLaren          PIA         True
# 101       Gasly       0093cc           Alpine          GAS         True
# 69    Magnussen       B6BABD     Haas F1 Team          MAG         True
# 9        Bottas       52E252      Kick Sauber          BOT         True
# 13       Stroll       229971     Aston Martin          STR         True
# 3          Zhou       52E252      Kick Sauber          ZHO         True
# 55      Tsunoda       6692FF               RB          TSU         True
# 91        Albon       64C4FF         Williams          ALB         True
# 59         None       6692FF             None          LAW         True
# 39   Hulkenberg       B6BABD     Haas F1 Team          HUL         True
# 22         None       64C4FF             None          COL         True
# 105        Ocon       0093cc           Alpine          OCO         True
#
# [20 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver,I will do a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P15 = q1Data[14:15]
P15
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 55           1251           9646             22       250       286     320.0
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 55  2024-11-30T18:17:38.787000+00:00        82.364           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 55             30.419  ...       Y TSUNODA           JPN       Yuki
#
#        full_name                                       headshot_url  \
# 55  Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
#
#     last_name  team_colour  team_name name_acronym isFastestLap
# 55    Tsunoda       6692FF         RB          TSU         True
#
# [1 rows x 28 columns]

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Yuki TSUNODA Sector 1:  30.419 Sector 2:  27.879 Sector 3:  24.066

# %%
q1Data[15::]
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 91            1251           9646             23       249       285
# 59            1251           9646             30       248       285
# 39            1251           9646             27       249       286
# 22            1251           9646             43       247       285
# 105           1251           9646             31       246       286
#
#      st_speed                        date_start  lap_duration  is_pit_out_lap  \
# 91      318.0  2024-11-30T18:16:44.323000+00:00        82.390           False
# 59      318.0  2024-11-30T18:07:32.511000+00:00        82.411           False
# 39      315.0  2024-11-30T18:11:23.255000+00:00        82.442           False
# 22      317.0  2024-11-30T18:16:39.651000+00:00        82.594           False
# 105       NaN  2024-11-30T18:16:50.825000+00:00        82.714           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 91              30.259  ...         A ALBON           THA  Alexander
# 59              30.291  ...        L LAWSON          None       None
# 39              30.495  ...    N HULKENBERG           GER       Nico
# 22              30.474  ...     F COLAPINTO          None       None
# 105             30.537  ...          E OCON           FRA    Esteban
#
#             full_name                                       headshot_url  \
# 91    Alexander ALBON  https://media.formula1.com/d_driver_fallback_i...
# 59        Liam LAWSON                                               None
# 39    Nico HULKENBERG  https://media.formula1.com/d_driver_fallback_i...
# 22   Franco COLAPINTO                                               None
# 105      Esteban OCON  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name  team_colour     team_name name_acronym isFastestLap
# 91        Albon       64C4FF      Williams          ALB         True
# 59         None       6692FF          None          LAW         True
# 39   Hulkenberg       B6BABD  Haas F1 Team          HUL         True
# 22         None       64C4FF          None          COL         True
# 105        Ocon       0093cc        Alpine          OCO         True
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             23         0.026               -0.160               -0.097
# 1             30         0.047               -0.128                0.057
# 2             27         0.078                0.076               -0.182
# 3             43         0.230                0.055                0.022
# 4             31         0.350                0.118                0.133
#
#    difference_sector_3 name_acronym
# 0                0.283          ALB
# 1                0.118          LAW
# 2                0.184          HUL
# 3                0.153          COL
# 4                0.099          OCO

# %%
libraryDataF1.draw_gap(P15,15,20,q1Data,drivers,session)
# Out:
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk
# I bring this section in order to know where the driver at risk lost his chances to improve in the qualyfing.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[0:14].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2
# Out:
#     driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0              63        -1.123               -0.534               -0.298
# 1              16        -1.086               -0.592               -0.089
# 2              55        -0.917               -0.411               -0.243
# 3               4        -0.786               -0.391               -0.151
# 4               1        -0.785               -0.452               -0.081
# 5              14        -0.756               -0.395               -0.141
# 6              44        -0.727               -0.336               -0.052
# 7              11        -0.689               -0.398               -0.026
# 8              81        -0.543               -0.137               -0.131
# 9              10        -0.521               -0.268               -0.166
# 10             20        -0.473               -0.186               -0.263
# 11             77        -0.437               -0.289               -0.275
# 12             18        -0.353               -0.208               -0.085
# 13             24        -0.261               -0.340               -0.087
#
#     difference_sector_3 name_acronym
# 0                -0.291          RUS
# 1                -0.405          LEC
# 2                -0.263          SAI
# 3                -0.244          NOR
# 4                -0.252          VER
# 5                -0.220          ALO
# 6                -0.339          HAM
# 7                -0.265          PER
# 8                -0.275          PIA
# 9                -0.087          GAS
# 10               -0.024          MAG
# 11                0.127          BOT
# 12               -0.060          STR
# 13                0.166          ZHO

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# LEC                      29.827
# RUS                      29.885
# VER                      29.967
# SAI                      30.008
# PER                      30.021
# ALO                      30.024
# NOR                      30.028
# ZHO                      30.079
# HAM                      30.083
# BOT                      30.130
# GAS                      30.151
# STR                      30.211
# MAG                      30.233
# ALB                      30.259
# PIA                      30.282
# LAW                      30.291
# TSU                      30.419
# COL                      30.474
# HUL                      30.495
# OCO                      30.537

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# RUS                      27.581
# BOT                      27.604
# MAG                      27.616
# SAI                      27.636
# HUL                      27.697
# GAS                      27.713
# NOR                      27.728
# ALO                      27.738
# PIA                      27.748
# ALB                      27.782
# LEC                      27.790
# ZHO                      27.792
# STR                      27.794
# VER                      27.798
# HAM                      27.827
# PER                      27.853
# TSU                      27.879
# COL                      27.901
# LAW                      27.936
# OCO                      28.012

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# LEC                      23.661
# HAM                      23.727
# RUS                      23.775
# PIA                      23.791
# PER                      23.801
# SAI                      23.803
# VER                      23.814
# NOR                      23.822
# ALO                      23.846
# GAS                      23.979
# STR                      24.006
# MAG                      24.042
# TSU                      24.066
# OCO                      24.165
# LAW                      24.184
# BOT                      24.193
# COL                      24.219
# ZHO                      24.232
# HUL                      24.250
# ALB                      24.349

# %% [markdown]
# ### Qualyfing 2

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data
# Out:
#      meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  \
# 50            1251           9646              1       253       288
# 44            1251           9646              4       252       288
# 29            1251           9646             16       256       287
# 87            1251           9646             63       252       289
# 79            1251           9646             44       254       290
# 64            1251           9646             81       253       286
# 97            1251           9646             55       255       287
# 18            1251           9646             14       252       288
# 71            1251           9646             20       252       287
# 35            1251           9646             11       251       287
# 102           1251           9646             10       249       287
# 5             1251           9646             24       252       285
# 11            1251           9646             77       252       285
# 57            1251           9646             22       250       285
# 15            1251           9646             18       248       287
#
#      st_speed                        date_start  lap_duration  is_pit_out_lap  \
# 50      322.0  2024-11-30T18:39:36.100000+00:00        80.687           False
# 44      315.0  2024-11-30T18:35:01.990000+00:00        80.983           False
# 29      319.0  2024-11-30T18:39:02.076000+00:00        81.000           False
# 87      321.0  2024-11-30T18:39:05.712000+00:00        81.069           False
# 79      320.0  2024-11-30T18:39:24.184000+00:00        81.095           False
# 64      313.0  2024-11-30T18:31:52.501000+00:00        81.121           False
# 97      321.0  2024-11-30T18:39:10.096000+00:00        81.199           False
# 18      322.0  2024-11-30T18:39:17.641000+00:00        81.208           False
# 71      317.0  2024-11-30T18:38:34.346000+00:00        81.387           False
# 35      320.0  2024-11-30T18:27:44.909000+00:00        81.425           False
# 102       NaN  2024-11-30T18:30:03.133000+00:00        81.437           False
# 5       318.0  2024-11-30T18:38:39.534000+00:00        81.501           False
# 11      319.0  2024-11-30T18:38:57.333000+00:00        81.731           False
# 57      316.0  2024-11-30T18:38:05.154000+00:00        81.771           False
# 15      322.0  2024-11-30T18:38:46.510000+00:00        81.911           False
#
#      duration_sector_1  ...  broadcast_name  country_code first_name  \
# 50              29.692  ...    M VERSTAPPEN           NED        Max
# 44              29.840  ...        L NORRIS           GBR      Lando
# 29              29.827  ...       C LECLERC           MON    Charles
# 87              29.958  ...       G RUSSELL           GBR     George
# 79              29.809  ...      L HAMILTON           GBR      Lewis
# 64              30.015  ...       O PIASTRI           AUS      Oscar
# 97              29.812  ...         C SAINZ           ESP     Carlos
# 18              29.836  ...        F ALONSO           ESP   Fernando
# 71              30.148  ...     K MAGNUSSEN           DEN      Kevin
# 35              30.024  ...         S PEREZ           MEX     Sergio
# 102             30.062  ...         P GASLY           FRA     Pierre
# 5               29.872  ...          G ZHOU           CHN     Guanyu
# 11              29.992  ...        V BOTTAS           FIN   Valtteri
# 57              30.179  ...       Y TSUNODA           JPN       Yuki
# 15              30.386  ...        L STROLL           CAN      Lance
#
#            full_name                                       headshot_url  \
# 50    Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 44      Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 29   Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 87    George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 79    Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 64     Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 97      Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 18   Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 71   Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
# 35      Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 102     Pierre GASLY  https://media.formula1.com/d_driver_fallback_i...
# 5        ZHOU Guanyu  https://media.formula1.com/d_driver_fallback_i...
# 11   Valtteri BOTTAS  https://media.formula1.com/d_driver_fallback_i...
# 57      Yuki TSUNODA  https://media.formula1.com/d_driver_fallback_i...
# 15      Lance STROLL  https://media.formula1.com/d_driver_fallback_i...
#
#       last_name  team_colour        team_name name_acronym isFastestLap
# 50   Verstappen       3671C6  Red Bull Racing          VER         True
# 44       Norris       FF8000          McLaren          NOR         True
# 29      Leclerc       E80020          Ferrari          LEC         True
# 87      Russell       27F4D2         Mercedes          RUS         True
# 79     Hamilton       27F4D2         Mercedes          HAM         True
# 64      Piastri       FF8000          McLaren          PIA         True
# 97        Sainz       E80020          Ferrari          SAI         True
# 18       Alonso       229971     Aston Martin          ALO         True
# 71    Magnussen       B6BABD     Haas F1 Team          MAG         True
# 35        Perez       3671C6  Red Bull Racing          PER         True
# 102       Gasly       0093cc           Alpine          GAS         True
# 5          Zhou       52E252      Kick Sauber          ZHO         True
# 11       Bottas       52E252      Kick Sauber          BOT         True
# 57      Tsunoda       6692FF               RB          TSU         True
# 15       Stroll       229971     Aston Martin          STR         True
#
# [15 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Sergio PEREZ Sector 1:  30.024 Sector 2:  27.534 Sector 3:  23.867

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             10         0.012                0.038                0.028
# 1             24         0.076               -0.152               -0.001
# 2             77         0.306               -0.032                0.117
# 3             22         0.346                0.155                0.173
# 4             18         0.486                0.362                0.082
#
#    difference_sector_3 name_acronym
# 0               -0.054          GAS
# 1                0.229          ZHO
# 2                0.221          BOT
# 3                0.018          TSU
# 4                0.042          STR

# %%
libraryDataF1.draw_gap(P10,9,15,q2Data,drivers,session)
# Out:
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [95], line 1
# ----> 1 libraryDataF1.draw_gap(P10,9,15,q2Data,drivers,session)
#
# File ~/Escritorio/F1_notebooks/F1_24/F1_library/libraryF1dataNotebook.py:395, in draw_gap(driver_at_risk, position_min, position_max, dataset, drivers, session)
#     393 count = 0
#     394 for row in (name_acronym_reference):
# --> 395     ax.plot(ref_tel['Distance'], fastest_lap_session_qualyfing[count], '--',label=row,color = "#"+drivers.query("name_acronym=='"+row+"'").team_colour.to_string(index=False) )
#     396     ax.legend(loc=0)
#     397     count+=1
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4440, in DataFrame.query(self, expr, inplace, **kwargs)
#    4438 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4439 kwargs["target"] = None
# -> 4440 res = self.eval(expr, **kwargs)
#    4442 try:
#    4443     result = self.loc[res]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4566, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4563     kwargs["target"] = self
#    4564 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4566 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/computation/eval.py:311, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     308 multi_line = len(exprs) > 1
#     310 if multi_line and target is None:
# --> 311     raise ValueError(
#     312         "multi-line expressions are only valid in the "
#     313         "context of data, use DataFrame.eval"
#     314     )
#     315 engine = _check_engine(engine)
#     316 _check_parser(parser)
#
# ValueError: multi-line expressions are only valid in the context of data, use DataFrame.eval

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[0:9].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0              1        -0.738               -0.332               -0.169
# 1              4        -0.442               -0.184               -0.081
# 2             16        -0.425               -0.197               -0.021
# 3             63        -0.356               -0.066               -0.161
# 4             44        -0.330               -0.215                0.103
# 5             81        -0.304               -0.009               -0.111
# 6             55        -0.226               -0.212                0.063
# 7             14        -0.217               -0.188                0.101
# 8             20        -0.038                0.124               -0.153
#
#    difference_sector_3 name_acronym
# 0               -0.237          VER
# 1               -0.177          NOR
# 2               -0.207          LEC
# 3               -0.129          RUS
# 4               -0.218          HAM
# 5               -0.184          PIA
# 6               -0.077          SAI
# 7               -0.130          ALO
# 8               -0.009          MAG

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# VER                      29.692
# HAM                      29.809
# SAI                      29.812
# LEC                      29.827
# ALO                      29.836
# NOR                      29.840
# ZHO                      29.872
# RUS                      29.958
# BOT                      29.992
# PIA                      30.015
# PER                      30.024
# GAS                      30.062
# MAG                      30.148
# TSU                      30.179
# STR                      30.386

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# VER                      27.365
# RUS                      27.373
# MAG                      27.381
# PIA                      27.423
# NOR                      27.453
# LEC                      27.513
# ZHO                      27.533
# PER                      27.534
# GAS                      27.562
# SAI                      27.597
# STR                      27.616
# ALO                      27.635
# HAM                      27.637
# BOT                      27.651
# TSU                      27.707

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# VER                      23.630
# HAM                      23.649
# LEC                      23.660
# PIA                      23.683
# NOR                      23.690
# ALO                      23.737
# RUS                      23.738
# SAI                      23.790
# GAS                      23.813
# MAG                      23.858
# PER                      23.867
# TSU                      23.885
# STR                      23.909
# BOT                      24.088
# ZHO                      24.096

# %% [markdown]
# ### Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data
# Out:
#     meeting_key_x  session_key_x  driver_number  i1_speed  i2_speed  st_speed  \
# 52           1251           9646              1       253       288     322.0
# 88           1251           9646             63       254       289     317.0
# 45           1251           9646              4       253       287     318.0
# 66           1251           9646             81       254       287     318.0
# 31           1251           9646             16       256       286     317.0
# 80           1251           9646             44       256       290     321.0
# 99           1251           9646             55       252       287     314.0
# 19           1251           9646             14       251       288     323.0
# 37           1251           9646             11       252       287     324.0
# 72           1251           9646             20       251       286     316.0
#
#                           date_start  lap_duration  is_pit_out_lap  \
# 52  2024-11-30T18:59:28.120000+00:00        80.520           False
# 88  2024-11-30T18:51:23.933000+00:00        80.575           False
# 45  2024-11-30T18:59:09.438000+00:00        80.772           False
# 66  2024-11-30T18:59:02.042000+00:00        80.829           False
# 31  2024-11-30T18:58:55.318000+00:00        80.852           False
# 80  2024-11-30T18:51:37.529000+00:00        81.011           False
# 99  2024-11-30T18:58:42.494000+00:00        81.041           False
# 19  2024-11-30T18:59:17.505000+00:00        81.251           False
# 37  2024-11-30T18:59:32.527000+00:00        81.425           False
# 72  2024-11-30T18:49:38.249000+00:00        81.500           False
#
#     duration_sector_1  ...  broadcast_name  country_code first_name  \
# 52             29.598  ...    M VERSTAPPEN           NED        Max
# 88             29.742  ...       G RUSSELL           GBR     George
# 45             29.731  ...        L NORRIS           GBR      Lando
# 66             29.756  ...       O PIASTRI           AUS      Oscar
# 31             29.790  ...       C LECLERC           MON    Charles
# 80             29.826  ...      L HAMILTON           GBR      Lewis
# 99             29.915  ...         C SAINZ           ESP     Carlos
# 19             29.879  ...        F ALONSO           ESP   Fernando
# 37             30.045  ...         S PEREZ           MEX     Sergio
# 72             30.119  ...     K MAGNUSSEN           DEN      Kevin
#
#           full_name                                       headshot_url  \
# 52   Max VERSTAPPEN  https://media.formula1.com/d_driver_fallback_i...
# 88   George RUSSELL  https://media.formula1.com/d_driver_fallback_i...
# 45     Lando NORRIS  https://media.formula1.com/d_driver_fallback_i...
# 66    Oscar PIASTRI  https://media.formula1.com/d_driver_fallback_i...
# 31  Charles LECLERC  https://media.formula1.com/d_driver_fallback_i...
# 80   Lewis HAMILTON  https://media.formula1.com/d_driver_fallback_i...
# 99     Carlos SAINZ  https://media.formula1.com/d_driver_fallback_i...
# 19  Fernando ALONSO  https://media.formula1.com/d_driver_fallback_i...
# 37     Sergio PEREZ  https://media.formula1.com/d_driver_fallback_i...
# 72  Kevin MAGNUSSEN  https://media.formula1.com/d_driver_fallback_i...
#
#      last_name  team_colour        team_name name_acronym isFastestLap
# 52  Verstappen       3671C6  Red Bull Racing          VER         True
# 88     Russell       27F4D2         Mercedes          RUS         True
# 45      Norris       FF8000          McLaren          NOR         True
# 66     Piastri       FF8000          McLaren          PIA         True
# 31     Leclerc       E80020          Ferrari          LEC         True
# 80    Hamilton       27F4D2         Mercedes          HAM         True
# 99       Sainz       E80020          Ferrari          SAI         True
# 19      Alonso       229971     Aston Martin          ALO         True
# 37       Perez       3671C6  Red Bull Racing          PER         True
# 72   Magnussen       B6BABD     Haas F1 Team          MAG         True
#
# [10 rows x 28 columns]

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)
# Out:
# Driver: Max VERSTAPPEN Sector 1:  29.598 Sector 2:  27.353 Sector 3:  23.569

# %% [markdown]
# ##### Analysis of each sector of the poleman compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2
# Out:
#    driver_number  lap_duration  difference_sector_1  difference_sector_2  \
# 0             63         0.055                0.144               -0.085
# 1              4         0.252                0.133                0.059
# 2             81         0.309                0.158                0.123
# 3             16         0.332                0.192                0.098
# 4             44         0.491                0.228                0.127
# 5             55         0.521                0.317                0.049
# 6             14         0.731                0.281                0.283
# 7             11         0.905                0.447                0.204
# 8             20         0.980                0.521                0.147
#
#    difference_sector_3 name_acronym
# 0               -0.004          RUS
# 1                0.060          NOR
# 2                0.028          PIA
# 3                0.042          LEC
# 4                0.136          HAM
# 5                0.155          SAI
# 6                0.167          ALO
# 7                0.254          PER
# 8                0.312          MAG

# %%
libraryDataF1.draw_gap(P1,1,10,q3Data,drivers,session)
# Out:
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /home/frank/.local/lib/python3.8/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# VER                      29.598
# NOR                      29.731
# RUS                      29.742
# PIA                      29.756
# LEC                      29.790
# HAM                      29.826
# ALO                      29.879
# SAI                      29.915
# PER                      30.045
# MAG                      30.119

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# RUS                      27.268
# VER                      27.353
# SAI                      27.402
# NOR                      27.412
# LEC                      27.451
# PIA                      27.476
# HAM                      27.480
# MAG                      27.500
# PER                      27.557
# ALO                      27.636

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# VER                      29.598
# NOR                      29.731
# RUS                      29.742
# PIA                      29.756
# LEC                      29.790
# HAM                      29.826
# ALO                      29.879
# SAI                      29.915
# PER                      30.045
# MAG                      30.119

# %% [markdown]
# #### Best sector per driver of the session (in general)

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))
# Out:
#               duration_sector_1
# name_acronym
# VER                      29.598
# RUS                      29.649
# NOR                      29.731
# HAM                      29.747
# PIA                      29.756
# LEC                      29.782
# SAI                      29.812
# ALO                      29.836
# ZHO                      29.872
# BOT                      29.973
# PER                      30.021
# MAG                      30.022
# GAS                      30.062
# TSU                      30.179
# STR                      30.211
# ALB                      30.259
# LAW                      30.291
# HUL                      30.419
# COL                      30.474
# OCO                      30.537

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))
# Out:
#               duration_sector_2
# name_acronym
# RUS                      27.268
# VER                      27.335
# MAG                      27.381
# SAI                      27.402
# NOR                      27.412
# PIA                      27.423
# LEC                      27.451
# HAM                      27.480
# ZHO                      27.533
# PER                      27.534
# GAS                      27.562
# BOT                      27.604
# STR                      27.616
# ALO                      27.635
# HUL                      27.682
# TSU                      27.707
# ALB                      27.782
# LAW                      27.880
# COL                      27.901
# OCO                      28.012

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))
# Out:
#               duration_sector_3
# name_acronym
# RUS                      23.565
# VER                      23.569
# PIA                      23.597
# LEC                      23.611
# NOR                      23.629
# HAM                      23.649
# SAI                      23.670
# ALO                      23.736
# PER                      23.801
# GAS                      23.813
# MAG                      23.858
# TSU                      23.885
# STR                      23.909
# LAW                      24.079
# BOT                      24.088
# ZHO                      24.096
# OCO                      24.165
# HUL                      24.218
# COL                      24.219
# ALB                      24.243

# %% [markdown]
# ## Race
# ### Obtain setup

# %%
race = libraryDataF1.obtain_information('laps',session_key=9617)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9617)
drivers = libraryDataF1.obtain_information('drivers',session_key=9617)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)

# %%
raceLaps = race.query("is_pit_out_lap == False")
jointables = pd.merge(raceLaps,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# #### Obtain data tyres

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'HARD',104)

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'MEDIUM',104)

# %% [markdown]
# ### Soft tyres

# %%
#libraryDataF1.obtain_data_tyres(jointables,'SOFT',104)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >97 and lap_duration <=104").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Race pace

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >97 and lap_duration <=104").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Mean race pace per sector
# In this section, we can see the pace shown per each team in each sector sorted ascending.

# %% [markdown]
# #### Sector 1

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >97 and lap_duration <=104").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 2

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration >97 and lap_duration <=104").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 3

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False and lap_duration >97 and lap_duration <=104").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Comparaison beetween drivers

# %% [markdown]
# #### Red Bull Racing

# %%
race.query("driver_number== 1 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 11 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Ferrari

# %%
race.query("driver_number== 16 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 55 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### McLaren

# %%
race.query("driver_number== 4 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 81 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Mercedes

# %%
race.query("driver_number== 44 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 63 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Aston Martin

# %%
race.query("driver_number== 14 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 18 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Haas F1 Team

# %%
race.query("driver_number== 20 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 27 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### RB

# %%
race.query("driver_number== 30 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 22 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Williams

# %%
race.query("driver_number== 43 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 23 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Alpine

# %%
race.query("driver_number== 10 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 31 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# #### Kick Sauber

# %%
race.query("driver_number== 24 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %%
race.query("driver_number== 77 and lap_duration >97 and lap_duration <=104").lap_duration.mean()

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 97
MAXIMUM_SECONDS = 104

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')

# %%
libraryDataF1.getinfolongruns(jointables,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')

# %%
libraryDataF1.getinfolongruns(jointables,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 14 or driver_number == 18')

# %%
libraryDataF1.getinfolongruns(jointables,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 4 or driver_number == 81')

# %%
libraryDataF1.getinfolongruns(jointables,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables,30,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas F1 Team

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 23 or driver_number == 43')

# %%
libraryDataF1.getinfolongruns(jointables,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,43,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ### Pits
# Before to finish the analysis, I added the Pits sections where it can see how much time teams spent in the box.

# %%
pit = libraryDataF1.obtain_information('pit',session_key=9606)

# %%
jointables = pd.merge(drivers,pit,on=['driver_number']).query("pit_duration<120")
jointables
pit_duration = pd.DataFrame(jointables.groupby('team_name')['pit_duration'].mean().sort_values(ascending=True))
pit_duration
