# %%
from F1_library import libraryF1dataNotebook as libraryDataF1
import pandas as pd

# %% [markdown]
# # FORMULA 1 HUNGARIAN GRAND PRIX 2024
# The Hungarian Grand Prix (Hungarian: Magyar Nagydíj) is a motor race held in Hungary. The first edition was held on 21 June 1936 on a circuit laid out in a park near the centre of Budapest.
#  The manufacturers Mercedes-Benz, Auto Union and Ferrari sent three cars each and the event attracted
# cars each, and the event attracted a large crowd. Without
# However, politics and the approaching Second World War meant the end of motor racing for more than fifty years.
# The first Formula 1 Grand Prix to be held east of the Iron Curtain was the 1986 Hungarian Grand Prix at the Hungaroring racetrack in Mogyoród, near Budapest. Like the Dutch Grand Prix, which it replaced, the Hungarian Grand Prix was held in 1986 at the Hungaroring in Mogyoród, near Budapest,
#  which it replaced, the Hungarian Grand Prix is held in the middle of the European summer.
# European summer. Due to the climate in that region, the first race to be rained out was the 2006 Hungarian Grand Prix.
#  rained in 2006. The Hungarian Grand Prix attracts fans from
# various countries in the region that do not have a local Grand Prix, e.g. from the Scandinavian
# Scandinavian and Eastern European countries. Formula 3000 International, GP2 Series and FIA Formula 2 have held preliminary races at every edition since 1998.
#
# Due to the nature of the track, which is narrow, winding and often dusty from lack of use, the Hungarian Grand Prix usually sees groups of up to six cars all following a slightly slower car that cannot be lapped. This is one of the circuits where pit stop strategy is most crucial. The best example of this was seen at the 1998 Grand Prix when Michael Schumacher's Ferrari team changed strategy mid-race and managed to put their driver in a position to win at the end of the stops. Overtaking between drivers is rare at this circuit, but a notable exception was produced by Nigel Mansell in 1989 when he started from 12th position and overtook car by car and ended up taking the lead by taking advantage of Ayrton Senna being stuck passing a slower driver. In 2003 modifications were made to the circuit in an attempt to make overtaking more feasible.
#
# Other great moments at this circuit include the first victory for Damon Hill (in 1993), and for Fernando Alonso (in 2003). In 2001, Michael Schumacher equalled Alain Prost in number of victories at this circuit.
#
# In 2006, Jenson Button took his first Formula 1 victory, and Pedro de la Rosa his first podium. This race was the first ever Formula 1 race at this circuit to be held in wet conditions, and was notable for its high number of retirements, including those of Michael Schumacher and Fernando Alonso.
#
# In 2016 the race extended its current contract until 2021 for a further five years, securing the GP until 2026.
# Source: Wikipedia

# %% [markdown]
# ## Upgrades
# In this section those upgrades brought by the teams will be shown.
# <table>
# <tr>
#     <td>
#     Team
#     </td>
#     <td>
#     Updated component
#     </td>
#     <td>
#     Upgrade type
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Rear Corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Front wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Red Bull Racing
#     </td>
#     <td>
#     Front Corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Ferrari
#     </td>
#     <td>
#     Floor Body
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Front Wing
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor Fences
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Diffuser
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Aston Martin
#     </td>
#     <td>
#     Beam Wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
#
# <tr>
#     <td>
#     Mercedes
#     </td>
#     <td>
#     Beam wing
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Front corner
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Haas
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Visa Cash App RB
#     </td>
#     <td>
#     Cooling Louvres
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     BWT Alpine
#     </td>
#     <td>
#     Rear Corner
#     </td>
#     <td>
#     Circuit Specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Williams
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Circuit specific
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Sidepod Inlet
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Coke/Engine Cover
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Floor body
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Floor Edge
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Rear corner
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Rear Suspension
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Halo
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Mirror
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# <tr>
#     <td>
#     Kick Sauber
#     </td>
#     <td>
#     Headrest
#     </td>
#     <td>
#     Performance
#     </td>
# </tr>
# </table>

# %% [markdown]
# ## Obtain session information

# %%
libraryDataF1.obtain_information('sessions',year=2024,country_acronym='HUN')
# Out:
#    session_key session_name                 date_start  \
# 0         9559   Practice 1  2024-07-19T11:30:00+00:00
#
#                     date_end gmt_offset session_type  meeting_key  location  \
# 0  2024-07-19T12:30:00+00:00   02:00:00     Practice         1241  Budapest
#
#    country_key country_code country_name  circuit_key circuit_short_name  year
# 0           14          HUN      Hungary            4        Hungaroring  2024

# %% [markdown]
# ## Free Practice 1
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9559)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9559)
drivers = libraryDataF1.obtain_information('drivers',session_key=9559)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2
# Out:
#      meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0           1241         9559             14     197.0       150       NaN
# 1           1241         9559             11     220.0       215       NaN
# 2           1241         9559              2     122.0       155       NaN
# 3           1241         9559             55     198.0       211       NaN
# 4           1241         9559             63     229.0       188       NaN
# ..           ...          ...            ...       ...       ...       ...
# 510         1241         9559             77     122.0       182     259.0
# 511         1241         9559             63     178.0       228     255.0
# 512         1241         9559             22     167.0       177     259.0
# 513         1241         9559             44     192.0       215     260.0
# 514         1241         9559             55     262.0       226     257.0
#
#                            date_start  lap_duration  is_pit_out_lap  \
# 0    2024-07-19T11:30:03.019000+00:00           NaN            True
# 1    2024-07-19T11:30:13.121000+00:00           NaN            True
# 2    2024-07-19T11:30:20.144000+00:00           NaN            True
# 3    2024-07-19T11:30:22.072000+00:00           NaN            True
# 4    2024-07-19T11:30:27.722000+00:00           NaN            True
# ..                                ...           ...             ...
# 510  2024-07-19T12:33:31.280000+00:00       118.225           False
# 511  2024-07-19T12:33:32.439000+00:00       101.547           False
# 512  2024-07-19T12:33:35.935000+00:00       106.270           False
# 513  2024-07-19T12:33:47.269000+00:00       116.480           False
# 514  2024-07-19T12:33:50.196000+00:00        92.840           False
#
#      duration_sector_1  duration_sector_2  duration_sector_3  \
# 0                  NaN             33.817             27.595
# 1                  NaN             36.129             25.700
# 2                  NaN             43.457             35.303
# 3                  NaN             36.269             27.163
# 4                  NaN             39.655             27.498
# ..                 ...                ...                ...
# 510             39.933             43.273             35.019
# 511             36.737             34.652             30.158
# 512             34.491             40.441             31.338
# 513             36.235             52.477             27.768
# 514             32.590             31.991             28.259
#
#                               segments_sector_1  \
# 0    [2064, 2064, 2049, 2051, 2051, 2049, 2049]
# 1    [2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 2    [2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 3    [2064, 2064, 2049, 2049, 2049, 2049, 2049]
# 4    [2064, 2064, 2049, 2049, 2049, 2049, 2049]
# ..                                          ...
# 510  [None, 2048, 2048, 2048, 2048, 2048, 2048]
# 511  [None, 2048, 2048, 2048, 2048, 2048, 2048]
# 512  [None, 2048, 2048, 2048, 2048, 2048, 2048]
# 513  [None, 2048, 2048, 2048, 2048, 2048, 2048]
# 514  [None, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                                     segments_sector_2  \
# 0    [2051, 2051, 2051, 2051, 2051, 2051, 2051, 2049]
# 1    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2051]
# 2    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 3    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# 4    [2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049]
# ..                                                ...
# 510  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 511  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 512  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 513  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 514  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
#
#                   segments_sector_3  lap_number compound name_acronym  \
# 0    [2048, 2049, 2048, 2064, 2064]           1     HARD          ALO
# 1    [2049, 2049, 2048, 2064, 2064]           1     SOFT          PER
# 2    [2049, 2049, 2049, 2064, 2064]           1   MEDIUM          SAR
# 3    [2049, 2049, 2049, 2049, 2049]           1     HARD          SAI
# 4       [2051, 2049, 2049, 2051, 0]           1   MEDIUM          RUS
# ..                              ...         ...      ...          ...
# 510                              []          28     SOFT          BOT
# 511                              []          28   MEDIUM          RUS
# 512                              []          26     SOFT          TSU
# 513                              []          29   MEDIUM          HAM
# 514                              []          27     SOFT          SAI
#
#            full_name        team_name
# 0    Fernando ALONSO     Aston Martin
# 1       Sergio PEREZ  Red Bull Racing
# 2     Logan SARGEANT         Williams
# 3       Carlos SAINZ          Ferrari
# 4     George RUSSELL         Mercedes
# ..               ...              ...
# 510  Valtteri BOTTAS      Kick Sauber
# 511   George RUSSELL         Mercedes
# 512     Yuki TSUNODA               RB
# 513   Lewis HAMILTON         Mercedes
# 514     Carlos SAINZ          Ferrari
#
# [515 rows x 20 columns]

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",88)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",88)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",88)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]
# Out:
#          full_name compound  duration_sector_1  duration_sector_2  \
# 183   Carlos SAINZ     HARD             28.778             28.496
# 187  Oscar PIASTRI   MEDIUM             28.673             28.362
# 262   Carlos SAINZ     SOFT             28.356             27.865
#
#      duration_sector_3  lap_duration
# 183             22.820        80.094
# 187             22.803        79.838
# 262             22.492        78.713

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. Also, each sector will be commented. As we can see in the free practice, these data  are not very representative due to the changing conditions.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_1         full_name compound  lap_duration  lap_number
# 298             28.221      Lance STROLL     SOFT        79.265          15
# 343             28.232    Max VERSTAPPEN     SOFT        79.202          16
# 262             28.356      Carlos SAINZ     SOFT        78.713          13
# 338             28.394      Sergio PEREZ     SOFT        79.440          15
# 244             28.431   Charles LECLERC     SOFT        79.011          15
# 257             28.445   Fernando ALONSO     SOFT        79.730          12
# 248             28.496       ZHOU Guanyu     SOFT        79.180          11
# 208             28.511    George RUSSELL     SOFT        79.137          11
# 241             28.526      Yuki TSUNODA     SOFT        79.260          14
# 282             28.555   Valtteri BOTTAS     SOFT        79.876          18
# 245             28.576      Pierre GASLY     SOFT        79.976          12
# 212             28.576    Lewis HAMILTON     SOFT        79.287          10
# 279             28.613    Logan SARGEANT     SOFT        80.285          14
# 202             28.624   Alexander ALBON     SOFT        79.794           9
# 230             28.633      Lando NORRIS     SOFT        79.211          12
# 243             28.645  Daniel RICCIARDO     SOFT        79.578          14
# 187             28.673     Oscar PIASTRI   MEDIUM        79.838           8
# 198             28.847   Kevin MAGNUSSEN     SOFT        80.295          11
# 238             28.866    Oliver BEARMAN     SOFT        80.440          14
# 322             28.887      Esteban OCON     SOFT        80.023          17

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_2         full_name compound  lap_duration  lap_number
# 310             27.865    Max VERSTAPPEN     SOFT        78.989          13
# 262             27.865      Carlos SAINZ     SOFT        78.713          13
# 274             27.881      Lando NORRIS     SOFT        82.423          15
# 244             27.906   Charles LECLERC     SOFT        79.011          15
# 237             28.022     Oscar PIASTRI     SOFT        79.249          11
# 208             28.124    George RUSSELL     SOFT        79.137          11
# 212             28.154    Lewis HAMILTON     SOFT        79.287          10
# 248             28.160       ZHOU Guanyu     SOFT        79.180          11
# 286             28.175      Yuki TSUNODA     SOFT        79.507          17
# 298             28.220      Lance STROLL     SOFT        79.265          15
# 338             28.251      Sergio PEREZ     SOFT        79.440          15
# 202             28.362   Alexander ALBON     SOFT        79.794           9
# 243             28.389  Daniel RICCIARDO     SOFT        79.578          14
# 322             28.408      Esteban OCON     SOFT        80.023          17
# 304             28.426   Fernando ALONSO     SOFT        79.686          15
# 242             28.452   Valtteri BOTTAS     SOFT        79.804          15
# 235             28.490    Logan SARGEANT     SOFT        79.885          11
# 295             28.501      Pierre GASLY     SOFT        80.215          15
# 198             28.556   Kevin MAGNUSSEN     SOFT        80.295          11
# 204             28.699    Oliver BEARMAN     SOFT        80.371          11

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]
# Out:
#      duration_sector_3         full_name compound  lap_duration  lap_number
# 262             22.492      Carlos SAINZ     SOFT        78.713          13
# 208             22.502    George RUSSELL     SOFT        79.137          11
# 237             22.506     Oscar PIASTRI     SOFT        79.249          11
# 230             22.520      Lando NORRIS     SOFT        79.211          12
# 248             22.524       ZHOU Guanyu     SOFT        79.180          11
# 241             22.540      Yuki TSUNODA     SOFT        79.260          14
# 243             22.544  Daniel RICCIARDO     SOFT        79.578          14
# 209             22.547   Valtteri BOTTAS     SOFT        79.897          12
# 212             22.557    Lewis HAMILTON     SOFT        79.287          10
# 211             22.672      Sergio PEREZ     SOFT        80.056           9
# 244             22.674   Charles LECLERC     SOFT        79.011          15
# 235             22.703    Logan SARGEANT     SOFT        79.885          11
# 322             22.728      Esteban OCON     SOFT        80.023          17
# 310             22.734    Max VERSTAPPEN     SOFT        78.989          13
# 238             22.779    Oliver BEARMAN     SOFT        80.440          14
# 257             22.801   Fernando ALONSO     SOFT        79.730          12
# 202             22.808   Alexander ALBON     SOFT        79.794           9
# 298             22.824      Lance STROLL     SOFT        79.265          15
# 245             22.844      Pierre GASLY     SOFT        79.976          12
# 198             22.892   Kevin MAGNUSSEN     SOFT        80.295          11

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False  and lap_duration <= 88").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace
# Out:
#           lap_duration
# compound
# HARD         82.687762
# SOFT         83.069785
# MEDIUM       84.170130

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 84
MAXIMUM_SECONDS = 88

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 37')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 3          1241         9559             1              1          1        4
# 24         1241         9559             2              1          5        7
# 35         1241         9559             3              1          8       10
# 50         1241         9559             4              1         11       12
# 63         1241         9559             5              1         13       15
# 81         1241         9559             6              1         16       18
# 95         1241         9559             7              1         19       21
#
#    compound  tyre_age_at_start
# 3      SOFT                  0
# 24     SOFT                  3
# 35     SOFT                  6
# 50     SOFT                  0
# 63     SOFT                  2
# 81     SOFT                  5
# 95     SOFT                  9

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %%
libraryDataF1.getinfolongruns(jointables2,37,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')
# Out:
#      meeting_key  session_key  stint_number  driver_number  lap_start  \
# 7           1241         9559             1             55          1
# 12          1241         9559             1             16          1
# 29          1241         9559             2             55          5
# 40          1241         9559             2             16          8
# 47          1241         9559             3             55         10
# 59          1241         9559             3             16         12
# 64          1241         9559             4             55         13
# 76          1241         9559             4             16         15
# 82          1241         9559             5             55         16
# 90          1241         9559             5             16         18
# 100         1241         9559             6             16         20
#
#      lap_end compound  tyre_age_at_start
# 7          4     HARD                  0
# 12         7     HARD                  0
# 29         9     HARD                  3
# 40        11     HARD                  6
# 47        12     HARD                  8
# 59        14     HARD                  0
# 64        15     SOFT                  0
# 76        17     SOFT                  0
# 82        28     SOFT                  3
# 90        19     SOFT                  0
# 100       30     HARD                 13

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 288  Charles LECLERC     SOFT  2024-07-19T12:10:42.592000+00:00          18
# 336  Charles LECLERC     HARD  2024-07-19T12:18:41.652000+00:00          20
# 345  Charles LECLERC     HARD  2024-07-19T12:20:06.090000+00:00          21
# 364  Charles LECLERC     HARD  2024-07-19T12:21:30.723000+00:00          22
# 383  Charles LECLERC     HARD  2024-07-19T12:22:55.817000+00:00          23
# 401  Charles LECLERC     HARD  2024-07-19T12:24:21.225000+00:00          24
# 420  Charles LECLERC     HARD  2024-07-19T12:25:46.534000+00:00          25
# 458  Charles LECLERC     HARD  2024-07-19T12:28:39.664000+00:00          27
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 288             28.436             28.095             29.902        86.433
# 336             30.082             30.280             24.047        84.409
# 345             30.342             30.146             24.244        84.732
# 364             30.387             30.425             24.246        85.058
# 383             30.523             30.574             24.375        85.472
# 401             30.476             30.465             24.331        85.272
# 420             30.492             30.066             24.262        84.820
# 458             30.366             30.185             24.299        84.850

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 325  Carlos SAINZ     SOFT  2024-07-19T12:17:07.850000+00:00          16
# 334  Carlos SAINZ     SOFT  2024-07-19T12:18:32.095000+00:00          17
# 344  Carlos SAINZ     SOFT  2024-07-19T12:19:56.612000+00:00          18
# 363  Carlos SAINZ     SOFT  2024-07-19T12:21:21.196000+00:00          19
# 382  Carlos SAINZ     SOFT  2024-07-19T12:22:46.037000+00:00          20
# 400  Carlos SAINZ     SOFT  2024-07-19T12:24:11.472000+00:00          21
# 438  Carlos SAINZ     SOFT  2024-07-19T12:27:07.422000+00:00          23
# 456  Carlos SAINZ     SOFT  2024-07-19T12:28:32.479000+00:00          24
# 476  Carlos SAINZ     SOFT  2024-07-19T12:29:57.993000+00:00          25
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 325             30.250             30.364             23.573        84.187
# 334             30.292             30.321             23.884        84.497
# 344             30.319             30.410             23.951        84.680
# 363             30.388             30.259             24.191        84.838
# 382             30.564             30.522             24.305        85.391
# 400             30.519             30.652             24.439        85.610
# 438             30.427             30.378             24.364        85.169
# 456             30.593             30.654             24.387        85.634
# 476             30.622             30.840             24.353        85.815

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 5          1241         9559             1             44          1        4
# 8          1241         9559             1             63          1        4
# 26         1241         9559             2             44          5        7
# 28         1241         9559             2             63          5        7
# 34         1241         9559             3             44          8        9
# 39         1241         9559             3             63          8       10
# 46         1241         9559             4             44         10       12
# 53         1241         9559             4             63         11       13
# 66         1241         9559             5             44         13       30
# 67         1241         9559             5             63         14       14
# 80         1241         9559             6             63         15       29
#
#    compound  tyre_age_at_start
# 5    MEDIUM                  0
# 8    MEDIUM                  0
# 26   MEDIUM                  3
# 28   MEDIUM                  3
# 34   MEDIUM                  6
# 39   MEDIUM                  6
# 46     SOFT                  0
# 53     SOFT                  0
# 66   MEDIUM                  8
# 67   MEDIUM                  0
# 80   MEDIUM                 10

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 5          1241         9559             1             44          1        4
# 8          1241         9559             1             63          1        4
# 26         1241         9559             2             44          5        7
# 28         1241         9559             2             63          5        7
# 34         1241         9559             3             44          8        9
# 39         1241         9559             3             63          8       10
# 46         1241         9559             4             44         10       12
# 53         1241         9559             4             63         11       13
# 66         1241         9559             5             44         13       30
# 67         1241         9559             5             63         14       14
# 80         1241         9559             6             63         15       29
#
#    compound  tyre_age_at_start
# 5    MEDIUM                  0
# 8    MEDIUM                  0
# 26   MEDIUM                  3
# 28   MEDIUM                  3
# 34   MEDIUM                  6
# 39   MEDIUM                  6
# 46     SOFT                  0
# 53     SOFT                  0
# 66   MEDIUM                  8
# 67   MEDIUM                  0
# 80   MEDIUM                 10

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')
# Out:
#      meeting_key  session_key  stint_number  driver_number  lap_start  \
# 11          1241         9559             1              3          1
# 14          1241         9559             1             22          1
# 41          1241         9559             2              3          8
# 42          1241         9559             2             22          8
# 69          1241         9559             3              3         14
# 70          1241         9559             3             22         14
# 83          1241         9559             4              3         17
# 85          1241         9559             4             22         17
# 96          1241         9559             5             22         20
# 97          1241         9559             5              3         20
# 103         1241         9559             6             22         25
#
#      lap_end compound  tyre_age_at_start
# 11         7   MEDIUM                  0
# 14         7   MEDIUM                  0
# 41        13   MEDIUM                  6
# 42        13   MEDIUM                  6
# 69        16     SOFT                  0
# 70        16     SOFT                  0
# 83        19     SOFT                  3
# 85        19     SOFT                  0
# 96        24   MEDIUM                 12
# 97        28   MEDIUM                 12
# 103       27     SOFT                  6

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#             full_name compound                        date_start  lap_number  \
# 376  Daniel RICCIARDO   MEDIUM  2024-07-19T12:22:28.992000+00:00          20
# 395  Daniel RICCIARDO   MEDIUM  2024-07-19T12:23:54.235000+00:00          21
# 414  Daniel RICCIARDO   MEDIUM  2024-07-19T12:25:19.614000+00:00          22
# 433  Daniel RICCIARDO   MEDIUM  2024-07-19T12:26:45.145000+00:00          23
# 451  Daniel RICCIARDO   MEDIUM  2024-07-19T12:28:11.018000+00:00          24
# 470  Daniel RICCIARDO   MEDIUM  2024-07-19T12:29:37.440000+00:00          25
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 376             30.314             30.753             24.141        85.208
# 395             30.319             30.787             24.250        85.356
# 414             30.482             30.662             24.400        85.544
# 433             30.548             30.785             24.536        85.869
# 451             30.604             31.291             24.526        86.421
# 470             30.719             31.411             24.649        86.779

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 388  Yuki TSUNODA   MEDIUM  2024-07-19T12:23:24.725000+00:00          20
# 406  Yuki TSUNODA   MEDIUM  2024-07-19T12:24:49.220000+00:00          21
# 425  Yuki TSUNODA   MEDIUM  2024-07-19T12:26:14.800000+00:00          22
# 444  Yuki TSUNODA   MEDIUM  2024-07-19T12:27:40.454000+00:00          23
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 388             30.302             30.412             24.361        85.075
# 406             30.440             30.813             24.250        85.503
# 425             30.590             30.829             24.357        85.776
# 444             30.565             30.705             26.716        87.986

# %% [markdown]
# #### Haas

# %%
stintInformation.query('driver_number == 50 or driver_number == 27')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 6          1241         9559             1             50          1        4
# 27         1241         9559             2             50          5        7
# 38         1241         9559             3             50          8       10
# 52         1241         9559             4             50         11       13
# 72         1241         9559             5             50         14       16
# 86         1241         9559             6             50         17       19
# 99         1241         9559             7             50         20       28
#
#    compound  tyre_age_at_start
# 6    MEDIUM                  0
# 27   MEDIUM                  0
# 38   MEDIUM                  6
# 52     SOFT                  0
# 72     SOFT                  0
# 86     SOFT                  0
# 99   MEDIUM                  9

# %%
libraryDataF1.getinfolongruns(jointables2,50,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#           full_name compound                        date_start  lap_number  \
# 367  Oliver BEARMAN   MEDIUM  2024-07-19T12:21:47.120000+00:00          20
# 385  Oliver BEARMAN   MEDIUM  2024-07-19T12:23:13.241000+00:00          21
# 403  Oliver BEARMAN   MEDIUM  2024-07-19T12:24:39.050000+00:00          22
# 422  Oliver BEARMAN   MEDIUM  2024-07-19T12:26:04.854000+00:00          23
# 441  Oliver BEARMAN   MEDIUM  2024-07-19T12:27:30.809000+00:00          24
# 460  Oliver BEARMAN   MEDIUM  2024-07-19T12:28:56.610000+00:00          25
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 367             30.677             31.099             24.380        86.156
# 385             30.449             30.975             24.411        85.835
# 403             30.420             30.991             24.463        85.874
# 422             30.472             30.900             24.477        85.849
# 441             30.431             31.033             24.363        85.827
# 460             30.308             31.470             24.535        86.313

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 31 or driver_number == 61')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 19         1241         9559             1             31          1       12
# 65         1241         9559             2             31         13       16
# 89         1241         9559             3             31         17       27
#
#    compound  tyre_age_at_start
# 19   MEDIUM                  0
# 65   MEDIUM                 11
# 89     SOFT                  0

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#         full_name compound                        date_start  lap_number  \
# 429  Esteban OCON     SOFT  2024-07-19T12:26:30.899000+00:00          23
# 447  Esteban OCON     SOFT  2024-07-19T12:27:55.556000+00:00          24
# 465  Esteban OCON     SOFT  2024-07-19T12:29:19.656000+00:00          25
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 429             30.485             30.242             23.907        84.634
# 447             29.940             30.134             24.029        84.103
# 465             30.015             30.809             24.429        85.253

# %%
libraryDataF1.getinfolongruns(jointables2,61,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 45 or driver_number == 23')
# Out:
#     meeting_key  session_key  stint_number  driver_number  lap_start  lap_end  \
# 10         1241         9559             1             23          1        5
# 31         1241         9559             2             23          6        8
# 43         1241         9559             3             23          9       11
# 60         1241         9559             4             23         12       14
# 79         1241         9559             5             23         15       23
#
#    compound  tyre_age_at_start
# 10   MEDIUM                  0
# 31   MEDIUM                  4
# 43     SOFT                  0
# 60     SOFT                  3
# 79     SOFT                  6

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
#            full_name compound                        date_start  lap_number  \
# 375  Alexander ALBON     SOFT  2024-07-19T12:22:27.011000+00:00          15
# 394  Alexander ALBON     SOFT  2024-07-19T12:23:51.109000+00:00          16
# 413  Alexander ALBON     SOFT  2024-07-19T12:25:16.267000+00:00          17
# 450  Alexander ALBON     SOFT  2024-07-19T12:28:10.177000+00:00          19
# 469  Alexander ALBON     SOFT  2024-07-19T12:29:35.944000+00:00          20
#
#      duration_sector_1  duration_sector_2  duration_sector_3  lap_duration
# 375             30.187             30.100             23.864        84.151
# 394             30.293             30.562             24.176        85.031
# 413             30.613             30.895             24.348        85.856
# 450             30.619             30.686             24.406        85.711
# 469             30.605             30.946             24.678        86.229

# %%
libraryDataF1.getinfolongruns(jointables2,45,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# Empty DataFrame
# Columns: [full_name, compound, date_start, lap_number, duration_sector_1, duration_sector_2, duration_sector_3, lap_duration]
# Index: []

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')
# Out:
#      meeting_key  session_key  stint_number  driver_number  lap_start  \
# 4           1241         9559             1             24          1
# 18          1241         9559             1             77          1
# 25          1241         9559             2             24          5
# 37          1241         9559             3             24          8
# 51          1241         9559             4             24         11
# 62          1241         9559             2             77         12
# 71          1241         9559             5             24         14
# 87          1241         9559             6             24         17
# 102         1241         9559             3             77         21
#
#      lap_end compound  tyre_age_at_start
# 4          4   MEDIUM                  0
# 18        11   MEDIUM                  0
# 25         7   MEDIUM                  3
# 37        10   MEDIUM                  0
# 51        13     SOFT                  0
# 62        20     SOFT                  0
# 71        16     SOFT                  0
# 87        25     SOFT                  6
# 102       29     SOFT                  9

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)
# Out:
# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)
# Out:
#               driver compound  lap_duration    sector1    sector2    sector3
# 11      Esteban OCON     SOFT     84.663333  30.146667  30.395000  24.121667
# 14      Carlos SAINZ     SOFT     85.091222  30.441556  30.488889  24.160778
# 17     Oscar PIASTRI   MEDIUM     85.495000  30.473273  30.761364  24.260364
# 9    Alexander ALBON     SOFT     85.395600  30.463400  30.637800  24.294400
# 4    Fernando ALONSO     SOFT     85.978143  30.633571  30.953571  24.391000
# 16   Valtteri BOTTAS     SOFT     86.071000  30.710000  30.947000  24.414000
# 1   Daniel RICCIARDO   MEDIUM     85.862833  30.497667  30.948167  24.417000
# 15    George RUSSELL   MEDIUM     85.828000  30.550000  30.844909  24.433091
# 13    Oliver BEARMAN   MEDIUM     85.975667  30.459500  31.078000  24.438167
# 0     Logan SARGEANT     SOFT     86.397571  30.820857  31.114714  24.462000
# 12    Lewis HAMILTON   MEDIUM     85.804867  30.589000  30.750867  24.465000
# 3       Pierre GASLY   MEDIUM     86.367429  30.662000  31.181571  24.523857
# 10       ZHOU Guanyu     SOFT     86.436167  30.804167  31.070833  24.561167
# 7    Kevin MAGNUSSEN   MEDIUM     86.154286  30.586143  30.894857  24.673286
# 8       Yuki TSUNODA   MEDIUM     86.085000  30.474250  30.689750  24.921000
# 5    Charles LECLERC     HARD     85.130750  30.138000  30.029500  24.963250
# 2       Lando NORRIS   MEDIUM     85.659143  30.186286  30.343000  25.129857
# 6       Lance STROLL     SOFT     86.225167  30.246667  30.745833  25.232667

# %% [markdown]
# ## Free Practice 2
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9552)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9552)
drivers = libraryDataF1.obtain_information('drivers',session_key=9552)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"MEDIUM",94)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"SOFT",94)

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"HARD",94)

# %% [markdown]
# ### Intermediate tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"INTERMEDIATE",120)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session.Due to changing conditions, only a part of the free practice were important and this part will be taken into consideration.

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector. As I said in the previous section, the changing conditions made that the data obtained in this section are not representatives.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False  and lap_duration <= 94").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Long runs

# %%
MINIMUN_SECONDS = 90.5
MAXIMUM_SECONDS = 94

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 2 or driver_number == 23')

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)

# %% [markdown]
# ## Free Practice 3
# ### Obtain setup

# %%
practice = libraryDataF1.obtain_information('laps',session_key=9553)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9553)
drivers = libraryDataF1.obtain_information('drivers',session_key=9553)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)
jointables2 = pd.merge(practice,stintsDataFrame,on=['lap_number','driver_number'])
jointables2

# %% [markdown]
# ### See race pace by means of the charts

# %% [markdown]
# ### Intermediate tyres

# %%
libraryDataF1.obtain_data_tyres(jointables2,"INTERMEDIATE",120)

# %% [markdown]
# ### Speed trap

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables2.loc[jointables2.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %% [markdown]
# ### Fastest lap per compound
# In this section, I will show the best lap with the different compounds of the session.

# %%
compoundsPace = jointables2.loc[jointables2.groupby(['compound'])['lap_duration'].idxmin()]
compoundsPace[['full_name','compound','duration_sector_1','duration_sector_2','duration_sector_3','lap_duration']]

# %% [markdown]
# ### Deltas
# In this section we can see the deltas of the fastest lap of each driver compared with the fastest lap of the session

# %%
practiceCleaned = jointables2.query("lap_duration >1")
drivers_list = list(practiceCleaned['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_fastest_lap(driver,practiceCleaned,newdataset)

arr= libraryDataF1.obtain_deltas(newdataset)
newdataset.insert(3,'delta',arr)

# %%
dt = newdataset.sort_values(ascending=True,by='delta')
libraryDataF1.obtainchart("name_acronym","delta",dt)

# %% [markdown]
# ### Track dominance
# In this section, best sector are taken of each sector to see the car's performance in each sector.

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_1'].idxmin()].sort_values(by=['duration_sector_1'],ascending=True)
sectorPace[['duration_sector_1','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_2'].idxmin()].sort_values(by=['duration_sector_2'],ascending=True)
sectorPace[['duration_sector_2','full_name','compound','lap_duration','lap_number']]

# %%
sectorPace = jointables2.loc[jointables2.groupby(['driver_number'])['duration_sector_3'].idxmin()].sort_values(by=['duration_sector_3'],ascending=True)
sectorPace[['duration_sector_3','full_name','compound','lap_duration','lap_number']]

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables2.query("is_pit_out_lap == False  and lap_duration <= 103").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Long laps

# %%
MINIMUN_SECONDS = 98
MAXIMUM_SECONDS = 102

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables2,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
libraryDataF1.getinfolongruns(jointables2,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 63 or driver_number == 44')

# %%
libraryDataF1.getinfolongruns(jointables2,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 81 or driver_number == 4')

# %%
libraryDataF1.getinfolongruns(jointables2,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 18 or driver_number == 14')

# %%
libraryDataF1.getinfolongruns(jointables2,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables2,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas

# %%
libraryDataF1.getinfolongruns(jointables2,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
libraryDataF1.getinfolongruns(jointables2,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
libraryDataF1.getinfolongruns(jointables2,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
libraryDataF1.getinfolongruns(jointables2,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables2,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Long runs mean for each driver

# %%
longrun_data = libraryDataF1.obtainLongRunData(drivers,jointables2,MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ##### Sorted by lap duration

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='lap_duration',ascending=True)

# %% [markdown]
# ##### Sorted by sector 1

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector1',ascending=True)

# %% [markdown]
# ##### Sorted by sector 2

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector2',ascending=True)

# %% [markdown]
# ##### Sorted by sector 3

# %%
pd.DataFrame(longrun_data,columns=['driver','compound','lap_duration','sector1','sector2','sector3']).sort_values(by='sector3',ascending=True)

# %% [markdown]
# ## Qualyfing
# ### Set up
# First of all, it is neccesary to obtain the data about the qualyfing
# #### Race control
# This section has been added in order to know which laps has been deleted and knowing what happened on track during this session. As every laptime that has been deleted were slow laps, none of them were removed.

# %%
libraryDataF1.obtain_information('race_control',session_key=9554)

# %% [markdown]
# ### Obtain setup

# %%
qualyfing = libraryDataF1.obtain_information('laps',session_key=9554)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9554)
drivers = libraryDataF1.obtain_information('drivers',session_key=9554)

# %% [markdown]
# To obtain a better analysis, those laptimes deleted will be removed from this analysis in order to obtain the data with valid values. So that,taking into account the race control table, it will be neccesary to consult the qualyfing data to obtain the ids.

# %%
laptimes_deleted = [115.370,96.993,109.924,104.377,102.586,128.082,95.902,102.051]
driver_number_lap_deleted = [4,63,1,24,22,14,55,23]

for ltime_deleted, dn_time_deleted in zip(laptimes_deleted,driver_number_lap_deleted):
    try:
        id_deleted = qualyfing.query("driver_number == @dn_time_deleted and lap_duration == @ltime_deleted").index[0]
        qualyfing = qualyfing.drop(id_deleted)
    except:
        print("Laptime deleted associated with the selected driver does not exist. Please, check again the order of the arrays")

# %%
bestlap = qualyfing.loc[qualyfing.groupby(['driver_number'])['lap_duration'].idxmin()].sort_values(by=['lap_duration'],ascending=True)
bestlap[0:1]

# %% [markdown]
# In previous analysis, you can see that I discard those laptimes that are slower than the 1.07%, but, in this case this rule will not be applied because there are two drivers that did not finished their laps with the slick tyres and the track evolution was very high such as degree that the fastest lap in Q1 was 1.29.547 and in the third sector was 1.25.819.So that I will use a number that includes every fastest lap of the drivers.

# %%
competitiveLaps = qualyfing.query("is_pit_out_lap == False and lap_duration < 100")
competitiveLaps

# %%
drivers_list = list(competitiveLaps['driver_number'].unique())
newdataset = pd.DataFrame()
for driver in drivers_list:
    newdataset =libraryDataF1.obtain_information_qualy(driver,competitiveLaps,newdataset)
jointables = pd.merge(newdataset,drivers,on=['driver_number'])
jointables.sort_values(by=['fastest_lap'],ascending=True)

# %% [markdown]
# #### Best lap per driver compared with the best lap of the session
# In this chart we can see the deltas with compared with the fastest lap of the session that it could be different than the pole.

# %%
libraryDataF1.obtainchart("name_acronym","delta",jointables.sort_values(by=['fastest_lap'],ascending=True))

# %% [markdown]
# ### Speed trap

# %% [markdown]
# #### Maximum speed per drivers

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['name_acronym'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("name_acronym","st_speed",top_speed)

# %% [markdown]
# ### Maximum speed per teams

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i1_speed'].idxmax()].sort_values(by=['i1_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i1_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['i2_speed'].idxmax()].sort_values(by=['i2_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","i2_speed",top_speed)

# %%
top_speed = jointables.loc[jointables.groupby(['team_name'])['st_speed'].idxmax()].sort_values(by=['st_speed'],ascending=False)
libraryDataF1.obtainchart("team_name","st_speed",top_speed)

# %%
mergequaly = pd.merge(competitiveLaps,drivers,on=['driver_number'])
mergequaly

# %% [markdown]
# In order to know when each session finished, race control dataset will be consulted.

# %%
maximumDateQ1 = "date_start <'2024-07-06T14:34:00+00:00'"
maximumDateQ2 = "date_start <'2024-07-06T14:57:00+00:00' and date_start >'2024-07-06T14:34:00+00:00'"
maximumDateQ3 = "date_start >'2024-07-06T14:57:00+00:00'"

# %% [markdown]
# ### Qualyfing 1
# In this session the surprise came from Sergio Perez that was knocked-out in this section. In the next sesssion, we will see what happened with Perez.

# %%
q1Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ1).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q1Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver,I will do a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap. As we can see in Qualyfing 1, the qualy was very crazy, stsrting with intermediate tyres and fnishing with slicks. In the change to softs, Perez in his trying to improve his laptime, he finished beached on the gravvel and consequently, out of the session. Also,Pierre Gasly did not score any time with softs because, in his case, he had a penalty for changing some parts of his engine. If we compared the laptime of the rest of the drivers eliminated, we can see that the difference is big. The unique driver that could have beaten Hulkenberg, Bottas, messed up in the second and third sector.

# %%
#Reference
P15 = q1Data[14:15]
P15

# %%
print(
"Driver:",P15.full_name.to_string(index=False),
"Sector 1: ",P15.duration_sector_1.to_string(index=False),
"Sector 2: ",P15.duration_sector_2.to_string(index=False),
"Sector 3: ",P15.duration_sector_3.to_string(index=False)
)

# %%
q1Data[15::]

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[15::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk
# I bring this section in order to know where the driver at risk lost his chances to improve in the qualyfing.

# %%
newdataset2 = pd.DataFrame()
for index,row in q1Data[0:14].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P15,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q1Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 2
# In this session, both Ferrari were knocked-out in Q2.

# %%
q2Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ2).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q2Data

# %% [markdown]
# ##### Comparaison with driver at risk
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P10 = q2Data[9:10]
print(
"Driver:",P10.full_name.to_string(index=False),
"Sector 1: ",P10.duration_sector_1.to_string(index=False),
"Sector 2: ",P10.duration_sector_2.to_string(index=False),
"Sector 3: ",P10.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.
# In free practices we can see that Ferrari was going to suffer in qualyfing and this supposition was true with Leclerc.Leclerc was able to qualyfy to Q2, but, he lost his chances in the second sector that was 1 tenths slower than Stroll and the thirdd did not help as well.
# Tsunoda was in the same situation. He improved the Hulkenberg's first sector but his pace was not enough to improve in the whole lap.

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[10::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# ##### Analysis with the drivers that finished better than the driver at risk

# %%
newdataset2 = pd.DataFrame()
for index,row in q2Data[0:9].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P10,newdataset2)

newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q2Data.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ### Qualyfing 3

# %%
q3Data = libraryDataF1.obtainInfoAboutQualySession(mergequaly,maximumDateQ3).query("isFastestLap == True").sort_values(by=['lap_duration'],ascending=True)
q3Data

# %% [markdown]
# ##### Comparaison with poleman
# In this section with the fastest lap done for each driver (laptimes deleted will not be taken into account to do this analysis) it will be a comparaison in order to see where the driver eliminated lost/gain time in their fastest lap.

# %%
#Reference
P1 = q3Data[:1]
print(
"Driver:",P1.full_name.to_string(index=False),
"Sector 1: ",P1.duration_sector_1.to_string(index=False),
"Sector 2: ",P1.duration_sector_2.to_string(index=False),
"Sector 3: ",P1.duration_sector_3.to_string(index=False)
)

# %% [markdown]
# ##### Analysis of each sector of the driver at risk compared to the drivers eliminated.
# Pole position laptime was so close. With the Verstappen's incident in Q1, we lost one of the favourites to take the pole. So, in the qualy there were 4 drivers that can fight for the pole. Both McLaren and Mercedes, and incredibly Verstappen, fought for the pole with narrow difference in each sector.
# In sector 1, Hamilton was the fastest in overall but in the slow zones was Verstappen who gained time and in the straights both McLaren were dominant.
# In sector 2, after Brooklands, was Russell the fastest being faster than Mclaren in the exit of Brooklands and in the straight before the exit of Copse.In the fast corners, Maggots and Beckets, Verstappen was the fastest cutting 30 miliseconds the difference with Russell.
# In sector 3, difference grew up with Verstappen losing 2 tenths in the Hangar staright finishing 3 tenths behind the poleman. Both McLaren were unable to fight the German's pace. They were 1 tenth behind Rusell before the Hangar straight and 2 tenths behind after this straight. Piastri was very closee to his teammate but the exit of the last chicane annoyed the Austrilian driver.
# Hamilon could have taken the pole because, in the exit of the turn he was 0.026 milisecond faster than Rusell but the traction of Rusell was better and the gap that he gained enough to take the pole.
# Note: All this analysis can be checked in F1 tempo

# %%
newdataset2 = pd.DataFrame()
for index,row in q3Data[1::].iterrows():
    newdataset2 = libraryDataF1.obtain_difference_regard_reference(row,P1,newdataset2)
newdataset2

# %% [markdown]
# #### Best sector per driver
# In this section we can see the best sector of the session

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(q3Data.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %% [markdown]
# #### Best sector per driver of the session (in general)

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_1'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_2'].min().sort_values(ascending=True))

# %%
pd.DataFrame(mergequaly.groupby("name_acronym")['duration_sector_3'].min().sort_values(ascending=True))

# %% [markdown]
# ## Race
# ### Obtain setup

# %%
race = libraryDataF1.obtain_information('laps',session_key=9558)
stintInformation = libraryDataF1.obtain_information('stints',session_key=9558)
drivers = libraryDataF1.obtain_information('drivers',session_key=9558)

# %%
stintsDataFrame =libraryDataF1.stint_configuration(drivers,stintInformation)

# %%
raceLaps = race.query("is_pit_out_lap == False")
jointables = pd.merge(raceLaps,stintsDataFrame,on=['lap_number','driver_number'])

# %% [markdown]
# #### Obtain data tyres

# %% [markdown]
# ### Hard tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'HARD',95)

# %% [markdown]
# ### Medium tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'MEDIUM',95)

# %% [markdown]
# ### Soft tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'SOFT',95)

# %% [markdown]
# ### Intermediate tyres

# %%
libraryDataF1.obtain_data_tyres(jointables,'INTERMEDIATE',99)

# %% [markdown]
# ### Mean pace with the different compound used on the session

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <= 95").groupby("compound")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Race pace

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <= 95").dropna().groupby("team_name")['lap_duration'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Mean race pace per sector
# In this section, we can see the pace shown per each team in each sector sorted ascending.

# %% [markdown]
# #### Sector 1

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <= 95").dropna().groupby("team_name")['duration_sector_1'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 2

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <= 95").dropna().groupby("team_name")['duration_sector_2'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# #### Sector 3

# %%
race_pace = pd.DataFrame(jointables.query("is_pit_out_lap == False  and lap_duration <= 95").dropna().groupby("team_name")['duration_sector_3'].mean().sort_values(ascending=True))
race_pace

# %% [markdown]
# ### Comparaison beetween drivers

# %% [markdown]
# #### Red Bull Racing

# %%
race.query("driver_number== 1 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 11 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Ferrari

# %%
race.query("driver_number== 16 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 55 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### McLaren

# %%
race.query("driver_number== 4 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 81 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Mercedes

# %%
race.query("driver_number== 44 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 63 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Aston Martin

# %%
race.query("driver_number== 14 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 18 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Haas F1 Team

# %%
race.query("driver_number== 20 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 27 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### RB

# %%
race.query("driver_number== 3 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 22 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Williams

# %%
race.query("driver_number== 2 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 23 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Alpine

# %%
race.query("driver_number== 10 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 31 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# #### Kick Sauber

# %%
race.query("driver_number== 24 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %%
race.query("driver_number== 77 and lap_duration <=95 and lap_duration>89").lap_duration.mean()

# %% [markdown]
# ### Race pace

# %%
MINIMUN_SECONDS = 89
MAXIMUM_SECONDS = 95

# %% [markdown]
# #### Red Bull Racing

# %%
stintInformation.query('driver_number == 1 or driver_number == 11')

# %%
libraryDataF1.getinfolongruns(jointables,1,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,11,'Red Bull Racing',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Ferrari

# %%
stintInformation.query('driver_number == 16 or driver_number == 55')

# %%
libraryDataF1.getinfolongruns(jointables,16,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,55,'Ferrari',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Mercedes

# %%
stintInformation.query('driver_number == 44 or driver_number == 63')

# %%
libraryDataF1.getinfolongruns(jointables,44,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,63,'Mercedes',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Aston Martin

# %%
stintInformation.query('driver_number == 14 or driver_number == 18')

# %%
libraryDataF1.getinfolongruns(jointables,14,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,18,'Aston Martin',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### McLaren

# %%
stintInformation.query('driver_number == 4 or driver_number == 81')

# %%
libraryDataF1.getinfolongruns(jointables,4,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,81,'McLaren',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### RB

# %%
stintInformation.query('driver_number == 3 or driver_number == 22')

# %%
libraryDataF1.getinfolongruns(jointables,3,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,22,'RB',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Haas F1 Team

# %%
stintInformation.query('driver_number == 20 or driver_number == 27')

# %%
libraryDataF1.getinfolongruns(jointables,20,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,27,'Haas F1 Team',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Kick Sauber

# %%
stintInformation.query('driver_number == 24 or driver_number == 77')

# %%
libraryDataF1.getinfolongruns(jointables,24,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,77,'Kick Sauber',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Williams

# %%
stintInformation.query('driver_number == 23 or driver_number == 2')

# %%
libraryDataF1.getinfolongruns(jointables,23,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,2,'Williams',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# #### Alpine

# %%
stintInformation.query('driver_number == 10 or driver_number == 31')

# %%
libraryDataF1.getinfolongruns(jointables,31,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %%
libraryDataF1.getinfolongruns(jointables,10,'Alpine',MINIMUN_SECONDS,MAXIMUM_SECONDS)

# %% [markdown]
# ### Pits
# Before to finish the analysis, I added the Pits sections where it can see how much time teams spent in the box.

# %%
pit = libraryDataF1.obtain_information('pit',session_key=9558)

# %%
jointables = pd.merge(drivers,pit,on=['driver_number']).query("pit_duration<120")
jointables
pit_duration = pd.DataFrame(jointables.groupby('team_name')['pit_duration'].mean().sort_values(ascending=True))
pit_duration
